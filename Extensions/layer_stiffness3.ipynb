# %%
import torch
import torch.nn as nn
from torch.optim import SGD

import numpy as np
from numpy import dot
import matplotlib.pyplot as plt

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, hidden_size3, num_classes):
        super(NeuralNet, self).__init__()
        self.input_layer = nn.Linear(input_size, hidden_size1)
        self.hidden_one = nn.Linear(hidden_size1, hidden_size2)
        self.hidden_two = nn.Linear(hidden_size2,hidden_size3)
        self.output_layer = nn.Linear(hidden_size3, num_classes)
    
    def forward(self, x):
        x=self.input_layer(x)
        x=x.relu()
        x=self.hidden_one(x)
        x=x.relu()
        x=self.hidden_two(x)
        x=x.relu()
        x=self.output_layer(x)
        return x
    
def ReLU_glorot_init(model):
    for name, param in model.named_parameters():
        
        if name.endswith(".bias"):
            param.data.fill_(0)
        else:
            nn.init.xavier_normal_(param)

# %%
RES=50
X=[]
for x_1 in np.linspace(-1,1,RES):
    for x_2 in np.linspace(-1,1,RES):
        X.append([x_1,x_2])
X=np.array(X)

encode_inputs=lambda x: 1 if abs(x[1])<0.05 or ((abs(x[0]-0.5)<0.05 or abs(x[0]+0.5)<0.05) and abs(x[1])<0.25) else 0
Y=np.array([encode_inputs(x) for x in X])

X=torch.from_numpy(X).float()
Y=torch.from_numpy(Y).float()


colors=np.full(len(Y), 'cadetblue')
colors[Y==0]='teal'

plt.scatter(X[:,0],X[:,1],c=colors)

# %%
def random_sample(X,Y,size=5):
    ind_zeros=np.array([k for k in range(len(X)) if Y[k]==0])
    ind_ones=np.array([k for k in range(len(X)) if Y[k]==1])
    return(np.concatenate((np.random.choice(ind_zeros,size=size),np.random.choice(ind_ones,size=size))))

# %%
model = NeuralNet(2,16,8,16,2)
ReLU_glorot_init(model)

def next_batch(inputs, targets, batchSize):
	for i in range(0, inputs.shape[0], batchSize):
		yield (inputs[i:i + batchSize], targets[i:i + batchSize])

BATCH_SIZE = 100
EPOCHS = 500
LR = 0.05

opt = SGD(model.parameters(), lr=LR)
lossFunc = nn.CrossEntropyLoss()

# %%
grads_input_layer=[]
grads_hidden_one=[]
grads_hidden_two=[]
grads_output_layer=[]

for x,y in zip(X,Y):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient_input_layer=[]
    gradient_hidden_one=[]
    gradient_hidden_two=[]
    gradient_output_layer=[]

    gradient_input_layer+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient_input_layer+=model.input_layer.bias.grad.tolist()

    gradient_hidden_one+=torch.flatten(model.hidden_one.weight.grad).tolist()
    gradient_hidden_one+=model.hidden_one.bias.grad.tolist()

    gradient_hidden_two+=torch.flatten(model.hidden_two.weight.grad).tolist()
    gradient_hidden_two+=model.hidden_two.bias.grad.tolist()

    gradient_output_layer+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient_output_layer+=model.output_layer.bias.grad.tolist()

    
    gradient_input_layer=np.array(gradient_input_layer)
    gradient_hidden_one=np.array(gradient_hidden_one)
    gradient_hidden_two=np.array(gradient_hidden_two)
    gradient_output_layer=np.array(gradient_output_layer)

    grads_input_layer.append(gradient_input_layer/np.linalg.norm(gradient_input_layer))
    grads_hidden_one.append(gradient_hidden_one/np.linalg.norm(gradient_hidden_one))
    grads_hidden_two.append(gradient_hidden_two/np.linalg.norm(gradient_hidden_two))
    grads_output_layer.append(gradient_output_layer/np.linalg.norm(gradient_output_layer))

dot_matrix_input_layer=[]
dot_matrix_hidden_one=[]
dot_matrix_hidden_two=[]
dot_matrix_output_layer=[]
for i,x1 in enumerate(X):
    avg_dot_input=0
    avg_dot_h1=0
    avg_dot_h2=0
    avg_dot_output=0
    samples=0
    sample_ind=random_sample(X,Y)
    for j,x2 in enumerate(X):
        if j in sample_ind:        
            avg_dot_input+=np.dot(grads_input_layer[i],grads_input_layer[j])
            avg_dot_h1+=np.dot(grads_hidden_one[i],grads_hidden_one[j])
            avg_dot_h2+=np.dot(grads_hidden_two[i],grads_hidden_two[j])
            avg_dot_output+=np.dot(grads_output_layer[i],grads_output_layer[j])
            samples+=1
    avg_dot_input/=samples
    avg_dot_h1/=samples
    avg_dot_h2/=samples
    avg_dot_output/=samples
    dot_matrix_input_layer.append(avg_dot_input)
    dot_matrix_hidden_one.append(avg_dot_h1)
    dot_matrix_hidden_two.append(avg_dot_h2)
    dot_matrix_output_layer.append(avg_dot_output)

# %%
fig, axs = plt.subplots(4,1,figsize=(6,15),layout='constrained')

pcm0 = axs[0].scatter(X[:,0], X[:,1],c=dot_matrix_input_layer)
axs[0].set_title('Input Layer')

fig.colorbar(pcm0, ax=axs[0])

pcm1 = axs[1].scatter(X[:,0], X[:,1],c=dot_matrix_hidden_one)
axs[1].set_title('Hidden Layer 1')

fig.colorbar(pcm1, ax=axs[1])

pcm2 = axs[2].scatter(X[:,0], X[:,1],c=dot_matrix_hidden_two)
axs[2].set_title('Hidden Layer 2')

fig.colorbar(pcm2, ax=axs[2])

pcm3 = axs[3].scatter(X[:,0], X[:,1],c=dot_matrix_output_layer)
axs[3].set_title('Output Layer')

fig.colorbar(pcm3, ax=axs[3])

# %%
def training():
	trainLoss = 0
	samples = 0
	model.train()
	for batchX, batchY in next_batch(X, Y, BATCH_SIZE):
		predictions = model(batchX)
		loss = lossFunc(predictions, batchY.long())
		opt.zero_grad()
		loss.backward()
		opt.step()
		samples += len(batchY)
		trainLoss += loss.item()*len(batchY)
	return trainLoss/samples

# %%
for n in range(EPOCHS):
    l=training()
    print('Epoch {}: Loss {:.3f}'.format(n+1,l))

grads_input_layer=[]
grads_hidden_one=[]
grads_hidden_two=[]
grads_output_layer=[]

for x,y in zip(X,Y):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient_input_layer=[]
    gradient_hidden_one=[]
    gradient_hidden_two=[]
    gradient_output_layer=[]

    gradient_input_layer+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient_input_layer+=model.input_layer.bias.grad.tolist()

    gradient_hidden_one+=torch.flatten(model.hidden_one.weight.grad).tolist()
    gradient_hidden_one+=model.hidden_one.bias.grad.tolist()

    gradient_hidden_two+=torch.flatten(model.hidden_two.weight.grad).tolist()
    gradient_hidden_two+=model.hidden_two.bias.grad.tolist()

    gradient_output_layer+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient_output_layer+=model.output_layer.bias.grad.tolist()

    
    gradient_input_layer=np.array(gradient_input_layer)
    gradient_hidden_one=np.array(gradient_hidden_one)
    gradient_hidden_two=np.array(gradient_hidden_two)
    gradient_output_layer=np.array(gradient_output_layer)

    grads_input_layer.append(gradient_input_layer/np.linalg.norm(gradient_input_layer))
    grads_hidden_one.append(gradient_hidden_one/np.linalg.norm(gradient_hidden_one))
    grads_hidden_two.append(gradient_hidden_two/np.linalg.norm(gradient_hidden_two))
    grads_output_layer.append(gradient_output_layer/np.linalg.norm(gradient_output_layer))

dot_matrix_input_layer=[]
dot_matrix_hidden_one=[]
dot_matrix_hidden_two=[]
dot_matrix_output_layer=[]
for i,x1 in enumerate(X):
    avg_dot_input=0
    avg_dot_h1=0
    avg_dot_h2=0
    avg_dot_output=0
    samples=0
    sample_ind=random_sample(X,Y)
    for j,x2 in enumerate(X):
        if j in sample_ind:        
            avg_dot_input+=np.dot(grads_input_layer[i],grads_input_layer[j])
            avg_dot_h1+=np.dot(grads_hidden_one[i],grads_hidden_one[j])
            avg_dot_h2+=np.dot(grads_hidden_two[i],grads_hidden_two[j])
            avg_dot_output+=np.dot(grads_output_layer[i],grads_output_layer[j])
            samples+=1
    avg_dot_input/=samples
    avg_dot_h1/=samples
    avg_dot_h2/=samples
    avg_dot_output/=samples
    dot_matrix_input_layer.append(avg_dot_input)
    dot_matrix_hidden_one.append(avg_dot_h1)
    dot_matrix_hidden_two.append(avg_dot_h2)
    dot_matrix_output_layer.append(avg_dot_output)
# Out:
# Epoch 1: Loss 0.441
# Epoch 2: Loss 0.260
# Epoch 3: Loss 0.223
# Epoch 4: Loss 0.214
# Epoch 5: Loss 0.211
# Epoch 6: Loss 0.209
# Epoch 7: Loss 0.207
# Epoch 8: Loss 0.206
# Epoch 9: Loss 0.204
# Epoch 10: Loss 0.203
# Epoch 11: Loss 0.202
# Epoch 12: Loss 0.201
# Epoch 13: Loss 0.200
# Epoch 14: Loss 0.198
# Epoch 15: Loss 0.197
# Epoch 16: Loss 0.196
# Epoch 17: Loss 0.195
# Epoch 18: Loss 0.193
# Epoch 19: Loss 0.192
# Epoch 20: Loss 0.190
# Epoch 21: Loss 0.189
# Epoch 22: Loss 0.187
# Epoch 23: Loss 0.185
# Epoch 24: Loss 0.183
# Epoch 25: Loss 0.181
# Epoch 26: Loss 0.179
# Epoch 27: Loss 0.177
# Epoch 28: Loss 0.175
# Epoch 29: Loss 0.172
# Epoch 30: Loss 0.169
# Epoch 31: Loss 0.166
# Epoch 32: Loss 0.163
# Epoch 33: Loss 0.160
# Epoch 34: Loss 0.157
# Epoch 35: Loss 0.154
# Epoch 36: Loss 0.151
# Epoch 37: Loss 0.148
# Epoch 38: Loss 0.145
# Epoch 39: Loss 0.142
# Epoch 40: Loss 0.139
# Epoch 41: Loss 0.136
# Epoch 42: Loss 0.134
# Epoch 43: Loss 0.132
# Epoch 44: Loss 0.130
# Epoch 45: Loss 0.128
# Epoch 46: Loss 0.126
# Epoch 47: Loss 0.124
# Epoch 48: Loss 0.122
# Epoch 49: Loss 0.121
# Epoch 50: Loss 0.119
# Epoch 51: Loss 0.118
# Epoch 52: Loss 0.116
# Epoch 53: Loss 0.115
# Epoch 54: Loss 0.114
# Epoch 55: Loss 0.113
# Epoch 56: Loss 0.112
# Epoch 57: Loss 0.111
# Epoch 58: Loss 0.111
# Epoch 59: Loss 0.110
# Epoch 60: Loss 0.110
# Epoch 61: Loss 0.109
# Epoch 62: Loss 0.109
# Epoch 63: Loss 0.108
# Epoch 64: Loss 0.108
# Epoch 65: Loss 0.108
# Epoch 66: Loss 0.107
# Epoch 67: Loss 0.107
# Epoch 68: Loss 0.107
# Epoch 69: Loss 0.107
# Epoch 70: Loss 0.106
# Epoch 71: Loss 0.106
# Epoch 72: Loss 0.106
# Epoch 73: Loss 0.106
# Epoch 74: Loss 0.106
# Epoch 75: Loss 0.105
# Epoch 76: Loss 0.105
# Epoch 77: Loss 0.105
# Epoch 78: Loss 0.105
# Epoch 79: Loss 0.105
# Epoch 80: Loss 0.105
# Epoch 81: Loss 0.105
# Epoch 82: Loss 0.105
# Epoch 83: Loss 0.104
# Epoch 84: Loss 0.104
# Epoch 85: Loss 0.104
# Epoch 86: Loss 0.104
# Epoch 87: Loss 0.104
# Epoch 88: Loss 0.104
# Epoch 89: Loss 0.104
# Epoch 90: Loss 0.104
# Epoch 91: Loss 0.104
# Epoch 92: Loss 0.104
# Epoch 93: Loss 0.103
# Epoch 94: Loss 0.103
# Epoch 95: Loss 0.103
# Epoch 96: Loss 0.103
# Epoch 97: Loss 0.103
# Epoch 98: Loss 0.103
# Epoch 99: Loss 0.103
# Epoch 100: Loss 0.103
# Epoch 101: Loss 0.103
# Epoch 102: Loss 0.103
# Epoch 103: Loss 0.103
# Epoch 104: Loss 0.103
# Epoch 105: Loss 0.102
# Epoch 106: Loss 0.102
# Epoch 107: Loss 0.102
# Epoch 108: Loss 0.102
# Epoch 109: Loss 0.102
# Epoch 110: Loss 0.102
# Epoch 111: Loss 0.102
# Epoch 112: Loss 0.102
# Epoch 113: Loss 0.102
# Epoch 114: Loss 0.102
# Epoch 115: Loss 0.102
# Epoch 116: Loss 0.102
# Epoch 117: Loss 0.102
# Epoch 118: Loss 0.102
# Epoch 119: Loss 0.102
# Epoch 120: Loss 0.102
# Epoch 121: Loss 0.101
# Epoch 122: Loss 0.101
# Epoch 123: Loss 0.101
# Epoch 124: Loss 0.101
# Epoch 125: Loss 0.101
# Epoch 126: Loss 0.101
# Epoch 127: Loss 0.101
# Epoch 128: Loss 0.101
# Epoch 129: Loss 0.101
# Epoch 130: Loss 0.101
# Epoch 131: Loss 0.101
# Epoch 132: Loss 0.101
# Epoch 133: Loss 0.101
# Epoch 134: Loss 0.101
# Epoch 135: Loss 0.101
# Epoch 136: Loss 0.101
# Epoch 137: Loss 0.101
# Epoch 138: Loss 0.101
# Epoch 139: Loss 0.100
# Epoch 140: Loss 0.100
# Epoch 141: Loss 0.100
# Epoch 142: Loss 0.100
# Epoch 143: Loss 0.100
# Epoch 144: Loss 0.100
# Epoch 145: Loss 0.100
# Epoch 146: Loss 0.100
# Epoch 147: Loss 0.100
# Epoch 148: Loss 0.100
# Epoch 149: Loss 0.100
# Epoch 150: Loss 0.100
# Epoch 151: Loss 0.100
# Epoch 152: Loss 0.100
# Epoch 153: Loss 0.100
# Epoch 154: Loss 0.100
# Epoch 155: Loss 0.100
# Epoch 156: Loss 0.099
# Epoch 157: Loss 0.099
# Epoch 158: Loss 0.099
# Epoch 159: Loss 0.099
# Epoch 160: Loss 0.099
# Epoch 161: Loss 0.099
# Epoch 162: Loss 0.099
# Epoch 163: Loss 0.099
# Epoch 164: Loss 0.099
# Epoch 165: Loss 0.099
# Epoch 166: Loss 0.099
# Epoch 167: Loss 0.099
# Epoch 168: Loss 0.099
# Epoch 169: Loss 0.099
# Epoch 170: Loss 0.099
# Epoch 171: Loss 0.099
# Epoch 172: Loss 0.099
# Epoch 173: Loss 0.099
# Epoch 174: Loss 0.098
# Epoch 175: Loss 0.098
# Epoch 176: Loss 0.098
# Epoch 177: Loss 0.098
# Epoch 178: Loss 0.098
# Epoch 179: Loss 0.098
# Epoch 180: Loss 0.098
# Epoch 181: Loss 0.098
# Epoch 182: Loss 0.098
# Epoch 183: Loss 0.098
# Epoch 184: Loss 0.098
# Epoch 185: Loss 0.098
# Epoch 186: Loss 0.098
# Epoch 187: Loss 0.098
# Epoch 188: Loss 0.098
# Epoch 189: Loss 0.098
# Epoch 190: Loss 0.098
# Epoch 191: Loss 0.098
# Epoch 192: Loss 0.098
# Epoch 193: Loss 0.098
# Epoch 194: Loss 0.098
# Epoch 195: Loss 0.098
# Epoch 196: Loss 0.098
# Epoch 197: Loss 0.097
# Epoch 198: Loss 0.097
# Epoch 199: Loss 0.097
# Epoch 200: Loss 0.097
# Epoch 201: Loss 0.097
# Epoch 202: Loss 0.097
# Epoch 203: Loss 0.097
# Epoch 204: Loss 0.097
# Epoch 205: Loss 0.097
# Epoch 206: Loss 0.097
# Epoch 207: Loss 0.097
# Epoch 208: Loss 0.097
# Epoch 209: Loss 0.097
# Epoch 210: Loss 0.097
# Epoch 211: Loss 0.097
# Epoch 212: Loss 0.097
# Epoch 213: Loss 0.097
# Epoch 214: Loss 0.097
# Epoch 215: Loss 0.097
# Epoch 216: Loss 0.097
# Epoch 217: Loss 0.097
# Epoch 218: Loss 0.097
# Epoch 219: Loss 0.097
# Epoch 220: Loss 0.096
# Epoch 221: Loss 0.096
# Epoch 222: Loss 0.096
# Epoch 223: Loss 0.096
# Epoch 224: Loss 0.096
# Epoch 225: Loss 0.096
# Epoch 226: Loss 0.096
# Epoch 227: Loss 0.096
# Epoch 228: Loss 0.096
# Epoch 229: Loss 0.096
# Epoch 230: Loss 0.096
# Epoch 231: Loss 0.096
# Epoch 232: Loss 0.096
# Epoch 233: Loss 0.096
# Epoch 234: Loss 0.096
# Epoch 235: Loss 0.096
# Epoch 236: Loss 0.096
# Epoch 237: Loss 0.096
# Epoch 238: Loss 0.096
# Epoch 239: Loss 0.096
# Epoch 240: Loss 0.096
# Epoch 241: Loss 0.096
# Epoch 242: Loss 0.096
# Epoch 243: Loss 0.096
# Epoch 244: Loss 0.096
# Epoch 245: Loss 0.096
# Epoch 246: Loss 0.095
# Epoch 247: Loss 0.095
# Epoch 248: Loss 0.095
# Epoch 249: Loss 0.095
# Epoch 250: Loss 0.095
# Epoch 251: Loss 0.095
# Epoch 252: Loss 0.095
# Epoch 253: Loss 0.095
# Epoch 254: Loss 0.095
# Epoch 255: Loss 0.095
# Epoch 256: Loss 0.095
# Epoch 257: Loss 0.095
# Epoch 258: Loss 0.095
# Epoch 259: Loss 0.095
# Epoch 260: Loss 0.095
# Epoch 261: Loss 0.095
# Epoch 262: Loss 0.095
# Epoch 263: Loss 0.095
# Epoch 264: Loss 0.095
# Epoch 265: Loss 0.095
# Epoch 266: Loss 0.095
# Epoch 267: Loss 0.095
# Epoch 268: Loss 0.095
# Epoch 269: Loss 0.095
# Epoch 270: Loss 0.095
# Epoch 271: Loss 0.095
# Epoch 272: Loss 0.094
# Epoch 273: Loss 0.094
# Epoch 274: Loss 0.094
# Epoch 275: Loss 0.094
# Epoch 276: Loss 0.094
# Epoch 277: Loss 0.094
# Epoch 278: Loss 0.094
# Epoch 279: Loss 0.094
# Epoch 280: Loss 0.094
# Epoch 281: Loss 0.094
# Epoch 282: Loss 0.094
# Epoch 283: Loss 0.094
# Epoch 284: Loss 0.094
# Epoch 285: Loss 0.094
# Epoch 286: Loss 0.094
# Epoch 287: Loss 0.094
# Epoch 288: Loss 0.094
# Epoch 289: Loss 0.094
# Epoch 290: Loss 0.094
# Epoch 291: Loss 0.094
# Epoch 292: Loss 0.094
# Epoch 293: Loss 0.094
# Epoch 294: Loss 0.094
# Epoch 295: Loss 0.094
# Epoch 296: Loss 0.094
# Epoch 297: Loss 0.093
# Epoch 298: Loss 0.094
# Epoch 299: Loss 0.093
# Epoch 300: Loss 0.093
# Epoch 301: Loss 0.093
# Epoch 302: Loss 0.093
# Epoch 303: Loss 0.093
# Epoch 304: Loss 0.093
# Epoch 305: Loss 0.093
# Epoch 306: Loss 0.093
# Epoch 307: Loss 0.093
# Epoch 308: Loss 0.093
# Epoch 309: Loss 0.093
# Epoch 310: Loss 0.093
# Epoch 311: Loss 0.093
# Epoch 312: Loss 0.093
# Epoch 313: Loss 0.093
# Epoch 314: Loss 0.093
# Epoch 315: Loss 0.093
# Epoch 316: Loss 0.093
# Epoch 317: Loss 0.093
# Epoch 318: Loss 0.093
# Epoch 319: Loss 0.092
# Epoch 320: Loss 0.093
# Epoch 321: Loss 0.092
# Epoch 322: Loss 0.092
# Epoch 323: Loss 0.092
# Epoch 324: Loss 0.092
# Epoch 325: Loss 0.092
# Epoch 326: Loss 0.092
# Epoch 327: Loss 0.092
# Epoch 328: Loss 0.092
# Epoch 329: Loss 0.092
# Epoch 330: Loss 0.092
# Epoch 331: Loss 0.092
# Epoch 332: Loss 0.092
# Epoch 333: Loss 0.092
# Epoch 334: Loss 0.092
# Epoch 335: Loss 0.092
# Epoch 336: Loss 0.092
# Epoch 337: Loss 0.092
# Epoch 338: Loss 0.092
# Epoch 339: Loss 0.092
# Epoch 340: Loss 0.092
# Epoch 341: Loss 0.092
# Epoch 342: Loss 0.091
# Epoch 343: Loss 0.091
# Epoch 344: Loss 0.092
# Epoch 345: Loss 0.091
# Epoch 346: Loss 0.091
# Epoch 347: Loss 0.091
# Epoch 348: Loss 0.091
# Epoch 349: Loss 0.091
# Epoch 350: Loss 0.091
# Epoch 351: Loss 0.091
# Epoch 352: Loss 0.091
# Epoch 353: Loss 0.091
# Epoch 354: Loss 0.091
# Epoch 355: Loss 0.091
# Epoch 356: Loss 0.091
# Epoch 357: Loss 0.091
# Epoch 358: Loss 0.091
# Epoch 359: Loss 0.091
# Epoch 360: Loss 0.091
# Epoch 361: Loss 0.091
# Epoch 362: Loss 0.091
# Epoch 363: Loss 0.090
# Epoch 364: Loss 0.090
# Epoch 365: Loss 0.090
# Epoch 366: Loss 0.090
# Epoch 367: Loss 0.090
# Epoch 368: Loss 0.090
# Epoch 369: Loss 0.090
# Epoch 370: Loss 0.090
# Epoch 371: Loss 0.090
# Epoch 372: Loss 0.090
# Epoch 373: Loss 0.090
# Epoch 374: Loss 0.090
# Epoch 375: Loss 0.090
# Epoch 376: Loss 0.090
# Epoch 377: Loss 0.090
# Epoch 378: Loss 0.090
# Epoch 379: Loss 0.090
# Epoch 380: Loss 0.089
# Epoch 381: Loss 0.090
# Epoch 382: Loss 0.089
# Epoch 383: Loss 0.089
# Epoch 384: Loss 0.089
# Epoch 385: Loss 0.089
# Epoch 386: Loss 0.089
# Epoch 387: Loss 0.089
# Epoch 388: Loss 0.089
# Epoch 389: Loss 0.089
# Epoch 390: Loss 0.089
# Epoch 391: Loss 0.089
# Epoch 392: Loss 0.089
# Epoch 393: Loss 0.089
# Epoch 394: Loss 0.089
# Epoch 395: Loss 0.089
# Epoch 396: Loss 0.089
# Epoch 397: Loss 0.088
# Epoch 398: Loss 0.089
# Epoch 399: Loss 0.088
# Epoch 400: Loss 0.088
# Epoch 401: Loss 0.088
# Epoch 402: Loss 0.088
# Epoch 403: Loss 0.088
# Epoch 404: Loss 0.088
# Epoch 405: Loss 0.088
# Epoch 406: Loss 0.088
# Epoch 407: Loss 0.088
# Epoch 408: Loss 0.088
# Epoch 409: Loss 0.088
# Epoch 410: Loss 0.088
# Epoch 411: Loss 0.088
# Epoch 412: Loss 0.087
# Epoch 413: Loss 0.087
# Epoch 414: Loss 0.087
# Epoch 415: Loss 0.087
# Epoch 416: Loss 0.087
# Epoch 417: Loss 0.087
# Epoch 418: Loss 0.087
# Epoch 419: Loss 0.087
# Epoch 420: Loss 0.087
# Epoch 421: Loss 0.087
# Epoch 422: Loss 0.087
# Epoch 423: Loss 0.087
# Epoch 424: Loss 0.087
# Epoch 425: Loss 0.087
# Epoch 426: Loss 0.086
# Epoch 427: Loss 0.086
# Epoch 428: Loss 0.087
# Epoch 429: Loss 0.086
# Epoch 430: Loss 0.086
# Epoch 431: Loss 0.086
# Epoch 432: Loss 0.086
# Epoch 433: Loss 0.086
# Epoch 434: Loss 0.086
# Epoch 435: Loss 0.086
# Epoch 436: Loss 0.086
# Epoch 437: Loss 0.086
# Epoch 438: Loss 0.086
# Epoch 439: Loss 0.086
# Epoch 440: Loss 0.085
# Epoch 441: Loss 0.085
# Epoch 442: Loss 0.086
# Epoch 443: Loss 0.085
# Epoch 444: Loss 0.085
# Epoch 445: Loss 0.085
# Epoch 446: Loss 0.085
# Epoch 447: Loss 0.085
# Epoch 448: Loss 0.085
# Epoch 449: Loss 0.085
# Epoch 450: Loss 0.085
# Epoch 451: Loss 0.085
# Epoch 452: Loss 0.085
# Epoch 453: Loss 0.084
# Epoch 454: Loss 0.084
# Epoch 455: Loss 0.084
# Epoch 456: Loss 0.084
# Epoch 457: Loss 0.084
# Epoch 458: Loss 0.084
# Epoch 459: Loss 0.084
# Epoch 460: Loss 0.084
# Epoch 461: Loss 0.084
# Epoch 462: Loss 0.084
# Epoch 463: Loss 0.084
# Epoch 464: Loss 0.084
# Epoch 465: Loss 0.084
# Epoch 466: Loss 0.083
# Epoch 467: Loss 0.084
# Epoch 468: Loss 0.083
# Epoch 469: Loss 0.083
# Epoch 470: Loss 0.083
# Epoch 471: Loss 0.083
# Epoch 472: Loss 0.083
# Epoch 473: Loss 0.083
# Epoch 474: Loss 0.083
# Epoch 475: Loss 0.083
# Epoch 476: Loss 0.083
# Epoch 477: Loss 0.083
# Epoch 478: Loss 0.082
# Epoch 479: Loss 0.082
# Epoch 480: Loss 0.082
# Epoch 481: Loss 0.082
# Epoch 482: Loss 0.082
# Epoch 483: Loss 0.082
# Epoch 484: Loss 0.082
# Epoch 485: Loss 0.082
# Epoch 486: Loss 0.082
# Epoch 487: Loss 0.082
# Epoch 488: Loss 0.082
# Epoch 489: Loss 0.082
# Epoch 490: Loss 0.081
# Epoch 491: Loss 0.082
# Epoch 492: Loss 0.081
# Epoch 493: Loss 0.081
# Epoch 494: Loss 0.081
# Epoch 495: Loss 0.081
# Epoch 496: Loss 0.081
# Epoch 497: Loss 0.081
# Epoch 498: Loss 0.081
# Epoch 499: Loss 0.081
# Epoch 500: Loss 0.081

# %%
fig, axs = plt.subplots(4,1,figsize=(6,15),layout='constrained')

pcm0 = axs[0].scatter(X[:,0], X[:,1],c=dot_matrix_input_layer)
axs[0].set_title('Input Layer')

fig.colorbar(pcm0, ax=axs[0])

pcm1 = axs[1].scatter(X[:,0], X[:,1],c=dot_matrix_hidden_one)
axs[1].set_title('Hidden Layer 1')

fig.colorbar(pcm1, ax=axs[1])

pcm2 = axs[2].scatter(X[:,0], X[:,1],c=dot_matrix_hidden_two)
axs[2].set_title('Hidden Layer 2')

fig.colorbar(pcm2, ax=axs[2])

pcm3 = axs[3].scatter(X[:,0], X[:,1],c=dot_matrix_output_layer)
axs[3].set_title('Output Layer')

fig.colorbar(pcm3, ax=axs[3])
