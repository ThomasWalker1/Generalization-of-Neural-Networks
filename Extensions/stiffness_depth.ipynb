# %%
import torch
import torch.nn as nn
from torch.optim import SGD

import numpy as np
from numpy import dot
import matplotlib.pyplot as plt

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_units, hidden_layers, output_size):
        super(NeuralNet, self).__init__()
        self.hidden = nn.ModuleList()
        self.input_layer = nn.Linear(input_size, hidden_units)
        for k in range(hidden_layers):
            self.hidden.append(nn.Linear(hidden_units, hidden_units))
        self.output_layer = nn.Linear(hidden_units, output_size)
        
    
    def forward(self, x):
        x=self.input_layer(x)
        x=x.relu()
        for layer in self.hidden:
            x=layer(x)
            x=x.relu()
        x=self.output_layer(x)
        return x

    
def ReLU_glorot_init(model):
    for name, param in model.named_parameters():
        
        if name.endswith(".bias"):
            param.data.fill_(0)
        else:
            nn.init.xavier_normal_(param)

# %%
RES=50
X=[]
for x_1 in np.linspace(-1,1,RES):
    for x_2 in np.linspace(-1,1,RES):
        X.append([x_1,x_2])
X=np.array(X)

encode_inputs=lambda x: 1 if (abs((x[0]+0.25)**2+x[1]**2-0.25)<0.05 and x[1]<0.1) or (abs((x[0]-0.25)**2+x[1]**2-0.25)<0.05 and x[1]>-0.1) else 0
Y=np.array([encode_inputs(x) for x in X])

X=torch.from_numpy(X).float()
Y=torch.from_numpy(Y).float()


colors=np.full(len(Y), 'cadetblue')
colors[Y==0]='teal'

plt.scatter(X[:,0],X[:,1],c=colors)

# %%
def random_sample(X,Y,size=5):
    ind_zeros=np.array([k for k in range(len(X)) if Y[k]==0])
    ind_ones=np.array([k for k in range(len(X)) if Y[k]==1])
    return np.concatenate((np.random.choice(ind_zeros,size=size),np.random.choice(ind_ones,size=size)))

# %%
def layer_stiffness(epochs,learning_rate,batch_size,num_hidden_units,num_hidden_layers,init=False):
    model = NeuralNet(2,num_hidden_units,num_hidden_layers,2)
    ReLU_glorot_init(model)

    def next_batch(inputs, targets, batchSize):
        for i in range(0, inputs.shape[0], batchSize):
            yield (inputs[i:i + batchSize], targets[i:i + batchSize])

    opt = SGD(model.parameters(), lr=learning_rate)
    lossFunc = nn.CrossEntropyLoss()

    def training():
        trainLoss = 0
        samples = 0
        model.train()
        for batchX, batchY in next_batch(X, Y, batch_size):
            predictions = model(batchX)
            loss = lossFunc(predictions, batchY.long())
            opt.zero_grad()
            loss.backward()
            opt.step()
            samples += len(batchY)
            trainLoss += loss.item()*len(batchY)
        return trainLoss/samples

    def get_dots():
        N_h=len(model.hidden)
        grads_input_layer=[]
        grads_hidden_layers=[[] for n in range(N_h)]
        grads_output_layer=[]

        for x,y in zip(X,Y):
            predictions = model(x)
            loss = lossFunc(predictions, y.long())
            opt.zero_grad()
            loss.backward()

            gradient_input_layer=[]
            gradient_input_layer+=torch.flatten(model.input_layer.weight.grad).tolist()
            gradient_input_layer+=model.input_layer.bias.grad.tolist()
            gradient_input_layer=np.array(gradient_input_layer)
            if np.linalg.norm(gradient_input_layer)!=0:
                grads_input_layer.append(gradient_input_layer/np.linalg.norm(gradient_input_layer))
            else:
                grads_input_layer.append(gradient_input_layer)

            for k,h_layer in enumerate(model.hidden):
                gradient=[]
                gradient+=torch.flatten(h_layer.weight.grad).tolist()
                gradient+=h_layer.bias.grad.tolist()
                gradient=np.array(gradient)
                if np.linalg.norm(gradient)!=0:
                    grads_hidden_layers[k].append(gradient/np.linalg.norm(gradient))
                else:
                    grads_hidden_layers[k].append(gradient)

            gradient_output_layer=[]
            gradient_output_layer+=torch.flatten(model.output_layer.weight.grad).tolist()
            gradient_output_layer+=model.output_layer.bias.grad.tolist()
            gradient_output_layer=np.array(gradient_output_layer)
            if np.linalg.norm(gradient_output_layer)!=0:
                grads_output_layer.append(gradient_output_layer/np.linalg.norm(gradient_output_layer))
            else:
                grads_output_layer.append(gradient_output_layer)

        dot_matrix_input_layer=[]
        dot_matrix_hidden_layers=[[] for n in range(N_h)]
        dot_matrix_output_layer=[]
        for i in range(len(X)):
            avg_dot_input=0
            avg_dot_hidden=np.zeros(N_h)
            avg_dot_output=0
            samples=0
            sample_ind=random_sample(X,Y,size=10)
            for j in sample_ind:        
                avg_dot_input+=np.dot(grads_input_layer[i],grads_input_layer[j])
                for k in range(N_h):
                    avg_dot_hidden[k]+=np.dot(grads_hidden_layers[k][i],grads_hidden_layers[k][j])
                avg_dot_output+=np.dot(grads_output_layer[i],grads_output_layer[j])
                samples+=1
            
            dot_matrix_input_layer.append(avg_dot_input/samples)
            for k,avg_dot in enumerate(avg_dot_hidden):
                dot_matrix_hidden_layers[k].append(avg_dot/samples)
            dot_matrix_output_layer.append(avg_dot_output/samples)
    
        return dot_matrix_input_layer, dot_matrix_hidden_layers, dot_matrix_output_layer
    if init:
        init_input_matrix,init_hidden_matrices,init_output_matrix=get_dots()
    for n in range(epochs):
        l=training()
        print('Epoch {}: Loss {:.3f}'.format(n+1,l))
        if l<0.01:
            break
    input_matrix,hidden_matrix,output_matrix=get_dots()
    if init:
        return init_input_matrix,init_hidden_matrices,init_output_matrix,input_matrix,hidden_matrix,output_matrix
    return input_matrix,hidden_matrix,output_matrix

# %%
number_hidden_layers=[0,1,2,3]
number_hidden_units=16

dot_matrices=[]

for num_hidden_layers in number_hidden_layers:
    D_1,D_2,D_3=layer_stiffness(1000,0.1,100,number_hidden_units,num_hidden_layers,False)
    dot_matrices.append([D_1,D_2,D_3])
# Out:
# Epoch 1: Loss 0.393
# Epoch 2: Loss 0.292
# Epoch 3: Loss 0.281
# Epoch 4: Loss 0.275
# Epoch 5: Loss 0.272
# Epoch 6: Loss 0.269
# Epoch 7: Loss 0.267
# Epoch 8: Loss 0.265
# Epoch 9: Loss 0.264
# Epoch 10: Loss 0.263
# Epoch 11: Loss 0.262
# Epoch 12: Loss 0.261
# Epoch 13: Loss 0.260
# Epoch 14: Loss 0.260
# Epoch 15: Loss 0.259
# Epoch 16: Loss 0.258
# Epoch 17: Loss 0.257
# Epoch 18: Loss 0.257
# Epoch 19: Loss 0.256
# Epoch 20: Loss 0.255
# Epoch 21: Loss 0.254
# Epoch 22: Loss 0.254
# Epoch 23: Loss 0.253
# Epoch 24: Loss 0.252
# Epoch 25: Loss 0.251
# Epoch 26: Loss 0.250
# Epoch 27: Loss 0.249
# Epoch 28: Loss 0.248
# Epoch 29: Loss 0.247
# Epoch 30: Loss 0.247
# Epoch 31: Loss 0.246
# Epoch 32: Loss 0.246
# Epoch 33: Loss 0.245
# Epoch 34: Loss 0.245
# Epoch 35: Loss 0.244
# Epoch 36: Loss 0.244
# Epoch 37: Loss 0.243
# Epoch 38: Loss 0.243
# Epoch 39: Loss 0.242
# Epoch 40: Loss 0.242
# Epoch 41: Loss 0.241
# Epoch 42: Loss 0.241
# Epoch 43: Loss 0.241
# Epoch 44: Loss 0.240
# Epoch 45: Loss 0.240
# Epoch 46: Loss 0.239
# Epoch 47: Loss 0.239
# Epoch 48: Loss 0.239
# Epoch 49: Loss 0.238
# Epoch 50: Loss 0.238
# Epoch 51: Loss 0.238
# Epoch 52: Loss 0.237
# Epoch 53: Loss 0.237
# Epoch 54: Loss 0.236
# Epoch 55: Loss 0.236
# Epoch 56: Loss 0.236
# Epoch 57: Loss 0.235
# Epoch 58: Loss 0.235
# Epoch 59: Loss 0.235
# Epoch 60: Loss 0.235
# Epoch 61: Loss 0.234
# Epoch 62: Loss 0.234
# Epoch 63: Loss 0.234
# Epoch 64: Loss 0.233
# Epoch 65: Loss 0.233
# Epoch 66: Loss 0.233
# Epoch 67: Loss 0.232
# Epoch 68: Loss 0.232
# Epoch 69: Loss 0.232
# Epoch 70: Loss 0.232
# Epoch 71: Loss 0.231
# Epoch 72: Loss 0.231
# Epoch 73: Loss 0.231
# Epoch 74: Loss 0.231
# Epoch 75: Loss 0.230
# Epoch 76: Loss 0.230
# Epoch 77: Loss 0.230
# Epoch 78: Loss 0.230
# Epoch 79: Loss 0.229
# Epoch 80: Loss 0.229
# Epoch 81: Loss 0.229
# Epoch 82: Loss 0.229
# Epoch 83: Loss 0.229
# Epoch 84: Loss 0.228
# Epoch 85: Loss 0.228
# Epoch 86: Loss 0.228
# Epoch 87: Loss 0.228
# Epoch 88: Loss 0.228
# Epoch 89: Loss 0.227
# Epoch 90: Loss 0.227
# Epoch 91: Loss 0.227
# Epoch 92: Loss 0.227
# Epoch 93: Loss 0.227
# Epoch 94: Loss 0.226
# Epoch 95: Loss 0.226
# Epoch 96: Loss 0.226
# Epoch 97: Loss 0.226
# Epoch 98: Loss 0.226
# Epoch 99: Loss 0.226
# Epoch 100: Loss 0.225
# Epoch 101: Loss 0.225
# Epoch 102: Loss 0.225
# Epoch 103: Loss 0.225
# Epoch 104: Loss 0.225
# Epoch 105: Loss 0.225
# Epoch 106: Loss 0.225
# Epoch 107: Loss 0.224
# Epoch 108: Loss 0.224
# Epoch 109: Loss 0.224
# Epoch 110: Loss 0.224
# Epoch 111: Loss 0.224
# Epoch 112: Loss 0.224
# Epoch 113: Loss 0.224
# Epoch 114: Loss 0.224
# Epoch 115: Loss 0.223
# Epoch 116: Loss 0.223
# Epoch 117: Loss 0.223
# Epoch 118: Loss 0.223
# Epoch 119: Loss 0.223
# Epoch 120: Loss 0.223
# Epoch 121: Loss 0.223
# Epoch 122: Loss 0.223
# Epoch 123: Loss 0.222
# Epoch 124: Loss 0.222
# Epoch 125: Loss 0.222
# Epoch 126: Loss 0.222
# Epoch 127: Loss 0.222
# Epoch 128: Loss 0.222
# Epoch 129: Loss 0.222
# Epoch 130: Loss 0.222
# Epoch 131: Loss 0.222
# Epoch 132: Loss 0.221
# Epoch 133: Loss 0.221
# Epoch 134: Loss 0.221
# Epoch 135: Loss 0.221
# Epoch 136: Loss 0.221
# Epoch 137: Loss 0.221
# Epoch 138: Loss 0.221
# Epoch 139: Loss 0.221
# Epoch 140: Loss 0.221
# Epoch 141: Loss 0.220
# Epoch 142: Loss 0.220
# Epoch 143: Loss 0.220
# Epoch 144: Loss 0.220
# Epoch 145: Loss 0.220
# Epoch 146: Loss 0.220
# Epoch 147: Loss 0.220
# Epoch 148: Loss 0.220
# Epoch 149: Loss 0.220
# Epoch 150: Loss 0.220
# Epoch 151: Loss 0.219
# Epoch 152: Loss 0.219
# Epoch 153: Loss 0.219
# Epoch 154: Loss 0.219
# Epoch 155: Loss 0.219
# Epoch 156: Loss 0.219
# Epoch 157: Loss 0.219
# Epoch 158: Loss 0.219
# Epoch 159: Loss 0.219
# Epoch 160: Loss 0.219
# Epoch 161: Loss 0.218
# Epoch 162: Loss 0.218
# Epoch 163: Loss 0.218
# Epoch 164: Loss 0.218
# Epoch 165: Loss 0.218
# Epoch 166: Loss 0.218
# Epoch 167: Loss 0.218
# Epoch 168: Loss 0.218
# Epoch 169: Loss 0.218
# Epoch 170: Loss 0.217
# Epoch 171: Loss 0.217
# Epoch 172: Loss 0.217
# Epoch 173: Loss 0.217
# Epoch 174: Loss 0.217
# Epoch 175: Loss 0.217
# Epoch 176: Loss 0.217
# Epoch 177: Loss 0.217
# Epoch 178: Loss 0.217
# Epoch 179: Loss 0.216
# Epoch 180: Loss 0.216
# Epoch 181: Loss 0.216
# Epoch 182: Loss 0.216
# Epoch 183: Loss 0.216
# Epoch 184: Loss 0.216
# Epoch 185: Loss 0.216
# Epoch 186: Loss 0.216
# Epoch 187: Loss 0.216
# Epoch 188: Loss 0.216
# Epoch 189: Loss 0.215
# Epoch 190: Loss 0.215
# Epoch 191: Loss 0.215
# Epoch 192: Loss 0.215
# Epoch 193: Loss 0.215
# Epoch 194: Loss 0.215
# Epoch 195: Loss 0.215
# Epoch 196: Loss 0.215
# Epoch 197: Loss 0.215
# Epoch 198: Loss 0.215
# Epoch 199: Loss 0.215
# Epoch 200: Loss 0.214
# Epoch 201: Loss 0.214
# Epoch 202: Loss 0.214
# Epoch 203: Loss 0.214
# Epoch 204: Loss 0.214
# Epoch 205: Loss 0.214
# Epoch 206: Loss 0.214
# Epoch 207: Loss 0.214
# Epoch 208: Loss 0.214
# Epoch 209: Loss 0.214
# Epoch 210: Loss 0.214
# Epoch 211: Loss 0.214
# Epoch 212: Loss 0.213
# Epoch 213: Loss 0.213
# Epoch 214: Loss 0.213
# Epoch 215: Loss 0.213
# Epoch 216: Loss 0.213
# Epoch 217: Loss 0.213
# Epoch 218: Loss 0.213
# Epoch 219: Loss 0.213
# Epoch 220: Loss 0.213
# Epoch 221: Loss 0.213
# Epoch 222: Loss 0.213
# Epoch 223: Loss 0.213
# Epoch 224: Loss 0.212
# Epoch 225: Loss 0.212
# Epoch 226: Loss 0.212
# Epoch 227: Loss 0.212
# Epoch 228: Loss 0.212
# Epoch 229: Loss 0.212
# Epoch 230: Loss 0.212
# Epoch 231: Loss 0.212
# Epoch 232: Loss 0.212
# Epoch 233: Loss 0.212
# Epoch 234: Loss 0.212
# Epoch 235: Loss 0.211
# Epoch 236: Loss 0.211
# Epoch 237: Loss 0.211
# Epoch 238: Loss 0.211
# Epoch 239: Loss 0.211
# Epoch 240: Loss 0.211
# Epoch 241: Loss 0.211
# Epoch 242: Loss 0.211
# Epoch 243: Loss 0.211
# Epoch 244: Loss 0.211
# Epoch 245: Loss 0.211
# Epoch 246: Loss 0.211
# Epoch 247: Loss 0.210
# Epoch 248: Loss 0.210
# Epoch 249: Loss 0.210
# Epoch 250: Loss 0.210
# Epoch 251: Loss 0.210
# Epoch 252: Loss 0.210
# Epoch 253: Loss 0.210
# Epoch 254: Loss 0.210
# Epoch 255: Loss 0.210
# Epoch 256: Loss 0.210
# Epoch 257: Loss 0.210
# Epoch 258: Loss 0.210
# Epoch 259: Loss 0.210
# Epoch 260: Loss 0.209
# Epoch 261: Loss 0.209
# Epoch 262: Loss 0.209
# Epoch 263: Loss 0.209
# Epoch 264: Loss 0.209
# Epoch 265: Loss 0.209
# Epoch 266: Loss 0.209
# Epoch 267: Loss 0.209
# Epoch 268: Loss 0.209
# Epoch 269: Loss 0.209
# Epoch 270: Loss 0.209
# Epoch 271: Loss 0.209
# Epoch 272: Loss 0.208
# Epoch 273: Loss 0.208
# Epoch 274: Loss 0.208
# Epoch 275: Loss 0.208
# Epoch 276: Loss 0.208
# Epoch 277: Loss 0.208
# Epoch 278: Loss 0.208
# Epoch 279: Loss 0.208
# Epoch 280: Loss 0.208
# Epoch 281: Loss 0.208
# Epoch 282: Loss 0.208
# Epoch 283: Loss 0.208
# Epoch 284: Loss 0.207
# Epoch 285: Loss 0.207
# Epoch 286: Loss 0.207
# Epoch 287: Loss 0.207
# Epoch 288: Loss 0.207
# Epoch 289: Loss 0.207
# Epoch 290: Loss 0.207
# Epoch 291: Loss 0.207
# Epoch 292: Loss 0.207
# Epoch 293: Loss 0.207
# Epoch 294: Loss 0.207
# Epoch 295: Loss 0.207
# Epoch 296: Loss 0.206
# Epoch 297: Loss 0.206
# Epoch 298: Loss 0.206
# Epoch 299: Loss 0.206
# Epoch 300: Loss 0.206
# Epoch 301: Loss 0.206
# Epoch 302: Loss 0.206
# Epoch 303: Loss 0.206
# Epoch 304: Loss 0.206
# Epoch 305: Loss 0.206
# Epoch 306: Loss 0.206
# Epoch 307: Loss 0.206
# Epoch 308: Loss 0.206
# Epoch 309: Loss 0.206
# Epoch 310: Loss 0.206
# Epoch 311: Loss 0.206
# Epoch 312: Loss 0.206
# Epoch 313: Loss 0.205
# Epoch 314: Loss 0.205
# Epoch 315: Loss 0.205
# Epoch 316: Loss 0.205
# Epoch 317: Loss 0.205
# Epoch 318: Loss 0.205
# Epoch 319: Loss 0.205
# Epoch 320: Loss 0.205
# Epoch 321: Loss 0.205
# Epoch 322: Loss 0.205
# Epoch 323: Loss 0.205
# Epoch 324: Loss 0.205
# Epoch 325: Loss 0.205
# Epoch 326: Loss 0.205
# Epoch 327: Loss 0.205
# Epoch 328: Loss 0.204
# Epoch 329: Loss 0.204
# Epoch 330: Loss 0.204
# Epoch 331: Loss 0.204
# Epoch 332: Loss 0.204
# Epoch 333: Loss 0.204
# Epoch 334: Loss 0.204
# Epoch 335: Loss 0.204
# Epoch 336: Loss 0.204
# Epoch 337: Loss 0.204
# Epoch 338: Loss 0.204
# Epoch 339: Loss 0.204
# Epoch 340: Loss 0.204
# Epoch 341: Loss 0.204
# Epoch 342: Loss 0.204
# Epoch 343: Loss 0.204
# Epoch 344: Loss 0.204
# Epoch 345: Loss 0.203
# Epoch 346: Loss 0.203
# Epoch 347: Loss 0.203
# Epoch 348: Loss 0.203
# Epoch 349: Loss 0.203
# Epoch 350: Loss 0.203
# Epoch 351: Loss 0.203
# Epoch 352: Loss 0.203
# Epoch 353: Loss 0.203
# Epoch 354: Loss 0.203
# Epoch 355: Loss 0.203
# Epoch 356: Loss 0.203
# Epoch 357: Loss 0.203
# Epoch 358: Loss 0.203
# Epoch 359: Loss 0.203
# Epoch 360: Loss 0.203
# Epoch 361: Loss 0.202
# Epoch 362: Loss 0.202
# Epoch 363: Loss 0.202
# Epoch 364: Loss 0.202
# Epoch 365: Loss 0.202
# Epoch 366: Loss 0.202
# Epoch 367: Loss 0.202
# Epoch 368: Loss 0.202
# Epoch 369: Loss 0.202
# Epoch 370: Loss 0.202
# Epoch 371: Loss 0.202
# Epoch 372: Loss 0.202
# Epoch 373: Loss 0.202
# Epoch 374: Loss 0.202
# Epoch 375: Loss 0.202
# Epoch 376: Loss 0.202
# Epoch 377: Loss 0.201
# Epoch 378: Loss 0.201
# Epoch 379: Loss 0.201
# Epoch 380: Loss 0.201
# Epoch 381: Loss 0.201
# Epoch 382: Loss 0.201
# Epoch 383: Loss 0.201
# Epoch 384: Loss 0.201
# Epoch 385: Loss 0.201
# Epoch 386: Loss 0.201
# Epoch 387: Loss 0.201
# Epoch 388: Loss 0.201
# Epoch 389: Loss 0.201
# Epoch 390: Loss 0.201
# Epoch 391: Loss 0.201
# Epoch 392: Loss 0.201
# Epoch 393: Loss 0.201
# Epoch 394: Loss 0.201
# Epoch 395: Loss 0.201
# Epoch 396: Loss 0.201
# Epoch 397: Loss 0.200
# Epoch 398: Loss 0.200
# Epoch 399: Loss 0.200
# Epoch 400: Loss 0.200
# Epoch 401: Loss 0.200
# Epoch 402: Loss 0.200
# Epoch 403: Loss 0.200
# Epoch 404: Loss 0.200
# Epoch 405: Loss 0.200
# Epoch 406: Loss 0.200
# Epoch 407: Loss 0.200
# Epoch 408: Loss 0.200
# Epoch 409: Loss 0.200
# Epoch 410: Loss 0.200
# Epoch 411: Loss 0.200
# Epoch 412: Loss 0.200
# Epoch 413: Loss 0.200
# Epoch 414: Loss 0.200
# Epoch 415: Loss 0.200
# Epoch 416: Loss 0.200
# Epoch 417: Loss 0.200
# Epoch 418: Loss 0.199
# Epoch 419: Loss 0.199
# Epoch 420: Loss 0.199
# Epoch 421: Loss 0.199
# Epoch 422: Loss 0.199
# Epoch 423: Loss 0.199
# Epoch 424: Loss 0.199
# Epoch 425: Loss 0.199
# Epoch 426: Loss 0.199
# Epoch 427: Loss 0.199
# Epoch 428: Loss 0.199
# Epoch 429: Loss 0.199
# Epoch 430: Loss 0.199
# Epoch 431: Loss 0.199
# Epoch 432: Loss 0.199
# Epoch 433: Loss 0.199
# Epoch 434: Loss 0.199
# Epoch 435: Loss 0.199
# Epoch 436: Loss 0.199
# Epoch 437: Loss 0.199
# Epoch 438: Loss 0.199
# Epoch 439: Loss 0.199
# Epoch 440: Loss 0.199
# Epoch 441: Loss 0.198
# Epoch 442: Loss 0.198
# Epoch 443: Loss 0.198
# Epoch 444: Loss 0.198
# Epoch 445: Loss 0.198
# Epoch 446: Loss 0.198
# Epoch 447: Loss 0.198
# Epoch 448: Loss 0.198
# Epoch 449: Loss 0.198
# Epoch 450: Loss 0.198
# Epoch 451: Loss 0.198
# Epoch 452: Loss 0.198
# Epoch 453: Loss 0.198
# Epoch 454: Loss 0.198
# Epoch 455: Loss 0.198
# Epoch 456: Loss 0.198
# Epoch 457: Loss 0.198
# Epoch 458: Loss 0.198
# Epoch 459: Loss 0.198
# Epoch 460: Loss 0.198
# Epoch 461: Loss 0.198
# Epoch 462: Loss 0.198
# Epoch 463: Loss 0.198
# Epoch 464: Loss 0.198
# Epoch 465: Loss 0.197
# Epoch 466: Loss 0.197
# Epoch 467: Loss 0.197
# Epoch 468: Loss 0.197
# Epoch 469: Loss 0.197
# Epoch 470: Loss 0.197
# Epoch 471: Loss 0.197
# Epoch 472: Loss 0.197
# Epoch 473: Loss 0.197
# Epoch 474: Loss 0.197
# Epoch 475: Loss 0.197
# Epoch 476: Loss 0.197
# Epoch 477: Loss 0.197
# Epoch 478: Loss 0.197
# Epoch 479: Loss 0.197
# Epoch 480: Loss 0.197
# Epoch 481: Loss 0.197
# Epoch 482: Loss 0.197
# Epoch 483: Loss 0.197
# Epoch 484: Loss 0.197
# Epoch 485: Loss 0.197
# Epoch 486: Loss 0.197
# Epoch 487: Loss 0.197
# Epoch 488: Loss 0.197
# Epoch 489: Loss 0.197
# Epoch 490: Loss 0.197
# Epoch 491: Loss 0.197
# Epoch 492: Loss 0.196
# Epoch 493: Loss 0.196
# Epoch 494: Loss 0.196
# Epoch 495: Loss 0.196
# Epoch 496: Loss 0.196
# Epoch 497: Loss 0.196
# Epoch 498: Loss 0.196
# Epoch 499: Loss 0.196
# Epoch 500: Loss 0.196
# Epoch 501: Loss 0.196
# Epoch 502: Loss 0.196
# Epoch 503: Loss 0.196
# Epoch 504: Loss 0.196
# Epoch 505: Loss 0.196
# Epoch 506: Loss 0.196
# Epoch 507: Loss 0.196
# Epoch 508: Loss 0.196
# Epoch 509: Loss 0.196
# Epoch 510: Loss 0.196
# Epoch 511: Loss 0.196
# Epoch 512: Loss 0.196
# Epoch 513: Loss 0.196
# Epoch 514: Loss 0.196
# Epoch 515: Loss 0.196
# Epoch 516: Loss 0.196
# Epoch 517: Loss 0.196
# Epoch 518: Loss 0.196
# Epoch 519: Loss 0.196
# Epoch 520: Loss 0.196
# Epoch 521: Loss 0.195
# Epoch 522: Loss 0.195
# Epoch 523: Loss 0.195
# Epoch 524: Loss 0.195
# Epoch 525: Loss 0.195
# Epoch 526: Loss 0.195
# Epoch 527: Loss 0.195
# Epoch 528: Loss 0.195
# Epoch 529: Loss 0.195
# Epoch 530: Loss 0.195
# Epoch 531: Loss 0.195
# Epoch 532: Loss 0.195
# Epoch 533: Loss 0.195
# Epoch 534: Loss 0.195
# Epoch 535: Loss 0.195
# Epoch 536: Loss 0.195
# Epoch 537: Loss 0.195
# Epoch 538: Loss 0.195
# Epoch 539: Loss 0.195
# Epoch 540: Loss 0.195
# Epoch 541: Loss 0.195
# Epoch 542: Loss 0.195
# Epoch 543: Loss 0.195
# Epoch 544: Loss 0.195
# Epoch 545: Loss 0.195
# Epoch 546: Loss 0.195
# Epoch 547: Loss 0.195
# Epoch 548: Loss 0.195
# Epoch 549: Loss 0.195
# Epoch 550: Loss 0.195
# Epoch 551: Loss 0.194
# Epoch 552: Loss 0.194
# Epoch 553: Loss 0.194
# Epoch 554: Loss 0.194
# Epoch 555: Loss 0.194
# Epoch 556: Loss 0.194
# Epoch 557: Loss 0.194
# Epoch 558: Loss 0.194
# Epoch 559: Loss 0.194
# Epoch 560: Loss 0.194
# Epoch 561: Loss 0.194
# Epoch 562: Loss 0.194
# Epoch 563: Loss 0.194
# Epoch 564: Loss 0.194
# Epoch 565: Loss 0.194
# Epoch 566: Loss 0.194
# Epoch 567: Loss 0.194
# Epoch 568: Loss 0.194
# Epoch 569: Loss 0.194
# Epoch 570: Loss 0.194
# Epoch 571: Loss 0.194
# Epoch 572: Loss 0.194
# Epoch 573: Loss 0.194
# Epoch 574: Loss 0.194
# Epoch 575: Loss 0.194
# Epoch 576: Loss 0.194
# Epoch 577: Loss 0.194
# Epoch 578: Loss 0.194
# Epoch 579: Loss 0.194
# Epoch 580: Loss 0.194
# Epoch 581: Loss 0.194
# Epoch 582: Loss 0.194
# Epoch 583: Loss 0.194
# Epoch 584: Loss 0.194
# Epoch 585: Loss 0.194
# Epoch 586: Loss 0.194
# Epoch 587: Loss 0.194
# Epoch 588: Loss 0.193
# Epoch 589: Loss 0.193
# Epoch 590: Loss 0.193
# Epoch 591: Loss 0.193
# Epoch 592: Loss 0.193
# Epoch 593: Loss 0.193
# Epoch 594: Loss 0.193
# Epoch 595: Loss 0.193
# Epoch 596: Loss 0.193
# Epoch 597: Loss 0.193
# Epoch 598: Loss 0.193
# Epoch 599: Loss 0.193
# Epoch 600: Loss 0.193
# Epoch 601: Loss 0.193
# Epoch 602: Loss 0.193
# Epoch 603: Loss 0.193
# Epoch 604: Loss 0.193
# Epoch 605: Loss 0.193
# Epoch 606: Loss 0.193
# Epoch 607: Loss 0.193
# Epoch 608: Loss 0.193
# Epoch 609: Loss 0.193
# Epoch 610: Loss 0.193
# Epoch 611: Loss 0.193
# Epoch 612: Loss 0.193
# Epoch 613: Loss 0.193
# Epoch 614: Loss 0.193
# Epoch 615: Loss 0.193
# Epoch 616: Loss 0.193
# Epoch 617: Loss 0.193
# Epoch 618: Loss 0.193
# Epoch 619: Loss 0.193
# Epoch 620: Loss 0.193
# Epoch 621: Loss 0.193
# Epoch 622: Loss 0.193
# Epoch 623: Loss 0.193
# Epoch 624: Loss 0.193
# Epoch 625: Loss 0.193
# Epoch 626: Loss 0.192
# Epoch 627: Loss 0.192
# Epoch 628: Loss 0.192
# Epoch 629: Loss 0.192
# Epoch 630: Loss 0.192
# Epoch 631: Loss 0.192
# Epoch 632: Loss 0.192
# Epoch 633: Loss 0.192
# Epoch 634: Loss 0.192
# Epoch 635: Loss 0.192
# Epoch 636: Loss 0.192
# Epoch 637: Loss 0.192
# Epoch 638: Loss 0.192
# Epoch 639: Loss 0.192
# Epoch 640: Loss 0.192
# Epoch 641: Loss 0.192
# Epoch 642: Loss 0.192
# Epoch 643: Loss 0.192
# Epoch 644: Loss 0.192
# Epoch 645: Loss 0.192
# Epoch 646: Loss 0.192
# Epoch 647: Loss 0.192
# Epoch 648: Loss 0.192
# Epoch 649: Loss 0.192
# Epoch 650: Loss 0.192
# Epoch 651: Loss 0.192
# Epoch 652: Loss 0.192
# Epoch 653: Loss 0.192
# Epoch 654: Loss 0.192
# Epoch 655: Loss 0.192
# Epoch 656: Loss 0.192
# Epoch 657: Loss 0.192
# Epoch 658: Loss 0.192
# Epoch 659: Loss 0.192
# Epoch 660: Loss 0.192
# Epoch 661: Loss 0.192
# Epoch 662: Loss 0.192
# Epoch 663: Loss 0.192
# Epoch 664: Loss 0.192
# Epoch 665: Loss 0.192
# Epoch 666: Loss 0.191
# Epoch 667: Loss 0.191
# Epoch 668: Loss 0.191
# Epoch 669: Loss 0.191
# Epoch 670: Loss 0.191
# Epoch 671: Loss 0.191
# Epoch 672: Loss 0.191
# Epoch 673: Loss 0.191
# Epoch 674: Loss 0.191
# Epoch 675: Loss 0.191
# Epoch 676: Loss 0.191
# Epoch 677: Loss 0.191
# Epoch 678: Loss 0.191
# Epoch 679: Loss 0.191
# Epoch 680: Loss 0.191
# Epoch 681: Loss 0.191
# Epoch 682: Loss 0.191
# Epoch 683: Loss 0.191
# Epoch 684: Loss 0.191
# Epoch 685: Loss 0.191
# Epoch 686: Loss 0.191
# Epoch 687: Loss 0.191
# Epoch 688: Loss 0.191
# Epoch 689: Loss 0.191
# Epoch 690: Loss 0.191
# Epoch 691: Loss 0.191
# Epoch 692: Loss 0.191
# Epoch 693: Loss 0.191
# Epoch 694: Loss 0.191
# Epoch 695: Loss 0.191
# Epoch 696: Loss 0.191
# Epoch 697: Loss 0.191
# Epoch 698: Loss 0.191
# Epoch 699: Loss 0.191
# Epoch 700: Loss 0.191
# Epoch 701: Loss 0.191
# Epoch 702: Loss 0.191
# Epoch 703: Loss 0.191
# Epoch 704: Loss 0.191
# Epoch 705: Loss 0.191
# Epoch 706: Loss 0.191
# Epoch 707: Loss 0.191
# Epoch 708: Loss 0.191
# Epoch 709: Loss 0.191
# Epoch 710: Loss 0.191
# Epoch 711: Loss 0.191
# Epoch 712: Loss 0.191
# Epoch 713: Loss 0.191
# Epoch 714: Loss 0.191
# Epoch 715: Loss 0.191
# Epoch 716: Loss 0.191
# Epoch 717: Loss 0.190
# Epoch 718: Loss 0.190
# Epoch 719: Loss 0.190
# Epoch 720: Loss 0.190
# Epoch 721: Loss 0.190
# Epoch 722: Loss 0.190
# Epoch 723: Loss 0.190
# Epoch 724: Loss 0.190
# Epoch 725: Loss 0.190
# Epoch 726: Loss 0.190
# Epoch 727: Loss 0.190
# Epoch 728: Loss 0.190
# Epoch 729: Loss 0.190
# Epoch 730: Loss 0.190
# Epoch 731: Loss 0.190
# Epoch 732: Loss 0.190
# Epoch 733: Loss 0.190
# Epoch 734: Loss 0.190
# Epoch 735: Loss 0.190
# Epoch 736: Loss 0.190
# Epoch 737: Loss 0.190
# Epoch 738: Loss 0.190
# Epoch 739: Loss 0.190
# Epoch 740: Loss 0.190
# Epoch 741: Loss 0.190
# Epoch 742: Loss 0.190
# Epoch 743: Loss 0.190
# Epoch 744: Loss 0.190
# Epoch 745: Loss 0.190
# Epoch 746: Loss 0.190
# Epoch 747: Loss 0.190
# Epoch 748: Loss 0.190
# Epoch 749: Loss 0.190
# Epoch 750: Loss 0.190
# Epoch 751: Loss 0.190
# Epoch 752: Loss 0.190
# Epoch 753: Loss 0.190
# Epoch 754: Loss 0.190
# Epoch 755: Loss 0.190
# Epoch 756: Loss 0.190
# Epoch 757: Loss 0.190
# Epoch 758: Loss 0.190
# Epoch 759: Loss 0.190
# Epoch 760: Loss 0.190
# Epoch 761: Loss 0.190
# Epoch 762: Loss 0.190
# Epoch 763: Loss 0.190
# Epoch 764: Loss 0.190
# Epoch 765: Loss 0.190
# Epoch 766: Loss 0.190
# Epoch 767: Loss 0.190
# Epoch 768: Loss 0.190
# Epoch 769: Loss 0.190
# Epoch 770: Loss 0.190
# Epoch 771: Loss 0.190
# Epoch 772: Loss 0.190
# Epoch 773: Loss 0.190
# Epoch 774: Loss 0.190
# Epoch 775: Loss 0.189
# Epoch 776: Loss 0.189
# Epoch 777: Loss 0.189
# Epoch 778: Loss 0.189
# Epoch 779: Loss 0.189
# Epoch 780: Loss 0.189
# Epoch 781: Loss 0.189
# Epoch 782: Loss 0.189
# Epoch 783: Loss 0.189
# Epoch 784: Loss 0.189
# Epoch 785: Loss 0.189
# Epoch 786: Loss 0.189
# Epoch 787: Loss 0.189
# Epoch 788: Loss 0.189
# Epoch 789: Loss 0.189
# Epoch 790: Loss 0.189
# Epoch 791: Loss 0.189
# Epoch 792: Loss 0.189
# Epoch 793: Loss 0.189
# Epoch 794: Loss 0.189
# Epoch 795: Loss 0.189
# Epoch 796: Loss 0.189
# Epoch 797: Loss 0.189
# Epoch 798: Loss 0.189
# Epoch 799: Loss 0.189
# Epoch 800: Loss 0.189
# Epoch 801: Loss 0.189
# Epoch 802: Loss 0.189
# Epoch 803: Loss 0.189
# Epoch 804: Loss 0.189
# Epoch 805: Loss 0.189
# Epoch 806: Loss 0.189
# Epoch 807: Loss 0.189
# Epoch 808: Loss 0.189
# Epoch 809: Loss 0.189
# Epoch 810: Loss 0.189
# Epoch 811: Loss 0.189
# Epoch 812: Loss 0.189
# Epoch 813: Loss 0.189
# Epoch 814: Loss 0.189
# Epoch 815: Loss 0.189
# Epoch 816: Loss 0.189
# Epoch 817: Loss 0.189
# Epoch 818: Loss 0.189
# Epoch 819: Loss 0.189
# Epoch 820: Loss 0.189
# Epoch 821: Loss 0.189
# Epoch 822: Loss 0.189
# Epoch 823: Loss 0.189
# Epoch 824: Loss 0.189
# Epoch 825: Loss 0.189
# Epoch 826: Loss 0.189
# Epoch 827: Loss 0.189
# Epoch 828: Loss 0.189
# Epoch 829: Loss 0.189
# Epoch 830: Loss 0.189
# Epoch 831: Loss 0.189
# Epoch 832: Loss 0.189
# Epoch 833: Loss 0.189
# Epoch 834: Loss 0.189
# Epoch 835: Loss 0.189
# Epoch 836: Loss 0.189
# Epoch 837: Loss 0.189
# Epoch 838: Loss 0.189
# Epoch 839: Loss 0.188
# Epoch 840: Loss 0.188
# Epoch 841: Loss 0.188
# Epoch 842: Loss 0.188
# Epoch 843: Loss 0.188
# Epoch 844: Loss 0.188
# Epoch 845: Loss 0.188
# Epoch 846: Loss 0.188
# Epoch 847: Loss 0.188
# Epoch 848: Loss 0.188
# Epoch 849: Loss 0.188
# Epoch 850: Loss 0.188
# Epoch 851: Loss 0.188
# Epoch 852: Loss 0.188
# Epoch 853: Loss 0.188
# Epoch 854: Loss 0.188
# Epoch 855: Loss 0.188
# Epoch 856: Loss 0.188
# Epoch 857: Loss 0.188
# Epoch 858: Loss 0.188
# Epoch 859: Loss 0.188
# Epoch 860: Loss 0.188
# Epoch 861: Loss 0.188
# Epoch 862: Loss 0.188
# Epoch 863: Loss 0.188
# Epoch 864: Loss 0.188
# Epoch 865: Loss 0.188
# Epoch 866: Loss 0.188
# Epoch 867: Loss 0.188
# Epoch 868: Loss 0.188
# Epoch 869: Loss 0.188
# Epoch 870: Loss 0.188
# Epoch 871: Loss 0.188
# Epoch 872: Loss 0.188
# Epoch 873: Loss 0.188
# Epoch 874: Loss 0.188
# Epoch 875: Loss 0.188
# Epoch 876: Loss 0.188
# Epoch 877: Loss 0.188
# Epoch 878: Loss 0.188
# Epoch 879: Loss 0.188
# Epoch 880: Loss 0.188
# Epoch 881: Loss 0.188
# Epoch 882: Loss 0.188
# Epoch 883: Loss 0.188
# Epoch 884: Loss 0.188
# Epoch 885: Loss 0.188
# Epoch 886: Loss 0.188
# Epoch 887: Loss 0.188
# Epoch 888: Loss 0.188
# Epoch 889: Loss 0.188
# Epoch 890: Loss 0.188
# Epoch 891: Loss 0.188
# Epoch 892: Loss 0.188
# Epoch 893: Loss 0.188
# Epoch 894: Loss 0.188
# Epoch 895: Loss 0.188
# Epoch 896: Loss 0.188
# Epoch 897: Loss 0.188
# Epoch 898: Loss 0.188
# Epoch 899: Loss 0.188
# Epoch 900: Loss 0.188
# Epoch 901: Loss 0.188
# Epoch 902: Loss 0.188
# Epoch 903: Loss 0.188
# Epoch 904: Loss 0.188
# Epoch 905: Loss 0.188
# Epoch 906: Loss 0.188
# Epoch 907: Loss 0.188
# Epoch 908: Loss 0.188
# Epoch 909: Loss 0.188
# Epoch 910: Loss 0.188
# Epoch 911: Loss 0.188
# Epoch 912: Loss 0.188
# Epoch 913: Loss 0.188
# Epoch 914: Loss 0.188
# Epoch 915: Loss 0.188
# Epoch 916: Loss 0.188
# Epoch 917: Loss 0.188
# Epoch 918: Loss 0.187
# Epoch 919: Loss 0.187
# Epoch 920: Loss 0.187
# Epoch 921: Loss 0.187
# Epoch 922: Loss 0.187
# Epoch 923: Loss 0.187
# Epoch 924: Loss 0.187
# Epoch 925: Loss 0.187
# Epoch 926: Loss 0.187
# Epoch 927: Loss 0.187
# Epoch 928: Loss 0.187
# Epoch 929: Loss 0.187
# Epoch 930: Loss 0.187
# Epoch 931: Loss 0.187
# Epoch 932: Loss 0.187
# Epoch 933: Loss 0.187
# Epoch 934: Loss 0.187
# Epoch 935: Loss 0.187
# Epoch 936: Loss 0.187
# Epoch 937: Loss 0.187
# Epoch 938: Loss 0.187
# Epoch 939: Loss 0.187
# Epoch 940: Loss 0.187
# Epoch 941: Loss 0.187
# Epoch 942: Loss 0.187
# Epoch 943: Loss 0.187
# Epoch 944: Loss 0.187
# Epoch 945: Loss 0.187
# Epoch 946: Loss 0.187
# Epoch 947: Loss 0.187
# Epoch 948: Loss 0.187
# Epoch 949: Loss 0.187
# Epoch 950: Loss 0.187
# Epoch 951: Loss 0.187
# Epoch 952: Loss 0.187
# Epoch 953: Loss 0.187
# Epoch 954: Loss 0.187
# Epoch 955: Loss 0.187
# Epoch 956: Loss 0.187
# Epoch 957: Loss 0.187
# Epoch 958: Loss 0.187
# Epoch 959: Loss 0.187
# Epoch 960: Loss 0.187
# Epoch 961: Loss 0.187
# Epoch 962: Loss 0.187
# Epoch 963: Loss 0.187
# Epoch 964: Loss 0.187
# Epoch 965: Loss 0.187
# Epoch 966: Loss 0.187
# Epoch 967: Loss 0.187
# Epoch 968: Loss 0.187
# Epoch 969: Loss 0.187
# Epoch 970: Loss 0.187
# Epoch 971: Loss 0.187
# Epoch 972: Loss 0.187
# Epoch 973: Loss 0.187
# Epoch 974: Loss 0.187
# Epoch 975: Loss 0.187
# Epoch 976: Loss 0.187
# Epoch 977: Loss 0.187
# Epoch 978: Loss 0.187
# Epoch 979: Loss 0.187
# Epoch 980: Loss 0.187
# Epoch 981: Loss 0.187
# Epoch 982: Loss 0.187
# Epoch 983: Loss 0.187
# Epoch 984: Loss 0.187
# Epoch 985: Loss 0.187
# Epoch 986: Loss 0.187
# Epoch 987: Loss 0.187
# Epoch 988: Loss 0.187
# Epoch 989: Loss 0.187
# Epoch 990: Loss 0.187
# Epoch 991: Loss 0.187
# Epoch 992: Loss 0.187
# Epoch 993: Loss 0.187
# Epoch 994: Loss 0.187
# Epoch 995: Loss 0.187
# Epoch 996: Loss 0.187
# Epoch 997: Loss 0.187
# Epoch 998: Loss 0.187
# Epoch 999: Loss 0.187
# Epoch 1000: Loss 0.187
# Epoch 1: Loss 0.434
# Epoch 2: Loss 0.285
# Epoch 3: Loss 0.272
# Epoch 4: Loss 0.269
# Epoch 5: Loss 0.268
# Epoch 6: Loss 0.267
# Epoch 7: Loss 0.265
# Epoch 8: Loss 0.264
# Epoch 9: Loss 0.263
# Epoch 10: Loss 0.261
# Epoch 11: Loss 0.260
# Epoch 12: Loss 0.259
# Epoch 13: Loss 0.258
# Epoch 14: Loss 0.257
# Epoch 15: Loss 0.256
# Epoch 16: Loss 0.255
# Epoch 17: Loss 0.254
# Epoch 18: Loss 0.253
# Epoch 19: Loss 0.252
# Epoch 20: Loss 0.251
# Epoch 21: Loss 0.250
# Epoch 22: Loss 0.249
# Epoch 23: Loss 0.248
# Epoch 24: Loss 0.247
# Epoch 25: Loss 0.246
# Epoch 26: Loss 0.245
# Epoch 27: Loss 0.244
# Epoch 28: Loss 0.243
# Epoch 29: Loss 0.242
# Epoch 30: Loss 0.241
# Epoch 31: Loss 0.240
# Epoch 32: Loss 0.239
# Epoch 33: Loss 0.239
# Epoch 34: Loss 0.238
# Epoch 35: Loss 0.237
# Epoch 36: Loss 0.236
# Epoch 37: Loss 0.235
# Epoch 38: Loss 0.234
# Epoch 39: Loss 0.233
# Epoch 40: Loss 0.233
# Epoch 41: Loss 0.232
# Epoch 42: Loss 0.231
# Epoch 43: Loss 0.230
# Epoch 44: Loss 0.230
# Epoch 45: Loss 0.229
# Epoch 46: Loss 0.228
# Epoch 47: Loss 0.228
# Epoch 48: Loss 0.227
# Epoch 49: Loss 0.226
# Epoch 50: Loss 0.226
# Epoch 51: Loss 0.225
# Epoch 52: Loss 0.224
# Epoch 53: Loss 0.224
# Epoch 54: Loss 0.223
# Epoch 55: Loss 0.222
# Epoch 56: Loss 0.222
# Epoch 57: Loss 0.221
# Epoch 58: Loss 0.220
# Epoch 59: Loss 0.219
# Epoch 60: Loss 0.219
# Epoch 61: Loss 0.218
# Epoch 62: Loss 0.217
# Epoch 63: Loss 0.217
# Epoch 64: Loss 0.216
# Epoch 65: Loss 0.215
# Epoch 66: Loss 0.214
# Epoch 67: Loss 0.214
# Epoch 68: Loss 0.213
# Epoch 69: Loss 0.212
# Epoch 70: Loss 0.212
# Epoch 71: Loss 0.211
# Epoch 72: Loss 0.211
# Epoch 73: Loss 0.210
# Epoch 74: Loss 0.209
# Epoch 75: Loss 0.209
# Epoch 76: Loss 0.208
# Epoch 77: Loss 0.208
# Epoch 78: Loss 0.207
# Epoch 79: Loss 0.207
# Epoch 80: Loss 0.206
# Epoch 81: Loss 0.205
# Epoch 82: Loss 0.205
# Epoch 83: Loss 0.204
# Epoch 84: Loss 0.204
# Epoch 85: Loss 0.203
# Epoch 86: Loss 0.203
# Epoch 87: Loss 0.202
# Epoch 88: Loss 0.202
# Epoch 89: Loss 0.201
# Epoch 90: Loss 0.201
# Epoch 91: Loss 0.200
# Epoch 92: Loss 0.200
# Epoch 93: Loss 0.199
# Epoch 94: Loss 0.199
# Epoch 95: Loss 0.198
# Epoch 96: Loss 0.198
# Epoch 97: Loss 0.197
# Epoch 98: Loss 0.197
# Epoch 99: Loss 0.196
# Epoch 100: Loss 0.196
# Epoch 101: Loss 0.196
# Epoch 102: Loss 0.195
# Epoch 103: Loss 0.195
# Epoch 104: Loss 0.195
# Epoch 105: Loss 0.194
# Epoch 106: Loss 0.194
# Epoch 107: Loss 0.193
# Epoch 108: Loss 0.193
# Epoch 109: Loss 0.193
# Epoch 110: Loss 0.192
# Epoch 111: Loss 0.192
# Epoch 112: Loss 0.192
# Epoch 113: Loss 0.191
# Epoch 114: Loss 0.191
# Epoch 115: Loss 0.191
# Epoch 116: Loss 0.191
# Epoch 117: Loss 0.190
# Epoch 118: Loss 0.190
# Epoch 119: Loss 0.190
# Epoch 120: Loss 0.189
# Epoch 121: Loss 0.189
# Epoch 122: Loss 0.189
# Epoch 123: Loss 0.188
# Epoch 124: Loss 0.188
# Epoch 125: Loss 0.188
# Epoch 126: Loss 0.187
# Epoch 127: Loss 0.187
# Epoch 128: Loss 0.187
# Epoch 129: Loss 0.186
# Epoch 130: Loss 0.186
# Epoch 131: Loss 0.186
# Epoch 132: Loss 0.186
# Epoch 133: Loss 0.185
# Epoch 134: Loss 0.185
# Epoch 135: Loss 0.185
# Epoch 136: Loss 0.184
# Epoch 137: Loss 0.184
# Epoch 138: Loss 0.184
# Epoch 139: Loss 0.183
# Epoch 140: Loss 0.183
# Epoch 141: Loss 0.183
# Epoch 142: Loss 0.183
# Epoch 143: Loss 0.182
# Epoch 144: Loss 0.182
# Epoch 145: Loss 0.182
# Epoch 146: Loss 0.181
# Epoch 147: Loss 0.181
# Epoch 148: Loss 0.181
# Epoch 149: Loss 0.180
# Epoch 150: Loss 0.180
# Epoch 151: Loss 0.180
# Epoch 152: Loss 0.179
# Epoch 153: Loss 0.179
# Epoch 154: Loss 0.179
# Epoch 155: Loss 0.179
# Epoch 156: Loss 0.178
# Epoch 157: Loss 0.178
# Epoch 158: Loss 0.178
# Epoch 159: Loss 0.177
# Epoch 160: Loss 0.177
# Epoch 161: Loss 0.177
# Epoch 162: Loss 0.176
# Epoch 163: Loss 0.176
# Epoch 164: Loss 0.175
# Epoch 165: Loss 0.175
# Epoch 166: Loss 0.175
# Epoch 167: Loss 0.175
# Epoch 168: Loss 0.174
# Epoch 169: Loss 0.174
# Epoch 170: Loss 0.174
# Epoch 171: Loss 0.173
# Epoch 172: Loss 0.173
# Epoch 173: Loss 0.172
# Epoch 174: Loss 0.172
# Epoch 175: Loss 0.172
# Epoch 176: Loss 0.171
# Epoch 177: Loss 0.171
# Epoch 178: Loss 0.171
# Epoch 179: Loss 0.170
# Epoch 180: Loss 0.170
# Epoch 181: Loss 0.169
# Epoch 182: Loss 0.169
# Epoch 183: Loss 0.169
# Epoch 184: Loss 0.168
# Epoch 185: Loss 0.168
# Epoch 186: Loss 0.167
# Epoch 187: Loss 0.167
# Epoch 188: Loss 0.167
# Epoch 189: Loss 0.166
# Epoch 190: Loss 0.166
# Epoch 191: Loss 0.166
# Epoch 192: Loss 0.165
# Epoch 193: Loss 0.165
# Epoch 194: Loss 0.165
# Epoch 195: Loss 0.164
# Epoch 196: Loss 0.164
# Epoch 197: Loss 0.163
# Epoch 198: Loss 0.163
# Epoch 199: Loss 0.163
# Epoch 200: Loss 0.162
# Epoch 201: Loss 0.162
# Epoch 202: Loss 0.161
# Epoch 203: Loss 0.161
# Epoch 204: Loss 0.161
# Epoch 205: Loss 0.160
# Epoch 206: Loss 0.160
# Epoch 207: Loss 0.159
# Epoch 208: Loss 0.159
# Epoch 209: Loss 0.159
# Epoch 210: Loss 0.158
# Epoch 211: Loss 0.158
# Epoch 212: Loss 0.158
# Epoch 213: Loss 0.157
# Epoch 214: Loss 0.157
# Epoch 215: Loss 0.156
# Epoch 216: Loss 0.156
# Epoch 217: Loss 0.156
# Epoch 218: Loss 0.155
# Epoch 219: Loss 0.155
# Epoch 220: Loss 0.155
# Epoch 221: Loss 0.154
# Epoch 222: Loss 0.154
# Epoch 223: Loss 0.154
# Epoch 224: Loss 0.153
# Epoch 225: Loss 0.153
# Epoch 226: Loss 0.153
# Epoch 227: Loss 0.152
# Epoch 228: Loss 0.152
# Epoch 229: Loss 0.152
# Epoch 230: Loss 0.151
# Epoch 231: Loss 0.151
# Epoch 232: Loss 0.151
# Epoch 233: Loss 0.150
# Epoch 234: Loss 0.150
# Epoch 235: Loss 0.150
# Epoch 236: Loss 0.149
# Epoch 237: Loss 0.149
# Epoch 238: Loss 0.149
# Epoch 239: Loss 0.149
# Epoch 240: Loss 0.148
# Epoch 241: Loss 0.148
# Epoch 242: Loss 0.148
# Epoch 243: Loss 0.147
# Epoch 244: Loss 0.147
# Epoch 245: Loss 0.147
# Epoch 246: Loss 0.147
# Epoch 247: Loss 0.146
# Epoch 248: Loss 0.146
# Epoch 249: Loss 0.146
# Epoch 250: Loss 0.145
# Epoch 251: Loss 0.145
# Epoch 252: Loss 0.145
# Epoch 253: Loss 0.145
# Epoch 254: Loss 0.144
# Epoch 255: Loss 0.144
# Epoch 256: Loss 0.144
# Epoch 257: Loss 0.144
# Epoch 258: Loss 0.143
# Epoch 259: Loss 0.143
# Epoch 260: Loss 0.143
# Epoch 261: Loss 0.143
# Epoch 262: Loss 0.142
# Epoch 263: Loss 0.142
# Epoch 264: Loss 0.142
# Epoch 265: Loss 0.142
# Epoch 266: Loss 0.141
# Epoch 267: Loss 0.141
# Epoch 268: Loss 0.141
# Epoch 269: Loss 0.141
# Epoch 270: Loss 0.141
# Epoch 271: Loss 0.140
# Epoch 272: Loss 0.140
# Epoch 273: Loss 0.140
# Epoch 274: Loss 0.140
# Epoch 275: Loss 0.139
# Epoch 276: Loss 0.139
# Epoch 277: Loss 0.139
# Epoch 278: Loss 0.139
# Epoch 279: Loss 0.139
# Epoch 280: Loss 0.139
# Epoch 281: Loss 0.138
# Epoch 282: Loss 0.138
# Epoch 283: Loss 0.138
# Epoch 284: Loss 0.138
# Epoch 285: Loss 0.137
# Epoch 286: Loss 0.137
# Epoch 287: Loss 0.137
# Epoch 288: Loss 0.137
# Epoch 289: Loss 0.137
# Epoch 290: Loss 0.136
# Epoch 291: Loss 0.136
# Epoch 292: Loss 0.136
# Epoch 293: Loss 0.136
# Epoch 294: Loss 0.136
# Epoch 295: Loss 0.135
# Epoch 296: Loss 0.135
# Epoch 297: Loss 0.135
# Epoch 298: Loss 0.135
# Epoch 299: Loss 0.135
# Epoch 300: Loss 0.134
# Epoch 301: Loss 0.134
# Epoch 302: Loss 0.134
# Epoch 303: Loss 0.134
# Epoch 304: Loss 0.134
# Epoch 305: Loss 0.134
# Epoch 306: Loss 0.134
# Epoch 307: Loss 0.133
# Epoch 308: Loss 0.133
# Epoch 309: Loss 0.133
# Epoch 310: Loss 0.133
# Epoch 311: Loss 0.133
# Epoch 312: Loss 0.132
# Epoch 313: Loss 0.132
# Epoch 314: Loss 0.132
# Epoch 315: Loss 0.132
# Epoch 316: Loss 0.132
# Epoch 317: Loss 0.132
# Epoch 318: Loss 0.132
# Epoch 319: Loss 0.132
# Epoch 320: Loss 0.131
# Epoch 321: Loss 0.131
# Epoch 322: Loss 0.131
# Epoch 323: Loss 0.131
# Epoch 324: Loss 0.131
# Epoch 325: Loss 0.131
# Epoch 326: Loss 0.131
# Epoch 327: Loss 0.131
# Epoch 328: Loss 0.131
# Epoch 329: Loss 0.130
# Epoch 330: Loss 0.131
# Epoch 331: Loss 0.130
# Epoch 332: Loss 0.130
# Epoch 333: Loss 0.130
# Epoch 334: Loss 0.130
# Epoch 335: Loss 0.130
# Epoch 336: Loss 0.130
# Epoch 337: Loss 0.129
# Epoch 338: Loss 0.129
# Epoch 339: Loss 0.129
# Epoch 340: Loss 0.129
# Epoch 341: Loss 0.129
# Epoch 342: Loss 0.129
# Epoch 343: Loss 0.129
# Epoch 344: Loss 0.129
# Epoch 345: Loss 0.128
# Epoch 346: Loss 0.128
# Epoch 347: Loss 0.128
# Epoch 348: Loss 0.128
# Epoch 349: Loss 0.128
# Epoch 350: Loss 0.128
# Epoch 351: Loss 0.128
# Epoch 352: Loss 0.128
# Epoch 353: Loss 0.128
# Epoch 354: Loss 0.128
# Epoch 355: Loss 0.127
# Epoch 356: Loss 0.127
# Epoch 357: Loss 0.127
# Epoch 358: Loss 0.127
# Epoch 359: Loss 0.127
# Epoch 360: Loss 0.127
# Epoch 361: Loss 0.127
# Epoch 362: Loss 0.127
# Epoch 363: Loss 0.127
# Epoch 364: Loss 0.126
# Epoch 365: Loss 0.126
# Epoch 366: Loss 0.126
# Epoch 367: Loss 0.127
# Epoch 368: Loss 0.126
# Epoch 369: Loss 0.126
# Epoch 370: Loss 0.126
# Epoch 371: Loss 0.126
# Epoch 372: Loss 0.126
# Epoch 373: Loss 0.126
# Epoch 374: Loss 0.125
# Epoch 375: Loss 0.125
# Epoch 376: Loss 0.125
# Epoch 377: Loss 0.125
# Epoch 378: Loss 0.125
# Epoch 379: Loss 0.125
# Epoch 380: Loss 0.125
# Epoch 381: Loss 0.125
# Epoch 382: Loss 0.125
# Epoch 383: Loss 0.125
# Epoch 384: Loss 0.125
# Epoch 385: Loss 0.125
# Epoch 386: Loss 0.125
# Epoch 387: Loss 0.124
# Epoch 388: Loss 0.124
# Epoch 389: Loss 0.124
# Epoch 390: Loss 0.124
# Epoch 391: Loss 0.124
# Epoch 392: Loss 0.124
# Epoch 393: Loss 0.124
# Epoch 394: Loss 0.124
# Epoch 395: Loss 0.123
# Epoch 396: Loss 0.123
# Epoch 397: Loss 0.123
# Epoch 398: Loss 0.123
# Epoch 399: Loss 0.123
# Epoch 400: Loss 0.123
# Epoch 401: Loss 0.123
# Epoch 402: Loss 0.123
# Epoch 403: Loss 0.122
# Epoch 404: Loss 0.122
# Epoch 405: Loss 0.122
# Epoch 406: Loss 0.122
# Epoch 407: Loss 0.122
# Epoch 408: Loss 0.122
# Epoch 409: Loss 0.122
# Epoch 410: Loss 0.122
# Epoch 411: Loss 0.122
# Epoch 412: Loss 0.121
# Epoch 413: Loss 0.121
# Epoch 414: Loss 0.121
# Epoch 415: Loss 0.121
# Epoch 416: Loss 0.121
# Epoch 417: Loss 0.121
# Epoch 418: Loss 0.121
# Epoch 419: Loss 0.121
# Epoch 420: Loss 0.121
# Epoch 421: Loss 0.121
# Epoch 422: Loss 0.121
# Epoch 423: Loss 0.120
# Epoch 424: Loss 0.120
# Epoch 425: Loss 0.120
# Epoch 426: Loss 0.120
# Epoch 427: Loss 0.120
# Epoch 428: Loss 0.120
# Epoch 429: Loss 0.119
# Epoch 430: Loss 0.120
# Epoch 431: Loss 0.120
# Epoch 432: Loss 0.120
# Epoch 433: Loss 0.120
# Epoch 434: Loss 0.119
# Epoch 435: Loss 0.119
# Epoch 436: Loss 0.119
# Epoch 437: Loss 0.119
# Epoch 438: Loss 0.119
# Epoch 439: Loss 0.119
# Epoch 440: Loss 0.118
# Epoch 441: Loss 0.119
# Epoch 442: Loss 0.119
# Epoch 443: Loss 0.118
# Epoch 444: Loss 0.119
# Epoch 445: Loss 0.119
# Epoch 446: Loss 0.118
# Epoch 447: Loss 0.118
# Epoch 448: Loss 0.118
# Epoch 449: Loss 0.118
# Epoch 450: Loss 0.118
# Epoch 451: Loss 0.118
# Epoch 452: Loss 0.118
# Epoch 453: Loss 0.118
# Epoch 454: Loss 0.117
# Epoch 455: Loss 0.118
# Epoch 456: Loss 0.118
# Epoch 457: Loss 0.117
# Epoch 458: Loss 0.117
# Epoch 459: Loss 0.117
# Epoch 460: Loss 0.117
# Epoch 461: Loss 0.117
# Epoch 462: Loss 0.117
# Epoch 463: Loss 0.117
# Epoch 464: Loss 0.117
# Epoch 465: Loss 0.117
# Epoch 466: Loss 0.117
# Epoch 467: Loss 0.117
# Epoch 468: Loss 0.117
# Epoch 469: Loss 0.117
# Epoch 470: Loss 0.116
# Epoch 471: Loss 0.117
# Epoch 472: Loss 0.116
# Epoch 473: Loss 0.116
# Epoch 474: Loss 0.116
# Epoch 475: Loss 0.117
# Epoch 476: Loss 0.116
# Epoch 477: Loss 0.116
# Epoch 478: Loss 0.116
# Epoch 479: Loss 0.116
# Epoch 480: Loss 0.116
# Epoch 481: Loss 0.116
# Epoch 482: Loss 0.116
# Epoch 483: Loss 0.116
# Epoch 484: Loss 0.115
# Epoch 485: Loss 0.116
# Epoch 486: Loss 0.116
# Epoch 487: Loss 0.116
# Epoch 488: Loss 0.115
# Epoch 489: Loss 0.115
# Epoch 490: Loss 0.115
# Epoch 491: Loss 0.115
# Epoch 492: Loss 0.115
# Epoch 493: Loss 0.115
# Epoch 494: Loss 0.115
# Epoch 495: Loss 0.115
# Epoch 496: Loss 0.114
# Epoch 497: Loss 0.115
# Epoch 498: Loss 0.115
# Epoch 499: Loss 0.114
# Epoch 500: Loss 0.114
# Epoch 501: Loss 0.114
# Epoch 502: Loss 0.114
# Epoch 503: Loss 0.114
# Epoch 504: Loss 0.114
# Epoch 505: Loss 0.114
# Epoch 506: Loss 0.114
# Epoch 507: Loss 0.114
# Epoch 508: Loss 0.114
# Epoch 509: Loss 0.114
# Epoch 510: Loss 0.113
# Epoch 511: Loss 0.114
# Epoch 512: Loss 0.113
# Epoch 513: Loss 0.113
# Epoch 514: Loss 0.113
# Epoch 515: Loss 0.113
# Epoch 516: Loss 0.113
# Epoch 517: Loss 0.113
# Epoch 518: Loss 0.113
# Epoch 519: Loss 0.113
# Epoch 520: Loss 0.112
# Epoch 521: Loss 0.113
# Epoch 522: Loss 0.113
# Epoch 523: Loss 0.112
# Epoch 524: Loss 0.112
# Epoch 525: Loss 0.112
# Epoch 526: Loss 0.112
# Epoch 527: Loss 0.112
# Epoch 528: Loss 0.112
# Epoch 529: Loss 0.111
# Epoch 530: Loss 0.112
# Epoch 531: Loss 0.111
# Epoch 532: Loss 0.111
# Epoch 533: Loss 0.111
# Epoch 534: Loss 0.111
# Epoch 535: Loss 0.111
# Epoch 536: Loss 0.111
# Epoch 537: Loss 0.111
# Epoch 538: Loss 0.111
# Epoch 539: Loss 0.111
# Epoch 540: Loss 0.111
# Epoch 541: Loss 0.111
# Epoch 542: Loss 0.110
# Epoch 543: Loss 0.110
# Epoch 544: Loss 0.110
# Epoch 545: Loss 0.110
# Epoch 546: Loss 0.110
# Epoch 547: Loss 0.110
# Epoch 548: Loss 0.110
# Epoch 549: Loss 0.110
# Epoch 550: Loss 0.110
# Epoch 551: Loss 0.110
# Epoch 552: Loss 0.110
# Epoch 553: Loss 0.109
# Epoch 554: Loss 0.110
# Epoch 555: Loss 0.109
# Epoch 556: Loss 0.109
# Epoch 557: Loss 0.109
# Epoch 558: Loss 0.109
# Epoch 559: Loss 0.109
# Epoch 560: Loss 0.109
# Epoch 561: Loss 0.109
# Epoch 562: Loss 0.109
# Epoch 563: Loss 0.109
# Epoch 564: Loss 0.108
# Epoch 565: Loss 0.108
# Epoch 566: Loss 0.109
# Epoch 567: Loss 0.108
# Epoch 568: Loss 0.108
# Epoch 569: Loss 0.107
# Epoch 570: Loss 0.108
# Epoch 571: Loss 0.107
# Epoch 572: Loss 0.107
# Epoch 573: Loss 0.108
# Epoch 574: Loss 0.107
# Epoch 575: Loss 0.107
# Epoch 576: Loss 0.107
# Epoch 577: Loss 0.107
# Epoch 578: Loss 0.107
# Epoch 579: Loss 0.107
# Epoch 580: Loss 0.107
# Epoch 581: Loss 0.106
# Epoch 582: Loss 0.106
# Epoch 583: Loss 0.107
# Epoch 584: Loss 0.106
# Epoch 585: Loss 0.106
# Epoch 586: Loss 0.106
# Epoch 587: Loss 0.106
# Epoch 588: Loss 0.106
# Epoch 589: Loss 0.106
# Epoch 590: Loss 0.105
# Epoch 591: Loss 0.106
# Epoch 592: Loss 0.106
# Epoch 593: Loss 0.105
# Epoch 594: Loss 0.105
# Epoch 595: Loss 0.105
# Epoch 596: Loss 0.105
# Epoch 597: Loss 0.106
# Epoch 598: Loss 0.105
# Epoch 599: Loss 0.105
# Epoch 600: Loss 0.105
# Epoch 601: Loss 0.105
# Epoch 602: Loss 0.105
# Epoch 603: Loss 0.104
# Epoch 604: Loss 0.104
# Epoch 605: Loss 0.105
# Epoch 606: Loss 0.103
# Epoch 607: Loss 0.105
# Epoch 608: Loss 0.104
# Epoch 609: Loss 0.104
# Epoch 610: Loss 0.104
# Epoch 611: Loss 0.104
# Epoch 612: Loss 0.103
# Epoch 613: Loss 0.103
# Epoch 614: Loss 0.103
# Epoch 615: Loss 0.103
# Epoch 616: Loss 0.103
# Epoch 617: Loss 0.102
# Epoch 618: Loss 0.102
# Epoch 619: Loss 0.103
# Epoch 620: Loss 0.102
# Epoch 621: Loss 0.102
# Epoch 622: Loss 0.102
# Epoch 623: Loss 0.103
# Epoch 624: Loss 0.104
# Epoch 625: Loss 0.103
# Epoch 626: Loss 0.103
# Epoch 627: Loss 0.103
# Epoch 628: Loss 0.102
# Epoch 629: Loss 0.102
# Epoch 630: Loss 0.101
# Epoch 631: Loss 0.103
# Epoch 632: Loss 0.101
# Epoch 633: Loss 0.101
# Epoch 634: Loss 0.101
# Epoch 635: Loss 0.101
# Epoch 636: Loss 0.102
# Epoch 637: Loss 0.102
# Epoch 638: Loss 0.101
# Epoch 639: Loss 0.101
# Epoch 640: Loss 0.102
# Epoch 641: Loss 0.102
# Epoch 642: Loss 0.100
# Epoch 643: Loss 0.102
# Epoch 644: Loss 0.100
# Epoch 645: Loss 0.099
# Epoch 646: Loss 0.101
# Epoch 647: Loss 0.100
# Epoch 648: Loss 0.100
# Epoch 649: Loss 0.100
# Epoch 650: Loss 0.100
# Epoch 651: Loss 0.100
# Epoch 652: Loss 0.100
# Epoch 653: Loss 0.100
# Epoch 654: Loss 0.099
# Epoch 655: Loss 0.099
# Epoch 656: Loss 0.100
# Epoch 657: Loss 0.098
# Epoch 658: Loss 0.100
# Epoch 659: Loss 0.098
# Epoch 660: Loss 0.099
# Epoch 661: Loss 0.098
# Epoch 662: Loss 0.099
# Epoch 663: Loss 0.098
# Epoch 664: Loss 0.099
# Epoch 665: Loss 0.098
# Epoch 666: Loss 0.097
# Epoch 667: Loss 0.098
# Epoch 668: Loss 0.097
# Epoch 669: Loss 0.097
# Epoch 670: Loss 0.098
# Epoch 671: Loss 0.096
# Epoch 672: Loss 0.098
# Epoch 673: Loss 0.097
# Epoch 674: Loss 0.097
# Epoch 675: Loss 0.098
# Epoch 676: Loss 0.097
# Epoch 677: Loss 0.098
# Epoch 678: Loss 0.096
# Epoch 679: Loss 0.096
# Epoch 680: Loss 0.097
# Epoch 681: Loss 0.096
# Epoch 682: Loss 0.097
# Epoch 683: Loss 0.096
# Epoch 684: Loss 0.095
# Epoch 685: Loss 0.096
# Epoch 686: Loss 0.096
# Epoch 687: Loss 0.096
# Epoch 688: Loss 0.096
# Epoch 689: Loss 0.096
# Epoch 690: Loss 0.095
# Epoch 691: Loss 0.096
# Epoch 692: Loss 0.095
# Epoch 693: Loss 0.095
# Epoch 694: Loss 0.094
# Epoch 695: Loss 0.094
# Epoch 696: Loss 0.095
# Epoch 697: Loss 0.095
# Epoch 698: Loss 0.095
# Epoch 699: Loss 0.094
# Epoch 700: Loss 0.095
# Epoch 701: Loss 0.095
# Epoch 702: Loss 0.095
# Epoch 703: Loss 0.094
# Epoch 704: Loss 0.095
# Epoch 705: Loss 0.094
# Epoch 706: Loss 0.095
# Epoch 707: Loss 0.094
# Epoch 708: Loss 0.094
# Epoch 709: Loss 0.094
# Epoch 710: Loss 0.094
# Epoch 711: Loss 0.094
# Epoch 712: Loss 0.094
# Epoch 713: Loss 0.093
# Epoch 714: Loss 0.093
# Epoch 715: Loss 0.092
# Epoch 716: Loss 0.092
# Epoch 717: Loss 0.091
# Epoch 718: Loss 0.091
# Epoch 719: Loss 0.091
# Epoch 720: Loss 0.091
# Epoch 721: Loss 0.092
# Epoch 722: Loss 0.091
# Epoch 723: Loss 0.091
# Epoch 724: Loss 0.090
# Epoch 725: Loss 0.091
# Epoch 726: Loss 0.091
# Epoch 727: Loss 0.090
# Epoch 728: Loss 0.090
# Epoch 729: Loss 0.090
# Epoch 730: Loss 0.090
# Epoch 731: Loss 0.089
# Epoch 732: Loss 0.089
# Epoch 733: Loss 0.088
# Epoch 734: Loss 0.088
# Epoch 735: Loss 0.088
# Epoch 736: Loss 0.087
# Epoch 737: Loss 0.088
# Epoch 738: Loss 0.087
# Epoch 739: Loss 0.088
# Epoch 740: Loss 0.087
# Epoch 741: Loss 0.087
# Epoch 742: Loss 0.087
# Epoch 743: Loss 0.087
# Epoch 744: Loss 0.088
# Epoch 745: Loss 0.088
# Epoch 746: Loss 0.088
# Epoch 747: Loss 0.087
# Epoch 748: Loss 0.087
# Epoch 749: Loss 0.087
# Epoch 750: Loss 0.088
# Epoch 751: Loss 0.087
# Epoch 752: Loss 0.087
# Epoch 753: Loss 0.088
# Epoch 754: Loss 0.086
# Epoch 755: Loss 0.088
# Epoch 756: Loss 0.086
# Epoch 757: Loss 0.087
# Epoch 758: Loss 0.086
# Epoch 759: Loss 0.086
# Epoch 760: Loss 0.088
# Epoch 761: Loss 0.086
# Epoch 762: Loss 0.087
# Epoch 763: Loss 0.085
# Epoch 764: Loss 0.087
# Epoch 765: Loss 0.085
# Epoch 766: Loss 0.086
# Epoch 767: Loss 0.087
# Epoch 768: Loss 0.085
# Epoch 769: Loss 0.086
# Epoch 770: Loss 0.085
# Epoch 771: Loss 0.087
# Epoch 772: Loss 0.085
# Epoch 773: Loss 0.087
# Epoch 774: Loss 0.084
# Epoch 775: Loss 0.086
# Epoch 776: Loss 0.085
# Epoch 777: Loss 0.086
# Epoch 778: Loss 0.084
# Epoch 779: Loss 0.086
# Epoch 780: Loss 0.084
# Epoch 781: Loss 0.086
# Epoch 782: Loss 0.084
# Epoch 783: Loss 0.084
# Epoch 784: Loss 0.086
# Epoch 785: Loss 0.083
# Epoch 786: Loss 0.085
# Epoch 787: Loss 0.084
# Epoch 788: Loss 0.086
# Epoch 789: Loss 0.083
# Epoch 790: Loss 0.084
# Epoch 791: Loss 0.084
# Epoch 792: Loss 0.088
# Epoch 793: Loss 0.082
# Epoch 794: Loss 0.086
# Epoch 795: Loss 0.083
# Epoch 796: Loss 0.082
# Epoch 797: Loss 0.087
# Epoch 798: Loss 0.082
# Epoch 799: Loss 0.082
# Epoch 800: Loss 0.081
# Epoch 801: Loss 0.083
# Epoch 802: Loss 0.081
# Epoch 803: Loss 0.085
# Epoch 804: Loss 0.085
# Epoch 805: Loss 0.082
# Epoch 806: Loss 0.083
# Epoch 807: Loss 0.082
# Epoch 808: Loss 0.084
# Epoch 809: Loss 0.083
# Epoch 810: Loss 0.083
# Epoch 811: Loss 0.083
# Epoch 812: Loss 0.083
# Epoch 813: Loss 0.083
# Epoch 814: Loss 0.084
# Epoch 815: Loss 0.084
# Epoch 816: Loss 0.084
# Epoch 817: Loss 0.084
# Epoch 818: Loss 0.084
# Epoch 819: Loss 0.082
# Epoch 820: Loss 0.083
# Epoch 821: Loss 0.082
# Epoch 822: Loss 0.082
# Epoch 823: Loss 0.081
# Epoch 824: Loss 0.082
# Epoch 825: Loss 0.082
# Epoch 826: Loss 0.082
# Epoch 827: Loss 0.081
# Epoch 828: Loss 0.081
# Epoch 829: Loss 0.081
# Epoch 830: Loss 0.081
# Epoch 831: Loss 0.080
# Epoch 832: Loss 0.081
# Epoch 833: Loss 0.079
# Epoch 834: Loss 0.080
# Epoch 835: Loss 0.080
# Epoch 836: Loss 0.080
# Epoch 837: Loss 0.079
# Epoch 838: Loss 0.081
# Epoch 839: Loss 0.079
# Epoch 840: Loss 0.080
# Epoch 841: Loss 0.079
# Epoch 842: Loss 0.078
# Epoch 843: Loss 0.079
# Epoch 844: Loss 0.079
# Epoch 845: Loss 0.078
# Epoch 846: Loss 0.079
# Epoch 847: Loss 0.077
# Epoch 848: Loss 0.079
# Epoch 849: Loss 0.078
# Epoch 850: Loss 0.077
# Epoch 851: Loss 0.079
# Epoch 852: Loss 0.077
# Epoch 853: Loss 0.078
# Epoch 854: Loss 0.076
# Epoch 855: Loss 0.078
# Epoch 856: Loss 0.078
# Epoch 857: Loss 0.076
# Epoch 858: Loss 0.076
# Epoch 859: Loss 0.076
# Epoch 860: Loss 0.077
# Epoch 861: Loss 0.078
# Epoch 862: Loss 0.076
# Epoch 863: Loss 0.078
# Epoch 864: Loss 0.076
# Epoch 865: Loss 0.078
# Epoch 866: Loss 0.078
# Epoch 867: Loss 0.076
# Epoch 868: Loss 0.078
# Epoch 869: Loss 0.077
# Epoch 870: Loss 0.076
# Epoch 871: Loss 0.077
# Epoch 872: Loss 0.077
# Epoch 873: Loss 0.075
# Epoch 874: Loss 0.077
# Epoch 875: Loss 0.076
# Epoch 876: Loss 0.077
# Epoch 877: Loss 0.076
# Epoch 878: Loss 0.076
# Epoch 879: Loss 0.077
# Epoch 880: Loss 0.076
# Epoch 881: Loss 0.075
# Epoch 882: Loss 0.076
# Epoch 883: Loss 0.075
# Epoch 884: Loss 0.074
# Epoch 885: Loss 0.075
# Epoch 886: Loss 0.077
# Epoch 887: Loss 0.075
# Epoch 888: Loss 0.074
# Epoch 889: Loss 0.076
# Epoch 890: Loss 0.075
# Epoch 891: Loss 0.074
# Epoch 892: Loss 0.076
# Epoch 893: Loss 0.075
# Epoch 894: Loss 0.074
# Epoch 895: Loss 0.075
# Epoch 896: Loss 0.073
# Epoch 897: Loss 0.075
# Epoch 898: Loss 0.074
# Epoch 899: Loss 0.074
# Epoch 900: Loss 0.074
# Epoch 901: Loss 0.075
# Epoch 902: Loss 0.073
# Epoch 903: Loss 0.075
# Epoch 904: Loss 0.074
# Epoch 905: Loss 0.073
# Epoch 906: Loss 0.074
# Epoch 907: Loss 0.073
# Epoch 908: Loss 0.075
# Epoch 909: Loss 0.074
# Epoch 910: Loss 0.073
# Epoch 911: Loss 0.073
# Epoch 912: Loss 0.072
# Epoch 913: Loss 0.073
# Epoch 914: Loss 0.073
# Epoch 915: Loss 0.073
# Epoch 916: Loss 0.072
# Epoch 917: Loss 0.074
# Epoch 918: Loss 0.072
# Epoch 919: Loss 0.073
# Epoch 920: Loss 0.073
# Epoch 921: Loss 0.072
# Epoch 922: Loss 0.073
# Epoch 923: Loss 0.072
# Epoch 924: Loss 0.072
# Epoch 925: Loss 0.072
# Epoch 926: Loss 0.073
# Epoch 927: Loss 0.073
# Epoch 928: Loss 0.071
# Epoch 929: Loss 0.071
# Epoch 930: Loss 0.072
# Epoch 931: Loss 0.071
# Epoch 932: Loss 0.072
# Epoch 933: Loss 0.072
# Epoch 934: Loss 0.072
# Epoch 935: Loss 0.071
# Epoch 936: Loss 0.071
# Epoch 937: Loss 0.073
# Epoch 938: Loss 0.072
# Epoch 939: Loss 0.072
# Epoch 940: Loss 0.071
# Epoch 941: Loss 0.071
# Epoch 942: Loss 0.072
# Epoch 943: Loss 0.071
# Epoch 944: Loss 0.072
# Epoch 945: Loss 0.070
# Epoch 946: Loss 0.071
# Epoch 947: Loss 0.071
# Epoch 948: Loss 0.072
# Epoch 949: Loss 0.070
# Epoch 950: Loss 0.071
# Epoch 951: Loss 0.071
# Epoch 952: Loss 0.071
# Epoch 953: Loss 0.072
# Epoch 954: Loss 0.070
# Epoch 955: Loss 0.071
# Epoch 956: Loss 0.071
# Epoch 957: Loss 0.069
# Epoch 958: Loss 0.071
# Epoch 959: Loss 0.071
# Epoch 960: Loss 0.069
# Epoch 961: Loss 0.071
# Epoch 962: Loss 0.069
# Epoch 963: Loss 0.071
# Epoch 964: Loss 0.070
# Epoch 965: Loss 0.070
# Epoch 966: Loss 0.069
# Epoch 967: Loss 0.070
# Epoch 968: Loss 0.071
# Epoch 969: Loss 0.069
# Epoch 970: Loss 0.070
# Epoch 971: Loss 0.069
# Epoch 972: Loss 0.070
# Epoch 973: Loss 0.070
# Epoch 974: Loss 0.070
# Epoch 975: Loss 0.069
# Epoch 976: Loss 0.070
# Epoch 977: Loss 0.068
# Epoch 978: Loss 0.069
# Epoch 979: Loss 0.069
# Epoch 980: Loss 0.070
# Epoch 981: Loss 0.069
# Epoch 982: Loss 0.069
# Epoch 983: Loss 0.068
# Epoch 984: Loss 0.069
# Epoch 985: Loss 0.068
# Epoch 986: Loss 0.069
# Epoch 987: Loss 0.069
# Epoch 988: Loss 0.068
# Epoch 989: Loss 0.069
# Epoch 990: Loss 0.068
# Epoch 991: Loss 0.068
# Epoch 992: Loss 0.068
# Epoch 993: Loss 0.068
# Epoch 994: Loss 0.070
# Epoch 995: Loss 0.069
# Epoch 996: Loss 0.068
# Epoch 997: Loss 0.068
# Epoch 998: Loss 0.068
# Epoch 999: Loss 0.068
# Epoch 1000: Loss 0.069
# Epoch 1: Loss 0.428
# Epoch 2: Loss 0.277
# Epoch 3: Loss 0.272
# Epoch 4: Loss 0.270
# Epoch 5: Loss 0.269
# Epoch 6: Loss 0.268
# Epoch 7: Loss 0.267
# Epoch 8: Loss 0.266
# Epoch 9: Loss 0.264
# Epoch 10: Loss 0.263
# Epoch 11: Loss 0.262
# Epoch 12: Loss 0.260
# Epoch 13: Loss 0.259
# Epoch 14: Loss 0.257
# Epoch 15: Loss 0.255
# Epoch 16: Loss 0.253
# Epoch 17: Loss 0.252
# Epoch 18: Loss 0.250
# Epoch 19: Loss 0.248
# Epoch 20: Loss 0.246
# Epoch 21: Loss 0.244
# Epoch 22: Loss 0.243
# Epoch 23: Loss 0.241
# Epoch 24: Loss 0.239
# Epoch 25: Loss 0.236
# Epoch 26: Loss 0.234
# Epoch 27: Loss 0.232
# Epoch 28: Loss 0.230
# Epoch 29: Loss 0.228
# Epoch 30: Loss 0.227
# Epoch 31: Loss 0.225
# Epoch 32: Loss 0.223
# Epoch 33: Loss 0.222
# Epoch 34: Loss 0.221
# Epoch 35: Loss 0.220
# Epoch 36: Loss 0.219
# Epoch 37: Loss 0.218
# Epoch 38: Loss 0.217
# Epoch 39: Loss 0.216
# Epoch 40: Loss 0.215
# Epoch 41: Loss 0.215
# Epoch 42: Loss 0.214
# Epoch 43: Loss 0.213
# Epoch 44: Loss 0.213
# Epoch 45: Loss 0.212
# Epoch 46: Loss 0.211
# Epoch 47: Loss 0.210
# Epoch 48: Loss 0.210
# Epoch 49: Loss 0.209
# Epoch 50: Loss 0.209
# Epoch 51: Loss 0.208
# Epoch 52: Loss 0.207
# Epoch 53: Loss 0.207
# Epoch 54: Loss 0.206
# Epoch 55: Loss 0.205
# Epoch 56: Loss 0.204
# Epoch 57: Loss 0.204
# Epoch 58: Loss 0.203
# Epoch 59: Loss 0.203
# Epoch 60: Loss 0.202
# Epoch 61: Loss 0.202
# Epoch 62: Loss 0.201
# Epoch 63: Loss 0.201
# Epoch 64: Loss 0.200
# Epoch 65: Loss 0.199
# Epoch 66: Loss 0.198
# Epoch 67: Loss 0.197
# Epoch 68: Loss 0.196
# Epoch 69: Loss 0.195
# Epoch 70: Loss 0.194
# Epoch 71: Loss 0.194
# Epoch 72: Loss 0.193
# Epoch 73: Loss 0.193
# Epoch 74: Loss 0.192
# Epoch 75: Loss 0.191
# Epoch 76: Loss 0.191
# Epoch 77: Loss 0.191
# Epoch 78: Loss 0.190
# Epoch 79: Loss 0.189
# Epoch 80: Loss 0.189
# Epoch 81: Loss 0.189
# Epoch 82: Loss 0.188
# Epoch 83: Loss 0.187
# Epoch 84: Loss 0.187
# Epoch 85: Loss 0.186
# Epoch 86: Loss 0.186
# Epoch 87: Loss 0.186
# Epoch 88: Loss 0.185
# Epoch 89: Loss 0.185
# Epoch 90: Loss 0.184
# Epoch 91: Loss 0.184
# Epoch 92: Loss 0.184
# Epoch 93: Loss 0.183
# Epoch 94: Loss 0.183
# Epoch 95: Loss 0.182
# Epoch 96: Loss 0.182
# Epoch 97: Loss 0.182
# Epoch 98: Loss 0.181
# Epoch 99: Loss 0.181
# Epoch 100: Loss 0.180
# Epoch 101: Loss 0.180
# Epoch 102: Loss 0.179
# Epoch 103: Loss 0.179
# Epoch 104: Loss 0.178
# Epoch 105: Loss 0.178
# Epoch 106: Loss 0.179
# Epoch 107: Loss 0.178
# Epoch 108: Loss 0.178
# Epoch 109: Loss 0.178
# Epoch 110: Loss 0.177
# Epoch 111: Loss 0.177
# Epoch 112: Loss 0.177
# Epoch 113: Loss 0.176
# Epoch 114: Loss 0.176
# Epoch 115: Loss 0.175
# Epoch 116: Loss 0.174
# Epoch 117: Loss 0.174
# Epoch 118: Loss 0.174
# Epoch 119: Loss 0.173
# Epoch 120: Loss 0.173
# Epoch 121: Loss 0.172
# Epoch 122: Loss 0.172
# Epoch 123: Loss 0.171
# Epoch 124: Loss 0.170
# Epoch 125: Loss 0.170
# Epoch 126: Loss 0.169
# Epoch 127: Loss 0.169
# Epoch 128: Loss 0.168
# Epoch 129: Loss 0.167
# Epoch 130: Loss 0.167
# Epoch 131: Loss 0.166
# Epoch 132: Loss 0.166
# Epoch 133: Loss 0.165
# Epoch 134: Loss 0.164
# Epoch 135: Loss 0.164
# Epoch 136: Loss 0.163
# Epoch 137: Loss 0.162
# Epoch 138: Loss 0.162
# Epoch 139: Loss 0.161
# Epoch 140: Loss 0.161
# Epoch 141: Loss 0.161
# Epoch 142: Loss 0.159
# Epoch 143: Loss 0.160
# Epoch 144: Loss 0.158
# Epoch 145: Loss 0.159
# Epoch 146: Loss 0.158
# Epoch 147: Loss 0.158
# Epoch 148: Loss 0.156
# Epoch 149: Loss 0.155
# Epoch 150: Loss 0.155
# Epoch 151: Loss 0.155
# Epoch 152: Loss 0.154
# Epoch 153: Loss 0.154
# Epoch 154: Loss 0.153
# Epoch 155: Loss 0.152
# Epoch 156: Loss 0.153
# Epoch 157: Loss 0.154
# Epoch 158: Loss 0.152
# Epoch 159: Loss 0.151
# Epoch 160: Loss 0.150
# Epoch 161: Loss 0.151
# Epoch 162: Loss 0.149
# Epoch 163: Loss 0.151
# Epoch 164: Loss 0.150
# Epoch 165: Loss 0.151
# Epoch 166: Loss 0.148
# Epoch 167: Loss 0.149
# Epoch 168: Loss 0.149
# Epoch 169: Loss 0.148
# Epoch 170: Loss 0.147
# Epoch 171: Loss 0.152
# Epoch 172: Loss 0.147
# Epoch 173: Loss 0.146
# Epoch 174: Loss 0.148
# Epoch 175: Loss 0.147
# Epoch 176: Loss 0.147
# Epoch 177: Loss 0.146
# Epoch 178: Loss 0.146
# Epoch 179: Loss 0.146
# Epoch 180: Loss 0.146
# Epoch 181: Loss 0.145
# Epoch 182: Loss 0.148
# Epoch 183: Loss 0.143
# Epoch 184: Loss 0.144
# Epoch 185: Loss 0.141
# Epoch 186: Loss 0.141
# Epoch 187: Loss 0.141
# Epoch 188: Loss 0.146
# Epoch 189: Loss 0.143
# Epoch 190: Loss 0.145
# Epoch 191: Loss 0.142
# Epoch 192: Loss 0.140
# Epoch 193: Loss 0.150
# Epoch 194: Loss 0.149
# Epoch 195: Loss 0.143
# Epoch 196: Loss 0.150
# ...
# Epoch 274: Loss 0.095
# Epoch 275: Loss 0.101
# Epoch 276: Loss 0.108
# Epoch 277: Loss 0.097
# Epoch 278: Loss 0.105
# Epoch 279: Loss 0.114
# Epoch 280: Loss 0.102
# Epoch 281: Loss 0.098
# Epoch 282: Loss 0.109
# Epoch 283: Loss 0.116
# Epoch 284: Loss 0.104
# Epoch 285: Loss 0.092
# Epoch 286: Loss 0.118
# Epoch 287: Loss 0.127
# Epoch 288: Loss 0.100
# Epoch 289: Loss 0.094
# Epoch 290: Loss 0.115
# Epoch 291: Loss 0.102
# Epoch 292: Loss 0.094
# Epoch 293: Loss 0.098
# Epoch 294: Loss 0.111
# Epoch 295: Loss 0.121
# Epoch 296: Loss 0.097
# Epoch 297: Loss 0.115
# Epoch 298: Loss 0.094
# Epoch 299: Loss 0.108
# Epoch 300: Loss 0.104
# Epoch 301: Loss 0.101
# Epoch 302: Loss 0.105
# Epoch 303: Loss 0.091
# Epoch 304: Loss 0.097
# Epoch 305: Loss 0.104
# Epoch 306: Loss 0.095
# Epoch 307: Loss 0.100
# Epoch 308: Loss 0.102
# Epoch 309: Loss 0.100
# Epoch 310: Loss 0.091
# Epoch 311: Loss 0.094
# Epoch 312: Loss 0.097
# Epoch 313: Loss 0.104
# Epoch 314: Loss 0.100
# Epoch 315: Loss 0.097
# Epoch 316: Loss 0.126
# Epoch 317: Loss 0.105
# Epoch 318: Loss 0.099
# Epoch 319: Loss 0.112
# Epoch 320: Loss 0.089
# Epoch 321: Loss 0.116
# Epoch 322: Loss 0.105
# Epoch 323: Loss 0.087
# Epoch 324: Loss 0.101
# Epoch 325: Loss 0.093
# Epoch 326: Loss 0.089
# Epoch 327: Loss 0.104
# Epoch 328: Loss 0.093
# Epoch 329: Loss 0.105
# Epoch 330: Loss 0.124
# Epoch 331: Loss 0.104
# Epoch 332: Loss 0.096
# Epoch 333: Loss 0.093
# Epoch 334: Loss 0.086
# Epoch 335: Loss 0.091
# Epoch 336: Loss 0.098
# Epoch 337: Loss 0.107
# Epoch 338: Loss 0.095
# Epoch 339: Loss 0.098
# Epoch 340: Loss 0.094
# Epoch 341: Loss 0.102
# Epoch 342: Loss 0.105
# Epoch 343: Loss 0.103
# Epoch 344: Loss 0.087
# Epoch 345: Loss 0.084
# Epoch 346: Loss 0.105
# Epoch 347: Loss 0.091
# Epoch 348: Loss 0.094
# Epoch 349: Loss 0.105
# Epoch 350: Loss 0.109
# Epoch 351: Loss 0.100
# Epoch 352: Loss 0.088
# Epoch 353: Loss 0.115
# Epoch 354: Loss 0.103
# Epoch 355: Loss 0.090
# Epoch 356: Loss 0.084
# Epoch 357: Loss 0.086
# Epoch 358: Loss 0.081
# Epoch 359: Loss 0.103
# Epoch 360: Loss 0.091
# Epoch 361: Loss 0.089
# Epoch 362: Loss 0.127
# Epoch 363: Loss 0.095
# Epoch 364: Loss 0.084
# Epoch 365: Loss 0.094
# Epoch 366: Loss 0.089
# Epoch 367: Loss 0.125
# Epoch 368: Loss 0.105
# Epoch 369: Loss 0.084
# Epoch 370: Loss 0.077
# Epoch 371: Loss 0.100
# Epoch 372: Loss 0.078
# Epoch 373: Loss 0.090
# Epoch 374: Loss 0.085
# Epoch 375: Loss 0.096
# Epoch 376: Loss 0.104
# Epoch 377: Loss 0.088
# Epoch 378: Loss 0.083
# Epoch 379: Loss 0.085
# Epoch 380: Loss 0.113
# Epoch 381: Loss 0.103
# Epoch 382: Loss 0.082
# Epoch 383: Loss 0.088
# Epoch 384: Loss 0.078
# Epoch 385: Loss 0.099
# Epoch 386: Loss 0.095
# Epoch 387: Loss 0.082
# Epoch 388: Loss 0.103
# Epoch 389: Loss 0.097
# Epoch 390: Loss 0.079
# Epoch 391: Loss 0.084
# Epoch 392: Loss 0.097
# Epoch 393: Loss 0.107
# Epoch 394: Loss 0.097
# Epoch 395: Loss 0.081
# Epoch 396: Loss 0.082
# Epoch 397: Loss 0.094
# Epoch 398: Loss 0.103
# Epoch 399: Loss 0.082
# Epoch 400: Loss 0.075
# Epoch 401: Loss 0.074
# Epoch 402: Loss 0.079
# Epoch 403: Loss 0.083
# Epoch 404: Loss 0.092
# Epoch 405: Loss 0.081
# Epoch 406: Loss 0.086
# Epoch 407: Loss 0.089
# Epoch 408: Loss 0.087
# Epoch 409: Loss 0.072
# Epoch 410: Loss 0.082
# Epoch 411: Loss 0.091
# Epoch 412: Loss 0.101
# Epoch 413: Loss 0.089
# Epoch 414: Loss 0.094
# Epoch 415: Loss 0.087
# Epoch 416: Loss 0.071
# Epoch 417: Loss 0.077
# Epoch 418: Loss 0.095
# Epoch 419: Loss 0.093
# Epoch 420: Loss 0.089
# Epoch 421: Loss 0.116
# Epoch 422: Loss 0.098
# Epoch 423: Loss 0.083
# Epoch 424: Loss 0.077
# Epoch 425: Loss 0.074
# Epoch 426: Loss 0.078
# Epoch 427: Loss 0.071
# Epoch 428: Loss 0.098
# Epoch 429: Loss 0.092
# Epoch 430: Loss 0.076
# Epoch 431: Loss 0.082
# Epoch 432: Loss 0.088
# Epoch 433: Loss 0.071
# Epoch 434: Loss 0.077
# Epoch 435: Loss 0.078
# Epoch 436: Loss 0.110
# Epoch 437: Loss 0.086
# Epoch 438: Loss 0.069
# Epoch 439: Loss 0.076
# Epoch 440: Loss 0.071
# Epoch 441: Loss 0.075
# Epoch 442: Loss 0.081
# Epoch 443: Loss 0.084
# Epoch 444: Loss 0.095
# Epoch 445: Loss 0.078
# Epoch 446: Loss 0.118
# Epoch 447: Loss 0.075
# Epoch 448: Loss 0.086
# Epoch 449: Loss 0.081
# Epoch 450: Loss 0.144
# Epoch 451: Loss 0.118
# Epoch 452: Loss 0.090
# Epoch 453: Loss 0.087
# Epoch 454: Loss 0.073
# Epoch 455: Loss 0.080
# Epoch 456: Loss 0.065
# Epoch 457: Loss 0.072
# Epoch 458: Loss 0.074
# Epoch 459: Loss 0.075
# Epoch 460: Loss 0.088
# Epoch 461: Loss 0.074
# Epoch 462: Loss 0.069
# Epoch 463: Loss 0.079
# Epoch 464: Loss 0.078
# Epoch 465: Loss 0.080
# Epoch 466: Loss 0.079
# Epoch 467: Loss 0.081
# Epoch 468: Loss 0.070
# Epoch 469: Loss 0.080
# Epoch 470: Loss 0.075
# Epoch 471: Loss 0.071
# Epoch 472: Loss 0.067
# Epoch 473: Loss 0.081
# Epoch 474: Loss 0.074
# Epoch 475: Loss 0.111
# Epoch 476: Loss 0.069
# Epoch 477: Loss 0.084
# Epoch 478: Loss 0.071
# Epoch 479: Loss 0.066
# Epoch 480: Loss 0.081
# Epoch 481: Loss 0.074
# Epoch 482: Loss 0.090
# Epoch 483: Loss 0.075
# Epoch 484: Loss 0.068
# Epoch 485: Loss 0.065
# Epoch 486: Loss 0.120
# Epoch 487: Loss 0.095
# Epoch 488: Loss 0.077
# Epoch 489: Loss 0.067
# Epoch 490: Loss 0.126
# Epoch 491: Loss 0.090
# Epoch 492: Loss 0.080
# Epoch 493: Loss 0.073
# Epoch 494: Loss 0.063
# Epoch 495: Loss 0.067
# Epoch 496: Loss 0.066
# Epoch 497: Loss 0.070
# Epoch 498: Loss 0.063
# Epoch 499: Loss 0.066
# Epoch 500: Loss 0.071
# Epoch 501: Loss 0.071
# Epoch 502: Loss 0.068
# Epoch 503: Loss 0.081
# Epoch 504: Loss 0.077
# Epoch 505: Loss 0.072
# Epoch 506: Loss 0.067
# Epoch 507: Loss 0.073
# Epoch 508: Loss 0.091
# Epoch 509: Loss 0.085
# Epoch 510: Loss 0.115
# Epoch 511: Loss 0.081
# Epoch 512: Loss 0.071
# Epoch 513: Loss 0.074
# Epoch 514: Loss 0.066
# Epoch 515: Loss 0.137
# Epoch 516: Loss 0.109
# Epoch 517: Loss 0.084
# Epoch 518: Loss 0.076
# Epoch 519: Loss 0.072
# Epoch 520: Loss 0.072
# Epoch 521: Loss 0.073
# Epoch 522: Loss 0.069
# Epoch 523: Loss 0.064
# Epoch 524: Loss 0.074
# Epoch 525: Loss 0.062
# Epoch 526: Loss 0.060
# Epoch 527: Loss 0.059
# Epoch 528: Loss 0.067
# Epoch 529: Loss 0.062
# Epoch 530: Loss 0.076
# Epoch 531: Loss 0.069
# Epoch 532: Loss 0.061
# Epoch 533: Loss 0.065
# Epoch 534: Loss 0.061
# Epoch 535: Loss 0.066
# Epoch 536: Loss 0.073
# Epoch 537: Loss 0.061
# Epoch 538: Loss 0.062
# Epoch 539: Loss 0.111
# Epoch 540: Loss 0.101
# Epoch 541: Loss 0.072
# Epoch 542: Loss 0.096
# Epoch 543: Loss 0.066
# Epoch 544: Loss 0.059
# Epoch 545: Loss 0.066
# Epoch 546: Loss 0.066
# Epoch 547: Loss 0.054
# Epoch 548: Loss 0.072
# Epoch 549: Loss 0.065
# Epoch 550: Loss 0.073
# Epoch 551: Loss 0.056
# Epoch 552: Loss 0.053
# Epoch 553: Loss 0.057
# Epoch 554: Loss 0.077
# Epoch 555: Loss 0.053
# Epoch 556: Loss 0.072
# Epoch 557: Loss 0.068
# Epoch 558: Loss 0.139
# Epoch 559: Loss 0.103
# Epoch 560: Loss 0.069
# Epoch 561: Loss 0.068
# Epoch 562: Loss 0.065
# Epoch 563: Loss 0.057
# Epoch 564: Loss 0.058
# Epoch 565: Loss 0.064
# Epoch 566: Loss 0.056
# Epoch 567: Loss 0.060
# Epoch 568: Loss 0.063
# Epoch 569: Loss 0.066
# Epoch 570: Loss 0.077
# Epoch 571: Loss 0.063
# Epoch 572: Loss 0.071
# Epoch 573: Loss 0.057
# Epoch 574: Loss 0.055
# Epoch 575: Loss 0.053
# Epoch 576: Loss 0.078
# Epoch 577: Loss 0.051
# Epoch 578: Loss 0.053
# Epoch 579: Loss 0.056
# Epoch 580: Loss 0.062
# Epoch 581: Loss 0.079
# Epoch 582: Loss 0.057
# Epoch 583: Loss 0.054
# Epoch 584: Loss 0.047
# Epoch 585: Loss 0.067
# Epoch 586: Loss 0.077
# Epoch 587: Loss 0.068
# Epoch 588: Loss 0.084
# Epoch 589: Loss 0.076
# Epoch 590: Loss 0.092
# Epoch 591: Loss 0.051
# Epoch 592: Loss 0.073
# Epoch 593: Loss 0.054
# Epoch 594: Loss 0.054
# Epoch 595: Loss 0.065
# Epoch 596: Loss 0.050
# Epoch 597: Loss 0.063
# Epoch 598: Loss 0.047
# Epoch 599: Loss 0.062
# Epoch 600: Loss 0.077
# Epoch 601: Loss 0.070
# Epoch 602: Loss 0.080
# Epoch 603: Loss 0.053
# Epoch 604: Loss 0.065
# Epoch 605: Loss 0.052
# Epoch 606: Loss 0.066
# Epoch 607: Loss 0.048
# Epoch 608: Loss 0.065
# Epoch 609: Loss 0.046
# Epoch 610: Loss 0.055
# Epoch 611: Loss 0.054
# Epoch 612: Loss 0.059
# Epoch 613: Loss 0.056
# Epoch 614: Loss 0.069
# Epoch 615: Loss 0.053
# Epoch 616: Loss 0.051
# Epoch 617: Loss 0.064
# Epoch 618: Loss 0.061
# Epoch 619: Loss 0.062
# Epoch 620: Loss 0.056
# Epoch 621: Loss 0.147
# Epoch 622: Loss 0.066
# Epoch 623: Loss 0.057
# Epoch 624: Loss 0.070
# Epoch 625: Loss 0.065
# Epoch 626: Loss 0.074
# Epoch 627: Loss 0.069
# Epoch 628: Loss 0.062
# Epoch 629: Loss 0.059
# Epoch 630: Loss 0.061
# Epoch 631: Loss 0.063
# Epoch 632: Loss 0.054
# Epoch 633: Loss 0.056
# Epoch 634: Loss 0.046
# Epoch 635: Loss 0.046
# Epoch 636: Loss 0.046
# Epoch 637: Loss 0.058
# Epoch 638: Loss 0.047
# Epoch 639: Loss 0.059
# Epoch 640: Loss 0.052
# Epoch 641: Loss 0.064
# Epoch 642: Loss 0.065
# Epoch 643: Loss 0.052
# Epoch 644: Loss 0.058
# Epoch 645: Loss 0.052
# Epoch 646: Loss 0.049
# Epoch 647: Loss 0.045
# Epoch 648: Loss 0.046
# Epoch 649: Loss 0.049
# Epoch 650: Loss 0.047
# Epoch 651: Loss 0.066
# Epoch 652: Loss 0.059
# Epoch 653: Loss 0.068
# Epoch 654: Loss 0.086
# Epoch 655: Loss 0.062
# Epoch 656: Loss 0.064
# Epoch 657: Loss 0.051
# Epoch 658: Loss 0.086
# Epoch 659: Loss 0.083
# Epoch 660: Loss 0.049
# Epoch 661: Loss 0.051
# Epoch 662: Loss 0.094
# Epoch 663: Loss 0.098
# Epoch 664: Loss 0.051
# Epoch 665: Loss 0.040
# Epoch 666: Loss 0.071
# Epoch 667: Loss 0.050
# Epoch 668: Loss 0.050
# Epoch 669: Loss 0.043
# Epoch 670: Loss 0.043
# Epoch 671: Loss 0.050
# Epoch 672: Loss 0.040
# Epoch 673: Loss 0.061
# Epoch 674: Loss 0.065
# Epoch 675: Loss 0.063
# Epoch 676: Loss 0.044
# Epoch 677: Loss 0.043
# Epoch 678: Loss 0.042
# Epoch 679: Loss 0.039
# Epoch 680: Loss 0.049
# Epoch 681: Loss 0.058
# Epoch 682: Loss 0.058
# Epoch 683: Loss 0.072
# Epoch 684: Loss 0.066
# Epoch 685: Loss 0.077
# Epoch 686: Loss 0.046
# Epoch 687: Loss 0.045
# Epoch 688: Loss 0.048
# Epoch 689: Loss 0.043
# Epoch 690: Loss 0.055
# Epoch 691: Loss 0.115
# Epoch 692: Loss 0.100
# Epoch 693: Loss 0.057
# Epoch 694: Loss 0.041
# Epoch 695: Loss 0.045
# Epoch 696: Loss 0.050
# Epoch 697: Loss 0.077
# Epoch 698: Loss 0.046
# Epoch 699: Loss 0.044
# Epoch 700: Loss 0.042
# Epoch 701: Loss 0.049
# Epoch 702: Loss 0.052
# Epoch 703: Loss 0.038
# Epoch 704: Loss 0.036
# Epoch 705: Loss 0.044
# Epoch 706: Loss 0.060
# Epoch 707: Loss 0.083
# Epoch 708: Loss 0.051
# Epoch 709: Loss 0.039
# Epoch 710: Loss 0.038
# Epoch 711: Loss 0.045
# Epoch 712: Loss 0.037
# Epoch 713: Loss 0.051
# Epoch 714: Loss 0.051
# Epoch 715: Loss 0.048
# Epoch 716: Loss 0.054
# Epoch 717: Loss 0.056
# Epoch 718: Loss 0.040
# Epoch 719: Loss 0.036
# Epoch 720: Loss 0.042
# Epoch 721: Loss 0.035
# Epoch 722: Loss 0.046
# Epoch 723: Loss 0.039
# Epoch 724: Loss 0.044
# Epoch 725: Loss 0.037
# Epoch 726: Loss 0.048
# Epoch 727: Loss 0.103
# Epoch 728: Loss 0.066
# Epoch 729: Loss 0.072
# Epoch 730: Loss 0.048
# Epoch 731: Loss 0.038
# Epoch 732: Loss 0.041
# Epoch 733: Loss 0.038
# Epoch 734: Loss 0.047
# Epoch 735: Loss 0.048
# Epoch 736: Loss 0.046
# Epoch 737: Loss 0.035
# Epoch 738: Loss 0.035
# Epoch 739: Loss 0.030
# Epoch 740: Loss 0.033
# Epoch 741: Loss 0.054
# Epoch 742: Loss 0.042
# Epoch 743: Loss 0.049
# Epoch 744: Loss 0.154
# Epoch 745: Loss 0.064
# Epoch 746: Loss 0.049
# Epoch 747: Loss 0.049
# Epoch 748: Loss 0.043
# Epoch 749: Loss 0.039
# Epoch 750: Loss 0.037
# Epoch 751: Loss 0.044
# Epoch 752: Loss 0.046
# Epoch 753: Loss 0.055
# Epoch 754: Loss 0.050
# Epoch 755: Loss 0.055
# Epoch 756: Loss 0.041
# Epoch 757: Loss 0.048
# Epoch 758: Loss 0.061
# Epoch 759: Loss 0.059
# Epoch 760: Loss 0.052
# Epoch 761: Loss 0.051
# Epoch 762: Loss 0.039
# Epoch 763: Loss 0.052
# Epoch 764: Loss 0.039
# Epoch 765: Loss 0.050
# Epoch 766: Loss 0.045
# Epoch 767: Loss 0.036
# Epoch 768: Loss 0.032
# Epoch 769: Loss 0.037
# Epoch 770: Loss 0.056
# Epoch 771: Loss 0.041
# Epoch 772: Loss 0.051
# Epoch 773: Loss 0.047
# Epoch 774: Loss 0.050
# Epoch 775: Loss 0.064
# Epoch 776: Loss 0.058
# Epoch 777: Loss 0.050
# Epoch 778: Loss 0.052
# Epoch 779: Loss 0.037
# Epoch 780: Loss 0.033
# Epoch 781: Loss 0.036
# Epoch 782: Loss 0.032
# Epoch 783: Loss 0.029
# Epoch 784: Loss 0.028
# Epoch 785: Loss 0.028
# Epoch 786: Loss 0.050
# Epoch 787: Loss 0.035
# Epoch 788: Loss 0.031
# Epoch 789: Loss 0.044
# Epoch 790: Loss 0.029
# Epoch 791: Loss 0.056
# Epoch 792: Loss 0.058
# Epoch 793: Loss 0.060
# Epoch 794: Loss 0.118
# Epoch 795: Loss 0.053
# Epoch 796: Loss 0.034
# Epoch 797: Loss 0.033
# Epoch 798: Loss 0.039
# Epoch 799: Loss 0.026
# Epoch 800: Loss 0.026
# Epoch 801: Loss 0.035
# Epoch 802: Loss 0.040
# Epoch 803: Loss 0.032
# Epoch 804: Loss 0.054
# Epoch 805: Loss 0.056
# Epoch 806: Loss 0.056
# Epoch 807: Loss 0.057
# Epoch 808: Loss 0.065
# Epoch 809: Loss 0.036
# Epoch 810: Loss 0.040
# Epoch 811: Loss 0.035
# Epoch 812: Loss 0.036
# Epoch 813: Loss 0.039
# Epoch 814: Loss 0.054
# Epoch 815: Loss 0.057
# Epoch 816: Loss 0.086
# Epoch 817: Loss 0.103
# Epoch 818: Loss 0.055
# Epoch 819: Loss 0.058
# Epoch 820: Loss 0.053
# Epoch 821: Loss 0.068
# Epoch 822: Loss 0.054
# Epoch 823: Loss 0.037
# Epoch 824: Loss 0.035
# Epoch 825: Loss 0.041
# Epoch 826: Loss 0.042
# Epoch 827: Loss 0.040
# Epoch 828: Loss 0.053
# Epoch 829: Loss 0.038
# Epoch 830: Loss 0.045
# Epoch 831: Loss 0.070
# Epoch 832: Loss 0.069
# Epoch 833: Loss 0.046
# Epoch 834: Loss 0.037
# Epoch 835: Loss 0.041
# Epoch 836: Loss 0.039
# Epoch 837: Loss 0.048
# Epoch 838: Loss 0.052
# Epoch 839: Loss 0.036
# Epoch 840: Loss 0.050
# Epoch 841: Loss 0.030
# Epoch 842: Loss 0.040
# Epoch 843: Loss 0.041
# Epoch 844: Loss 0.041
# Epoch 845: Loss 0.042
# Epoch 846: Loss 0.057
# Epoch 847: Loss 0.059
# Epoch 848: Loss 0.059
# Epoch 849: Loss 0.037
# Epoch 850: Loss 0.031
# Epoch 851: Loss 0.046
# Epoch 852: Loss 0.035
# Epoch 853: Loss 0.045
# Epoch 854: Loss 0.050
# Epoch 855: Loss 0.033
# Epoch 856: Loss 0.041
# Epoch 857: Loss 0.044
# Epoch 858: Loss 0.169
# Epoch 859: Loss 0.038
# Epoch 860: Loss 0.036
# Epoch 861: Loss 0.035
# Epoch 862: Loss 0.028
# Epoch 863: Loss 0.048
# Epoch 864: Loss 0.047
# Epoch 865: Loss 0.044
# Epoch 866: Loss 0.055
# Epoch 867: Loss 0.062
# Epoch 868: Loss 0.071
# Epoch 869: Loss 0.050
# Epoch 870: Loss 0.031
# Epoch 871: Loss 0.052
# Epoch 872: Loss 0.032
# Epoch 873: Loss 0.032
# Epoch 874: Loss 0.039
# Epoch 875: Loss 0.031
# Epoch 876: Loss 0.028
# Epoch 877: Loss 0.037
# Epoch 878: Loss 0.049
# Epoch 879: Loss 0.050
# Epoch 880: Loss 0.042
# Epoch 881: Loss 0.056
# Epoch 882: Loss 0.039
# Epoch 883: Loss 0.043
# Epoch 884: Loss 0.038
# Epoch 885: Loss 0.037
# Epoch 886: Loss 0.039
# Epoch 887: Loss 0.061
# Epoch 888: Loss 0.059
# Epoch 889: Loss 0.048
# Epoch 890: Loss 0.047
# Epoch 891: Loss 0.046
# Epoch 892: Loss 0.048
# Epoch 893: Loss 0.028
# Epoch 894: Loss 0.034
# Epoch 895: Loss 0.046
# Epoch 896: Loss 0.046
# Epoch 897: Loss 0.031
# Epoch 898: Loss 0.027
# Epoch 899: Loss 0.028
# Epoch 900: Loss 0.069
# Epoch 901: Loss 0.046
# Epoch 902: Loss 0.030
# Epoch 903: Loss 0.044
# Epoch 904: Loss 0.031
# Epoch 905: Loss 0.050
# Epoch 906: Loss 0.036
# Epoch 907: Loss 0.028
# Epoch 908: Loss 0.025
# Epoch 909: Loss 0.062
# Epoch 910: Loss 0.061
# Epoch 911: Loss 0.050
# Epoch 912: Loss 0.033
# Epoch 913: Loss 0.033
# Epoch 914: Loss 0.032
# Epoch 915: Loss 0.059
# Epoch 916: Loss 0.034
# Epoch 917: Loss 0.028
# Epoch 918: Loss 0.034
# Epoch 919: Loss 0.027
# Epoch 920: Loss 0.035
# Epoch 921: Loss 0.027
# Epoch 922: Loss 0.023
# Epoch 923: Loss 0.023
# Epoch 924: Loss 0.026
# Epoch 925: Loss 0.023
# Epoch 926: Loss 0.041
# Epoch 927: Loss 0.179
# Epoch 928: Loss 0.108
# Epoch 929: Loss 0.044
# Epoch 930: Loss 0.038
# Epoch 931: Loss 0.034
# Epoch 932: Loss 0.039
# Epoch 933: Loss 0.027
# Epoch 934: Loss 0.033
# Epoch 935: Loss 0.031
# Epoch 936: Loss 0.024
# Epoch 937: Loss 0.024
# Epoch 938: Loss 0.030
# Epoch 939: Loss 0.030
# Epoch 940: Loss 0.032
# Epoch 941: Loss 0.028
# Epoch 942: Loss 0.071
# Epoch 943: Loss 0.063
# Epoch 944: Loss 0.040
# Epoch 945: Loss 0.028
# Epoch 946: Loss 0.037
# Epoch 947: Loss 0.024
# Epoch 948: Loss 0.022
# Epoch 949: Loss 0.034
# Epoch 950: Loss 0.039
# Epoch 951: Loss 0.034
# Epoch 952: Loss 0.035
# Epoch 953: Loss 0.030
# Epoch 954: Loss 0.034
# Epoch 955: Loss 0.031
# Epoch 956: Loss 0.052
# Epoch 957: Loss 0.040
# Epoch 958: Loss 0.033
# Epoch 959: Loss 0.031
# Epoch 960: Loss 0.031
# Epoch 961: Loss 0.065
# Epoch 962: Loss 0.034
# Epoch 963: Loss 0.048
# Epoch 964: Loss 0.030
# Epoch 965: Loss 0.026
# Epoch 966: Loss 0.039
# Epoch 967: Loss 0.032
# Epoch 968: Loss 0.035
# Epoch 969: Loss 0.029
# Epoch 970: Loss 0.029
# Epoch 971: Loss 0.024
# Epoch 972: Loss 0.030
# Epoch 973: Loss 0.034
# Epoch 974: Loss 0.027
# Epoch 975: Loss 0.023
# Epoch 976: Loss 0.024
# Epoch 977: Loss 0.024
# Epoch 978: Loss 0.050
# Epoch 979: Loss 0.026
# Epoch 980: Loss 0.033
# Epoch 981: Loss 0.026
# Epoch 982: Loss 0.020
# Epoch 983: Loss 0.029
# Epoch 984: Loss 0.039
# Epoch 985: Loss 0.021
# Epoch 986: Loss 0.025
# Epoch 987: Loss 0.020
# Epoch 988: Loss 0.026
# Epoch 989: Loss 0.029
# Epoch 990: Loss 0.033
# Epoch 991: Loss 0.022
# Epoch 992: Loss 0.033
# Epoch 993: Loss 0.023
# Epoch 994: Loss 0.053
# Epoch 995: Loss 0.070
# Epoch 996: Loss 0.040
# Epoch 997: Loss 0.024
# Epoch 998: Loss 0.057
# Epoch 999: Loss 0.082
# Epoch 1000: Loss 0.049

# %%
fig, axs = plt.subplots(len(number_hidden_layers),max(number_hidden_layers)+2,figsize=(12,8),layout='constrained')

for k, num_h_layers in enumerate(number_hidden_layers):
    axs[k,0].scatter(X[:,0], X[:,1],c=dot_matrices[k][0])
    for n in range(num_h_layers):
        axs[k,1+n].scatter(X[:,0], X[:,1],c=dot_matrices[k][1][n])
    pcm=axs[k,num_h_layers+1].scatter(X[:,0], X[:,1],c=dot_matrices[k][-1])
    fig.colorbar(pcm, ax=axs[k,:])

plt.savefig('plots/Stiffness_depth.png')
