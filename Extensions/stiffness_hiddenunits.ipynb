# %%
import torch
import torch.nn as nn
from torch.optim import SGD

import numpy as np
from numpy import dot
import matplotlib.pyplot as plt

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_sizes, output_size):
        super(NeuralNet, self).__init__()
        self.hidden = nn.ModuleList()
        self.input_layer = nn.Linear(input_size, hidden_sizes[0])
        for k in range(len(hidden_sizes)-1):
            self.hidden.append(nn.Linear(hidden_sizes[k], hidden_sizes[k+1]))
        self.output_layer = nn.Linear(hidden_sizes[-1], output_size)
        
    
    def forward(self, x):
        x=self.input_layer(x)
        x=x.relu()
        for layer in self.hidden:
            x=layer(x)
            x=x.relu()
        x=self.output_layer(x)
        return x

    
def ReLU_glorot_init(model):
    for name, param in model.named_parameters():
        
        if name.endswith(".bias"):
            param.data.fill_(0)
        else:
            nn.init.xavier_normal_(param)

# %%
RES=50
X=[]
for x_1 in np.linspace(-1,1,RES):
    for x_2 in np.linspace(-1,1,RES):
        X.append([x_1,x_2])
X=np.array(X)

encode_inputs=lambda x: 1 if (abs((x[0]+0.25)**2+x[1]**2-0.25)<0.05 and x[1]<0.1) or (abs((x[0]-0.25)**2+x[1]**2-0.25)<0.05 and x[1]>-0.1) else 0
Y=np.array([encode_inputs(x) for x in X])

X=torch.from_numpy(X).float()
Y=torch.from_numpy(Y).float()


colors=np.full(len(Y), 'cadetblue')
colors[Y==0]='teal'

plt.scatter(X[:,0],X[:,1],c=colors)

# %%
def random_sample(X,Y,size=5):
    ind_zeros=np.array([k for k in range(len(X)) if Y[k]==0])
    ind_ones=np.array([k for k in range(len(X)) if Y[k]==1])
    return np.concatenate((np.random.choice(ind_zeros,size=size),np.random.choice(ind_ones,size=size)))

# %%
def layer_stiffness(epochs,learning_rate,batch_size,hidden_sizes,init=False):
    model = NeuralNet(2,hidden_sizes,2)
    ReLU_glorot_init(model)

    def next_batch(inputs, targets, batchSize):
        for i in range(0, inputs.shape[0], batchSize):
            yield (inputs[i:i + batchSize], targets[i:i + batchSize])

    opt = SGD(model.parameters(), lr=learning_rate)
    lossFunc = nn.CrossEntropyLoss()

    def training():
        trainLoss = 0
        samples = 0
        model.train()
        for batchX, batchY in next_batch(X, Y, batch_size):
            predictions = model(batchX)
            loss = lossFunc(predictions, batchY.long())
            opt.zero_grad()
            loss.backward()
            opt.step()
            samples += len(batchY)
            trainLoss += loss.item()*len(batchY)
        return trainLoss/samples

    def get_dots():
        N_h=len(model.hidden)
        grads_input_layer=[]
        grads_hidden_layers=[[] for n in range(N_h)]
        grads_output_layer=[]

        for x,y in zip(X,Y):
            predictions = model(x)
            loss = lossFunc(predictions, y.long())
            opt.zero_grad()
            loss.backward()

            gradient_input_layer=[]
            gradient_input_layer+=torch.flatten(model.input_layer.weight.grad).tolist()
            gradient_input_layer+=model.input_layer.bias.grad.tolist()
            gradient_input_layer=np.array(gradient_input_layer)
            if np.linalg.norm(gradient_input_layer)!=0:
                grads_input_layer.append(gradient_input_layer/np.linalg.norm(gradient_input_layer))
            else:
                grads_input_layer.append(gradient_input_layer)

            for k,h_layer in enumerate(model.hidden):
                gradient=[]
                gradient+=torch.flatten(h_layer.weight.grad).tolist()
                gradient+=h_layer.bias.grad.tolist()
                gradient=np.array(gradient)
                if np.linalg.norm(gradient)!=0:
                    grads_hidden_layers[k].append(gradient/np.linalg.norm(gradient))
                else:
                    grads_hidden_layers[k].append(gradient)

            gradient_output_layer=[]
            gradient_output_layer+=torch.flatten(model.output_layer.weight.grad).tolist()
            gradient_output_layer+=model.output_layer.bias.grad.tolist()
            gradient_output_layer=np.array(gradient_output_layer)
            if np.linalg.norm(gradient_output_layer)!=0:
                grads_output_layer.append(gradient_output_layer/np.linalg.norm(gradient_output_layer))
            else:
                grads_output_layer.append(gradient_output_layer)

        dot_matrix_input_layer=[]
        dot_matrix_hidden_layers=[[] for n in range(N_h)]
        dot_matrix_output_layer=[]
        for i in range(len(X)):
            avg_dot_input=0
            avg_dot_hidden=np.zeros(N_h)
            avg_dot_output=0
            samples=0
            sample_ind=random_sample(X,Y,size=10)
            for j in sample_ind:        
                avg_dot_input+=np.dot(grads_input_layer[i],grads_input_layer[j])
                for k in range(N_h):
                    avg_dot_hidden[k]+=np.dot(grads_hidden_layers[k][i],grads_hidden_layers[k][j])
                avg_dot_output+=np.dot(grads_output_layer[i],grads_output_layer[j])
                samples+=1
            
            dot_matrix_input_layer.append(avg_dot_input/samples)
            for k,avg_dot in enumerate(avg_dot_hidden):
                dot_matrix_hidden_layers[k].append(avg_dot/samples)
            dot_matrix_output_layer.append(avg_dot_output/samples)
    
        return dot_matrix_input_layer, dot_matrix_hidden_layers, dot_matrix_output_layer
    if init:
        init_input_matrix,init_hidden_matrices,init_output_matrix=get_dots()
    for n in range(epochs):
        l=training()
        print('Epoch {}: Loss {:.3f}'.format(n+1,l))
        if l<0.01:
            break
    input_matrix,hidden_matrix,output_matrix=get_dots()
    if init:
        return init_input_matrix,init_hidden_matrices,init_output_matrix,input_matrix,hidden_matrix,output_matrix
    return input_matrix,hidden_matrix,output_matrix

# %%
hidden_layers=[[64,8,4],[8,64,8],[64,8,64]]

dot_matrices=[]

for hidden_layer in hidden_layers:
    D_1,D_2,D_3=layer_stiffness(1000,0.1,100,hidden_layer,False)
    dot_matrices.append([D_1,D_2,D_3])
# Out:
# Epoch 1: Loss 0.365
# Epoch 2: Loss 0.270
# Epoch 3: Loss 0.267
# Epoch 4: Loss 0.266
# Epoch 5: Loss 0.264
# Epoch 6: Loss 0.262
# Epoch 7: Loss 0.260
# Epoch 8: Loss 0.258
# Epoch 9: Loss 0.257
# Epoch 10: Loss 0.255
# Epoch 11: Loss 0.253
# Epoch 12: Loss 0.251
# Epoch 13: Loss 0.250
# Epoch 14: Loss 0.248
# Epoch 15: Loss 0.246
# Epoch 16: Loss 0.244
# Epoch 17: Loss 0.242
# Epoch 18: Loss 0.240
# Epoch 19: Loss 0.238
# Epoch 20: Loss 0.236
# Epoch 21: Loss 0.235
# Epoch 22: Loss 0.233
# Epoch 23: Loss 0.232
# Epoch 24: Loss 0.230
# Epoch 25: Loss 0.228
# Epoch 26: Loss 0.227
# Epoch 27: Loss 0.226
# Epoch 28: Loss 0.224
# Epoch 29: Loss 0.223
# Epoch 30: Loss 0.222
# Epoch 31: Loss 0.221
# Epoch 32: Loss 0.220
# Epoch 33: Loss 0.219
# Epoch 34: Loss 0.219
# Epoch 35: Loss 0.218
# Epoch 36: Loss 0.217
# Epoch 37: Loss 0.217
# Epoch 38: Loss 0.216
# Epoch 39: Loss 0.215
# Epoch 40: Loss 0.214
# Epoch 41: Loss 0.214
# Epoch 42: Loss 0.213
# Epoch 43: Loss 0.212
# Epoch 44: Loss 0.212
# Epoch 45: Loss 0.211
# Epoch 46: Loss 0.211
# Epoch 47: Loss 0.209
# Epoch 48: Loss 0.209
# Epoch 49: Loss 0.209
# Epoch 50: Loss 0.208
# Epoch 51: Loss 0.208
# Epoch 52: Loss 0.206
# Epoch 53: Loss 0.206
# Epoch 54: Loss 0.205
# Epoch 55: Loss 0.205
# Epoch 56: Loss 0.204
# Epoch 57: Loss 0.203
# Epoch 58: Loss 0.203
# Epoch 59: Loss 0.203
# Epoch 60: Loss 0.202
# Epoch 61: Loss 0.201
# Epoch 62: Loss 0.200
# Epoch 63: Loss 0.199
# Epoch 64: Loss 0.199
# Epoch 65: Loss 0.198
# Epoch 66: Loss 0.198
# Epoch 67: Loss 0.197
# Epoch 68: Loss 0.196
# Epoch 69: Loss 0.196
# Epoch 70: Loss 0.195
# Epoch 71: Loss 0.194
# Epoch 72: Loss 0.195
# Epoch 73: Loss 0.194
# Epoch 74: Loss 0.192
# Epoch 75: Loss 0.191
# Epoch 76: Loss 0.190
# Epoch 77: Loss 0.190
# Epoch 78: Loss 0.190
# Epoch 79: Loss 0.188
# Epoch 80: Loss 0.189
# Epoch 81: Loss 0.189
# Epoch 82: Loss 0.187
# Epoch 83: Loss 0.187
# Epoch 84: Loss 0.186
# Epoch 85: Loss 0.185
# Epoch 86: Loss 0.185
# Epoch 87: Loss 0.184
# Epoch 88: Loss 0.184
# Epoch 89: Loss 0.183
# Epoch 90: Loss 0.183
# Epoch 91: Loss 0.182
# Epoch 92: Loss 0.181
# Epoch 93: Loss 0.182
# Epoch 94: Loss 0.181
# Epoch 95: Loss 0.180
# Epoch 96: Loss 0.179
# Epoch 97: Loss 0.179
# Epoch 98: Loss 0.179
# Epoch 99: Loss 0.178
# Epoch 100: Loss 0.178
# Epoch 101: Loss 0.177
# Epoch 102: Loss 0.176
# Epoch 103: Loss 0.175
# Epoch 104: Loss 0.175
# Epoch 105: Loss 0.174
# Epoch 106: Loss 0.173
# Epoch 107: Loss 0.173
# Epoch 108: Loss 0.171
# Epoch 109: Loss 0.173
# Epoch 110: Loss 0.172
# Epoch 111: Loss 0.170
# Epoch 112: Loss 0.169
# Epoch 113: Loss 0.169
# Epoch 114: Loss 0.168
# Epoch 115: Loss 0.169
# Epoch 116: Loss 0.168
# Epoch 117: Loss 0.166
# Epoch 118: Loss 0.166
# Epoch 119: Loss 0.165
# Epoch 120: Loss 0.165
# Epoch 121: Loss 0.165
# Epoch 122: Loss 0.164
# Epoch 123: Loss 0.163
# Epoch 124: Loss 0.162
# Epoch 125: Loss 0.161
# Epoch 126: Loss 0.162
# Epoch 127: Loss 0.161
# Epoch 128: Loss 0.161
# Epoch 129: Loss 0.161
# Epoch 130: Loss 0.159
# Epoch 131: Loss 0.159
# Epoch 132: Loss 0.158
# Epoch 133: Loss 0.158
# Epoch 134: Loss 0.155
# Epoch 135: Loss 0.155
# Epoch 136: Loss 0.160
# Epoch 137: Loss 0.159
# Epoch 138: Loss 0.155
# Epoch 139: Loss 0.157
# Epoch 140: Loss 0.155
# Epoch 141: Loss 0.156
# Epoch 142: Loss 0.158
# Epoch 143: Loss 0.158
# Epoch 144: Loss 0.158
# Epoch 145: Loss 0.173
# Epoch 146: Loss 0.154
# Epoch 147: Loss 0.151
# Epoch 148: Loss 0.155
# Epoch 149: Loss 0.156
# Epoch 150: Loss 0.165
# Epoch 151: Loss 0.153
# Epoch 152: Loss 0.150
# Epoch 153: Loss 0.154
# Epoch 154: Loss 0.154
# Epoch 155: Loss 0.178
# Epoch 156: Loss 0.160
# Epoch 157: Loss 0.160
# Epoch 158: Loss 0.162
# Epoch 159: Loss 0.157
# Epoch 160: Loss 0.174
# Epoch 161: Loss 0.152
# Epoch 162: Loss 0.151
# Epoch 163: Loss 0.153
# Epoch 164: Loss 0.150
# Epoch 165: Loss 0.150
# Epoch 166: Loss 0.161
# Epoch 167: Loss 0.149
# Epoch 168: Loss 0.146
# Epoch 169: Loss 0.153
# Epoch 170: Loss 0.169
# Epoch 171: Loss 0.150
# Epoch 172: Loss 0.146
# Epoch 173: Loss 0.149
# Epoch 174: Loss 0.149
# Epoch 175: Loss 0.166
# Epoch 176: Loss 0.148
# Epoch 177: Loss 0.148
# Epoch 178: Loss 0.149
# Epoch 179: Loss 0.147
# Epoch 180: Loss 0.148
# Epoch 181: Loss 0.148
# Epoch 182: Loss 0.145
# Epoch 183: Loss 0.143
# Epoch 184: Loss 0.151
# Epoch 185: Loss 0.150
# Epoch 186: Loss 0.152
# Epoch 187: Loss 0.143
# Epoch 188: Loss 0.144
# Epoch 189: Loss 0.145
# Epoch 190: Loss 0.139
# Epoch 191: Loss 0.141
# Epoch 192: Loss 0.139
# Epoch 193: Loss 0.143
# Epoch 194: Loss 0.138
# Epoch 195: Loss 0.140
# Epoch 196: Loss 0.138
# Epoch 197: Loss 0.139
# Epoch 198: Loss 0.139
# Epoch 199: Loss 0.138
# Epoch 200: Loss 0.138
# Epoch 201: Loss 0.138
# Epoch 202: Loss 0.137
# Epoch 203: Loss 0.137
# Epoch 204: Loss 0.137
# Epoch 205: Loss 0.136
# Epoch 206: Loss 0.137
# Epoch 207: Loss 0.137
# Epoch 208: Loss 0.135
# Epoch 209: Loss 0.135
# Epoch 210: Loss 0.135
# Epoch 211: Loss 0.138
# Epoch 212: Loss 0.135
# Epoch 213: Loss 0.136
# Epoch 214: Loss 0.135
# Epoch 215: Loss 0.135
# Epoch 216: Loss 0.135
# Epoch 217: Loss 0.134
# Epoch 218: Loss 0.136
# Epoch 219: Loss 0.134
# Epoch 220: Loss 0.134
# Epoch 221: Loss 0.135
# Epoch 222: Loss 0.135
# Epoch 223: Loss 0.135
# Epoch 224: Loss 0.134
# Epoch 225: Loss 0.134
# Epoch 226: Loss 0.134
# Epoch 227: Loss 0.132
# Epoch 228: Loss 0.135
# Epoch 229: Loss 0.132
# Epoch 230: Loss 0.133
# Epoch 231: Loss 0.131
# Epoch 232: Loss 0.137
# Epoch 233: Loss 0.133
# Epoch 234: Loss 0.134
# Epoch 235: Loss 0.132
# Epoch 236: Loss 0.137
# Epoch 237: Loss 0.138
# Epoch 238: Loss 0.136
# Epoch 239: Loss 0.135
# Epoch 240: Loss 0.137
# Epoch 241: Loss 0.133
# Epoch 242: Loss 0.133
# Epoch 243: Loss 0.130
# Epoch 244: Loss 0.131
# Epoch 245: Loss 0.131
# Epoch 246: Loss 0.129
# Epoch 247: Loss 0.130
# Epoch 248: Loss 0.145
# Epoch 249: Loss 0.132
# Epoch 250: Loss 0.139
# Epoch 251: Loss 0.134
# Epoch 252: Loss 0.135
# Epoch 253: Loss 0.138
# Epoch 254: Loss 0.133
# Epoch 255: Loss 0.130
# Epoch 256: Loss 0.137
# Epoch 257: Loss 0.130
# Epoch 258: Loss 0.136
# Epoch 259: Loss 0.134
# Epoch 260: Loss 0.135
# Epoch 261: Loss 0.135
# Epoch 262: Loss 0.136
# Epoch 263: Loss 0.130
# Epoch 264: Loss 0.134
# Epoch 265: Loss 0.129
# Epoch 266: Loss 0.127
# Epoch 267: Loss 0.135
# Epoch 268: Loss 0.136
# Epoch 269: Loss 0.130
# Epoch 270: Loss 0.136
# Epoch 271: Loss 0.127
# Epoch 272: Loss 0.138
# Epoch 273: Loss 0.137
# Epoch 274: Loss 0.129
# Epoch 275: Loss 0.128
# Epoch 276: Loss 0.128
# Epoch 277: Loss 0.129
# Epoch 278: Loss 0.126
# Epoch 279: Loss 0.132
# Epoch 280: Loss 0.133
# Epoch 281: Loss 0.127
# Epoch 282: Loss 0.130
# Epoch 283: Loss 0.129
# Epoch 284: Loss 0.126
# Epoch 285: Loss 0.129
# Epoch 286: Loss 0.127
# Epoch 287: Loss 0.127
# Epoch 288: Loss 0.128
# Epoch 289: Loss 0.134
# Epoch 290: Loss 0.124
# Epoch 291: Loss 0.128
# Epoch 292: Loss 0.124
# Epoch 293: Loss 0.126
# Epoch 294: Loss 0.126
# Epoch 295: Loss 0.124
# Epoch 296: Loss 0.137
# Epoch 297: Loss 0.129
# Epoch 298: Loss 0.120
# Epoch 299: Loss 0.124
# Epoch 300: Loss 0.131
# Epoch 301: Loss 0.129
# Epoch 302: Loss 0.120
# Epoch 303: Loss 0.123
# Epoch 304: Loss 0.130
# Epoch 305: Loss 0.131
# Epoch 306: Loss 0.125
# Epoch 307: Loss 0.119
# Epoch 308: Loss 0.124
# Epoch 309: Loss 0.120
# Epoch 310: Loss 0.124
# Epoch 311: Loss 0.132
# Epoch 312: Loss 0.122
# Epoch 313: Loss 0.123
# Epoch 314: Loss 0.127
# Epoch 315: Loss 0.128
# Epoch 316: Loss 0.120
# Epoch 317: Loss 0.130
# Epoch 318: Loss 0.125
# Epoch 319: Loss 0.121
# Epoch 320: Loss 0.130
# Epoch 321: Loss 0.118
# Epoch 322: Loss 0.118
# Epoch 323: Loss 0.119
# Epoch 324: Loss 0.123
# Epoch 325: Loss 0.121
# Epoch 326: Loss 0.119
# Epoch 327: Loss 0.120
# Epoch 328: Loss 0.128
# Epoch 329: Loss 0.126
# Epoch 330: Loss 0.114
# Epoch 331: Loss 0.126
# Epoch 332: Loss 0.119
# Epoch 333: Loss 0.114
# Epoch 334: Loss 0.114
# Epoch 335: Loss 0.116
# Epoch 336: Loss 0.110
# Epoch 337: Loss 0.117
# Epoch 338: Loss 0.120
# Epoch 339: Loss 0.113
# Epoch 340: Loss 0.118
# Epoch 341: Loss 0.121
# Epoch 342: Loss 0.121
# Epoch 343: Loss 0.113
# Epoch 344: Loss 0.114
# Epoch 345: Loss 0.117
# Epoch 346: Loss 0.122
# Epoch 347: Loss 0.114
# Epoch 348: Loss 0.112
# Epoch 349: Loss 0.119
# Epoch 350: Loss 0.121
# Epoch 351: Loss 0.114
# Epoch 352: Loss 0.126
# Epoch 353: Loss 0.111
# Epoch 354: Loss 0.121
# Epoch 355: Loss 0.112
# Epoch 356: Loss 0.109
# Epoch 357: Loss 0.118
# Epoch 358: Loss 0.116
# Epoch 359: Loss 0.113
# Epoch 360: Loss 0.116
# Epoch 361: Loss 0.110
# Epoch 362: Loss 0.108
# Epoch 363: Loss 0.117
# Epoch 364: Loss 0.115
# Epoch 365: Loss 0.109
# Epoch 366: Loss 0.107
# Epoch 367: Loss 0.112
# Epoch 368: Loss 0.111
# Epoch 369: Loss 0.107
# Epoch 370: Loss 0.124
# Epoch 371: Loss 0.114
# Epoch 372: Loss 0.107
# Epoch 373: Loss 0.106
# Epoch 374: Loss 0.108
# Epoch 375: Loss 0.106
# Epoch 376: Loss 0.112
# Epoch 377: Loss 0.115
# Epoch 378: Loss 0.117
# Epoch 379: Loss 0.117
# Epoch 380: Loss 0.106
# Epoch 381: Loss 0.104
# Epoch 382: Loss 0.108
# Epoch 383: Loss 0.111
# Epoch 384: Loss 0.104
# Epoch 385: Loss 0.105
# Epoch 386: Loss 0.110
# Epoch 387: Loss 0.104
# Epoch 388: Loss 0.105
# Epoch 389: Loss 0.104
# Epoch 390: Loss 0.106
# Epoch 391: Loss 0.100
# Epoch 392: Loss 0.105
# Epoch 393: Loss 0.109
# Epoch 394: Loss 0.118
# Epoch 395: Loss 0.104
# Epoch 396: Loss 0.103
# Epoch 397: Loss 0.104
# Epoch 398: Loss 0.103
# Epoch 399: Loss 0.105
# Epoch 400: Loss 0.108
# Epoch 401: Loss 0.115
# Epoch 402: Loss 0.100
# Epoch 403: Loss 0.103
# Epoch 404: Loss 0.100
# Epoch 405: Loss 0.107
# Epoch 406: Loss 0.101
# Epoch 407: Loss 0.100
# Epoch 408: Loss 0.108
# Epoch 409: Loss 0.105
# Epoch 410: Loss 0.098
# Epoch 411: Loss 0.106
# Epoch 412: Loss 0.098
# Epoch 413: Loss 0.105
# Epoch 414: Loss 0.105
# Epoch 415: Loss 0.100
# Epoch 416: Loss 0.104
# Epoch 417: Loss 0.104
# Epoch 418: Loss 0.099
# Epoch 419: Loss 0.098
# Epoch 420: Loss 0.098
# Epoch 421: Loss 0.102
# Epoch 422: Loss 0.105
# Epoch 423: Loss 0.105
# Epoch 424: Loss 0.094
# Epoch 425: Loss 0.094
# Epoch 426: Loss 0.099
# Epoch 427: Loss 0.098
# Epoch 428: Loss 0.106
# Epoch 429: Loss 0.107
# Epoch 430: Loss 0.105
# Epoch 431: Loss 0.098
# Epoch 432: Loss 0.096
# Epoch 433: Loss 0.096
# Epoch 434: Loss 0.100
# Epoch 435: Loss 0.104
# Epoch 436: Loss 0.103
# Epoch 437: Loss 0.122
# Epoch 438: Loss 0.109
# Epoch 439: Loss 0.097
# Epoch 440: Loss 0.104
# Epoch 441: Loss 0.098
# Epoch 442: Loss 0.108
# Epoch 443: Loss 0.107
# Epoch 444: Loss 0.100
# Epoch 445: Loss 0.095
# Epoch 446: Loss 0.094
# Epoch 447: Loss 0.106
# Epoch 448: Loss 0.106
# Epoch 449: Loss 0.098
# Epoch 450: Loss 0.094
# Epoch 451: Loss 0.090
# Epoch 452: Loss 0.095
# Epoch 453: Loss 0.093
# Epoch 454: Loss 0.095
# Epoch 455: Loss 0.099
# Epoch 456: Loss 0.099
# Epoch 457: Loss 0.106
# Epoch 458: Loss 0.094
# Epoch 459: Loss 0.097
# Epoch 460: Loss 0.100
# Epoch 461: Loss 0.094
# Epoch 462: Loss 0.110
# Epoch 463: Loss 0.102
# Epoch 464: Loss 0.099
# Epoch 465: Loss 0.106
# Epoch 466: Loss 0.108
# Epoch 467: Loss 0.102
# Epoch 468: Loss 0.094
# Epoch 469: Loss 0.094
# Epoch 470: Loss 0.095
# Epoch 471: Loss 0.095
# Epoch 472: Loss 0.098
# Epoch 473: Loss 0.098
# Epoch 474: Loss 0.093
# Epoch 475: Loss 0.094
# Epoch 476: Loss 0.091
# Epoch 477: Loss 0.097
# Epoch 478: Loss 0.094
# Epoch 479: Loss 0.098
# Epoch 480: Loss 0.095
# Epoch 481: Loss 0.101
# Epoch 482: Loss 0.094
# Epoch 483: Loss 0.103
# Epoch 484: Loss 0.096
# Epoch 485: Loss 0.100
# Epoch 486: Loss 0.098
# Epoch 487: Loss 0.094
# Epoch 488: Loss 0.088
# Epoch 489: Loss 0.094
# Epoch 490: Loss 0.087
# Epoch 491: Loss 0.105
# Epoch 492: Loss 0.092
# Epoch 493: Loss 0.100
# Epoch 494: Loss 0.107
# Epoch 495: Loss 0.098
# Epoch 496: Loss 0.098
# Epoch 497: Loss 0.093
# Epoch 498: Loss 0.092
# Epoch 499: Loss 0.094
# Epoch 500: Loss 0.117
# Epoch 501: Loss 0.101
# Epoch 502: Loss 0.101
# Epoch 503: Loss 0.092
# Epoch 504: Loss 0.095
# Epoch 505: Loss 0.092
# Epoch 506: Loss 0.087
# Epoch 507: Loss 0.088
# Epoch 508: Loss 0.093
# Epoch 509: Loss 0.098
# Epoch 510: Loss 0.090
# Epoch 511: Loss 0.093
# Epoch 512: Loss 0.089
# Epoch 513: Loss 0.089
# Epoch 514: Loss 0.091
# Epoch 515: Loss 0.112
# Epoch 516: Loss 0.092
# Epoch 517: Loss 0.092
# Epoch 518: Loss 0.095
# Epoch 519: Loss 0.095
# Epoch 520: Loss 0.097
# Epoch 521: Loss 0.093
# Epoch 522: Loss 0.099
# Epoch 523: Loss 0.096
# Epoch 524: Loss 0.091
# Epoch 525: Loss 0.100
# Epoch 526: Loss 0.092
# Epoch 527: Loss 0.104
# Epoch 528: Loss 0.100
# Epoch 529: Loss 0.086
# Epoch 530: Loss 0.105
# Epoch 531: Loss 0.093
# Epoch 532: Loss 0.088
# Epoch 533: Loss 0.086
# Epoch 534: Loss 0.089
# Epoch 535: Loss 0.093
# Epoch 536: Loss 0.090
# Epoch 537: Loss 0.088
# Epoch 538: Loss 0.093
# Epoch 539: Loss 0.093
# Epoch 540: Loss 0.093
# Epoch 541: Loss 0.098
# Epoch 542: Loss 0.091
# Epoch 543: Loss 0.089
# Epoch 544: Loss 0.091
# Epoch 545: Loss 0.092
# Epoch 546: Loss 0.107
# Epoch 547: Loss 0.087
# Epoch 548: Loss 0.088
# Epoch 549: Loss 0.091
# Epoch 550: Loss 0.125
# Epoch 551: Loss 0.116
# Epoch 552: Loss 0.097
# Epoch 553: Loss 0.094
# Epoch 554: Loss 0.091
# Epoch 555: Loss 0.085
# Epoch 556: Loss 0.084
# Epoch 557: Loss 0.091
# Epoch 558: Loss 0.084
# Epoch 559: Loss 0.098
# Epoch 560: Loss 0.087
# Epoch 561: Loss 0.104
# Epoch 562: Loss 0.088
# Epoch 563: Loss 0.096
# Epoch 564: Loss 0.092
# Epoch 565: Loss 0.096
# Epoch 566: Loss 0.091
# Epoch 567: Loss 0.094
# Epoch 568: Loss 0.087
# Epoch 569: Loss 0.108
# Epoch 570: Loss 0.109
# Epoch 571: Loss 0.099
# Epoch 572: Loss 0.095
# Epoch 573: Loss 0.086
# Epoch 574: Loss 0.092
# Epoch 575: Loss 0.085
# Epoch 576: Loss 0.088
# Epoch 577: Loss 0.086
# Epoch 578: Loss 0.090
# Epoch 579: Loss 0.095
# Epoch 580: Loss 0.082
# Epoch 581: Loss 0.094
# Epoch 582: Loss 0.083
# Epoch 583: Loss 0.094
# Epoch 584: Loss 0.083
# Epoch 585: Loss 0.079
# Epoch 586: Loss 0.089
# Epoch 587: Loss 0.085
# Epoch 588: Loss 0.081
# Epoch 589: Loss 0.079
# Epoch 590: Loss 0.089
# Epoch 591: Loss 0.083
# Epoch 592: Loss 0.084
# Epoch 593: Loss 0.079
# Epoch 594: Loss 0.088
# Epoch 595: Loss 0.122
# Epoch 596: Loss 0.096
# Epoch 597: Loss 0.086
# Epoch 598: Loss 0.091
# Epoch 599: Loss 0.081
# Epoch 600: Loss 0.095
# Epoch 601: Loss 0.087
# Epoch 602: Loss 0.085
# Epoch 603: Loss 0.088
# Epoch 604: Loss 0.082
# Epoch 605: Loss 0.084
# Epoch 606: Loss 0.089
# Epoch 607: Loss 0.075
# Epoch 608: Loss 0.088
# Epoch 609: Loss 0.084
# Epoch 610: Loss 0.085
# Epoch 611: Loss 0.095
# Epoch 612: Loss 0.081
# Epoch 613: Loss 0.082
# Epoch 614: Loss 0.086
# Epoch 615: Loss 0.083
# Epoch 616: Loss 0.093
# Epoch 617: Loss 0.086
# Epoch 618: Loss 0.083
# Epoch 619: Loss 0.094
# Epoch 620: Loss 0.089
# Epoch 621: Loss 0.088
# Epoch 622: Loss 0.085
# Epoch 623: Loss 0.106
# Epoch 624: Loss 0.085
# Epoch 625: Loss 0.093
# Epoch 626: Loss 0.082
# Epoch 627: Loss 0.087
# Epoch 628: Loss 0.089
# Epoch 629: Loss 0.086
# Epoch 630: Loss 0.086
# Epoch 631: Loss 0.081
# Epoch 632: Loss 0.079
# Epoch 633: Loss 0.089
# Epoch 634: Loss 0.087
# Epoch 635: Loss 0.080
# Epoch 636: Loss 0.079
# Epoch 637: Loss 0.081
# Epoch 638: Loss 0.094
# Epoch 639: Loss 0.092
# Epoch 640: Loss 0.081
# Epoch 641: Loss 0.079
# Epoch 642: Loss 0.093
# Epoch 643: Loss 0.090
# Epoch 644: Loss 0.086
# Epoch 645: Loss 0.088
# Epoch 646: Loss 0.088
# Epoch 647: Loss 0.084
# Epoch 648: Loss 0.078
# Epoch 649: Loss 0.088
# Epoch 650: Loss 0.080
# Epoch 651: Loss 0.085
# Epoch 652: Loss 0.091
# Epoch 653: Loss 0.082
# Epoch 654: Loss 0.087
# Epoch 655: Loss 0.088
# Epoch 656: Loss 0.097
# Epoch 657: Loss 0.117
# Epoch 658: Loss 0.085
# Epoch 659: Loss 0.094
# Epoch 660: Loss 0.082
# Epoch 661: Loss 0.085
# Epoch 662: Loss 0.080
# Epoch 663: Loss 0.085
# Epoch 664: Loss 0.079
# Epoch 665: Loss 0.084
# Epoch 666: Loss 0.073
# Epoch 667: Loss 0.080
# Epoch 668: Loss 0.078
# Epoch 669: Loss 0.095
# Epoch 670: Loss 0.094
# Epoch 671: Loss 0.082
# Epoch 672: Loss 0.086
# Epoch 673: Loss 0.077
# Epoch 674: Loss 0.081
# Epoch 675: Loss 0.081
# Epoch 676: Loss 0.081
# Epoch 677: Loss 0.079
# Epoch 678: Loss 0.079
# Epoch 679: Loss 0.081
# Epoch 680: Loss 0.083
# Epoch 681: Loss 0.075
# Epoch 682: Loss 0.078
# Epoch 683: Loss 0.076
# Epoch 684: Loss 0.082
# Epoch 685: Loss 0.078
# Epoch 686: Loss 0.078
# Epoch 687: Loss 0.093
# Epoch 688: Loss 0.084
# Epoch 689: Loss 0.080
# Epoch 690: Loss 0.081
# Epoch 691: Loss 0.074
# Epoch 692: Loss 0.091
# Epoch 693: Loss 0.086
# Epoch 694: Loss 0.081
# Epoch 695: Loss 0.080
# Epoch 696: Loss 0.072
# Epoch 697: Loss 0.074
# Epoch 698: Loss 0.089
# Epoch 699: Loss 0.087
# Epoch 700: Loss 0.085
# Epoch 701: Loss 0.073
# Epoch 702: Loss 0.078
# Epoch 703: Loss 0.078
# Epoch 704: Loss 0.076
# Epoch 705: Loss 0.079
# Epoch 706: Loss 0.079
# Epoch 707: Loss 0.076
# Epoch 708: Loss 0.081
# Epoch 709: Loss 0.088
# Epoch 710: Loss 0.080
# Epoch 711: Loss 0.087
# Epoch 712: Loss 0.084
# Epoch 713: Loss 0.080
# Epoch 714: Loss 0.075
# Epoch 715: Loss 0.075
# Epoch 716: Loss 0.072
# Epoch 717: Loss 0.082
# Epoch 718: Loss 0.077
# Epoch 719: Loss 0.080
# Epoch 720: Loss 0.075
# Epoch 721: Loss 0.076
# Epoch 722: Loss 0.076
# Epoch 723: Loss 0.074
# Epoch 724: Loss 0.077
# Epoch 725: Loss 0.081
# Epoch 726: Loss 0.076
# Epoch 727: Loss 0.082
# Epoch 728: Loss 0.080
# Epoch 729: Loss 0.072
# Epoch 730: Loss 0.070
# Epoch 731: Loss 0.082
# Epoch 732: Loss 0.082
# Epoch 733: Loss 0.071
# Epoch 734: Loss 0.072
# Epoch 735: Loss 0.079
# Epoch 736: Loss 0.072
# Epoch 737: Loss 0.073
# Epoch 738: Loss 0.081
# Epoch 739: Loss 0.070
# Epoch 740: Loss 0.074
# Epoch 741: Loss 0.075
# Epoch 742: Loss 0.071
# Epoch 743: Loss 0.074
# Epoch 744: Loss 0.085
# Epoch 745: Loss 0.074
# Epoch 746: Loss 0.074
# Epoch 747: Loss 0.074
# Epoch 748: Loss 0.079
# Epoch 749: Loss 0.082
# Epoch 750: Loss 0.073
# Epoch 751: Loss 0.070
# Epoch 752: Loss 0.075
# Epoch 753: Loss 0.074
# Epoch 754: Loss 0.081
# Epoch 755: Loss 0.070
# Epoch 756: Loss 0.087
# Epoch 757: Loss 0.073
# Epoch 758: Loss 0.088
# Epoch 759: Loss 0.077
# Epoch 760: Loss 0.076
# Epoch 761: Loss 0.075
# Epoch 762: Loss 0.086
# Epoch 763: Loss 0.074
# Epoch 764: Loss 0.070
# Epoch 765: Loss 0.079
# Epoch 766: Loss 0.087
# Epoch 767: Loss 0.069
# Epoch 768: Loss 0.073
# Epoch 769: Loss 0.071
# Epoch 770: Loss 0.067
# Epoch 771: Loss 0.102
# Epoch 772: Loss 0.079
# Epoch 773: Loss 0.073
# Epoch 774: Loss 0.082
# Epoch 775: Loss 0.070
# Epoch 776: Loss 0.079
# Epoch 777: Loss 0.071
# Epoch 778: Loss 0.096
# Epoch 779: Loss 0.080
# Epoch 780: Loss 0.074
# Epoch 781: Loss 0.073
# Epoch 782: Loss 0.067
# Epoch 783: Loss 0.070
# Epoch 784: Loss 0.075
# Epoch 785: Loss 0.068
# Epoch 786: Loss 0.067
# Epoch 787: Loss 0.067
# Epoch 788: Loss 0.073
# Epoch 789: Loss 0.073
# Epoch 790: Loss 0.070
# Epoch 791: Loss 0.070
# Epoch 792: Loss 0.071
# Epoch 793: Loss 0.069
# Epoch 794: Loss 0.068
# Epoch 795: Loss 0.066
# Epoch 796: Loss 0.092
# Epoch 797: Loss 0.075
# Epoch 798: Loss 0.081
# Epoch 799: Loss 0.072
# Epoch 800: Loss 0.071
# Epoch 801: Loss 0.067
# Epoch 802: Loss 0.067
# Epoch 803: Loss 0.077
# Epoch 804: Loss 0.062
# Epoch 805: Loss 0.081
# Epoch 806: Loss 0.068
# Epoch 807: Loss 0.088
# Epoch 808: Loss 0.083
# Epoch 809: Loss 0.068
# Epoch 810: Loss 0.084
# Epoch 811: Loss 0.083
# Epoch 812: Loss 0.079
# Epoch 813: Loss 0.070
# Epoch 814: Loss 0.072
# Epoch 815: Loss 0.065
# Epoch 816: Loss 0.069
# Epoch 817: Loss 0.075
# Epoch 818: Loss 0.076
# Epoch 819: Loss 0.066
# Epoch 820: Loss 0.065
# Epoch 821: Loss 0.064
# Epoch 822: Loss 0.084
# Epoch 823: Loss 0.070
# Epoch 824: Loss 0.073
# Epoch 825: Loss 0.065
# Epoch 826: Loss 0.071
# Epoch 827: Loss 0.073
# Epoch 828: Loss 0.067
# Epoch 829: Loss 0.074
# Epoch 830: Loss 0.066
# Epoch 831: Loss 0.062
# Epoch 832: Loss 0.061
# Epoch 833: Loss 0.061
# Epoch 834: Loss 0.064
# Epoch 835: Loss 0.078
# Epoch 836: Loss 0.079
# Epoch 837: Loss 0.064
# Epoch 838: Loss 0.075
# Epoch 839: Loss 0.064
# Epoch 840: Loss 0.063
# Epoch 841: Loss 0.077
# Epoch 842: Loss 0.060
# Epoch 843: Loss 0.067
# Epoch 844: Loss 0.067
# Epoch 845: Loss 0.061
# Epoch 846: Loss 0.097
# Epoch 847: Loss 0.067
# Epoch 848: Loss 0.068
# Epoch 849: Loss 0.063
# Epoch 850: Loss 0.065
# Epoch 851: Loss 0.068
# Epoch 852: Loss 0.063
# Epoch 853: Loss 0.061
# Epoch 854: Loss 0.090
# Epoch 855: Loss 0.069
# Epoch 856: Loss 0.081
# Epoch 857: Loss 0.098
# Epoch 858: Loss 0.073
# Epoch 859: Loss 0.071
# Epoch 860: Loss 0.067
# Epoch 861: Loss 0.065
# Epoch 862: Loss 0.064
# Epoch 863: Loss 0.063
# Epoch 864: Loss 0.077
# Epoch 865: Loss 0.065
# Epoch 866: Loss 0.064
# Epoch 867: Loss 0.091
# Epoch 868: Loss 0.064
# Epoch 869: Loss 0.059
# Epoch 870: Loss 0.058
# Epoch 871: Loss 0.072
# Epoch 872: Loss 0.064
# Epoch 873: Loss 0.058
# Epoch 874: Loss 0.077
# Epoch 875: Loss 0.072
# Epoch 876: Loss 0.061
# Epoch 877: Loss 0.068
# Epoch 878: Loss 0.066
# Epoch 879: Loss 0.066
# Epoch 880: Loss 0.059
# Epoch 881: Loss 0.061
# Epoch 882: Loss 0.060
# Epoch 883: Loss 0.085
# Epoch 884: Loss 0.075
# Epoch 885: Loss 0.077
# Epoch 886: Loss 0.067
# Epoch 887: Loss 0.063
# Epoch 888: Loss 0.058
# Epoch 889: Loss 0.060
# Epoch 890: Loss 0.060
# Epoch 891: Loss 0.077
# Epoch 892: Loss 0.059
# Epoch 893: Loss 0.066
# Epoch 894: Loss 0.061
# Epoch 895: Loss 0.060
# Epoch 896: Loss 0.060
# Epoch 897: Loss 0.078
# Epoch 898: Loss 0.058
# Epoch 899: Loss 0.084
# Epoch 900: Loss 0.069
# Epoch 901: Loss 0.062
# Epoch 902: Loss 0.080
# Epoch 903: Loss 0.062
# Epoch 904: Loss 0.097
# Epoch 905: Loss 0.068
# Epoch 906: Loss 0.059
# Epoch 907: Loss 0.062
# Epoch 908: Loss 0.079
# Epoch 909: Loss 0.062
# Epoch 910: Loss 0.057
# Epoch 911: Loss 0.061
# Epoch 912: Loss 0.058
# Epoch 913: Loss 0.063
# Epoch 914: Loss 0.057
# Epoch 915: Loss 0.067
# Epoch 916: Loss 0.057
# Epoch 917: Loss 0.057
# Epoch 918: Loss 0.058
# Epoch 919: Loss 0.061
# Epoch 920: Loss 0.069
# Epoch 921: Loss 0.060
# Epoch 922: Loss 0.059
# Epoch 923: Loss 0.061
# Epoch 924: Loss 0.063
# Epoch 925: Loss 0.061
# Epoch 926: Loss 0.072
# Epoch 927: Loss 0.060
# Epoch 928: Loss 0.074
# Epoch 929: Loss 0.087
# Epoch 930: Loss 0.074
# Epoch 931: Loss 0.065
# Epoch 932: Loss 0.063
# Epoch 933: Loss 0.061
# Epoch 934: Loss 0.083
# Epoch 935: Loss 0.069
# Epoch 936: Loss 0.062
# Epoch 937: Loss 0.087
# Epoch 938: Loss 0.059
# Epoch 939: Loss 0.060
# Epoch 940: Loss 0.057
# Epoch 941: Loss 0.055
# Epoch 942: Loss 0.060
# Epoch 943: Loss 0.071
# Epoch 944: Loss 0.063
# Epoch 945: Loss 0.068
# Epoch 946: Loss 0.059
# Epoch 947: Loss 0.059
# Epoch 948: Loss 0.055
# Epoch 949: Loss 0.052
# Epoch 950: Loss 0.056
# Epoch 951: Loss 0.060
# Epoch 952: Loss 0.064
# Epoch 953: Loss 0.081
# Epoch 954: Loss 0.062
# Epoch 955: Loss 0.063
# Epoch 956: Loss 0.073
# Epoch 957: Loss 0.075
# Epoch 958: Loss 0.067
# Epoch 959: Loss 0.061
# Epoch 960: Loss 0.074
# Epoch 961: Loss 0.070
# Epoch 962: Loss 0.068
# Epoch 963: Loss 0.059
# Epoch 964: Loss 0.057
# Epoch 965: Loss 0.067
# Epoch 966: Loss 0.058
# Epoch 967: Loss 0.069
# Epoch 968: Loss 0.057
# Epoch 969: Loss 0.056
# Epoch 970: Loss 0.053
# Epoch 971: Loss 0.070
# Epoch 972: Loss 0.058
# Epoch 973: Loss 0.058
# Epoch 974: Loss 0.056
# Epoch 975: Loss 0.086
# Epoch 976: Loss 0.071
# Epoch 977: Loss 0.083
# Epoch 978: Loss 0.066
# Epoch 979: Loss 0.092
# Epoch 980: Loss 0.070
# Epoch 981: Loss 0.071
# Epoch 982: Loss 0.062
# Epoch 983: Loss 0.074
# Epoch 984: Loss 0.062
# Epoch 985: Loss 0.060
# Epoch 986: Loss 0.049
# Epoch 987: Loss 0.053
# Epoch 988: Loss 0.062
# Epoch 989: Loss 0.063
# Epoch 990: Loss 0.057
# Epoch 991: Loss 0.070
# Epoch 992: Loss 0.061
# Epoch 993: Loss 0.055
# Epoch 994: Loss 0.074
# Epoch 995: Loss 0.061
# Epoch 996: Loss 0.061
# Epoch 997: Loss 0.047
# Epoch 998: Loss 0.043
# Epoch 999: Loss 0.071
# Epoch 1000: Loss 0.053
# Epoch 1: Loss 0.403
# Epoch 2: Loss 0.277
# Epoch 3: Loss 0.272
# Epoch 4: Loss 0.271
# Epoch 5: Loss 0.270
# Epoch 6: Loss 0.269
# Epoch 7: Loss 0.269
# Epoch 8: Loss 0.268
# Epoch 9: Loss 0.267
# Epoch 10: Loss 0.266
# Epoch 11: Loss 0.265
# Epoch 12: Loss 0.264
# Epoch 13: Loss 0.263
# Epoch 14: Loss 0.261
# Epoch 15: Loss 0.260
# Epoch 16: Loss 0.259
# Epoch 17: Loss 0.257
# Epoch 18: Loss 0.256
# Epoch 19: Loss 0.254
# Epoch 20: Loss 0.252
# Epoch 21: Loss 0.251
# Epoch 22: Loss 0.249
# Epoch 23: Loss 0.247
# Epoch 24: Loss 0.246
# Epoch 25: Loss 0.244
# Epoch 26: Loss 0.243
# Epoch 27: Loss 0.241
# Epoch 28: Loss 0.240
# Epoch 29: Loss 0.238
# Epoch 30: Loss 0.237
# Epoch 31: Loss 0.236
# Epoch 32: Loss 0.235
# Epoch 33: Loss 0.234
# Epoch 34: Loss 0.233
# Epoch 35: Loss 0.232
# Epoch 36: Loss 0.231
# Epoch 37: Loss 0.230
# Epoch 38: Loss 0.229
# Epoch 39: Loss 0.227
# Epoch 40: Loss 0.226
# Epoch 41: Loss 0.225
# Epoch 42: Loss 0.224
# Epoch 43: Loss 0.223
# Epoch 44: Loss 0.222
# Epoch 45: Loss 0.220
# Epoch 46: Loss 0.219
# Epoch 47: Loss 0.218
# Epoch 48: Loss 0.217
# Epoch 49: Loss 0.216
# Epoch 50: Loss 0.216
# Epoch 51: Loss 0.215
# Epoch 52: Loss 0.214
# Epoch 53: Loss 0.213
# Epoch 54: Loss 0.212
# Epoch 55: Loss 0.211
# Epoch 56: Loss 0.210
# Epoch 57: Loss 0.209
# Epoch 58: Loss 0.208
# Epoch 59: Loss 0.207
# Epoch 60: Loss 0.206
# Epoch 61: Loss 0.206
# Epoch 62: Loss 0.205
# Epoch 63: Loss 0.204
# Epoch 64: Loss 0.204
# Epoch 65: Loss 0.203
# Epoch 66: Loss 0.202
# Epoch 67: Loss 0.202
# Epoch 68: Loss 0.201
# Epoch 69: Loss 0.201
# Epoch 70: Loss 0.200
# Epoch 71: Loss 0.199
# Epoch 72: Loss 0.199
# Epoch 73: Loss 0.198
# Epoch 74: Loss 0.197
# Epoch 75: Loss 0.197
# Epoch 76: Loss 0.196
# Epoch 77: Loss 0.196
# Epoch 78: Loss 0.195
# Epoch 79: Loss 0.195
# Epoch 80: Loss 0.194
# Epoch 81: Loss 0.193
# Epoch 82: Loss 0.192
# Epoch 83: Loss 0.192
# Epoch 84: Loss 0.192
# Epoch 85: Loss 0.191
# Epoch 86: Loss 0.190
# Epoch 87: Loss 0.190
# Epoch 88: Loss 0.189
# Epoch 89: Loss 0.188
# Epoch 90: Loss 0.188
# Epoch 91: Loss 0.188
# Epoch 92: Loss 0.187
# Epoch 93: Loss 0.186
# Epoch 94: Loss 0.185
# Epoch 95: Loss 0.185
# Epoch 96: Loss 0.184
# Epoch 97: Loss 0.183
# Epoch 98: Loss 0.183
# Epoch 99: Loss 0.182
# Epoch 100: Loss 0.181
# Epoch 101: Loss 0.180
# Epoch 102: Loss 0.180
# Epoch 103: Loss 0.179
# Epoch 104: Loss 0.179
# Epoch 105: Loss 0.178
# Epoch 106: Loss 0.178
# Epoch 107: Loss 0.177
# Epoch 108: Loss 0.176
# Epoch 109: Loss 0.176
# Epoch 110: Loss 0.175
# Epoch 111: Loss 0.175
# Epoch 112: Loss 0.174
# Epoch 113: Loss 0.174
# Epoch 114: Loss 0.173
# Epoch 115: Loss 0.172
# Epoch 116: Loss 0.172
# Epoch 117: Loss 0.171
# Epoch 118: Loss 0.171
# Epoch 119: Loss 0.171
# Epoch 120: Loss 0.170
# Epoch 121: Loss 0.169
# Epoch 122: Loss 0.169
# Epoch 123: Loss 0.169
# Epoch 124: Loss 0.168
# Epoch 125: Loss 0.167
# Epoch 126: Loss 0.167
# Epoch 127: Loss 0.167
# Epoch 128: Loss 0.166
# Epoch 129: Loss 0.166
# Epoch 130: Loss 0.166
# Epoch 131: Loss 0.166
# Epoch 132: Loss 0.165
# Epoch 133: Loss 0.165
# Epoch 134: Loss 0.166
# Epoch 135: Loss 0.165
# Epoch 136: Loss 0.164
# Epoch 137: Loss 0.163
# Epoch 138: Loss 0.163
# Epoch 139: Loss 0.163
# Epoch 140: Loss 0.164
# Epoch 141: Loss 0.164
# Epoch 142: Loss 0.162
# Epoch 143: Loss 0.162
# Epoch 144: Loss 0.162
# Epoch 145: Loss 0.161
# Epoch 146: Loss 0.161
# Epoch 147: Loss 0.160
# Epoch 148: Loss 0.160
# Epoch 149: Loss 0.160
# Epoch 150: Loss 0.160
# Epoch 151: Loss 0.159
# Epoch 152: Loss 0.159
# Epoch 153: Loss 0.159
# Epoch 154: Loss 0.159
# Epoch 155: Loss 0.159
# Epoch 156: Loss 0.159
# Epoch 157: Loss 0.158
# Epoch 158: Loss 0.158
# Epoch 159: Loss 0.158
# Epoch 160: Loss 0.157
# Epoch 161: Loss 0.157
# Epoch 162: Loss 0.157
# Epoch 163: Loss 0.156
# Epoch 164: Loss 0.157
# Epoch 165: Loss 0.156
# Epoch 166: Loss 0.156
# Epoch 167: Loss 0.156
# Epoch 168: Loss 0.155
# Epoch 169: Loss 0.155
# Epoch 170: Loss 0.155
# Epoch 171: Loss 0.155
# Epoch 172: Loss 0.155
# Epoch 173: Loss 0.155
# Epoch 174: Loss 0.155
# Epoch 175: Loss 0.155
# Epoch 176: Loss 0.155
# Epoch 177: Loss 0.154
# Epoch 178: Loss 0.154
# Epoch 179: Loss 0.154
# Epoch 180: Loss 0.154
# Epoch 181: Loss 0.154
# Epoch 182: Loss 0.154
# Epoch 183: Loss 0.153
# Epoch 184: Loss 0.153
# Epoch 185: Loss 0.153
# Epoch 186: Loss 0.152
# Epoch 187: Loss 0.154
# Epoch 188: Loss 0.152
# Epoch 189: Loss 0.153
# Epoch 190: Loss 0.152
# Epoch 191: Loss 0.153
# Epoch 192: Loss 0.152
# Epoch 193: Loss 0.152
# Epoch 194: Loss 0.153
# Epoch 195: Loss 0.151
# Epoch 196: Loss 0.151
# Epoch 197: Loss 0.152
# Epoch 198: Loss 0.151
# Epoch 199: Loss 0.151
# Epoch 200: Loss 0.150
# Epoch 201: Loss 0.151
# Epoch 202: Loss 0.151
# Epoch 203: Loss 0.151
# Epoch 204: Loss 0.151
# Epoch 205: Loss 0.150
# Epoch 206: Loss 0.151
# Epoch 207: Loss 0.150
# Epoch 208: Loss 0.150
# Epoch 209: Loss 0.149
# Epoch 210: Loss 0.150
# Epoch 211: Loss 0.149
# Epoch 212: Loss 0.150
# Epoch 213: Loss 0.150
# Epoch 214: Loss 0.149
# Epoch 215: Loss 0.149
# Epoch 216: Loss 0.148
# Epoch 217: Loss 0.148
# Epoch 218: Loss 0.150
# Epoch 219: Loss 0.149
# Epoch 220: Loss 0.148
# Epoch 221: Loss 0.148
# Epoch 222: Loss 0.147
# Epoch 223: Loss 0.149
# Epoch 224: Loss 0.148
# Epoch 225: Loss 0.147
# Epoch 226: Loss 0.149
# Epoch 227: Loss 0.147
# Epoch 228: Loss 0.149
# Epoch 229: Loss 0.148
# Epoch 230: Loss 0.148
# Epoch 231: Loss 0.146
# Epoch 232: Loss 0.148
# Epoch 233: Loss 0.148
# Epoch 234: Loss 0.146
# Epoch 235: Loss 0.147
# Epoch 236: Loss 0.148
# Epoch 237: Loss 0.146
# Epoch 238: Loss 0.147
# Epoch 239: Loss 0.147
# Epoch 240: Loss 0.145
# Epoch 241: Loss 0.147
# Epoch 242: Loss 0.145
# Epoch 243: Loss 0.146
# Epoch 244: Loss 0.146
# Epoch 245: Loss 0.144
# Epoch 246: Loss 0.147
# Epoch 247: Loss 0.144
# Epoch 248: Loss 0.146
# Epoch 249: Loss 0.146
# Epoch 250: Loss 0.146
# Epoch 251: Loss 0.145
# Epoch 252: Loss 0.144
# Epoch 253: Loss 0.146
# Epoch 254: Loss 0.145
# Epoch 255: Loss 0.143
# Epoch 256: Loss 0.144
# Epoch 257: Loss 0.145
# Epoch 258: Loss 0.146
# Epoch 259: Loss 0.143
# Epoch 260: Loss 0.144
# Epoch 261: Loss 0.143
# Epoch 262: Loss 0.143
# Epoch 263: Loss 0.144
# Epoch 264: Loss 0.143
# Epoch 265: Loss 0.142
# Epoch 266: Loss 0.145
# Epoch 267: Loss 0.143
# Epoch 268: Loss 0.143
# Epoch 269: Loss 0.142
# Epoch 270: Loss 0.145
# Epoch 271: Loss 0.143
# Epoch 272: Loss 0.143
# Epoch 273: Loss 0.143
# Epoch 274: Loss 0.141
# Epoch 275: Loss 0.144
# Epoch 276: Loss 0.143
# Epoch 277: Loss 0.142
# Epoch 278: Loss 0.140
# Epoch 279: Loss 0.141
# Epoch 280: Loss 0.143
# Epoch 281: Loss 0.141
# Epoch 282: Loss 0.141
# Epoch 283: Loss 0.141
# Epoch 284: Loss 0.142
# Epoch 285: Loss 0.141
# Epoch 286: Loss 0.139
# Epoch 287: Loss 0.143
# Epoch 288: Loss 0.140
# Epoch 289: Loss 0.140
# Epoch 290: Loss 0.142
# Epoch 291: Loss 0.141
# Epoch 292: Loss 0.139
# Epoch 293: Loss 0.141
# Epoch 294: Loss 0.140
# Epoch 295: Loss 0.140
# Epoch 296: Loss 0.140
# Epoch 297: Loss 0.139
# Epoch 298: Loss 0.139
# Epoch 299: Loss 0.140
# Epoch 300: Loss 0.139
# Epoch 301: Loss 0.141
# Epoch 302: Loss 0.139
# Epoch 303: Loss 0.138
# Epoch 304: Loss 0.140
# Epoch 305: Loss 0.138
# Epoch 306: Loss 0.141
# Epoch 307: Loss 0.136
# Epoch 308: Loss 0.138
# Epoch 309: Loss 0.140
# Epoch 310: Loss 0.139
# Epoch 311: Loss 0.140
# Epoch 312: Loss 0.139
# Epoch 313: Loss 0.139
# Epoch 314: Loss 0.137
# Epoch 315: Loss 0.138
# Epoch 316: Loss 0.137
# Epoch 317: Loss 0.137
# Epoch 318: Loss 0.140
# Epoch 319: Loss 0.140
# Epoch 320: Loss 0.137
# Epoch 321: Loss 0.137
# Epoch 322: Loss 0.136
# Epoch 323: Loss 0.140
# Epoch 324: Loss 0.138
# Epoch 325: Loss 0.137
# Epoch 326: Loss 0.138
# Epoch 327: Loss 0.138
# Epoch 328: Loss 0.134
# Epoch 329: Loss 0.137
# Epoch 330: Loss 0.138
# Epoch 331: Loss 0.134
# Epoch 332: Loss 0.138
# Epoch 333: Loss 0.138
# Epoch 334: Loss 0.136
# Epoch 335: Loss 0.135
# Epoch 336: Loss 0.135
# Epoch 337: Loss 0.139
# Epoch 338: Loss 0.134
# Epoch 339: Loss 0.138
# Epoch 340: Loss 0.134
# Epoch 341: Loss 0.137
# Epoch 342: Loss 0.134
# Epoch 343: Loss 0.136
# Epoch 344: Loss 0.137
# Epoch 345: Loss 0.140
# Epoch 346: Loss 0.132
# Epoch 347: Loss 0.135
# Epoch 348: Loss 0.137
# Epoch 349: Loss 0.136
# Epoch 350: Loss 0.135
# Epoch 351: Loss 0.135
# Epoch 352: Loss 0.133
# Epoch 353: Loss 0.138
# Epoch 354: Loss 0.135
# Epoch 355: Loss 0.135
# Epoch 356: Loss 0.137
# Epoch 357: Loss 0.133
# Epoch 358: Loss 0.133
# Epoch 359: Loss 0.134
# Epoch 360: Loss 0.135
# Epoch 361: Loss 0.130
# Epoch 362: Loss 0.132
# Epoch 363: Loss 0.133
# Epoch 364: Loss 0.131
# Epoch 365: Loss 0.134
# Epoch 366: Loss 0.134
# Epoch 367: Loss 0.130
# Epoch 368: Loss 0.136
# Epoch 369: Loss 0.132
# Epoch 370: Loss 0.134
# Epoch 371: Loss 0.130
# Epoch 372: Loss 0.132
# Epoch 373: Loss 0.133
# Epoch 374: Loss 0.134
# Epoch 375: Loss 0.130
# Epoch 376: Loss 0.132
# Epoch 377: Loss 0.133
# Epoch 378: Loss 0.132
# Epoch 379: Loss 0.140
# Epoch 380: Loss 0.135
# Epoch 381: Loss 0.129
# Epoch 382: Loss 0.130
# Epoch 383: Loss 0.134
# Epoch 384: Loss 0.131
# Epoch 385: Loss 0.138
# Epoch 386: Loss 0.129
# Epoch 387: Loss 0.129
# Epoch 388: Loss 0.133
# Epoch 389: Loss 0.129
# Epoch 390: Loss 0.133
# Epoch 391: Loss 0.128
# Epoch 392: Loss 0.130
# Epoch 393: Loss 0.127
# Epoch 394: Loss 0.125
# Epoch 395: Loss 0.126
# Epoch 396: Loss 0.127
# Epoch 397: Loss 0.132
# Epoch 398: Loss 0.134
# Epoch 399: Loss 0.132
# Epoch 400: Loss 0.131
# Epoch 401: Loss 0.126
# Epoch 402: Loss 0.127
# Epoch 403: Loss 0.127
# Epoch 404: Loss 0.126
# Epoch 405: Loss 0.134
# Epoch 406: Loss 0.128
# Epoch 407: Loss 0.131
# Epoch 408: Loss 0.125
# Epoch 409: Loss 0.128
# Epoch 410: Loss 0.127
# Epoch 411: Loss 0.124
# Epoch 412: Loss 0.125
# Epoch 413: Loss 0.127
# Epoch 414: Loss 0.129
# Epoch 415: Loss 0.131
# Epoch 416: Loss 0.125
# Epoch 417: Loss 0.125
# Epoch 418: Loss 0.131
# Epoch 419: Loss 0.124
# Epoch 420: Loss 0.129
# Epoch 421: Loss 0.125
# Epoch 422: Loss 0.125
# Epoch 423: Loss 0.128
# Epoch 424: Loss 0.125
# Epoch 425: Loss 0.129
# Epoch 426: Loss 0.126
# Epoch 427: Loss 0.133
# Epoch 428: Loss 0.124
# Epoch 429: Loss 0.126
# Epoch 430: Loss 0.126
# Epoch 431: Loss 0.128
# Epoch 432: Loss 0.123
# Epoch 433: Loss 0.124
# Epoch 434: Loss 0.123
# Epoch 435: Loss 0.127
# Epoch 436: Loss 0.119
# Epoch 437: Loss 0.120
# Epoch 438: Loss 0.121
# Epoch 439: Loss 0.126
# Epoch 440: Loss 0.120
# Epoch 441: Loss 0.122
# Epoch 442: Loss 0.125
# Epoch 443: Loss 0.122
# Epoch 444: Loss 0.123
# Epoch 445: Loss 0.121
# Epoch 446: Loss 0.123
# Epoch 447: Loss 0.121
# Epoch 448: Loss 0.123
# Epoch 449: Loss 0.120
# Epoch 450: Loss 0.120
# Epoch 451: Loss 0.118
# Epoch 452: Loss 0.119
# Epoch 453: Loss 0.126
# Epoch 454: Loss 0.126
# Epoch 455: Loss 0.118
# Epoch 456: Loss 0.126
# Epoch 457: Loss 0.118
# Epoch 458: Loss 0.125
# Epoch 459: Loss 0.118
# Epoch 460: Loss 0.120
# Epoch 461: Loss 0.117
# Epoch 462: Loss 0.122
# Epoch 463: Loss 0.119
# Epoch 464: Loss 0.125
# Epoch 465: Loss 0.117
# Epoch 466: Loss 0.124
# Epoch 467: Loss 0.116
# Epoch 468: Loss 0.120
# Epoch 469: Loss 0.117
# Epoch 470: Loss 0.123
# Epoch 471: Loss 0.115
# Epoch 472: Loss 0.129
# Epoch 473: Loss 0.114
# Epoch 474: Loss 0.121
# Epoch 475: Loss 0.114
# Epoch 476: Loss 0.124
# Epoch 477: Loss 0.118
# Epoch 478: Loss 0.119
# Epoch 479: Loss 0.118
# Epoch 480: Loss 0.115
# Epoch 481: Loss 0.114
# Epoch 482: Loss 0.119
# Epoch 483: Loss 0.113
# Epoch 484: Loss 0.113
# Epoch 485: Loss 0.114
# Epoch 486: Loss 0.119
# Epoch 487: Loss 0.114
# Epoch 488: Loss 0.117
# Epoch 489: Loss 0.113
# Epoch 490: Loss 0.113
# Epoch 491: Loss 0.114
# Epoch 492: Loss 0.117
# Epoch 493: Loss 0.112
# Epoch 494: Loss 0.113
# Epoch 495: Loss 0.113
# Epoch 496: Loss 0.114
# Epoch 497: Loss 0.114
# Epoch 498: Loss 0.113
# Epoch 499: Loss 0.111
# Epoch 500: Loss 0.116
# Epoch 501: Loss 0.114
# Epoch 502: Loss 0.119
# Epoch 503: Loss 0.114
# Epoch 504: Loss 0.108
# Epoch 505: Loss 0.110
# Epoch 506: Loss 0.109
# Epoch 507: Loss 0.108
# Epoch 508: Loss 0.114
# Epoch 509: Loss 0.107
# Epoch 510: Loss 0.116
# Epoch 511: Loss 0.114
# Epoch 512: Loss 0.103
# Epoch 513: Loss 0.108
# Epoch 514: Loss 0.106
# Epoch 515: Loss 0.114
# Epoch 516: Loss 0.111
# Epoch 517: Loss 0.109
# Epoch 518: Loss 0.113
# Epoch 519: Loss 0.110
# Epoch 520: Loss 0.105
# Epoch 521: Loss 0.115
# Epoch 522: Loss 0.106
# Epoch 523: Loss 0.109
# Epoch 524: Loss 0.098
# Epoch 525: Loss 0.127
# Epoch 526: Loss 0.113
# Epoch 527: Loss 0.099
# Epoch 528: Loss 0.109
# Epoch 529: Loss 0.104
# Epoch 530: Loss 0.099
# Epoch 531: Loss 0.104
# Epoch 532: Loss 0.099
# Epoch 533: Loss 0.123
# Epoch 534: Loss 0.108
# Epoch 535: Loss 0.106
# Epoch 536: Loss 0.100
# Epoch 537: Loss 0.099
# Epoch 538: Loss 0.100
# Epoch 539: Loss 0.097
# Epoch 540: Loss 0.100
# Epoch 541: Loss 0.096
# Epoch 542: Loss 0.096
# Epoch 543: Loss 0.103
# Epoch 544: Loss 0.107
# Epoch 545: Loss 0.101
# Epoch 546: Loss 0.100
# Epoch 547: Loss 0.101
# Epoch 548: Loss 0.098
# Epoch 549: Loss 0.097
# Epoch 550: Loss 0.101
# Epoch 551: Loss 0.095
# Epoch 552: Loss 0.099
# Epoch 553: Loss 0.095
# Epoch 554: Loss 0.102
# Epoch 555: Loss 0.101
# Epoch 556: Loss 0.099
# Epoch 557: Loss 0.099
# Epoch 558: Loss 0.098
# Epoch 559: Loss 0.099
# Epoch 560: Loss 0.108
# Epoch 561: Loss 0.100
# Epoch 562: Loss 0.109
# Epoch 563: Loss 0.103
# Epoch 564: Loss 0.103
# Epoch 565: Loss 0.104
# Epoch 566: Loss 0.102
# Epoch 567: Loss 0.113
# Epoch 568: Loss 0.102
# Epoch 569: Loss 0.102
# Epoch 570: Loss 0.096
# Epoch 571: Loss 0.105
# Epoch 572: Loss 0.101
# Epoch 573: Loss 0.096
# Epoch 574: Loss 0.110
# Epoch 575: Loss 0.099
# Epoch 576: Loss 0.098
# Epoch 577: Loss 0.093
# Epoch 578: Loss 0.108
# Epoch 579: Loss 0.099
# Epoch 580: Loss 0.094
# Epoch 581: Loss 0.095
# Epoch 582: Loss 0.099
# Epoch 583: Loss 0.096
# Epoch 584: Loss 0.091
# Epoch 585: Loss 0.094
# Epoch 586: Loss 0.095
# Epoch 587: Loss 0.090
# Epoch 588: Loss 0.097
# Epoch 589: Loss 0.095
# Epoch 590: Loss 0.091
# Epoch 591: Loss 0.090
# Epoch 592: Loss 0.103
# Epoch 593: Loss 0.094
# Epoch 594: Loss 0.092
# Epoch 595: Loss 0.092
# Epoch 596: Loss 0.102
# Epoch 597: Loss 0.094
# Epoch 598: Loss 0.093
# Epoch 599: Loss 0.090
# Epoch 600: Loss 0.094
# Epoch 601: Loss 0.094
# Epoch 602: Loss 0.092
# Epoch 603: Loss 0.098
# Epoch 604: Loss 0.094
# Epoch 605: Loss 0.094
# Epoch 606: Loss 0.090
# Epoch 607: Loss 0.100
# Epoch 608: Loss 0.089
# Epoch 609: Loss 0.089
# Epoch 610: Loss 0.090
# Epoch 611: Loss 0.089
# Epoch 612: Loss 0.092
# Epoch 613: Loss 0.095
# Epoch 614: Loss 0.089
# Epoch 615: Loss 0.105
# Epoch 616: Loss 0.089
# Epoch 617: Loss 0.091
# Epoch 618: Loss 0.090
# Epoch 619: Loss 0.090
# Epoch 620: Loss 0.093
# Epoch 621: Loss 0.090
# Epoch 622: Loss 0.089
# Epoch 623: Loss 0.091
# Epoch 624: Loss 0.090
# Epoch 625: Loss 0.095
# Epoch 626: Loss 0.087
# Epoch 627: Loss 0.086
# Epoch 628: Loss 0.089
# Epoch 629: Loss 0.086
# Epoch 630: Loss 0.111
# Epoch 631: Loss 0.088
# Epoch 632: Loss 0.086
# Epoch 633: Loss 0.087
# Epoch 634: Loss 0.089
# Epoch 635: Loss 0.088
# Epoch 636: Loss 0.088
# Epoch 637: Loss 0.089
# Epoch 638: Loss 0.089
# Epoch 639: Loss 0.085
# Epoch 640: Loss 0.113
# Epoch 641: Loss 0.087
# Epoch 642: Loss 0.087
# Epoch 643: Loss 0.089
# Epoch 644: Loss 0.088
# Epoch 645: Loss 0.090
# Epoch 646: Loss 0.088
# Epoch 647: Loss 0.142
# Epoch 648: Loss 0.087
# Epoch 649: Loss 0.085
# Epoch 650: Loss 0.086
# Epoch 651: Loss 0.085
# Epoch 652: Loss 0.086
# Epoch 653: Loss 0.090
# Epoch 654: Loss 0.087
# Epoch 655: Loss 0.088
# Epoch 656: Loss 0.082
# Epoch 657: Loss 0.099
# Epoch 658: Loss 0.082
# Epoch 659: Loss 0.086
# Epoch 660: Loss 0.088
# Epoch 661: Loss 0.082
# Epoch 662: Loss 0.095
# Epoch 663: Loss 0.086
# Epoch 664: Loss 0.107
# Epoch 665: Loss 0.082
# Epoch 666: Loss 0.083
# Epoch 667: Loss 0.084
# Epoch 668: Loss 0.080
# Epoch 669: Loss 0.085
# Epoch 670: Loss 0.082
# Epoch 671: Loss 0.129
# Epoch 672: Loss 0.086
# Epoch 673: Loss 0.087
# Epoch 674: Loss 0.081
# Epoch 675: Loss 0.080
# Epoch 676: Loss 0.086
# Epoch 677: Loss 0.082
# Epoch 678: Loss 0.089
# Epoch 679: Loss 0.084
# Epoch 680: Loss 0.083
# Epoch 681: Loss 0.082
# Epoch 682: Loss 0.085
# Epoch 683: Loss 0.082
# Epoch 684: Loss 0.084
# Epoch 685: Loss 0.078
# Epoch 686: Loss 0.084
# Epoch 687: Loss 0.083
# Epoch 688: Loss 0.089
# Epoch 689: Loss 0.118
# Epoch 690: Loss 0.083
# Epoch 691: Loss 0.079
# Epoch 692: Loss 0.082
# Epoch 693: Loss 0.082
# Epoch 694: Loss 0.078
# Epoch 695: Loss 0.093
# Epoch 696: Loss 0.093
# Epoch 697: Loss 0.109
# Epoch 698: Loss 0.085
# Epoch 699: Loss 0.091
# Epoch 700: Loss 0.081
# Epoch 701: Loss 0.080
# Epoch 702: Loss 0.081
# Epoch 703: Loss 0.083
# Epoch 704: Loss 0.074
# Epoch 705: Loss 0.101
# Epoch 706: Loss 0.078
# Epoch 707: Loss 0.086
# Epoch 708: Loss 0.073
# Epoch 709: Loss 0.092
# Epoch 710: Loss 0.086
# Epoch 711: Loss 0.098
# Epoch 712: Loss 0.083
# Epoch 713: Loss 0.083
# Epoch 714: Loss 0.079
# Epoch 715: Loss 0.086
# Epoch 716: Loss 0.079
# Epoch 717: Loss 0.104
# Epoch 718: Loss 0.081
# Epoch 719: Loss 0.081
# Epoch 720: Loss 0.079
# Epoch 721: Loss 0.085
# Epoch 722: Loss 0.081
# Epoch 723: Loss 0.106
# Epoch 724: Loss 0.079
# Epoch 725: Loss 0.087
# Epoch 726: Loss 0.083
# Epoch 727: Loss 0.080
# Epoch 728: Loss 0.078
# Epoch 729: Loss 0.089
# Epoch 730: Loss 0.080
# Epoch 731: Loss 0.090
# Epoch 732: Loss 0.080
# Epoch 733: Loss 0.078
# Epoch 734: Loss 0.077
# Epoch 735: Loss 0.074
# Epoch 736: Loss 0.074
# Epoch 737: Loss 0.093
# Epoch 738: Loss 0.076
# Epoch 739: Loss 0.082
# Epoch 740: Loss 0.086
# Epoch 741: Loss 0.077
# Epoch 742: Loss 0.074
# Epoch 743: Loss 0.083
# Epoch 744: Loss 0.077
# Epoch 745: Loss 0.079
# Epoch 746: Loss 0.072
# Epoch 747: Loss 0.102
# Epoch 748: Loss 0.074
# Epoch 749: Loss 0.081
# Epoch 750: Loss 0.077
# Epoch 751: Loss 0.075
# Epoch 752: Loss 0.075
# Epoch 753: Loss 0.079
# Epoch 754: Loss 0.073
# Epoch 755: Loss 0.141
# Epoch 756: Loss 0.080
# Epoch 757: Loss 0.078
# Epoch 758: Loss 0.077
# Epoch 759: Loss 0.074
# Epoch 760: Loss 0.072
# Epoch 761: Loss 0.076
# Epoch 762: Loss 0.077
# Epoch 763: Loss 0.073
# Epoch 764: Loss 0.082
# Epoch 765: Loss 0.084
# Epoch 766: Loss 0.080
# Epoch 767: Loss 0.074
# Epoch 768: Loss 0.078
# Epoch 769: Loss 0.076
# Epoch 770: Loss 0.078
# Epoch 771: Loss 0.074
# Epoch 772: Loss 0.078
# Epoch 773: Loss 0.073
# Epoch 774: Loss 0.074
# Epoch 775: Loss 0.079
# Epoch 776: Loss 0.088
# Epoch 777: Loss 0.079
# Epoch 778: Loss 0.076
# Epoch 779: Loss 0.073
# Epoch 780: Loss 0.077
# Epoch 781: Loss 0.078
# Epoch 782: Loss 0.080
# Epoch 783: Loss 0.076
# Epoch 784: Loss 0.081
# Epoch 785: Loss 0.073
# Epoch 786: Loss 0.081
# Epoch 787: Loss 0.078
# Epoch 788: Loss 0.068
# Epoch 789: Loss 0.080
# Epoch 790: Loss 0.071
# Epoch 791: Loss 0.071
# Epoch 792: Loss 0.073
# Epoch 793: Loss 0.072
# Epoch 794: Loss 0.079
# Epoch 795: Loss 0.071
# Epoch 796: Loss 0.068
# Epoch 797: Loss 0.075
# Epoch 798: Loss 0.069
# Epoch 799: Loss 0.070
# Epoch 800: Loss 0.088
# Epoch 801: Loss 0.072
# Epoch 802: Loss 0.072
# Epoch 803: Loss 0.071
# Epoch 804: Loss 0.073
# Epoch 805: Loss 0.068
# Epoch 806: Loss 0.068
# Epoch 807: Loss 0.171
# Epoch 808: Loss 0.087
# Epoch 809: Loss 0.078
# Epoch 810: Loss 0.072
# Epoch 811: Loss 0.074
# Epoch 812: Loss 0.070
# Epoch 813: Loss 0.070
# Epoch 814: Loss 0.068
# Epoch 815: Loss 0.079
# Epoch 816: Loss 0.071
# Epoch 817: Loss 0.065
# Epoch 818: Loss 0.071
# Epoch 819: Loss 0.069
# Epoch 820: Loss 0.071
# Epoch 821: Loss 0.074
# Epoch 822: Loss 0.073
# Epoch 823: Loss 0.073
# Epoch 824: Loss 0.066
# Epoch 825: Loss 0.074
# Epoch 826: Loss 0.070
# Epoch 827: Loss 0.069
# Epoch 828: Loss 0.077
# Epoch 829: Loss 0.072
# Epoch 830: Loss 0.066
# Epoch 831: Loss 0.067
# Epoch 832: Loss 0.069
# Epoch 833: Loss 0.069
# Epoch 834: Loss 0.062
# Epoch 835: Loss 0.073
# Epoch 836: Loss 0.071
# Epoch 837: Loss 0.073
# Epoch 838: Loss 0.065
# Epoch 839: Loss 0.069
# Epoch 840: Loss 0.078
# Epoch 841: Loss 0.069
# Epoch 842: Loss 0.070
# Epoch 843: Loss 0.061
# Epoch 844: Loss 0.067
# Epoch 845: Loss 0.069
# Epoch 846: Loss 0.068
# Epoch 847: Loss 0.064
# Epoch 848: Loss 0.079
# Epoch 849: Loss 0.081
# Epoch 850: Loss 0.068
# Epoch 851: Loss 0.066
# Epoch 852: Loss 0.070
# Epoch 853: Loss 0.066
# Epoch 854: Loss 0.061
# Epoch 855: Loss 0.074
# Epoch 856: Loss 0.069
# Epoch 857: Loss 0.075
# Epoch 858: Loss 0.065
# Epoch 859: Loss 0.065
# Epoch 860: Loss 0.065
# Epoch 861: Loss 0.069
# Epoch 862: Loss 0.065
# Epoch 863: Loss 0.066
# Epoch 864: Loss 0.065
# Epoch 865: Loss 0.075
# Epoch 866: Loss 0.074
# Epoch 867: Loss 0.064
# Epoch 868: Loss 0.070
# Epoch 869: Loss 0.061
# Epoch 870: Loss 0.078
# Epoch 871: Loss 0.069
# Epoch 872: Loss 0.073
# Epoch 873: Loss 0.069
# Epoch 874: Loss 0.071
# Epoch 875: Loss 0.071
# Epoch 876: Loss 0.067
# Epoch 877: Loss 0.062
# Epoch 878: Loss 0.060
# Epoch 879: Loss 0.078
# Epoch 880: Loss 0.061
# Epoch 881: Loss 0.074
# Epoch 882: Loss 0.071
# Epoch 883: Loss 0.071
# Epoch 884: Loss 0.067
# Epoch 885: Loss 0.072
# Epoch 886: Loss 0.059
# Epoch 887: Loss 0.067
# Epoch 888: Loss 0.069
# Epoch 889: Loss 0.063
# Epoch 890: Loss 0.062
# Epoch 891: Loss 0.062
# Epoch 892: Loss 0.070
# Epoch 893: Loss 0.073
# Epoch 894: Loss 0.062
# Epoch 895: Loss 0.070
# Epoch 896: Loss 0.064
# Epoch 897: Loss 0.062
# Epoch 898: Loss 0.061
# Epoch 899: Loss 0.066
# Epoch 900: Loss 0.070
# Epoch 901: Loss 0.066
# Epoch 902: Loss 0.073
# Epoch 903: Loss 0.074
# Epoch 904: Loss 0.065
# Epoch 905: Loss 0.058
# Epoch 906: Loss 0.066
# Epoch 907: Loss 0.069
# Epoch 908: Loss 0.065
# Epoch 909: Loss 0.062
# Epoch 910: Loss 0.069
# Epoch 911: Loss 0.064
# Epoch 912: Loss 0.062
# Epoch 913: Loss 0.063
# Epoch 914: Loss 0.060
# Epoch 915: Loss 0.061
# Epoch 916: Loss 0.064
# Epoch 917: Loss 0.069
# Epoch 918: Loss 0.067
# Epoch 919: Loss 0.063
# Epoch 920: Loss 0.079
# Epoch 921: Loss 0.066
# Epoch 922: Loss 0.059
# Epoch 923: Loss 0.058
# Epoch 924: Loss 0.056
# Epoch 925: Loss 0.058
# Epoch 926: Loss 0.059
# Epoch 927: Loss 0.057
# Epoch 928: Loss 0.061
# Epoch 929: Loss 0.056
# Epoch 930: Loss 0.062
# Epoch 931: Loss 0.065
# Epoch 932: Loss 0.060
# Epoch 933: Loss 0.064
# Epoch 934: Loss 0.061
# Epoch 935: Loss 0.066
# Epoch 936: Loss 0.082
# Epoch 937: Loss 0.060
# Epoch 938: Loss 0.051
# Epoch 939: Loss 0.057
# Epoch 940: Loss 0.066
# Epoch 941: Loss 0.061
# Epoch 942: Loss 0.062
# Epoch 943: Loss 0.070
# Epoch 944: Loss 0.062
# Epoch 945: Loss 0.063
# Epoch 946: Loss 0.059
# Epoch 947: Loss 0.055
# Epoch 948: Loss 0.055
# Epoch 949: Loss 0.058
# Epoch 950: Loss 0.054
# Epoch 951: Loss 0.060
# Epoch 952: Loss 0.061
# Epoch 953: Loss 0.061
# Epoch 954: Loss 0.056
# Epoch 955: Loss 0.061
# Epoch 956: Loss 0.056
# Epoch 957: Loss 0.054
# Epoch 958: Loss 0.059
# Epoch 959: Loss 0.054
# Epoch 960: Loss 0.055
# Epoch 961: Loss 0.059
# Epoch 962: Loss 0.071
# Epoch 963: Loss 0.059
# Epoch 964: Loss 0.056
# Epoch 965: Loss 0.061
# Epoch 966: Loss 0.052
# Epoch 967: Loss 0.069
# Epoch 968: Loss 0.066
# Epoch 969: Loss 0.056
# Epoch 970: Loss 0.051
# Epoch 971: Loss 0.057
# Epoch 972: Loss 0.055
# Epoch 973: Loss 0.057
# Epoch 974: Loss 0.068
# Epoch 975: Loss 0.054
# Epoch 976: Loss 0.050
# Epoch 977: Loss 0.054
# Epoch 978: Loss 0.060
# Epoch 979: Loss 0.066
# Epoch 980: Loss 0.063
# Epoch 981: Loss 0.062
# Epoch 982: Loss 0.057
# Epoch 983: Loss 0.049
# Epoch 984: Loss 0.084
# Epoch 985: Loss 0.063
# Epoch 986: Loss 0.068
# Epoch 987: Loss 0.051
# Epoch 988: Loss 0.059
# Epoch 989: Loss 0.053
# Epoch 990: Loss 0.064
# Epoch 991: Loss 0.061
# Epoch 992: Loss 0.051
# Epoch 993: Loss 0.079
# Epoch 994: Loss 0.067
# Epoch 995: Loss 0.061
# Epoch 996: Loss 0.052
# Epoch 997: Loss 0.050
# Epoch 998: Loss 0.074
# Epoch 999: Loss 0.066
# Epoch 1000: Loss 0.061
# Epoch 1: Loss 0.410
# Epoch 2: Loss 0.279
# Epoch 3: Loss 0.275
# Epoch 4: Loss 0.274
# Epoch 5: Loss 0.273
# Epoch 6: Loss 0.271
# Epoch 7: Loss 0.270
# Epoch 8: Loss 0.269
# Epoch 9: Loss 0.268
# Epoch 10: Loss 0.267
# Epoch 11: Loss 0.266
# Epoch 12: Loss 0.264
# Epoch 13: Loss 0.263
# Epoch 14: Loss 0.261
# Epoch 15: Loss 0.260
# Epoch 16: Loss 0.258
# Epoch 17: Loss 0.256
# Epoch 18: Loss 0.254
# Epoch 19: Loss 0.252
# Epoch 20: Loss 0.249
# Epoch 21: Loss 0.247
# Epoch 22: Loss 0.245
# Epoch 23: Loss 0.242
# Epoch 24: Loss 0.239
# Epoch 25: Loss 0.237
# Epoch 26: Loss 0.234
# Epoch 27: Loss 0.231
# Epoch 28: Loss 0.229
# Epoch 29: Loss 0.226
# Epoch 30: Loss 0.224
# Epoch 31: Loss 0.222
# Epoch 32: Loss 0.220
# Epoch 33: Loss 0.218
# Epoch 34: Loss 0.216
# Epoch 35: Loss 0.215
# Epoch 36: Loss 0.213
# Epoch 37: Loss 0.212
# Epoch 38: Loss 0.211
# Epoch 39: Loss 0.210
# Epoch 40: Loss 0.209
# Epoch 41: Loss 0.207
# Epoch 42: Loss 0.207
# Epoch 43: Loss 0.205
# Epoch 44: Loss 0.204
# Epoch 45: Loss 0.204
# Epoch 46: Loss 0.203
# Epoch 47: Loss 0.202
# Epoch 48: Loss 0.201
# Epoch 49: Loss 0.200
# Epoch 50: Loss 0.199
# Epoch 51: Loss 0.199
# Epoch 52: Loss 0.198
# Epoch 53: Loss 0.198
# Epoch 54: Loss 0.197
# Epoch 55: Loss 0.197
# Epoch 56: Loss 0.197
# Epoch 57: Loss 0.196
# Epoch 58: Loss 0.195
# Epoch 59: Loss 0.195
# Epoch 60: Loss 0.194
# Epoch 61: Loss 0.193
# Epoch 62: Loss 0.193
# Epoch 63: Loss 0.192
# Epoch 64: Loss 0.193
# Epoch 65: Loss 0.191
# Epoch 66: Loss 0.191
# Epoch 67: Loss 0.190
# Epoch 68: Loss 0.190
# Epoch 69: Loss 0.191
# Epoch 70: Loss 0.190
# Epoch 71: Loss 0.189
# Epoch 72: Loss 0.190
# Epoch 73: Loss 0.188
# Epoch 74: Loss 0.188
# Epoch 75: Loss 0.189
# Epoch 76: Loss 0.188
# Epoch 77: Loss 0.187
# Epoch 78: Loss 0.187
# Epoch 79: Loss 0.188
# Epoch 80: Loss 0.186
# Epoch 81: Loss 0.186
# Epoch 82: Loss 0.185
# Epoch 83: Loss 0.184
# Epoch 84: Loss 0.184
# Epoch 85: Loss 0.183
# Epoch 86: Loss 0.183
# Epoch 87: Loss 0.186
# Epoch 88: Loss 0.182
# Epoch 89: Loss 0.182
# Epoch 90: Loss 0.182
# Epoch 91: Loss 0.180
# Epoch 92: Loss 0.181
# Epoch 93: Loss 0.182
# Epoch 94: Loss 0.179
# Epoch 95: Loss 0.180
# Epoch 96: Loss 0.178
# Epoch 97: Loss 0.181
# Epoch 98: Loss 0.177
# Epoch 99: Loss 0.176
# Epoch 100: Loss 0.176
# Epoch 101: Loss 0.175
# Epoch 102: Loss 0.175
# Epoch 103: Loss 0.175
# Epoch 104: Loss 0.175
# Epoch 105: Loss 0.176
# Epoch 106: Loss 0.172
# Epoch 107: Loss 0.172
# Epoch 108: Loss 0.177
# Epoch 109: Loss 0.171
# Epoch 110: Loss 0.169
# Epoch 111: Loss 0.169
# Epoch 112: Loss 0.172
# Epoch 113: Loss 0.168
# Epoch 114: Loss 0.173
# Epoch 115: Loss 0.167
# Epoch 116: Loss 0.164
# Epoch 117: Loss 0.164
# Epoch 118: Loss 0.166
# Epoch 119: Loss 0.163
# Epoch 120: Loss 0.162
# Epoch 121: Loss 0.161
# Epoch 122: Loss 0.164
# Epoch 123: Loss 0.163
# Epoch 124: Loss 0.161
# Epoch 125: Loss 0.159
# Epoch 126: Loss 0.161
# Epoch 127: Loss 0.159
# Epoch 128: Loss 0.170
# Epoch 129: Loss 0.161
# Epoch 130: Loss 0.156
# Epoch 131: Loss 0.155
# Epoch 132: Loss 0.163
# Epoch 133: Loss 0.157
# Epoch 134: Loss 0.168
# Epoch 135: Loss 0.158
# Epoch 136: Loss 0.154
# Epoch 137: Loss 0.155
# Epoch 138: Loss 0.161
# Epoch 139: Loss 0.154
# Epoch 140: Loss 0.152
# Epoch 141: Loss 0.164
# Epoch 142: Loss 0.153
# Epoch 143: Loss 0.152
# Epoch 144: Loss 0.161
# Epoch 145: Loss 0.153
# Epoch 146: Loss 0.151
# Epoch 147: Loss 0.151
# Epoch 148: Loss 0.154
# Epoch 149: Loss 0.150
# Epoch 150: Loss 0.147
# Epoch 151: Loss 0.146
# Epoch 152: Loss 0.154
# Epoch 153: Loss 0.149
# Epoch 154: Loss 0.149
# Epoch 155: Loss 0.146
# Epoch 156: Loss 0.152
# Epoch 157: Loss 0.146
# Epoch 158: Loss 0.152
# Epoch 159: Loss 0.164
# Epoch 160: Loss 0.158
# Epoch 161: Loss 0.155
# Epoch 162: Loss 0.153
# Epoch 163: Loss 0.147
# Epoch 164: Loss 0.142
# Epoch 165: Loss 0.173
# Epoch 166: Loss 0.160
# Epoch 167: Loss 0.176
# Epoch 168: Loss 0.166
# Epoch 169: Loss 0.160
# Epoch 170: Loss 0.155
# Epoch 171: Loss 0.150
# Epoch 172: Loss 0.146
# Epoch 173: Loss 0.146
# Epoch 174: Loss 0.148
# Epoch 175: Loss 0.146
# Epoch 176: Loss 0.146
# Epoch 177: Loss 0.145
# Epoch 178: Loss 0.146
# Epoch 179: Loss 0.141
# Epoch 180: Loss 0.139
# Epoch 181: Loss 0.155
# Epoch 182: Loss 0.151
# Epoch 183: Loss 0.140
# Epoch 184: Loss 0.168
# Epoch 185: Loss 0.153
# Epoch 186: Loss 0.151
# Epoch 187: Loss 0.151
# Epoch 188: Loss 0.144
# Epoch 189: Loss 0.147
# Epoch 190: Loss 0.163
# Epoch 191: Loss 0.149
# Epoch 192: Loss 0.134
# Epoch 193: Loss 0.154
# Epoch 194: Loss 0.145
# Epoch 195: Loss 0.162
# Epoch 196: Loss 0.169
# ...
# Epoch 274: Loss 0.135
# Epoch 275: Loss 0.130
# Epoch 276: Loss 0.122
# Epoch 277: Loss 0.135
# Epoch 278: Loss 0.134
# Epoch 279: Loss 0.124
# Epoch 280: Loss 0.126
# Epoch 281: Loss 0.135
# Epoch 282: Loss 0.128
# Epoch 283: Loss 0.128
# Epoch 284: Loss 0.123
# Epoch 285: Loss 0.123
# Epoch 286: Loss 0.128
# Epoch 287: Loss 0.143
# Epoch 288: Loss 0.126
# Epoch 289: Loss 0.126
# Epoch 290: Loss 0.126
# Epoch 291: Loss 0.122
# Epoch 292: Loss 0.127
# Epoch 293: Loss 0.149
# Epoch 294: Loss 0.123
# Epoch 295: Loss 0.123
# Epoch 296: Loss 0.140
# Epoch 297: Loss 0.120
# Epoch 298: Loss 0.119
# Epoch 299: Loss 0.134
# Epoch 300: Loss 0.120
# Epoch 301: Loss 0.119
# Epoch 302: Loss 0.122
# Epoch 303: Loss 0.135
# Epoch 304: Loss 0.119
# Epoch 305: Loss 0.121
# Epoch 306: Loss 0.117
# Epoch 307: Loss 0.131
# Epoch 308: Loss 0.121
# Epoch 309: Loss 0.109
# Epoch 310: Loss 0.124
# Epoch 311: Loss 0.123
# Epoch 312: Loss 0.137
# Epoch 313: Loss 0.112
# Epoch 314: Loss 0.107
# Epoch 315: Loss 0.106
# Epoch 316: Loss 0.155
# Epoch 317: Loss 0.119
# Epoch 318: Loss 0.114
# Epoch 319: Loss 0.141
# Epoch 320: Loss 0.111
# Epoch 321: Loss 0.111
# Epoch 322: Loss 0.134
# Epoch 323: Loss 0.106
# Epoch 324: Loss 0.111
# Epoch 325: Loss 0.142
# Epoch 326: Loss 0.105
# Epoch 327: Loss 0.101
# Epoch 328: Loss 0.125
# Epoch 329: Loss 0.114
# Epoch 330: Loss 0.133
# Epoch 331: Loss 0.108
# Epoch 332: Loss 0.106
# Epoch 333: Loss 0.122
# Epoch 334: Loss 0.113
# Epoch 335: Loss 0.119
# Epoch 336: Loss 0.114
# Epoch 337: Loss 0.125
# Epoch 338: Loss 0.106
# Epoch 339: Loss 0.105
# Epoch 340: Loss 0.103
# Epoch 341: Loss 0.102
# Epoch 342: Loss 0.124
# Epoch 343: Loss 0.105
# Epoch 344: Loss 0.113
# Epoch 345: Loss 0.100
# Epoch 346: Loss 0.112
# Epoch 347: Loss 0.104
# Epoch 348: Loss 0.117
# Epoch 349: Loss 0.103
# Epoch 350: Loss 0.099
# Epoch 351: Loss 0.130
# Epoch 352: Loss 0.101
# Epoch 353: Loss 0.101
# Epoch 354: Loss 0.106
# Epoch 355: Loss 0.098
# Epoch 356: Loss 0.133
# Epoch 357: Loss 0.106
# Epoch 358: Loss 0.105
# Epoch 359: Loss 0.100
# Epoch 360: Loss 0.122
# Epoch 361: Loss 0.102
# Epoch 362: Loss 0.097
# Epoch 363: Loss 0.111
# Epoch 364: Loss 0.108
# Epoch 365: Loss 0.098
# Epoch 366: Loss 0.097
# Epoch 367: Loss 0.108
# Epoch 368: Loss 0.117
# Epoch 369: Loss 0.099
# Epoch 370: Loss 0.101
# Epoch 371: Loss 0.096
# Epoch 372: Loss 0.110
# Epoch 373: Loss 0.098
# Epoch 374: Loss 0.097
# Epoch 375: Loss 0.096
# Epoch 376: Loss 0.094
# Epoch 377: Loss 0.121
# Epoch 378: Loss 0.095
# Epoch 379: Loss 0.097
# Epoch 380: Loss 0.105
# Epoch 381: Loss 0.111
# Epoch 382: Loss 0.092
# Epoch 383: Loss 0.092
# Epoch 384: Loss 0.108
# Epoch 385: Loss 0.096
# Epoch 386: Loss 0.093
# Epoch 387: Loss 0.118
# Epoch 388: Loss 0.097
# Epoch 389: Loss 0.096
# Epoch 390: Loss 0.114
# Epoch 391: Loss 0.095
# Epoch 392: Loss 0.098
# Epoch 393: Loss 0.104
# Epoch 394: Loss 0.094
# Epoch 395: Loss 0.093
# Epoch 396: Loss 0.107
# Epoch 397: Loss 0.091
# Epoch 398: Loss 0.098
# Epoch 399: Loss 0.103
# Epoch 400: Loss 0.103
# Epoch 401: Loss 0.106
# Epoch 402: Loss 0.091
# Epoch 403: Loss 0.105
# Epoch 404: Loss 0.093
# Epoch 405: Loss 0.103
# Epoch 406: Loss 0.091
# Epoch 407: Loss 0.105
# Epoch 408: Loss 0.086
# Epoch 409: Loss 0.106
# Epoch 410: Loss 0.090
# Epoch 411: Loss 0.093
# Epoch 412: Loss 0.090
# Epoch 413: Loss 0.085
# Epoch 414: Loss 0.095
# Epoch 415: Loss 0.088
# Epoch 416: Loss 0.098
# Epoch 417: Loss 0.106
# Epoch 418: Loss 0.090
# Epoch 419: Loss 0.096
# Epoch 420: Loss 0.091
# Epoch 421: Loss 0.091
# Epoch 422: Loss 0.092
# Epoch 423: Loss 0.088
# Epoch 424: Loss 0.090
# Epoch 425: Loss 0.092
# Epoch 426: Loss 0.088
# Epoch 427: Loss 0.094
# Epoch 428: Loss 0.088
# Epoch 429: Loss 0.092
# Epoch 430: Loss 0.089
# Epoch 431: Loss 0.096
# Epoch 432: Loss 0.092
# Epoch 433: Loss 0.092
# Epoch 434: Loss 0.087
# Epoch 435: Loss 0.085
# Epoch 436: Loss 0.086
# Epoch 437: Loss 0.085
# Epoch 438: Loss 0.085
# Epoch 439: Loss 0.086
# Epoch 440: Loss 0.083
# Epoch 441: Loss 0.085
# Epoch 442: Loss 0.085
# Epoch 443: Loss 0.086
# Epoch 444: Loss 0.084
# Epoch 445: Loss 0.086
# Epoch 446: Loss 0.083
# Epoch 447: Loss 0.084
# Epoch 448: Loss 0.085
# Epoch 449: Loss 0.084
# Epoch 450: Loss 0.088
# Epoch 451: Loss 0.084
# Epoch 452: Loss 0.087
# Epoch 453: Loss 0.088
# Epoch 454: Loss 0.086
# Epoch 455: Loss 0.085
# Epoch 456: Loss 0.084
# Epoch 457: Loss 0.082
# Epoch 458: Loss 0.082
# Epoch 459: Loss 0.082
# Epoch 460: Loss 0.082
# Epoch 461: Loss 0.083
# Epoch 462: Loss 0.082
# Epoch 463: Loss 0.081
# Epoch 464: Loss 0.081
# Epoch 465: Loss 0.082
# Epoch 466: Loss 0.081
# Epoch 467: Loss 0.079
# Epoch 468: Loss 0.080
# Epoch 469: Loss 0.081
# Epoch 470: Loss 0.081
# Epoch 471: Loss 0.080
# Epoch 472: Loss 0.081
# Epoch 473: Loss 0.087
# Epoch 474: Loss 0.095
# Epoch 475: Loss 0.088
# Epoch 476: Loss 0.085
# Epoch 477: Loss 0.082
# Epoch 478: Loss 0.083
# Epoch 479: Loss 0.083
# Epoch 480: Loss 0.083
# Epoch 481: Loss 0.081
# Epoch 482: Loss 0.079
# Epoch 483: Loss 0.080
# Epoch 484: Loss 0.082
# Epoch 485: Loss 0.084
# Epoch 486: Loss 0.083
# Epoch 487: Loss 0.083
# Epoch 488: Loss 0.078
# Epoch 489: Loss 0.082
# Epoch 490: Loss 0.086
# Epoch 491: Loss 0.089
# Epoch 492: Loss 0.084
# Epoch 493: Loss 0.084
# Epoch 494: Loss 0.084
# Epoch 495: Loss 0.078
# Epoch 496: Loss 0.081
# Epoch 497: Loss 0.080
# Epoch 498: Loss 0.082
# Epoch 499: Loss 0.077
# Epoch 500: Loss 0.081
# Epoch 501: Loss 0.083
# Epoch 502: Loss 0.078
# Epoch 503: Loss 0.078
# Epoch 504: Loss 0.077
# Epoch 505: Loss 0.079
# Epoch 506: Loss 0.077
# Epoch 507: Loss 0.079
# Epoch 508: Loss 0.076
# Epoch 509: Loss 0.080
# Epoch 510: Loss 0.076
# Epoch 511: Loss 0.081
# Epoch 512: Loss 0.082
# Epoch 513: Loss 0.086
# Epoch 514: Loss 0.082
# Epoch 515: Loss 0.079
# Epoch 516: Loss 0.077
# Epoch 517: Loss 0.080
# Epoch 518: Loss 0.075
# Epoch 519: Loss 0.080
# Epoch 520: Loss 0.072
# Epoch 521: Loss 0.078
# Epoch 522: Loss 0.083
# Epoch 523: Loss 0.098
# Epoch 524: Loss 0.081
# Epoch 525: Loss 0.079
# Epoch 526: Loss 0.078
# Epoch 527: Loss 0.075
# Epoch 528: Loss 0.077
# Epoch 529: Loss 0.076
# Epoch 530: Loss 0.074
# Epoch 531: Loss 0.074
# Epoch 532: Loss 0.097
# Epoch 533: Loss 0.081
# Epoch 534: Loss 0.078
# Epoch 535: Loss 0.078
# Epoch 536: Loss 0.072
# Epoch 537: Loss 0.076
# Epoch 538: Loss 0.078
# Epoch 539: Loss 0.076
# Epoch 540: Loss 0.070
# Epoch 541: Loss 0.070
# Epoch 542: Loss 0.072
# Epoch 543: Loss 0.075
# Epoch 544: Loss 0.071
# Epoch 545: Loss 0.071
# Epoch 546: Loss 0.072
# Epoch 547: Loss 0.073
# Epoch 548: Loss 0.074
# Epoch 549: Loss 0.073
# Epoch 550: Loss 0.076
# Epoch 551: Loss 0.074
# Epoch 552: Loss 0.073
# Epoch 553: Loss 0.073
# Epoch 554: Loss 0.073
# Epoch 555: Loss 0.071
# Epoch 556: Loss 0.073
# Epoch 557: Loss 0.073
# Epoch 558: Loss 0.073
# Epoch 559: Loss 0.071
# Epoch 560: Loss 0.073
# Epoch 561: Loss 0.070
# Epoch 562: Loss 0.070
# Epoch 563: Loss 0.072
# Epoch 564: Loss 0.071
# Epoch 565: Loss 0.076
# Epoch 566: Loss 0.074
# Epoch 567: Loss 0.078
# Epoch 568: Loss 0.069
# Epoch 569: Loss 0.070
# Epoch 570: Loss 0.069
# Epoch 571: Loss 0.075
# Epoch 572: Loss 0.080
# Epoch 573: Loss 0.080
# Epoch 574: Loss 0.076
# Epoch 575: Loss 0.075
# Epoch 576: Loss 0.074
# Epoch 577: Loss 0.073
# Epoch 578: Loss 0.068
# Epoch 579: Loss 0.068
# Epoch 580: Loss 0.068
# Epoch 581: Loss 0.069
# Epoch 582: Loss 0.072
# Epoch 583: Loss 0.073
# Epoch 584: Loss 0.071
# Epoch 585: Loss 0.073
# Epoch 586: Loss 0.075
# Epoch 587: Loss 0.072
# Epoch 588: Loss 0.075
# Epoch 589: Loss 0.074
# Epoch 590: Loss 0.073
# Epoch 591: Loss 0.068
# Epoch 592: Loss 0.068
# Epoch 593: Loss 0.066
# Epoch 594: Loss 0.068
# Epoch 595: Loss 0.065
# Epoch 596: Loss 0.067
# Epoch 597: Loss 0.065
# Epoch 598: Loss 0.067
# Epoch 599: Loss 0.065
# Epoch 600: Loss 0.066
# Epoch 601: Loss 0.078
# Epoch 602: Loss 0.087
# Epoch 603: Loss 0.076
# Epoch 604: Loss 0.073
# Epoch 605: Loss 0.069
# Epoch 606: Loss 0.067
# Epoch 607: Loss 0.068
# Epoch 608: Loss 0.063
# Epoch 609: Loss 0.066
# Epoch 610: Loss 0.062
# Epoch 611: Loss 0.064
# Epoch 612: Loss 0.064
# Epoch 613: Loss 0.063
# Epoch 614: Loss 0.070
# Epoch 615: Loss 0.069
# Epoch 616: Loss 0.065
# Epoch 617: Loss 0.075
# Epoch 618: Loss 0.081
# Epoch 619: Loss 0.076
# Epoch 620: Loss 0.073
# Epoch 621: Loss 0.066
# Epoch 622: Loss 0.068
# Epoch 623: Loss 0.071
# Epoch 624: Loss 0.065
# Epoch 625: Loss 0.064
# Epoch 626: Loss 0.064
# Epoch 627: Loss 0.063
# Epoch 628: Loss 0.064
# Epoch 629: Loss 0.063
# Epoch 630: Loss 0.063
# Epoch 631: Loss 0.065
# Epoch 632: Loss 0.066
# Epoch 633: Loss 0.065
# Epoch 634: Loss 0.069
# Epoch 635: Loss 0.064
# Epoch 636: Loss 0.066
# Epoch 637: Loss 0.068
# Epoch 638: Loss 0.065
# Epoch 639: Loss 0.064
# Epoch 640: Loss 0.065
# Epoch 641: Loss 0.066
# Epoch 642: Loss 0.066
# Epoch 643: Loss 0.069
# Epoch 644: Loss 0.068
# Epoch 645: Loss 0.072
# Epoch 646: Loss 0.066
# Epoch 647: Loss 0.066
# Epoch 648: Loss 0.065
# Epoch 649: Loss 0.065
# Epoch 650: Loss 0.068
# Epoch 651: Loss 0.063
# Epoch 652: Loss 0.063
# Epoch 653: Loss 0.066
# Epoch 654: Loss 0.068
# Epoch 655: Loss 0.064
# Epoch 656: Loss 0.061
# Epoch 657: Loss 0.064
# Epoch 658: Loss 0.068
# Epoch 659: Loss 0.073
# Epoch 660: Loss 0.075
# Epoch 661: Loss 0.071
# Epoch 662: Loss 0.072
# Epoch 663: Loss 0.067
# Epoch 664: Loss 0.062
# Epoch 665: Loss 0.063
# Epoch 666: Loss 0.064
# Epoch 667: Loss 0.081
# Epoch 668: Loss 0.075
# Epoch 669: Loss 0.069
# Epoch 670: Loss 0.062
# Epoch 671: Loss 0.062
# Epoch 672: Loss 0.062
# Epoch 673: Loss 0.065
# Epoch 674: Loss 0.069
# Epoch 675: Loss 0.063
# Epoch 676: Loss 0.064
# Epoch 677: Loss 0.064
# Epoch 678: Loss 0.061
# Epoch 679: Loss 0.066
# Epoch 680: Loss 0.073
# Epoch 681: Loss 0.064
# Epoch 682: Loss 0.061
# Epoch 683: Loss 0.061
# Epoch 684: Loss 0.062
# Epoch 685: Loss 0.061
# Epoch 686: Loss 0.061
# Epoch 687: Loss 0.061
# Epoch 688: Loss 0.060
# Epoch 689: Loss 0.060
# Epoch 690: Loss 0.071
# Epoch 691: Loss 0.078
# Epoch 692: Loss 0.076
# Epoch 693: Loss 0.068
# Epoch 694: Loss 0.062
# Epoch 695: Loss 0.063
# Epoch 696: Loss 0.061
# Epoch 697: Loss 0.062
# Epoch 698: Loss 0.067
# Epoch 699: Loss 0.076
# Epoch 700: Loss 0.085
# Epoch 701: Loss 0.071
# Epoch 702: Loss 0.066
# Epoch 703: Loss 0.075
# Epoch 704: Loss 0.069
# Epoch 705: Loss 0.078
# Epoch 706: Loss 0.077
# Epoch 707: Loss 0.084
# Epoch 708: Loss 0.062
# Epoch 709: Loss 0.078
# Epoch 710: Loss 0.068
# Epoch 711: Loss 0.073
# Epoch 712: Loss 0.073
# Epoch 713: Loss 0.072
# Epoch 714: Loss 0.076
# Epoch 715: Loss 0.071
# Epoch 716: Loss 0.068
# Epoch 717: Loss 0.077
# Epoch 718: Loss 0.068
# Epoch 719: Loss 0.067
# Epoch 720: Loss 0.074
# Epoch 721: Loss 0.071
# Epoch 722: Loss 0.071
# Epoch 723: Loss 0.068
# Epoch 724: Loss 0.075
# Epoch 725: Loss 0.059
# Epoch 726: Loss 0.075
# Epoch 727: Loss 0.067
# Epoch 728: Loss 0.071
# Epoch 729: Loss 0.070
# Epoch 730: Loss 0.067
# Epoch 731: Loss 0.069
# Epoch 732: Loss 0.070
# Epoch 733: Loss 0.068
# Epoch 734: Loss 0.074
# Epoch 735: Loss 0.056
# Epoch 736: Loss 0.065
# Epoch 737: Loss 0.066
# Epoch 738: Loss 0.069
# Epoch 739: Loss 0.062
# Epoch 740: Loss 0.073
# Epoch 741: Loss 0.062
# Epoch 742: Loss 0.067
# Epoch 743: Loss 0.068
# Epoch 744: Loss 0.061
# Epoch 745: Loss 0.071
# Epoch 746: Loss 0.071
# Epoch 747: Loss 0.064
# Epoch 748: Loss 0.068
# Epoch 749: Loss 0.062
# Epoch 750: Loss 0.066
# Epoch 751: Loss 0.058
# Epoch 752: Loss 0.062
# Epoch 753: Loss 0.069
# Epoch 754: Loss 0.069
# Epoch 755: Loss 0.059
# Epoch 756: Loss 0.064
# Epoch 757: Loss 0.067
# Epoch 758: Loss 0.074
# Epoch 759: Loss 0.056
# Epoch 760: Loss 0.067
# Epoch 761: Loss 0.066
# Epoch 762: Loss 0.068
# Epoch 763: Loss 0.068
# Epoch 764: Loss 0.055
# Epoch 765: Loss 0.062
# Epoch 766: Loss 0.070
# Epoch 767: Loss 0.055
# Epoch 768: Loss 0.065
# Epoch 769: Loss 0.068
# Epoch 770: Loss 0.064
# Epoch 771: Loss 0.068
# Epoch 772: Loss 0.058
# Epoch 773: Loss 0.069
# Epoch 774: Loss 0.063
# Epoch 775: Loss 0.064
# Epoch 776: Loss 0.064
# Epoch 777: Loss 0.059
# Epoch 778: Loss 0.067
# Epoch 779: Loss 0.057
# Epoch 780: Loss 0.068
# Epoch 781: Loss 0.057
# Epoch 782: Loss 0.067
# Epoch 783: Loss 0.057
# Epoch 784: Loss 0.058
# Epoch 785: Loss 0.066
# Epoch 786: Loss 0.054
# Epoch 787: Loss 0.055
# Epoch 788: Loss 0.060
# Epoch 789: Loss 0.064
# Epoch 790: Loss 0.055
# Epoch 791: Loss 0.067
# Epoch 792: Loss 0.058
# Epoch 793: Loss 0.056
# Epoch 794: Loss 0.065
# Epoch 795: Loss 0.053
# Epoch 796: Loss 0.057
# Epoch 797: Loss 0.060
# Epoch 798: Loss 0.061
# Epoch 799: Loss 0.063
# Epoch 800: Loss 0.059
# Epoch 801: Loss 0.057
# Epoch 802: Loss 0.064
# Epoch 803: Loss 0.053
# Epoch 804: Loss 0.066
# Epoch 805: Loss 0.054
# Epoch 806: Loss 0.054
# Epoch 807: Loss 0.067
# Epoch 808: Loss 0.073
# Epoch 809: Loss 0.069
# Epoch 810: Loss 0.062
# Epoch 811: Loss 0.055
# Epoch 812: Loss 0.053
# Epoch 813: Loss 0.051
# Epoch 814: Loss 0.062
# Epoch 815: Loss 0.059
# Epoch 816: Loss 0.068
# Epoch 817: Loss 0.061
# Epoch 818: Loss 0.070
# Epoch 819: Loss 0.057
# Epoch 820: Loss 0.055
# Epoch 821: Loss 0.055
# Epoch 822: Loss 0.054
# Epoch 823: Loss 0.059
# Epoch 824: Loss 0.055
# Epoch 825: Loss 0.052
# Epoch 826: Loss 0.051
# Epoch 827: Loss 0.054
# Epoch 828: Loss 0.066
# Epoch 829: Loss 0.051
# Epoch 830: Loss 0.054
# Epoch 831: Loss 0.064
# Epoch 832: Loss 0.057
# Epoch 833: Loss 0.053
# Epoch 834: Loss 0.053
# Epoch 835: Loss 0.053
# Epoch 836: Loss 0.051
# Epoch 837: Loss 0.050
# Epoch 838: Loss 0.049
# Epoch 839: Loss 0.065
# Epoch 840: Loss 0.060
# Epoch 841: Loss 0.056
# Epoch 842: Loss 0.052
# Epoch 843: Loss 0.050
# Epoch 844: Loss 0.049
# Epoch 845: Loss 0.048
# Epoch 846: Loss 0.057
# Epoch 847: Loss 0.057
# Epoch 848: Loss 0.067
# Epoch 849: Loss 0.063
# Epoch 850: Loss 0.062
# Epoch 851: Loss 0.056
# Epoch 852: Loss 0.079
# Epoch 853: Loss 0.046
# Epoch 854: Loss 0.062
# Epoch 855: Loss 0.062
# Epoch 856: Loss 0.065
# Epoch 857: Loss 0.055
# Epoch 858: Loss 0.051
# Epoch 859: Loss 0.048
# Epoch 860: Loss 0.053
# Epoch 861: Loss 0.063
# Epoch 862: Loss 0.052
# Epoch 863: Loss 0.066
# Epoch 864: Loss 0.051
# Epoch 865: Loss 0.071
# Epoch 866: Loss 0.045
# Epoch 867: Loss 0.057
# Epoch 868: Loss 0.064
# Epoch 869: Loss 0.051
# Epoch 870: Loss 0.051
# Epoch 871: Loss 0.062
# Epoch 872: Loss 0.054
# Epoch 873: Loss 0.048
# Epoch 874: Loss 0.048
# Epoch 875: Loss 0.046
# Epoch 876: Loss 0.065
# Epoch 877: Loss 0.051
# Epoch 878: Loss 0.068
# Epoch 879: Loss 0.062
# Epoch 880: Loss 0.056
# Epoch 881: Loss 0.049
# Epoch 882: Loss 0.047
# Epoch 883: Loss 0.046
# Epoch 884: Loss 0.064
# Epoch 885: Loss 0.046
# Epoch 886: Loss 0.064
# Epoch 887: Loss 0.046
# Epoch 888: Loss 0.070
# Epoch 889: Loss 0.047
# Epoch 890: Loss 0.047
# Epoch 891: Loss 0.068
# Epoch 892: Loss 0.043
# Epoch 893: Loss 0.045
# Epoch 894: Loss 0.051
# Epoch 895: Loss 0.057
# Epoch 896: Loss 0.049
# Epoch 897: Loss 0.048
# Epoch 898: Loss 0.057
# Epoch 899: Loss 0.055
# Epoch 900: Loss 0.061
# Epoch 901: Loss 0.071
# Epoch 902: Loss 0.071
# Epoch 903: Loss 0.056
# Epoch 904: Loss 0.048
# Epoch 905: Loss 0.045
# Epoch 906: Loss 0.044
# Epoch 907: Loss 0.056
# Epoch 908: Loss 0.053
# Epoch 909: Loss 0.061
# Epoch 910: Loss 0.052
# Epoch 911: Loss 0.064
# Epoch 912: Loss 0.044
# Epoch 913: Loss 0.063
# Epoch 914: Loss 0.047
# Epoch 915: Loss 0.051
# Epoch 916: Loss 0.068
# Epoch 917: Loss 0.045
# Epoch 918: Loss 0.045
# Epoch 919: Loss 0.058
# Epoch 920: Loss 0.045
# Epoch 921: Loss 0.050
# Epoch 922: Loss 0.049
# Epoch 923: Loss 0.050
# Epoch 924: Loss 0.047
# Epoch 925: Loss 0.049
# Epoch 926: Loss 0.047
# Epoch 927: Loss 0.046
# Epoch 928: Loss 0.046
# Epoch 929: Loss 0.046
# Epoch 930: Loss 0.053
# Epoch 931: Loss 0.050
# Epoch 932: Loss 0.046
# Epoch 933: Loss 0.044
# Epoch 934: Loss 0.045
# Epoch 935: Loss 0.056
# Epoch 936: Loss 0.047
# Epoch 937: Loss 0.065
# Epoch 938: Loss 0.050
# Epoch 939: Loss 0.060
# Epoch 940: Loss 0.064
# Epoch 941: Loss 0.052
# Epoch 942: Loss 0.049
# Epoch 943: Loss 0.048
# Epoch 944: Loss 0.045
# Epoch 945: Loss 0.042
# Epoch 946: Loss 0.050
# Epoch 947: Loss 0.045
# Epoch 948: Loss 0.060
# Epoch 949: Loss 0.052
# Epoch 950: Loss 0.063
# Epoch 951: Loss 0.063
# Epoch 952: Loss 0.056
# Epoch 953: Loss 0.061
# Epoch 954: Loss 0.055
# Epoch 955: Loss 0.060
# Epoch 956: Loss 0.048
# Epoch 957: Loss 0.056
# Epoch 958: Loss 0.047
# Epoch 959: Loss 0.056
# Epoch 960: Loss 0.056
# Epoch 961: Loss 0.050
# Epoch 962: Loss 0.059
# Epoch 963: Loss 0.053
# Epoch 964: Loss 0.049
# Epoch 965: Loss 0.059
# Epoch 966: Loss 0.049
# Epoch 967: Loss 0.050
# Epoch 968: Loss 0.057
# Epoch 969: Loss 0.047
# Epoch 970: Loss 0.054
# Epoch 971: Loss 0.049
# Epoch 972: Loss 0.059
# Epoch 973: Loss 0.057
# Epoch 974: Loss 0.056
# Epoch 975: Loss 0.053
# Epoch 976: Loss 0.045
# Epoch 977: Loss 0.051
# Epoch 978: Loss 0.048
# Epoch 979: Loss 0.052
# Epoch 980: Loss 0.050
# Epoch 981: Loss 0.054
# Epoch 982: Loss 0.051
# Epoch 983: Loss 0.049
# Epoch 984: Loss 0.056
# Epoch 985: Loss 0.045
# Epoch 986: Loss 0.052
# Epoch 987: Loss 0.047
# Epoch 988: Loss 0.052
# Epoch 989: Loss 0.046
# Epoch 990: Loss 0.056
# Epoch 991: Loss 0.074
# Epoch 992: Loss 0.043
# Epoch 993: Loss 0.043
# Epoch 994: Loss 0.043
# Epoch 995: Loss 0.043
# Epoch 996: Loss 0.046
# Epoch 997: Loss 0.044
# Epoch 998: Loss 0.041
# Epoch 999: Loss 0.057
# Epoch 1000: Loss 0.071

# %%
fig, axs = plt.subplots(3,4,figsize=(12,8),layout='constrained')

for k in range(3):
    axs[k,0].scatter(X[:,0], X[:,1],c=dot_matrices[k][0])
    axs[k,0].set_title('Input Layer {} -> {}'.format(2,hidden_layers[k][0]))

    for n, matrix in enumerate(dot_matrices[k][1]):
        axs[k,1+n].scatter(X[:,0], X[:,1],c=matrix)
        axs[k,1+n].set_title('Hidden Layer  {} -> {}'.format(hidden_layers[k][n],hidden_layers[k][n+1]))

    pcm = axs[k,-1].scatter(X[:,0], X[:,1],c=dot_matrices[k][-1])
    axs[k,-1].set_title('Output Layer {} -> {}'.format(hidden_layers[k][-1],2))

    fig.colorbar(pcm, ax=axs[k,:])

plt.savefig('plots/Stiffness_ReLU.png')
