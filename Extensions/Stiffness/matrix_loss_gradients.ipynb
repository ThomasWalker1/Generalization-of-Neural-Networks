# %%
import torch
import torch.nn as nn
from torch.optim import SGD

import numpy as np
from numpy import dot
import matplotlib.pyplot as plt

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.input_layer = nn.Linear(input_size, hidden_size)
        self.hidden = nn.Linear(hidden_size, hidden_size)
        self.output_layer = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        x=self.input_layer(x)
        x=x.relu()
        x=self.hidden(x)
        x=x.relu()
        x=self.output_layer(x)
        return x
    
def ReLU_glorot_init(model):
    for name, param in model.named_parameters():
        
        if name.endswith(".bias"):
            param.data.fill_(0)
        else:
            nn.init.xavier_normal_(param)

# %%
RES=50
X=[]
for x_1 in np.linspace(-1,1,RES):
    for x_2 in np.linspace(-1,1,RES):
        X.append([x_1,x_2])
X=np.array(X)

encode_inputs=lambda x: 1 if x[0]**2+x[1]**2<np.sqrt(2/np.pi) else 0
Y=np.array([encode_inputs(x) for x in X])

X_0=np.array([x for k,x in enumerate(X) if Y[k]==0])
X_1=np.array([x for k,x in enumerate(X) if Y[k]==1])
X=np.concatenate((X_0,X_1))
Y=np.concatenate((np.zeros(len(X_0)),np.ones(len(X_1))))

X=torch.from_numpy(X).float()
Y=torch.from_numpy(Y).float()


colors=np.full(len(Y), 'cadetblue')
colors[Y==0]='teal'

plt.scatter(X[:,0],X[:,1],c=colors)

# %%
model = NeuralNet(2,16,2)
ReLU_glorot_init(model)

def next_batch(inputs, targets, batchSize):
	for i in range(0, inputs.shape[0], batchSize):
		yield (inputs[i:i + batchSize], targets[i:i + batchSize])

BATCH_SIZE = 100
EPOCHS = 200
LR = 0.05

opt = SGD(model.parameters(), lr=LR)
lossFunc = nn.CrossEntropyLoss()

# %%
grads=[]
for x,y in next_batch(X,Y,1):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    loss.backward()
    gradient=[]
    gradient+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient+=model.input_layer.bias.grad.tolist()
    gradient+=torch.flatten(model.hidden.weight.grad).tolist()
    gradient+=model.hidden.bias.grad.tolist()
    gradient+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient+=model.output_layer.bias.grad.tolist()
    gradient=np.array(gradient)
    gradient=gradient/np.linalg.norm(gradient)
    grads.append(gradient)
dot_matrix=[]
for grad1 in grads:
    row=[]
    for grad2 in grads:
        row.append(dot(grad1,grad2))
    dot_matrix.append(np.array(row))
dot_matrix=np.array(dot_matrix)

fig, axs = plt.subplots(1,1)

pcm=axs.imshow(dot_matrix,origin='lower')

fig.colorbar(pcm, ax=axs)

# %%
def training():
	opt = SGD(model.parameters(), lr=LR)
	trainLoss = 0
	samples = 0
	model.train()
	for batchX, batchY in next_batch(X, Y, BATCH_SIZE):
		predictions = model(batchX)
		loss = lossFunc(predictions, batchY.long())
		opt.zero_grad()
		loss.backward()
		opt.step()
		samples += len(batchY)
		trainLoss += loss.item()*len(batchY)
	return trainLoss/samples

# %%
for n in range(5):
    l=training()
    print('Epoch {}: Loss {:.3f}'.format(n+1,l))

grads=[]
for x,y in next_batch(X,Y,1):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient=[]
    gradient+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient+=model.input_layer.bias.grad.tolist()
    gradient+=torch.flatten(model.hidden.weight.grad).tolist()
    gradient+=model.hidden.bias.grad.tolist()
    gradient+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient+=model.output_layer.bias.grad.tolist()
    gradient=np.array(gradient)
    gradient=gradient/np.linalg.norm(gradient)
    grads.append(gradient)
dot_matrix=[]
for grad1 in grads:
    row=[]
    for grad2 in grads:
        row.append(dot(grad1,grad2))
    dot_matrix.append(np.array(row))
dot_matrix=np.array(dot_matrix)

fig, axs = plt.subplots(1,1)

pcm=axs.imshow(dot_matrix,origin='lower')

fig.colorbar(pcm, ax=axs)
# Out:
# Epoch 1: Loss 0.687
# Epoch 2: Loss 0.706
# Epoch 3: Loss 0.692
# Epoch 4: Loss 0.674
# Epoch 5: Loss 0.657

# %%
for n in range(5):
    l=training()
    print('Epoch {}: Loss {:.3f}'.format(n+1,l))

grads=[]
for x,y in next_batch(X,Y,1):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient=[]
    gradient+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient+=model.input_layer.bias.grad.tolist()
    gradient+=torch.flatten(model.hidden.weight.grad).tolist()
    gradient+=model.hidden.bias.grad.tolist()
    gradient+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient+=model.output_layer.bias.grad.tolist()
    gradient=np.array(gradient)
    gradient=gradient/np.linalg.norm(gradient)
    grads.append(gradient)
dot_matrix=[]
for grad1 in grads:
    row=[]
    for grad2 in grads:
        row.append(dot(grad1,grad2))
    dot_matrix.append(np.array(row))
dot_matrix=np.array(dot_matrix)

fig, axs = plt.subplots(1,1)

pcm=axs.imshow(dot_matrix,origin='lower')

fig.colorbar(pcm, ax=axs)
# Out:
# Epoch 1: Loss 0.640
# Epoch 2: Loss 0.627
# Epoch 3: Loss 0.617
# Epoch 4: Loss 0.606
# Epoch 5: Loss 0.596

# %%
for n in range(5):
    l=training()
    print('Epoch {}: Loss {:.3f}'.format(n+1,l))

grads=[]
for x,y in next_batch(X,Y,1):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient=[]
    gradient+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient+=model.input_layer.bias.grad.tolist()
    gradient+=torch.flatten(model.hidden.weight.grad).tolist()
    gradient+=model.hidden.bias.grad.tolist()
    gradient+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient+=model.output_layer.bias.grad.tolist()
    gradient=np.array(gradient)
    gradient=gradient/np.linalg.norm(gradient)
    grads.append(gradient)
dot_matrix=[]
for grad1 in grads:
    row=[]
    for grad2 in grads:
        row.append(dot(grad1,grad2))
    dot_matrix.append(np.array(row))
dot_matrix=np.array(dot_matrix)

fig, axs = plt.subplots(1,1)

pcm=axs.imshow(dot_matrix,origin='lower')

fig.colorbar(pcm, ax=axs)
# Out:
# Epoch 1: Loss 0.591
# Epoch 2: Loss 0.584
# Epoch 3: Loss 0.567
# Epoch 4: Loss 0.554
# Epoch 5: Loss 0.542

# %%
for n in range(5):
    l=training()
    print('Epoch {}: Loss {:.3f}'.format(n+1,l))

grads=[]
for x,y in next_batch(X,Y,1):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient=[]
    gradient+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient+=model.input_layer.bias.grad.tolist()
    gradient+=torch.flatten(model.hidden.weight.grad).tolist()
    gradient+=model.hidden.bias.grad.tolist()
    gradient+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient+=model.output_layer.bias.grad.tolist()
    gradient=np.array(gradient)
    gradient=gradient/np.linalg.norm(gradient)
    grads.append(gradient)
dot_matrix=[]
for grad1 in grads:
    row=[]
    for grad2 in grads:
        row.append(dot(grad1,grad2))
    dot_matrix.append(np.array(row))
dot_matrix=np.array(dot_matrix)

fig, axs = plt.subplots(1,1)

pcm=axs.imshow(dot_matrix,origin='lower')

fig.colorbar(pcm, ax=axs)
# Out:
# Epoch 1: Loss 0.529
# Epoch 2: Loss 0.516
# Epoch 3: Loss 0.503
# Epoch 4: Loss 0.489
# Epoch 5: Loss 0.476

# %%
for n in range(100):
    l=training()
    print('Epoch {}: Loss {:.3f}'.format(n+1,l))

grads=[]
for x,y in next_batch(X,Y,1):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient=[]
    gradient+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient+=model.input_layer.bias.grad.tolist()
    gradient+=torch.flatten(model.hidden.weight.grad).tolist()
    gradient+=model.hidden.bias.grad.tolist()
    gradient+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient+=model.output_layer.bias.grad.tolist()
    gradient=np.array(gradient)
    gradient=gradient/np.linalg.norm(gradient)
    grads.append(gradient)
dot_matrix=[]
for grad1 in grads:
    row=[]
    for grad2 in grads:
        row.append(dot(grad1,grad2))
    dot_matrix.append(np.array(row))
dot_matrix=np.array(dot_matrix)

fig, axs = plt.subplots(1,1)

pcm=axs.imshow(dot_matrix,origin='lower')

fig.colorbar(pcm, ax=axs)
# Out:
# Epoch 1: Loss 0.462
# Epoch 2: Loss 0.449
# Epoch 3: Loss 0.435
# Epoch 4: Loss 0.421
# Epoch 5: Loss 0.409
# Epoch 6: Loss 0.396
# Epoch 7: Loss 0.384
# Epoch 8: Loss 0.372
# Epoch 9: Loss 0.361
# Epoch 10: Loss 0.350
# Epoch 11: Loss 0.339
# Epoch 12: Loss 0.329
# Epoch 13: Loss 0.320
# Epoch 14: Loss 0.311
# Epoch 15: Loss 0.303
# Epoch 16: Loss 0.295
# Epoch 17: Loss 0.288
# Epoch 18: Loss 0.280
# Epoch 19: Loss 0.274
# Epoch 20: Loss 0.268
# Epoch 21: Loss 0.262
# Epoch 22: Loss 0.257
# Epoch 23: Loss 0.252
# Epoch 24: Loss 0.247
# Epoch 25: Loss 0.242
# Epoch 26: Loss 0.238
# Epoch 27: Loss 0.233
# Epoch 28: Loss 0.230
# Epoch 29: Loss 0.226
# Epoch 30: Loss 0.222
# Epoch 31: Loss 0.220
# Epoch 32: Loss 0.216
# Epoch 33: Loss 0.212
# Epoch 34: Loss 0.209
# Epoch 35: Loss 0.207
# Epoch 36: Loss 0.203
# Epoch 37: Loss 0.200
# Epoch 38: Loss 0.198
# Epoch 39: Loss 0.196
# Epoch 40: Loss 0.193
# Epoch 41: Loss 0.190
# Epoch 42: Loss 0.188
# Epoch 43: Loss 0.186
# Epoch 44: Loss 0.183
# Epoch 45: Loss 0.181
# Epoch 46: Loss 0.179
# Epoch 47: Loss 0.177
# Epoch 48: Loss 0.175
# Epoch 49: Loss 0.173
# Epoch 50: Loss 0.171
# Epoch 51: Loss 0.169
# Epoch 52: Loss 0.167
# Epoch 53: Loss 0.166
# Epoch 54: Loss 0.164
# Epoch 55: Loss 0.162
# Epoch 56: Loss 0.161
# Epoch 57: Loss 0.159
# Epoch 58: Loss 0.158
# Epoch 59: Loss 0.156
# Epoch 60: Loss 0.155
# Epoch 61: Loss 0.154
# Epoch 62: Loss 0.152
# Epoch 63: Loss 0.151
# Epoch 64: Loss 0.150
# Epoch 65: Loss 0.149
# Epoch 66: Loss 0.147
# Epoch 67: Loss 0.146
# Epoch 68: Loss 0.145
# Epoch 69: Loss 0.144
# Epoch 70: Loss 0.143
# Epoch 71: Loss 0.142
# Epoch 72: Loss 0.141
# Epoch 73: Loss 0.140
# Epoch 74: Loss 0.139
# Epoch 75: Loss 0.138
# Epoch 76: Loss 0.137
# Epoch 77: Loss 0.135
# Epoch 78: Loss 0.134
# Epoch 79: Loss 0.133
# Epoch 80: Loss 0.133
# Epoch 81: Loss 0.131
# Epoch 82: Loss 0.130
# Epoch 83: Loss 0.130
# Epoch 84: Loss 0.129
# Epoch 85: Loss 0.128
# Epoch 86: Loss 0.127
# Epoch 87: Loss 0.126
# Epoch 88: Loss 0.125
# Epoch 89: Loss 0.125
# Epoch 90: Loss 0.124
# Epoch 91: Loss 0.123
# Epoch 92: Loss 0.122
# Epoch 93: Loss 0.121
# Epoch 94: Loss 0.120
# Epoch 95: Loss 0.120
# Epoch 96: Loss 0.119
# Epoch 97: Loss 0.118
# Epoch 98: Loss 0.117
# Epoch 99: Loss 0.117
# Epoch 100: Loss 0.116

# %%
RES=10
X=[]
for x_1 in np.linspace(-1,1,RES):
    for x_2 in np.linspace(-1,1,RES):
        X.append([x_1,x_2])
X=np.array(X)

encode_inputs=lambda x: 1 if np.random.random()<0.5 else 0
Y=np.array([encode_inputs(x) for x in X])

X_0=np.array([x for k,x in enumerate(X) if Y[k]==0])
X_1=np.array([x for k,x in enumerate(X) if Y[k]==1])
X=np.concatenate((X_0,X_1))
Y=np.concatenate((np.zeros(len(X_0)),np.ones(len(X_1))))

X=torch.from_numpy(X).float()
Y=torch.from_numpy(Y).float()


colors=np.full(len(Y), 'cadetblue')
colors[Y==0]='teal'

plt.scatter(X[:,0],X[:,1],c=colors)

# %%
model = NeuralNet(2,256,2)
ReLU_glorot_init(model)

def next_batch(inputs, targets, batchSize):
	for i in range(0, inputs.shape[0], batchSize):
		yield (inputs[i:i + batchSize], targets[i:i + batchSize])

BATCH_SIZE = 100
EPOCHS = 200
LR = 0.05

opt = SGD(model.parameters(), lr=LR)
lossFunc = nn.CrossEntropyLoss()

# %%
for n in range(5):
    l=training()
    print('Epoch {}: Loss {:.3f}'.format(n+1,l))

grads=[]
for x,y in next_batch(X,Y,1):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient=[]
    gradient+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient+=model.input_layer.bias.grad.tolist()
    gradient+=torch.flatten(model.hidden.weight.grad).tolist()
    gradient+=model.hidden.bias.grad.tolist()
    gradient+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient+=model.output_layer.bias.grad.tolist()
    gradient=np.array(gradient)
    gradient=gradient/np.linalg.norm(gradient)
    grads.append(gradient)
dot_matrix=[]
for grad1 in grads:
    row=[]
    for grad2 in grads:
        row.append(dot(grad1,grad2))
    dot_matrix.append(np.array(row))
dot_matrix=np.array(dot_matrix)

fig, axs = plt.subplots(1,1)

pcm=axs.imshow(dot_matrix,origin='lower')

fig.colorbar(pcm, ax=axs)
# Out:
# Epoch 1: Loss 0.693
# Epoch 2: Loss 0.692
# Epoch 3: Loss 0.691
# Epoch 4: Loss 0.689
# Epoch 5: Loss 0.688

# %%
for n in range(5):
    l=training()
    print('Epoch {}: Loss {:.3f}'.format(n+1,l))

grads=[]
for x,y in next_batch(X,Y,1):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient=[]
    gradient+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient+=model.input_layer.bias.grad.tolist()
    gradient+=torch.flatten(model.hidden.weight.grad).tolist()
    gradient+=model.hidden.bias.grad.tolist()
    gradient+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient+=model.output_layer.bias.grad.tolist()
    gradient=np.array(gradient)
    gradient=gradient/np.linalg.norm(gradient)
    grads.append(gradient)
dot_matrix=[]
for grad1 in grads:
    row=[]
    for grad2 in grads:
        row.append(dot(grad1,grad2))
    dot_matrix.append(np.array(row))
dot_matrix=np.array(dot_matrix)

fig, axs = plt.subplots(1,1)

pcm=axs.imshow(dot_matrix,origin='lower')

fig.colorbar(pcm, ax=axs)
# Out:
# Epoch 1: Loss 0.687
# Epoch 2: Loss 0.686
# Epoch 3: Loss 0.685
# Epoch 4: Loss 0.684
# Epoch 5: Loss 0.683

# %%
for n in range(5):
    l=training()
    print('Epoch {}: Loss {:.3f}'.format(n+1,l))

grads=[]
for x,y in next_batch(X,Y,1):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient=[]
    gradient+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient+=model.input_layer.bias.grad.tolist()
    gradient+=torch.flatten(model.hidden.weight.grad).tolist()
    gradient+=model.hidden.bias.grad.tolist()
    gradient+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient+=model.output_layer.bias.grad.tolist()
    gradient=np.array(gradient)
    gradient=gradient/np.linalg.norm(gradient)
    grads.append(gradient)
dot_matrix=[]
for grad1 in grads:
    row=[]
    for grad2 in grads:
        row.append(dot(grad1,grad2))
    dot_matrix.append(np.array(row))
dot_matrix=np.array(dot_matrix)

fig, axs = plt.subplots(1,1)

pcm=axs.imshow(dot_matrix,origin='lower')

fig.colorbar(pcm, ax=axs)
# Out:
# Epoch 1: Loss 0.683
# Epoch 2: Loss 0.682
# Epoch 3: Loss 0.681
# Epoch 4: Loss 0.680
# Epoch 5: Loss 0.680

# %%
for n in range(200):
    l=training()
    print('Epoch {}: Loss {:.3f}'.format(n+1,l))

grads=[]
for x,y in next_batch(X,Y,1):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient=[]
    gradient+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient+=model.input_layer.bias.grad.tolist()
    gradient+=torch.flatten(model.hidden.weight.grad).tolist()
    gradient+=model.hidden.bias.grad.tolist()
    gradient+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient+=model.output_layer.bias.grad.tolist()
    gradient=np.array(gradient)
    gradient=gradient/np.linalg.norm(gradient)
    grads.append(gradient)
dot_matrix=[]
for grad1 in grads:
    row=[]
    for grad2 in grads:
        row.append(dot(grad1,grad2))
    dot_matrix.append(np.array(row))
dot_matrix=np.array(dot_matrix)

fig, axs = plt.subplots(1,1)

pcm=axs.imshow(dot_matrix,origin='lower')

fig.colorbar(pcm, ax=axs)
# Out:
# Epoch 1: Loss 0.679
# Epoch 2: Loss 0.678
# Epoch 3: Loss 0.678
# Epoch 4: Loss 0.677
# Epoch 5: Loss 0.677
# Epoch 6: Loss 0.676
# Epoch 7: Loss 0.676
# Epoch 8: Loss 0.675
# Epoch 9: Loss 0.675
# Epoch 10: Loss 0.674
# Epoch 11: Loss 0.674
# Epoch 12: Loss 0.673
# Epoch 13: Loss 0.673
# Epoch 14: Loss 0.672
# Epoch 15: Loss 0.672
# Epoch 16: Loss 0.672
# Epoch 17: Loss 0.671
# Epoch 18: Loss 0.671
# Epoch 19: Loss 0.670
# Epoch 20: Loss 0.670
# Epoch 21: Loss 0.670
# Epoch 22: Loss 0.669
# Epoch 23: Loss 0.669
# Epoch 24: Loss 0.668
# Epoch 25: Loss 0.668
# Epoch 26: Loss 0.668
# Epoch 27: Loss 0.667
# Epoch 28: Loss 0.667
# Epoch 29: Loss 0.667
# Epoch 30: Loss 0.666
# Epoch 31: Loss 0.666
# Epoch 32: Loss 0.666
# Epoch 33: Loss 0.666
# Epoch 34: Loss 0.665
# Epoch 35: Loss 0.665
# Epoch 36: Loss 0.665
# Epoch 37: Loss 0.664
# Epoch 38: Loss 0.664
# Epoch 39: Loss 0.664
# Epoch 40: Loss 0.664
# Epoch 41: Loss 0.663
# Epoch 42: Loss 0.663
# Epoch 43: Loss 0.663
# Epoch 44: Loss 0.662
# Epoch 45: Loss 0.662
# Epoch 46: Loss 0.662
# Epoch 47: Loss 0.662
# Epoch 48: Loss 0.661
# Epoch 49: Loss 0.661
# Epoch 50: Loss 0.661
# Epoch 51: Loss 0.661
# Epoch 52: Loss 0.660
# Epoch 53: Loss 0.660
# Epoch 54: Loss 0.660
# Epoch 55: Loss 0.660
# Epoch 56: Loss 0.660
# Epoch 57: Loss 0.659
# Epoch 58: Loss 0.659
# Epoch 59: Loss 0.659
# Epoch 60: Loss 0.659
# Epoch 61: Loss 0.658
# Epoch 62: Loss 0.658
# Epoch 63: Loss 0.658
# Epoch 64: Loss 0.658
# Epoch 65: Loss 0.658
# Epoch 66: Loss 0.657
# Epoch 67: Loss 0.657
# Epoch 68: Loss 0.657
# Epoch 69: Loss 0.657
# Epoch 70: Loss 0.656
# Epoch 71: Loss 0.656
# Epoch 72: Loss 0.656
# Epoch 73: Loss 0.656
# Epoch 74: Loss 0.656
# Epoch 75: Loss 0.655
# Epoch 76: Loss 0.655
# Epoch 77: Loss 0.655
# Epoch 78: Loss 0.655
# Epoch 79: Loss 0.655
# Epoch 80: Loss 0.655
# Epoch 81: Loss 0.654
# Epoch 82: Loss 0.654
# Epoch 83: Loss 0.654
# Epoch 84: Loss 0.654
# Epoch 85: Loss 0.654
# Epoch 86: Loss 0.653
# Epoch 87: Loss 0.653
# Epoch 88: Loss 0.653
# Epoch 89: Loss 0.653
# Epoch 90: Loss 0.653
# Epoch 91: Loss 0.652
# Epoch 92: Loss 0.652
# Epoch 93: Loss 0.652
# Epoch 94: Loss 0.652
# Epoch 95: Loss 0.652
# Epoch 96: Loss 0.652
# Epoch 97: Loss 0.651
# Epoch 98: Loss 0.651
# Epoch 99: Loss 0.651
# Epoch 100: Loss 0.651
# Epoch 101: Loss 0.651
# Epoch 102: Loss 0.651
# Epoch 103: Loss 0.650
# Epoch 104: Loss 0.650
# Epoch 105: Loss 0.650
# Epoch 106: Loss 0.650
# Epoch 107: Loss 0.650
# Epoch 108: Loss 0.650
# Epoch 109: Loss 0.649
# Epoch 110: Loss 0.649
# Epoch 111: Loss 0.649
# Epoch 112: Loss 0.649
# Epoch 113: Loss 0.649
# Epoch 114: Loss 0.649
# Epoch 115: Loss 0.649
# Epoch 116: Loss 0.648
# Epoch 117: Loss 0.648
# Epoch 118: Loss 0.648
# Epoch 119: Loss 0.648
# Epoch 120: Loss 0.648
# Epoch 121: Loss 0.648
# Epoch 122: Loss 0.648
# Epoch 123: Loss 0.647
# Epoch 124: Loss 0.647
# Epoch 125: Loss 0.647
# Epoch 126: Loss 0.647
# Epoch 127: Loss 0.647
# Epoch 128: Loss 0.647
# Epoch 129: Loss 0.646
# Epoch 130: Loss 0.646
# Epoch 131: Loss 0.646
# Epoch 132: Loss 0.646
# Epoch 133: Loss 0.646
# Epoch 134: Loss 0.646
# Epoch 135: Loss 0.646
# Epoch 136: Loss 0.645
# Epoch 137: Loss 0.645
# Epoch 138: Loss 0.645
# Epoch 139: Loss 0.645
# Epoch 140: Loss 0.645
# Epoch 141: Loss 0.645
# Epoch 142: Loss 0.645
# Epoch 143: Loss 0.645
# Epoch 144: Loss 0.644
# Epoch 145: Loss 0.644
# Epoch 146: Loss 0.644
# Epoch 147: Loss 0.644
# Epoch 148: Loss 0.644
# Epoch 149: Loss 0.644
# Epoch 150: Loss 0.644
# Epoch 151: Loss 0.643
# Epoch 152: Loss 0.643
# Epoch 153: Loss 0.643
# Epoch 154: Loss 0.643
# Epoch 155: Loss 0.643
# Epoch 156: Loss 0.643
# Epoch 157: Loss 0.643
# Epoch 158: Loss 0.643
# Epoch 159: Loss 0.642
# Epoch 160: Loss 0.642
# Epoch 161: Loss 0.642
# Epoch 162: Loss 0.642
# Epoch 163: Loss 0.642
# Epoch 164: Loss 0.642
# Epoch 165: Loss 0.642
# Epoch 166: Loss 0.642
# Epoch 167: Loss 0.641
# Epoch 168: Loss 0.641
# Epoch 169: Loss 0.641
# Epoch 170: Loss 0.641
# Epoch 171: Loss 0.641
# Epoch 172: Loss 0.641
# Epoch 173: Loss 0.641
# Epoch 174: Loss 0.641
# Epoch 175: Loss 0.640
# Epoch 176: Loss 0.640
# Epoch 177: Loss 0.640
# Epoch 178: Loss 0.640
# Epoch 179: Loss 0.640
# Epoch 180: Loss 0.640
# Epoch 181: Loss 0.640
# Epoch 182: Loss 0.640
# Epoch 183: Loss 0.640
# Epoch 184: Loss 0.639
# Epoch 185: Loss 0.639
# Epoch 186: Loss 0.639
# Epoch 187: Loss 0.639
# Epoch 188: Loss 0.639
# Epoch 189: Loss 0.639
# Epoch 190: Loss 0.639
# Epoch 191: Loss 0.639
# Epoch 192: Loss 0.639
# Epoch 193: Loss 0.638
# Epoch 194: Loss 0.638
# Epoch 195: Loss 0.638
# Epoch 196: Loss 0.638
# Epoch 197: Loss 0.638
# Epoch 198: Loss 0.638
# Epoch 199: Loss 0.638
# Epoch 200: Loss 0.638
