# %%
import torch
import torch.nn as nn
from torch.optim import SGD

import numpy as np
from numpy import dot
import matplotlib.pyplot as plt

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_units, hidden_layers, output_size):
        super(NeuralNet, self).__init__()
        self.hidden = nn.ModuleList()
        self.input_layer = nn.Linear(input_size, hidden_units)
        for k in range(hidden_layers):
            self.hidden.append(nn.Linear(hidden_units, hidden_units))
        self.output_layer = nn.Linear(hidden_units, output_size)
        
    
    def forward(self, x):
        x=self.input_layer(x)
        x=x.relu()
        for layer in self.hidden:
            x=layer(x)
            x=x.relu()
        x=self.output_layer(x)
        return x

    
def ReLU_glorot_init(model):
    for name, param in model.named_parameters():
        
        if name.endswith(".bias"):
            param.data.fill_(0)
        else:
            nn.init.xavier_normal_(param)

# %%
RES=50
X=[]
for x_1 in np.linspace(-1,1,RES):
    for x_2 in np.linspace(-1,1,RES):
        X.append([x_1,x_2])
X=np.array(X)

encode_inputs=lambda x: 1 if (abs((x[0]+0.25)**2+x[1]**2-0.25)<0.05 and x[1]<0.1) or (abs((x[0]-0.25)**2+x[1]**2-0.25)<0.05 and x[1]>-0.1) else 0
Y=np.array([encode_inputs(x) for x in X])

X=torch.from_numpy(X).float()
Y=torch.from_numpy(Y).float()


colors=np.full(len(Y), 'cadetblue')
colors[Y==0]='teal'

plt.scatter(X[:,0],X[:,1],c=colors)

# %%
def random_sample(X,Y,size=5):
    ind_zeros=np.array([k for k in range(len(X)) if Y[k]==0])
    ind_ones=np.array([k for k in range(len(X)) if Y[k]==1])
    return np.concatenate((np.random.choice(ind_zeros,size=size),np.random.choice(ind_ones,size=size)))

# %%
def layer_stiffness(epochs,learning_rate,batch_size,num_hidden_units,num_hidden_layers,init=False):
    model = NeuralNet(2,num_hidden_units,num_hidden_layers,2)
    ReLU_glorot_init(model)

    def next_batch(inputs, targets, batchSize):
        for i in range(0, inputs.shape[0], batchSize):
            yield (inputs[i:i + batchSize], targets[i:i + batchSize])

    opt = SGD(model.parameters(), lr=learning_rate)
    lossFunc = nn.CrossEntropyLoss()

    def training():
        trainLoss = 0
        samples = 0
        model.train()
        for batchX, batchY in next_batch(X, Y, batch_size):
            predictions = model(batchX)
            loss = lossFunc(predictions, batchY.long())
            opt.zero_grad()
            loss.backward()
            opt.step()
            samples += len(batchY)
            trainLoss += loss.item()*len(batchY)
        return trainLoss/samples

    def get_dots():
        N_h=len(model.hidden)
        grads_input_layer=[]
        grads_hidden_layers=[[] for n in range(N_h)]
        grads_output_layer=[]

        for x,y in zip(X,Y):
            predictions = model(x)
            loss = lossFunc(predictions, y.long())
            opt.zero_grad()
            loss.backward()

            gradient_input_layer=[]
            gradient_input_layer+=torch.flatten(model.input_layer.weight.grad).tolist()
            gradient_input_layer+=model.input_layer.bias.grad.tolist()
            gradient_input_layer=np.array(gradient_input_layer)
            if np.linalg.norm(gradient_input_layer)!=0:
                grads_input_layer.append(gradient_input_layer/np.linalg.norm(gradient_input_layer))
            else:
                grads_input_layer.append(gradient_input_layer)

            for k,h_layer in enumerate(model.hidden):
                gradient=[]
                gradient+=torch.flatten(h_layer.weight.grad).tolist()
                gradient+=h_layer.bias.grad.tolist()
                gradient=np.array(gradient)
                if np.linalg.norm(gradient)!=0:
                    grads_hidden_layers[k].append(gradient/np.linalg.norm(gradient))
                else:
                    grads_hidden_layers[k].append(gradient)

            gradient_output_layer=[]
            gradient_output_layer+=torch.flatten(model.output_layer.weight.grad).tolist()
            gradient_output_layer+=model.output_layer.bias.grad.tolist()
            gradient_output_layer=np.array(gradient_output_layer)
            if np.linalg.norm(gradient_output_layer)!=0:
                grads_output_layer.append(gradient_output_layer/np.linalg.norm(gradient_output_layer))
            else:
                grads_output_layer.append(gradient_output_layer)

        dot_matrix_input_layer=[]
        dot_matrix_hidden_layers=[[] for n in range(N_h)]
        dot_matrix_output_layer=[]
        for i in range(len(X)):
            avg_dot_input=0
            avg_dot_hidden=np.zeros(N_h)
            avg_dot_output=0
            samples=0
            sample_ind=random_sample(X,Y,size=10)
            for j in sample_ind:        
                avg_dot_input+=np.dot(grads_input_layer[i],grads_input_layer[j])
                for k in range(N_h):
                    avg_dot_hidden[k]+=np.dot(grads_hidden_layers[k][i],grads_hidden_layers[k][j])
                avg_dot_output+=np.dot(grads_output_layer[i],grads_output_layer[j])
                samples+=1
            
            dot_matrix_input_layer.append(avg_dot_input/samples)
            for k,avg_dot in enumerate(avg_dot_hidden):
                dot_matrix_hidden_layers[k].append(avg_dot/samples)
            dot_matrix_output_layer.append(avg_dot_output/samples)
    
        return dot_matrix_input_layer, dot_matrix_hidden_layers, dot_matrix_output_layer
    if init:
        init_input_matrix,init_hidden_matrices,init_output_matrix=get_dots()
    for n in range(epochs):
        l=training()
        print('Epoch {}: Loss {:.3f}'.format(n+1,l))
        if l<0.01:
            break
    input_matrix,hidden_matrix,output_matrix=get_dots()
    if init:
        return init_input_matrix,init_hidden_matrices,init_output_matrix,input_matrix,hidden_matrix,output_matrix
    return input_matrix,hidden_matrix,output_matrix

# %%
number_hidden_layers=[0,1,2,3]
number_hidden_units=16

dot_matrices=[]

for num_hidden_layers in number_hidden_layers:
    D_1,D_2,D_3=layer_stiffness(1000,0.1,100,number_hidden_units,num_hidden_layers,False)
    dot_matrices.append([D_1,D_2,D_3])
# Out:
# Epoch 1: Loss 0.414
# Epoch 2: Loss 0.288
# Epoch 3: Loss 0.278
# Epoch 4: Loss 0.274
# Epoch 5: Loss 0.271
# Epoch 6: Loss 0.270
# Epoch 7: Loss 0.268
# Epoch 8: Loss 0.267
# Epoch 9: Loss 0.267
# Epoch 10: Loss 0.266
# Epoch 11: Loss 0.265
# Epoch 12: Loss 0.264
# Epoch 13: Loss 0.264
# Epoch 14: Loss 0.263
# Epoch 15: Loss 0.262
# Epoch 16: Loss 0.262
# Epoch 17: Loss 0.261
# Epoch 18: Loss 0.260
# Epoch 19: Loss 0.259
# Epoch 20: Loss 0.258
# Epoch 21: Loss 0.257
# Epoch 22: Loss 0.256
# Epoch 23: Loss 0.255
# Epoch 24: Loss 0.254
# Epoch 25: Loss 0.252
# Epoch 26: Loss 0.252
# Epoch 27: Loss 0.251
# Epoch 28: Loss 0.250
# Epoch 29: Loss 0.249
# Epoch 30: Loss 0.249
# Epoch 31: Loss 0.248
# Epoch 32: Loss 0.248
# Epoch 33: Loss 0.247
# Epoch 34: Loss 0.246
# Epoch 35: Loss 0.246
# Epoch 36: Loss 0.245
# Epoch 37: Loss 0.245
# Epoch 38: Loss 0.244
# Epoch 39: Loss 0.244
# Epoch 40: Loss 0.243
# Epoch 41: Loss 0.243
# Epoch 42: Loss 0.242
# Epoch 43: Loss 0.242
# Epoch 44: Loss 0.242
# Epoch 45: Loss 0.241
# Epoch 46: Loss 0.241
# Epoch 47: Loss 0.240
# Epoch 48: Loss 0.240
# Epoch 49: Loss 0.240
# Epoch 50: Loss 0.239
# Epoch 51: Loss 0.239
# Epoch 52: Loss 0.238
# Epoch 53: Loss 0.238
# Epoch 54: Loss 0.238
# Epoch 55: Loss 0.237
# Epoch 56: Loss 0.237
# Epoch 57: Loss 0.237
# Epoch 58: Loss 0.237
# Epoch 59: Loss 0.236
# Epoch 60: Loss 0.236
# Epoch 61: Loss 0.236
# Epoch 62: Loss 0.236
# Epoch 63: Loss 0.235
# Epoch 64: Loss 0.235
# Epoch 65: Loss 0.235
# Epoch 66: Loss 0.235
# Epoch 67: Loss 0.234
# Epoch 68: Loss 0.234
# Epoch 69: Loss 0.234
# Epoch 70: Loss 0.234
# Epoch 71: Loss 0.233
# Epoch 72: Loss 0.233
# Epoch 73: Loss 0.233
# Epoch 74: Loss 0.233
# Epoch 75: Loss 0.233
# Epoch 76: Loss 0.232
# Epoch 77: Loss 0.232
# Epoch 78: Loss 0.232
# Epoch 79: Loss 0.232
# Epoch 80: Loss 0.232
# Epoch 81: Loss 0.232
# Epoch 82: Loss 0.231
# Epoch 83: Loss 0.231
# Epoch 84: Loss 0.231
# Epoch 85: Loss 0.231
# Epoch 86: Loss 0.231
# Epoch 87: Loss 0.230
# Epoch 88: Loss 0.230
# Epoch 89: Loss 0.230
# Epoch 90: Loss 0.230
# Epoch 91: Loss 0.230
# Epoch 92: Loss 0.229
# Epoch 93: Loss 0.229
# Epoch 94: Loss 0.229
# Epoch 95: Loss 0.229
# Epoch 96: Loss 0.229
# Epoch 97: Loss 0.228
# Epoch 98: Loss 0.228
# Epoch 99: Loss 0.228
# Epoch 100: Loss 0.228
# Epoch 101: Loss 0.228
# Epoch 102: Loss 0.227
# Epoch 103: Loss 0.227
# Epoch 104: Loss 0.227
# Epoch 105: Loss 0.227
# Epoch 106: Loss 0.227
# Epoch 107: Loss 0.226
# Epoch 108: Loss 0.226
# Epoch 109: Loss 0.226
# Epoch 110: Loss 0.226
# Epoch 111: Loss 0.226
# Epoch 112: Loss 0.226
# Epoch 113: Loss 0.225
# Epoch 114: Loss 0.225
# Epoch 115: Loss 0.225
# Epoch 116: Loss 0.225
# Epoch 117: Loss 0.225
# Epoch 118: Loss 0.225
# Epoch 119: Loss 0.225
# Epoch 120: Loss 0.224
# Epoch 121: Loss 0.224
# Epoch 122: Loss 0.224
# Epoch 123: Loss 0.224
# Epoch 124: Loss 0.224
# Epoch 125: Loss 0.224
# Epoch 126: Loss 0.223
# Epoch 127: Loss 0.223
# Epoch 128: Loss 0.223
# Epoch 129: Loss 0.223
# Epoch 130: Loss 0.223
# Epoch 131: Loss 0.223
# Epoch 132: Loss 0.223
# Epoch 133: Loss 0.222
# Epoch 134: Loss 0.222
# Epoch 135: Loss 0.222
# Epoch 136: Loss 0.222
# Epoch 137: Loss 0.222
# Epoch 138: Loss 0.222
# Epoch 139: Loss 0.222
# Epoch 140: Loss 0.222
# Epoch 141: Loss 0.221
# Epoch 142: Loss 0.221
# Epoch 143: Loss 0.221
# Epoch 144: Loss 0.221
# Epoch 145: Loss 0.221
# Epoch 146: Loss 0.221
# Epoch 147: Loss 0.221
# Epoch 148: Loss 0.221
# Epoch 149: Loss 0.221
# Epoch 150: Loss 0.220
# Epoch 151: Loss 0.220
# Epoch 152: Loss 0.220
# Epoch 153: Loss 0.220
# Epoch 154: Loss 0.220
# Epoch 155: Loss 0.220
# Epoch 156: Loss 0.220
# Epoch 157: Loss 0.220
# Epoch 158: Loss 0.220
# Epoch 159: Loss 0.219
# Epoch 160: Loss 0.219
# Epoch 161: Loss 0.219
# Epoch 162: Loss 0.219
# Epoch 163: Loss 0.219
# Epoch 164: Loss 0.219
# Epoch 165: Loss 0.219
# Epoch 166: Loss 0.219
# Epoch 167: Loss 0.219
# Epoch 168: Loss 0.218
# Epoch 169: Loss 0.218
# Epoch 170: Loss 0.218
# Epoch 171: Loss 0.218
# Epoch 172: Loss 0.218
# Epoch 173: Loss 0.218
# Epoch 174: Loss 0.218
# Epoch 175: Loss 0.218
# Epoch 176: Loss 0.218
# Epoch 177: Loss 0.218
# Epoch 178: Loss 0.218
# Epoch 179: Loss 0.217
# Epoch 180: Loss 0.217
# Epoch 181: Loss 0.217
# Epoch 182: Loss 0.217
# Epoch 183: Loss 0.217
# Epoch 184: Loss 0.217
# Epoch 185: Loss 0.217
# Epoch 186: Loss 0.217
# Epoch 187: Loss 0.217
# Epoch 188: Loss 0.217
# Epoch 189: Loss 0.216
# Epoch 190: Loss 0.216
# Epoch 191: Loss 0.216
# Epoch 192: Loss 0.216
# Epoch 193: Loss 0.216
# Epoch 194: Loss 0.216
# Epoch 195: Loss 0.216
# Epoch 196: Loss 0.216
# Epoch 197: Loss 0.216
# Epoch 198: Loss 0.216
# Epoch 199: Loss 0.216
# Epoch 200: Loss 0.216
# Epoch 201: Loss 0.216
# Epoch 202: Loss 0.215
# Epoch 203: Loss 0.215
# Epoch 204: Loss 0.215
# Epoch 205: Loss 0.215
# Epoch 206: Loss 0.215
# Epoch 207: Loss 0.215
# Epoch 208: Loss 0.215
# Epoch 209: Loss 0.215
# Epoch 210: Loss 0.215
# Epoch 211: Loss 0.215
# Epoch 212: Loss 0.215
# Epoch 213: Loss 0.215
# Epoch 214: Loss 0.215
# Epoch 215: Loss 0.215
# Epoch 216: Loss 0.214
# Epoch 217: Loss 0.214
# Epoch 218: Loss 0.214
# Epoch 219: Loss 0.214
# Epoch 220: Loss 0.214
# Epoch 221: Loss 0.214
# Epoch 222: Loss 0.214
# Epoch 223: Loss 0.214
# Epoch 224: Loss 0.214
# Epoch 225: Loss 0.214
# Epoch 226: Loss 0.214
# Epoch 227: Loss 0.214
# Epoch 228: Loss 0.214
# Epoch 229: Loss 0.214
# Epoch 230: Loss 0.214
# Epoch 231: Loss 0.213
# Epoch 232: Loss 0.213
# Epoch 233: Loss 0.213
# Epoch 234: Loss 0.213
# Epoch 235: Loss 0.213
# Epoch 236: Loss 0.213
# Epoch 237: Loss 0.213
# Epoch 238: Loss 0.213
# Epoch 239: Loss 0.213
# Epoch 240: Loss 0.213
# Epoch 241: Loss 0.213
# Epoch 242: Loss 0.213
# Epoch 243: Loss 0.213
# Epoch 244: Loss 0.213
# Epoch 245: Loss 0.213
# Epoch 246: Loss 0.213
# Epoch 247: Loss 0.213
# Epoch 248: Loss 0.213
# Epoch 249: Loss 0.213
# Epoch 250: Loss 0.212
# Epoch 251: Loss 0.212
# Epoch 252: Loss 0.212
# Epoch 253: Loss 0.212
# Epoch 254: Loss 0.212
# Epoch 255: Loss 0.212
# Epoch 256: Loss 0.212
# Epoch 257: Loss 0.212
# Epoch 258: Loss 0.212
# Epoch 259: Loss 0.212
# Epoch 260: Loss 0.212
# Epoch 261: Loss 0.212
# Epoch 262: Loss 0.212
# Epoch 263: Loss 0.212
# Epoch 264: Loss 0.212
# Epoch 265: Loss 0.212
# Epoch 266: Loss 0.212
# Epoch 267: Loss 0.212
# Epoch 268: Loss 0.212
# Epoch 269: Loss 0.212
# Epoch 270: Loss 0.212
# Epoch 271: Loss 0.212
# Epoch 272: Loss 0.212
# Epoch 273: Loss 0.211
# Epoch 274: Loss 0.211
# Epoch 275: Loss 0.211
# Epoch 276: Loss 0.211
# Epoch 277: Loss 0.211
# Epoch 278: Loss 0.211
# Epoch 279: Loss 0.211
# Epoch 280: Loss 0.211
# Epoch 281: Loss 0.211
# Epoch 282: Loss 0.211
# Epoch 283: Loss 0.211
# Epoch 284: Loss 0.211
# Epoch 285: Loss 0.211
# Epoch 286: Loss 0.211
# Epoch 287: Loss 0.211
# Epoch 288: Loss 0.211
# Epoch 289: Loss 0.211
# Epoch 290: Loss 0.211
# Epoch 291: Loss 0.211
# Epoch 292: Loss 0.211
# Epoch 293: Loss 0.211
# Epoch 294: Loss 0.211
# Epoch 295: Loss 0.211
# Epoch 296: Loss 0.211
# Epoch 297: Loss 0.211
# Epoch 298: Loss 0.211
# Epoch 299: Loss 0.211
# Epoch 300: Loss 0.211
# Epoch 301: Loss 0.211
# Epoch 302: Loss 0.211
# Epoch 303: Loss 0.210
# Epoch 304: Loss 0.210
# Epoch 305: Loss 0.210
# Epoch 306: Loss 0.210
# Epoch 307: Loss 0.210
# Epoch 308: Loss 0.210
# Epoch 309: Loss 0.210
# Epoch 310: Loss 0.210
# Epoch 311: Loss 0.210
# Epoch 312: Loss 0.210
# Epoch 313: Loss 0.210
# Epoch 314: Loss 0.210
# Epoch 315: Loss 0.210
# Epoch 316: Loss 0.210
# Epoch 317: Loss 0.210
# Epoch 318: Loss 0.210
# Epoch 319: Loss 0.210
# Epoch 320: Loss 0.210
# Epoch 321: Loss 0.210
# Epoch 322: Loss 0.210
# Epoch 323: Loss 0.210
# Epoch 324: Loss 0.210
# Epoch 325: Loss 0.210
# Epoch 326: Loss 0.210
# Epoch 327: Loss 0.210
# Epoch 328: Loss 0.210
# Epoch 329: Loss 0.210
# Epoch 330: Loss 0.210
# Epoch 331: Loss 0.210
# Epoch 332: Loss 0.210
# Epoch 333: Loss 0.210
# Epoch 334: Loss 0.210
# Epoch 335: Loss 0.210
# Epoch 336: Loss 0.210
# Epoch 337: Loss 0.210
# Epoch 338: Loss 0.209
# Epoch 339: Loss 0.209
# Epoch 340: Loss 0.209
# Epoch 341: Loss 0.209
# Epoch 342: Loss 0.209
# Epoch 343: Loss 0.209
# Epoch 344: Loss 0.209
# Epoch 345: Loss 0.209
# Epoch 346: Loss 0.209
# Epoch 347: Loss 0.209
# Epoch 348: Loss 0.209
# Epoch 349: Loss 0.209
# Epoch 350: Loss 0.209
# Epoch 351: Loss 0.209
# Epoch 352: Loss 0.209
# Epoch 353: Loss 0.209
# Epoch 354: Loss 0.209
# Epoch 355: Loss 0.209
# Epoch 356: Loss 0.209
# Epoch 357: Loss 0.209
# Epoch 358: Loss 0.209
# Epoch 359: Loss 0.209
# Epoch 360: Loss 0.209
# Epoch 361: Loss 0.209
# Epoch 362: Loss 0.209
# Epoch 363: Loss 0.209
# Epoch 364: Loss 0.209
# Epoch 365: Loss 0.209
# Epoch 366: Loss 0.209
# Epoch 367: Loss 0.209
# Epoch 368: Loss 0.209
# Epoch 369: Loss 0.209
# Epoch 370: Loss 0.209
# Epoch 371: Loss 0.209
# Epoch 372: Loss 0.209
# Epoch 373: Loss 0.209
# Epoch 374: Loss 0.208
# Epoch 375: Loss 0.208
# Epoch 376: Loss 0.208
# Epoch 377: Loss 0.208
# Epoch 378: Loss 0.208
# Epoch 379: Loss 0.208
# Epoch 380: Loss 0.208
# Epoch 381: Loss 0.208
# Epoch 382: Loss 0.208
# Epoch 383: Loss 0.208
# Epoch 384: Loss 0.208
# Epoch 385: Loss 0.208
# Epoch 386: Loss 0.208
# Epoch 387: Loss 0.208
# Epoch 388: Loss 0.208
# Epoch 389: Loss 0.208
# Epoch 390: Loss 0.208
# Epoch 391: Loss 0.208
# Epoch 392: Loss 0.208
# Epoch 393: Loss 0.208
# Epoch 394: Loss 0.208
# Epoch 395: Loss 0.208
# Epoch 396: Loss 0.208
# Epoch 397: Loss 0.208
# Epoch 398: Loss 0.208
# Epoch 399: Loss 0.208
# Epoch 400: Loss 0.208
# Epoch 401: Loss 0.208
# Epoch 402: Loss 0.208
# Epoch 403: Loss 0.208
# Epoch 404: Loss 0.208
# Epoch 405: Loss 0.208
# Epoch 406: Loss 0.208
# Epoch 407: Loss 0.208
# Epoch 408: Loss 0.207
# Epoch 409: Loss 0.208
# Epoch 410: Loss 0.207
# Epoch 411: Loss 0.207
# Epoch 412: Loss 0.207
# Epoch 413: Loss 0.207
# Epoch 414: Loss 0.207
# Epoch 415: Loss 0.207
# Epoch 416: Loss 0.207
# Epoch 417: Loss 0.207
# Epoch 418: Loss 0.207
# Epoch 419: Loss 0.207
# Epoch 420: Loss 0.207
# Epoch 421: Loss 0.207
# Epoch 422: Loss 0.207
# Epoch 423: Loss 0.207
# Epoch 424: Loss 0.207
# Epoch 425: Loss 0.207
# Epoch 426: Loss 0.207
# Epoch 427: Loss 0.207
# Epoch 428: Loss 0.207
# Epoch 429: Loss 0.207
# Epoch 430: Loss 0.207
# Epoch 431: Loss 0.207
# Epoch 432: Loss 0.207
# Epoch 433: Loss 0.207
# Epoch 434: Loss 0.207
# Epoch 435: Loss 0.207
# Epoch 436: Loss 0.207
# Epoch 437: Loss 0.207
# Epoch 438: Loss 0.207
# Epoch 439: Loss 0.207
# Epoch 440: Loss 0.207
# Epoch 441: Loss 0.207
# Epoch 442: Loss 0.207
# Epoch 443: Loss 0.207
# Epoch 444: Loss 0.207
# Epoch 445: Loss 0.206
# Epoch 446: Loss 0.206
# Epoch 447: Loss 0.206
# Epoch 448: Loss 0.206
# Epoch 449: Loss 0.206
# Epoch 450: Loss 0.206
# Epoch 451: Loss 0.206
# Epoch 452: Loss 0.206
# Epoch 453: Loss 0.206
# Epoch 454: Loss 0.206
# Epoch 455: Loss 0.206
# Epoch 456: Loss 0.206
# Epoch 457: Loss 0.206
# Epoch 458: Loss 0.206
# Epoch 459: Loss 0.206
# Epoch 460: Loss 0.206
# Epoch 461: Loss 0.206
# Epoch 462: Loss 0.206
# Epoch 463: Loss 0.206
# Epoch 464: Loss 0.206
# Epoch 465: Loss 0.206
# Epoch 466: Loss 0.206
# Epoch 467: Loss 0.206
# Epoch 468: Loss 0.206
# Epoch 469: Loss 0.206
# Epoch 470: Loss 0.206
# Epoch 471: Loss 0.206
# Epoch 472: Loss 0.206
# Epoch 473: Loss 0.205
# Epoch 474: Loss 0.205
# Epoch 475: Loss 0.205
# Epoch 476: Loss 0.205
# Epoch 477: Loss 0.205
# Epoch 478: Loss 0.205
# Epoch 479: Loss 0.205
# Epoch 480: Loss 0.205
# Epoch 481: Loss 0.205
# Epoch 482: Loss 0.205
# Epoch 483: Loss 0.205
# Epoch 484: Loss 0.205
# Epoch 485: Loss 0.205
# Epoch 486: Loss 0.205
# Epoch 487: Loss 0.205
# Epoch 488: Loss 0.205
# Epoch 489: Loss 0.205
# Epoch 490: Loss 0.205
# Epoch 491: Loss 0.205
# Epoch 492: Loss 0.205
# Epoch 493: Loss 0.205
# Epoch 494: Loss 0.205
# Epoch 495: Loss 0.205
# Epoch 496: Loss 0.205
# Epoch 497: Loss 0.205
# Epoch 498: Loss 0.205
# Epoch 499: Loss 0.205
# Epoch 500: Loss 0.205
# Epoch 501: Loss 0.205
# Epoch 502: Loss 0.205
# Epoch 503: Loss 0.204
# Epoch 504: Loss 0.204
# Epoch 505: Loss 0.204
# Epoch 506: Loss 0.204
# Epoch 507: Loss 0.204
# Epoch 508: Loss 0.204
# Epoch 509: Loss 0.204
# Epoch 510: Loss 0.204
# Epoch 511: Loss 0.204
# Epoch 512: Loss 0.204
# Epoch 513: Loss 0.204
# Epoch 514: Loss 0.204
# Epoch 515: Loss 0.204
# Epoch 516: Loss 0.204
# Epoch 517: Loss 0.204
# Epoch 518: Loss 0.204
# Epoch 519: Loss 0.204
# Epoch 520: Loss 0.204
# Epoch 521: Loss 0.204
# Epoch 522: Loss 0.204
# Epoch 523: Loss 0.204
# Epoch 524: Loss 0.204
# Epoch 525: Loss 0.204
# Epoch 526: Loss 0.204
# Epoch 527: Loss 0.204
# Epoch 528: Loss 0.204
# Epoch 529: Loss 0.204
# Epoch 530: Loss 0.204
# Epoch 531: Loss 0.203
# Epoch 532: Loss 0.203
# Epoch 533: Loss 0.203
# Epoch 534: Loss 0.203
# Epoch 535: Loss 0.203
# Epoch 536: Loss 0.203
# Epoch 537: Loss 0.203
# Epoch 538: Loss 0.203
# Epoch 539: Loss 0.203
# Epoch 540: Loss 0.203
# Epoch 541: Loss 0.203
# Epoch 542: Loss 0.203
# Epoch 543: Loss 0.203
# Epoch 544: Loss 0.203
# Epoch 545: Loss 0.203
# Epoch 546: Loss 0.203
# Epoch 547: Loss 0.203
# Epoch 548: Loss 0.203
# Epoch 549: Loss 0.203
# Epoch 550: Loss 0.203
# Epoch 551: Loss 0.203
# Epoch 552: Loss 0.203
# Epoch 553: Loss 0.203
# Epoch 554: Loss 0.203
# Epoch 555: Loss 0.203
# Epoch 556: Loss 0.203
# Epoch 557: Loss 0.203
# Epoch 558: Loss 0.203
# Epoch 559: Loss 0.203
# Epoch 560: Loss 0.203
# Epoch 561: Loss 0.203
# Epoch 562: Loss 0.202
# Epoch 563: Loss 0.202
# Epoch 564: Loss 0.202
# Epoch 565: Loss 0.202
# Epoch 566: Loss 0.202
# Epoch 567: Loss 0.202
# Epoch 568: Loss 0.202
# Epoch 569: Loss 0.202
# Epoch 570: Loss 0.202
# Epoch 571: Loss 0.202
# Epoch 572: Loss 0.202
# Epoch 573: Loss 0.202
# Epoch 574: Loss 0.202
# Epoch 575: Loss 0.202
# Epoch 576: Loss 0.202
# Epoch 577: Loss 0.202
# Epoch 578: Loss 0.202
# Epoch 579: Loss 0.202
# Epoch 580: Loss 0.202
# Epoch 581: Loss 0.202
# Epoch 582: Loss 0.202
# Epoch 583: Loss 0.202
# Epoch 584: Loss 0.202
# Epoch 585: Loss 0.202
# Epoch 586: Loss 0.202
# Epoch 587: Loss 0.202
# Epoch 588: Loss 0.202
# Epoch 589: Loss 0.202
# Epoch 590: Loss 0.202
# Epoch 591: Loss 0.202
# Epoch 592: Loss 0.202
# Epoch 593: Loss 0.202
# Epoch 594: Loss 0.202
# Epoch 595: Loss 0.201
# Epoch 596: Loss 0.201
# Epoch 597: Loss 0.201
# Epoch 598: Loss 0.201
# Epoch 599: Loss 0.201
# Epoch 600: Loss 0.201
# Epoch 601: Loss 0.201
# Epoch 602: Loss 0.201
# Epoch 603: Loss 0.201
# Epoch 604: Loss 0.201
# Epoch 605: Loss 0.201
# Epoch 606: Loss 0.201
# Epoch 607: Loss 0.201
# Epoch 608: Loss 0.201
# Epoch 609: Loss 0.201
# Epoch 610: Loss 0.201
# Epoch 611: Loss 0.201
# Epoch 612: Loss 0.201
# Epoch 613: Loss 0.201
# Epoch 614: Loss 0.201
# Epoch 615: Loss 0.201
# Epoch 616: Loss 0.201
# Epoch 617: Loss 0.201
# Epoch 618: Loss 0.201
# Epoch 619: Loss 0.201
# Epoch 620: Loss 0.201
# Epoch 621: Loss 0.201
# Epoch 622: Loss 0.201
# Epoch 623: Loss 0.201
# Epoch 624: Loss 0.201
# Epoch 625: Loss 0.201
# Epoch 626: Loss 0.201
# Epoch 627: Loss 0.201
# Epoch 628: Loss 0.201
# Epoch 629: Loss 0.201
# Epoch 630: Loss 0.201
# Epoch 631: Loss 0.201
# Epoch 632: Loss 0.200
# Epoch 633: Loss 0.200
# Epoch 634: Loss 0.200
# Epoch 635: Loss 0.200
# Epoch 636: Loss 0.200
# Epoch 637: Loss 0.200
# Epoch 638: Loss 0.200
# Epoch 639: Loss 0.200
# Epoch 640: Loss 0.200
# Epoch 641: Loss 0.200
# Epoch 642: Loss 0.200
# Epoch 643: Loss 0.200
# Epoch 644: Loss 0.200
# Epoch 645: Loss 0.200
# Epoch 646: Loss 0.200
# Epoch 647: Loss 0.200
# Epoch 648: Loss 0.200
# Epoch 649: Loss 0.200
# Epoch 650: Loss 0.200
# Epoch 651: Loss 0.200
# Epoch 652: Loss 0.200
# Epoch 653: Loss 0.200
# Epoch 654: Loss 0.200
# Epoch 655: Loss 0.200
# Epoch 656: Loss 0.200
# Epoch 657: Loss 0.200
# Epoch 658: Loss 0.200
# Epoch 659: Loss 0.200
# Epoch 660: Loss 0.200
# Epoch 661: Loss 0.200
# Epoch 662: Loss 0.200
# Epoch 663: Loss 0.200
# Epoch 664: Loss 0.200
# Epoch 665: Loss 0.199
# Epoch 666: Loss 0.199
# Epoch 667: Loss 0.199
# Epoch 668: Loss 0.199
# Epoch 669: Loss 0.199
# Epoch 670: Loss 0.199
# Epoch 671: Loss 0.199
# Epoch 672: Loss 0.199
# Epoch 673: Loss 0.199
# Epoch 674: Loss 0.199
# Epoch 675: Loss 0.199
# Epoch 676: Loss 0.199
# Epoch 677: Loss 0.199
# Epoch 678: Loss 0.199
# Epoch 679: Loss 0.199
# Epoch 680: Loss 0.199
# Epoch 681: Loss 0.199
# Epoch 682: Loss 0.199
# Epoch 683: Loss 0.199
# Epoch 684: Loss 0.199
# Epoch 685: Loss 0.199
# Epoch 686: Loss 0.199
# Epoch 687: Loss 0.199
# Epoch 688: Loss 0.199
# Epoch 689: Loss 0.199
# Epoch 690: Loss 0.199
# Epoch 691: Loss 0.199
# Epoch 692: Loss 0.199
# Epoch 693: Loss 0.199
# Epoch 694: Loss 0.199
# Epoch 695: Loss 0.199
# Epoch 696: Loss 0.199
# Epoch 697: Loss 0.199
# Epoch 698: Loss 0.199
# Epoch 699: Loss 0.199
# Epoch 700: Loss 0.199
# Epoch 701: Loss 0.199
# Epoch 702: Loss 0.199
# Epoch 703: Loss 0.199
# Epoch 704: Loss 0.199
# Epoch 705: Loss 0.198
# Epoch 706: Loss 0.198
# Epoch 707: Loss 0.198
# Epoch 708: Loss 0.198
# Epoch 709: Loss 0.198
# Epoch 710: Loss 0.198
# Epoch 711: Loss 0.198
# Epoch 712: Loss 0.198
# Epoch 713: Loss 0.198
# Epoch 714: Loss 0.198
# Epoch 715: Loss 0.198
# Epoch 716: Loss 0.198
# Epoch 717: Loss 0.198
# Epoch 718: Loss 0.198
# Epoch 719: Loss 0.198
# Epoch 720: Loss 0.198
# Epoch 721: Loss 0.198
# Epoch 722: Loss 0.198
# Epoch 723: Loss 0.198
# Epoch 724: Loss 0.198
# Epoch 725: Loss 0.198
# Epoch 726: Loss 0.198
# Epoch 727: Loss 0.198
# Epoch 728: Loss 0.198
# Epoch 729: Loss 0.198
# Epoch 730: Loss 0.198
# Epoch 731: Loss 0.198
# Epoch 732: Loss 0.198
# Epoch 733: Loss 0.198
# Epoch 734: Loss 0.198
# Epoch 735: Loss 0.198
# Epoch 736: Loss 0.198
# Epoch 737: Loss 0.198
# Epoch 738: Loss 0.198
# Epoch 739: Loss 0.198
# Epoch 740: Loss 0.198
# Epoch 741: Loss 0.198
# Epoch 742: Loss 0.198
# Epoch 743: Loss 0.198
# Epoch 744: Loss 0.197
# Epoch 745: Loss 0.197
# Epoch 746: Loss 0.197
# Epoch 747: Loss 0.197
# Epoch 748: Loss 0.197
# Epoch 749: Loss 0.197
# Epoch 750: Loss 0.197
# Epoch 751: Loss 0.197
# Epoch 752: Loss 0.197
# Epoch 753: Loss 0.197
# Epoch 754: Loss 0.197
# Epoch 755: Loss 0.197
# Epoch 756: Loss 0.197
# Epoch 757: Loss 0.197
# Epoch 758: Loss 0.197
# Epoch 759: Loss 0.197
# Epoch 760: Loss 0.197
# Epoch 761: Loss 0.197
# Epoch 762: Loss 0.197
# Epoch 763: Loss 0.197
# Epoch 764: Loss 0.197
# Epoch 765: Loss 0.197
# Epoch 766: Loss 0.197
# Epoch 767: Loss 0.197
# Epoch 768: Loss 0.197
# Epoch 769: Loss 0.197
# Epoch 770: Loss 0.197
# Epoch 771: Loss 0.197
# Epoch 772: Loss 0.197
# Epoch 773: Loss 0.197
# Epoch 774: Loss 0.197
# Epoch 775: Loss 0.197
# Epoch 776: Loss 0.197
# Epoch 777: Loss 0.197
# Epoch 778: Loss 0.197
# Epoch 779: Loss 0.197
# Epoch 780: Loss 0.197
# Epoch 781: Loss 0.197
# Epoch 782: Loss 0.197
# Epoch 783: Loss 0.196
# Epoch 784: Loss 0.196
# Epoch 785: Loss 0.196
# Epoch 786: Loss 0.196
# Epoch 787: Loss 0.196
# Epoch 788: Loss 0.196
# Epoch 789: Loss 0.196
# Epoch 790: Loss 0.196
# Epoch 791: Loss 0.196
# Epoch 792: Loss 0.196
# Epoch 793: Loss 0.196
# Epoch 794: Loss 0.196
# Epoch 795: Loss 0.196
# Epoch 796: Loss 0.196
# Epoch 797: Loss 0.196
# Epoch 798: Loss 0.196
# Epoch 799: Loss 0.196
# Epoch 800: Loss 0.196
# Epoch 801: Loss 0.196
# Epoch 802: Loss 0.196
# Epoch 803: Loss 0.196
# Epoch 804: Loss 0.196
# Epoch 805: Loss 0.196
# Epoch 806: Loss 0.196
# Epoch 807: Loss 0.196
# Epoch 808: Loss 0.196
# Epoch 809: Loss 0.196
# Epoch 810: Loss 0.196
# Epoch 811: Loss 0.196
# Epoch 812: Loss 0.196
# Epoch 813: Loss 0.196
# Epoch 814: Loss 0.196
# Epoch 815: Loss 0.196
# Epoch 816: Loss 0.196
# Epoch 817: Loss 0.196
# Epoch 818: Loss 0.196
# Epoch 819: Loss 0.196
# Epoch 820: Loss 0.196
# Epoch 821: Loss 0.196
# Epoch 822: Loss 0.196
# Epoch 823: Loss 0.195
# Epoch 824: Loss 0.195
# Epoch 825: Loss 0.195
# Epoch 826: Loss 0.195
# Epoch 827: Loss 0.195
# Epoch 828: Loss 0.195
# Epoch 829: Loss 0.195
# Epoch 830: Loss 0.195
# Epoch 831: Loss 0.195
# Epoch 832: Loss 0.195
# Epoch 833: Loss 0.195
# Epoch 834: Loss 0.195
# Epoch 835: Loss 0.195
# Epoch 836: Loss 0.195
# Epoch 837: Loss 0.195
# Epoch 838: Loss 0.195
# Epoch 839: Loss 0.195
# Epoch 840: Loss 0.195
# Epoch 841: Loss 0.195
# Epoch 842: Loss 0.195
# Epoch 843: Loss 0.195
# Epoch 844: Loss 0.195
# Epoch 845: Loss 0.195
# Epoch 846: Loss 0.195
# Epoch 847: Loss 0.195
# Epoch 848: Loss 0.195
# Epoch 849: Loss 0.195
# Epoch 850: Loss 0.195
# Epoch 851: Loss 0.195
# Epoch 852: Loss 0.195
# Epoch 853: Loss 0.195
# Epoch 854: Loss 0.195
# Epoch 855: Loss 0.195
# Epoch 856: Loss 0.195
# Epoch 857: Loss 0.195
# Epoch 858: Loss 0.195
# Epoch 859: Loss 0.195
# Epoch 860: Loss 0.195
# Epoch 861: Loss 0.195
# Epoch 862: Loss 0.194
# Epoch 863: Loss 0.194
# Epoch 864: Loss 0.194
# Epoch 865: Loss 0.194
# Epoch 866: Loss 0.194
# Epoch 867: Loss 0.194
# Epoch 868: Loss 0.194
# Epoch 869: Loss 0.194
# Epoch 870: Loss 0.194
# Epoch 871: Loss 0.194
# Epoch 872: Loss 0.194
# Epoch 873: Loss 0.194
# Epoch 874: Loss 0.194
# Epoch 875: Loss 0.194
# Epoch 876: Loss 0.194
# Epoch 877: Loss 0.194
# Epoch 878: Loss 0.194
# Epoch 879: Loss 0.194
# Epoch 880: Loss 0.194
# Epoch 881: Loss 0.194
# Epoch 882: Loss 0.194
# Epoch 883: Loss 0.194
# Epoch 884: Loss 0.194
# Epoch 885: Loss 0.194
# Epoch 886: Loss 0.194
# Epoch 887: Loss 0.194
# Epoch 888: Loss 0.194
# Epoch 889: Loss 0.194
# Epoch 890: Loss 0.194
# Epoch 891: Loss 0.194
# Epoch 892: Loss 0.194
# Epoch 893: Loss 0.194
# Epoch 894: Loss 0.194
# Epoch 895: Loss 0.194
# Epoch 896: Loss 0.194
# Epoch 897: Loss 0.194
# Epoch 898: Loss 0.194
# Epoch 899: Loss 0.194
# Epoch 900: Loss 0.194
# Epoch 901: Loss 0.194
# Epoch 902: Loss 0.194
# Epoch 903: Loss 0.194
# Epoch 904: Loss 0.194
# Epoch 905: Loss 0.194
# Epoch 906: Loss 0.193
# Epoch 907: Loss 0.193
# Epoch 908: Loss 0.193
# Epoch 909: Loss 0.193
# Epoch 910: Loss 0.193
# Epoch 911: Loss 0.193
# Epoch 912: Loss 0.193
# Epoch 913: Loss 0.193
# Epoch 914: Loss 0.193
# Epoch 915: Loss 0.193
# Epoch 916: Loss 0.193
# Epoch 917: Loss 0.193
# Epoch 918: Loss 0.193
# Epoch 919: Loss 0.193
# Epoch 920: Loss 0.193
# Epoch 921: Loss 0.193
# Epoch 922: Loss 0.193
# Epoch 923: Loss 0.193
# Epoch 924: Loss 0.193
# Epoch 925: Loss 0.193
# Epoch 926: Loss 0.193
# Epoch 927: Loss 0.193
# Epoch 928: Loss 0.193
# Epoch 929: Loss 0.193
# Epoch 930: Loss 0.193
# Epoch 931: Loss 0.193
# Epoch 932: Loss 0.193
# Epoch 933: Loss 0.193
# Epoch 934: Loss 0.193
# Epoch 935: Loss 0.193
# Epoch 936: Loss 0.193
# Epoch 937: Loss 0.193
# Epoch 938: Loss 0.193
# Epoch 939: Loss 0.193
# Epoch 940: Loss 0.193
# Epoch 941: Loss 0.193
# Epoch 942: Loss 0.193
# Epoch 943: Loss 0.193
# Epoch 944: Loss 0.193
# Epoch 945: Loss 0.193
# Epoch 946: Loss 0.193
# Epoch 947: Loss 0.193
# Epoch 948: Loss 0.192
# Epoch 949: Loss 0.192
# Epoch 950: Loss 0.192
# Epoch 951: Loss 0.192
# Epoch 952: Loss 0.192
# Epoch 953: Loss 0.192
# Epoch 954: Loss 0.192
# Epoch 955: Loss 0.192
# Epoch 956: Loss 0.192
# Epoch 957: Loss 0.192
# Epoch 958: Loss 0.192
# Epoch 959: Loss 0.192
# Epoch 960: Loss 0.192
# Epoch 961: Loss 0.192
# Epoch 962: Loss 0.192
# Epoch 963: Loss 0.192
# Epoch 964: Loss 0.192
# Epoch 965: Loss 0.192
# Epoch 966: Loss 0.192
# Epoch 967: Loss 0.192
# Epoch 968: Loss 0.192
# Epoch 969: Loss 0.192
# Epoch 970: Loss 0.192
# Epoch 971: Loss 0.192
# Epoch 972: Loss 0.192
# Epoch 973: Loss 0.192
# Epoch 974: Loss 0.192
# Epoch 975: Loss 0.192
# Epoch 976: Loss 0.192
# Epoch 977: Loss 0.192
# Epoch 978: Loss 0.192
# Epoch 979: Loss 0.192
# Epoch 980: Loss 0.192
# Epoch 981: Loss 0.192
# Epoch 982: Loss 0.192
# Epoch 983: Loss 0.192
# Epoch 984: Loss 0.192
# Epoch 985: Loss 0.192
# Epoch 986: Loss 0.192
# Epoch 987: Loss 0.192
# Epoch 988: Loss 0.192
# Epoch 989: Loss 0.192
# Epoch 990: Loss 0.192
# Epoch 991: Loss 0.192
# Epoch 992: Loss 0.192
# Epoch 993: Loss 0.192
# Epoch 994: Loss 0.192
# Epoch 995: Loss 0.192
# Epoch 996: Loss 0.192
# Epoch 997: Loss 0.192
# Epoch 998: Loss 0.192
# Epoch 999: Loss 0.191
# Epoch 1000: Loss 0.191
# Epoch 1: Loss 0.382
# Epoch 2: Loss 0.269
# Epoch 3: Loss 0.265
# Epoch 4: Loss 0.263
# Epoch 5: Loss 0.262
# Epoch 6: Loss 0.260
# Epoch 7: Loss 0.259
# Epoch 8: Loss 0.258
# Epoch 9: Loss 0.256
# Epoch 10: Loss 0.255
# Epoch 11: Loss 0.254
# Epoch 12: Loss 0.253
# Epoch 13: Loss 0.251
# Epoch 14: Loss 0.250
# Epoch 15: Loss 0.249
# Epoch 16: Loss 0.248
# Epoch 17: Loss 0.247
# Epoch 18: Loss 0.246
# Epoch 19: Loss 0.245
# Epoch 20: Loss 0.244
# Epoch 21: Loss 0.243
# Epoch 22: Loss 0.242
# Epoch 23: Loss 0.241
# Epoch 24: Loss 0.240
# Epoch 25: Loss 0.240
# Epoch 26: Loss 0.239
# Epoch 27: Loss 0.238
# Epoch 28: Loss 0.237
# Epoch 29: Loss 0.237
# Epoch 30: Loss 0.236
# Epoch 31: Loss 0.235
# Epoch 32: Loss 0.234
# Epoch 33: Loss 0.234
# Epoch 34: Loss 0.233
# Epoch 35: Loss 0.232
# Epoch 36: Loss 0.231
# Epoch 37: Loss 0.231
# Epoch 38: Loss 0.230
# Epoch 39: Loss 0.229
# Epoch 40: Loss 0.228
# Epoch 41: Loss 0.228
# Epoch 42: Loss 0.227
# Epoch 43: Loss 0.227
# Epoch 44: Loss 0.226
# Epoch 45: Loss 0.225
# Epoch 46: Loss 0.225
# Epoch 47: Loss 0.224
# Epoch 48: Loss 0.224
# Epoch 49: Loss 0.223
# Epoch 50: Loss 0.223
# Epoch 51: Loss 0.222
# Epoch 52: Loss 0.222
# Epoch 53: Loss 0.222
# Epoch 54: Loss 0.221
# Epoch 55: Loss 0.221
# Epoch 56: Loss 0.220
# Epoch 57: Loss 0.220
# Epoch 58: Loss 0.220
# Epoch 59: Loss 0.219
# Epoch 60: Loss 0.219
# Epoch 61: Loss 0.219
# Epoch 62: Loss 0.218
# Epoch 63: Loss 0.218
# Epoch 64: Loss 0.217
# Epoch 65: Loss 0.217
# Epoch 66: Loss 0.217
# Epoch 67: Loss 0.217
# Epoch 68: Loss 0.216
# Epoch 69: Loss 0.216
# Epoch 70: Loss 0.216
# Epoch 71: Loss 0.215
# Epoch 72: Loss 0.215
# Epoch 73: Loss 0.215
# Epoch 74: Loss 0.214
# Epoch 75: Loss 0.214
# Epoch 76: Loss 0.214
# Epoch 77: Loss 0.214
# Epoch 78: Loss 0.214
# Epoch 79: Loss 0.213
# Epoch 80: Loss 0.213
# Epoch 81: Loss 0.213
# Epoch 82: Loss 0.213
# Epoch 83: Loss 0.213
# Epoch 84: Loss 0.212
# Epoch 85: Loss 0.212
# Epoch 86: Loss 0.212
# Epoch 87: Loss 0.212
# Epoch 88: Loss 0.211
# Epoch 89: Loss 0.211
# Epoch 90: Loss 0.211
# Epoch 91: Loss 0.211
# Epoch 92: Loss 0.211
# Epoch 93: Loss 0.210
# Epoch 94: Loss 0.210
# Epoch 95: Loss 0.209
# Epoch 96: Loss 0.209
# Epoch 97: Loss 0.209
# Epoch 98: Loss 0.208
# Epoch 99: Loss 0.208
# Epoch 100: Loss 0.208
# Epoch 101: Loss 0.208
# Epoch 102: Loss 0.207
# Epoch 103: Loss 0.207
# Epoch 104: Loss 0.207
# Epoch 105: Loss 0.207
# Epoch 106: Loss 0.207
# Epoch 107: Loss 0.206
# Epoch 108: Loss 0.206
# Epoch 109: Loss 0.206
# Epoch 110: Loss 0.206
# Epoch 111: Loss 0.206
# Epoch 112: Loss 0.205
# Epoch 113: Loss 0.205
# Epoch 114: Loss 0.205
# Epoch 115: Loss 0.205
# Epoch 116: Loss 0.204
# Epoch 117: Loss 0.204
# Epoch 118: Loss 0.204
# Epoch 119: Loss 0.204
# Epoch 120: Loss 0.204
# Epoch 121: Loss 0.203
# Epoch 122: Loss 0.203
# Epoch 123: Loss 0.203
# Epoch 124: Loss 0.203
# Epoch 125: Loss 0.203
# Epoch 126: Loss 0.202
# Epoch 127: Loss 0.202
# Epoch 128: Loss 0.202
# Epoch 129: Loss 0.202
# Epoch 130: Loss 0.201
# Epoch 131: Loss 0.201
# Epoch 132: Loss 0.201
# Epoch 133: Loss 0.201
# Epoch 134: Loss 0.201
# Epoch 135: Loss 0.201
# Epoch 136: Loss 0.200
# Epoch 137: Loss 0.200
# Epoch 138: Loss 0.200
# Epoch 139: Loss 0.200
# Epoch 140: Loss 0.200
# Epoch 141: Loss 0.199
# Epoch 142: Loss 0.199
# Epoch 143: Loss 0.199
# Epoch 144: Loss 0.199
# Epoch 145: Loss 0.199
# Epoch 146: Loss 0.198
# Epoch 147: Loss 0.198
# Epoch 148: Loss 0.198
# Epoch 149: Loss 0.198
# Epoch 150: Loss 0.197
# Epoch 151: Loss 0.197
# Epoch 152: Loss 0.197
# Epoch 153: Loss 0.197
# Epoch 154: Loss 0.196
# Epoch 155: Loss 0.196
# Epoch 156: Loss 0.196
# Epoch 157: Loss 0.196
# Epoch 158: Loss 0.196
# Epoch 159: Loss 0.195
# Epoch 160: Loss 0.195
# Epoch 161: Loss 0.195
# Epoch 162: Loss 0.195
# Epoch 163: Loss 0.194
# Epoch 164: Loss 0.194
# Epoch 165: Loss 0.194
# Epoch 166: Loss 0.194
# Epoch 167: Loss 0.194
# Epoch 168: Loss 0.193
# Epoch 169: Loss 0.193
# Epoch 170: Loss 0.193
# Epoch 171: Loss 0.193
# Epoch 172: Loss 0.192
# Epoch 173: Loss 0.192
# Epoch 174: Loss 0.192
# Epoch 175: Loss 0.192
# Epoch 176: Loss 0.191
# Epoch 177: Loss 0.191
# Epoch 178: Loss 0.191
# Epoch 179: Loss 0.191
# Epoch 180: Loss 0.190
# Epoch 181: Loss 0.190
# Epoch 182: Loss 0.190
# Epoch 183: Loss 0.190
# Epoch 184: Loss 0.189
# Epoch 185: Loss 0.189
# Epoch 186: Loss 0.189
# Epoch 187: Loss 0.189
# Epoch 188: Loss 0.188
# Epoch 189: Loss 0.188
# Epoch 190: Loss 0.188
# Epoch 191: Loss 0.188
# Epoch 192: Loss 0.187
# Epoch 193: Loss 0.187
# Epoch 194: Loss 0.187
# Epoch 195: Loss 0.187
# Epoch 196: Loss 0.187
# Epoch 197: Loss 0.186
# Epoch 198: Loss 0.186
# Epoch 199: Loss 0.186
# Epoch 200: Loss 0.185
# Epoch 201: Loss 0.185
# Epoch 202: Loss 0.185
# Epoch 203: Loss 0.185
# Epoch 204: Loss 0.184
# Epoch 205: Loss 0.184
# Epoch 206: Loss 0.184
# Epoch 207: Loss 0.183
# Epoch 208: Loss 0.183
# Epoch 209: Loss 0.183
# Epoch 210: Loss 0.183
# Epoch 211: Loss 0.182
# Epoch 212: Loss 0.182
# Epoch 213: Loss 0.182
# Epoch 214: Loss 0.181
# Epoch 215: Loss 0.181
# Epoch 216: Loss 0.181
# Epoch 217: Loss 0.181
# Epoch 218: Loss 0.180
# Epoch 219: Loss 0.180
# Epoch 220: Loss 0.180
# Epoch 221: Loss 0.179
# Epoch 222: Loss 0.179
# Epoch 223: Loss 0.179
# Epoch 224: Loss 0.178
# Epoch 225: Loss 0.178
# Epoch 226: Loss 0.178
# Epoch 227: Loss 0.177
# Epoch 228: Loss 0.177
# Epoch 229: Loss 0.177
# Epoch 230: Loss 0.176
# Epoch 231: Loss 0.176
# Epoch 232: Loss 0.176
# Epoch 233: Loss 0.175
# Epoch 234: Loss 0.175
# Epoch 235: Loss 0.175
# Epoch 236: Loss 0.174
# Epoch 237: Loss 0.174
# Epoch 238: Loss 0.174
# Epoch 239: Loss 0.174
# Epoch 240: Loss 0.173
# Epoch 241: Loss 0.173
# Epoch 242: Loss 0.173
# Epoch 243: Loss 0.172
# Epoch 244: Loss 0.172
# Epoch 245: Loss 0.172
# Epoch 246: Loss 0.171
# Epoch 247: Loss 0.171
# Epoch 248: Loss 0.170
# Epoch 249: Loss 0.170
# Epoch 250: Loss 0.170
# Epoch 251: Loss 0.170
# Epoch 252: Loss 0.169
# Epoch 253: Loss 0.169
# Epoch 254: Loss 0.169
# Epoch 255: Loss 0.168
# Epoch 256: Loss 0.168
# Epoch 257: Loss 0.168
# Epoch 258: Loss 0.167
# Epoch 259: Loss 0.167
# Epoch 260: Loss 0.167
# Epoch 261: Loss 0.166
# Epoch 262: Loss 0.166
# Epoch 263: Loss 0.166
# Epoch 264: Loss 0.165
# Epoch 265: Loss 0.165
# Epoch 266: Loss 0.165
# Epoch 267: Loss 0.165
# Epoch 268: Loss 0.164
# Epoch 269: Loss 0.164
# Epoch 270: Loss 0.164
# Epoch 271: Loss 0.163
# Epoch 272: Loss 0.163
# Epoch 273: Loss 0.163
# Epoch 274: Loss 0.163
# Epoch 275: Loss 0.162
# Epoch 276: Loss 0.162
# Epoch 277: Loss 0.162
# Epoch 278: Loss 0.161
# Epoch 279: Loss 0.161
# Epoch 280: Loss 0.161
# Epoch 281: Loss 0.161
# Epoch 282: Loss 0.160
# Epoch 283: Loss 0.160
# Epoch 284: Loss 0.160
# Epoch 285: Loss 0.159
# Epoch 286: Loss 0.159
# Epoch 287: Loss 0.158
# Epoch 288: Loss 0.158
# Epoch 289: Loss 0.158
# Epoch 290: Loss 0.158
# Epoch 291: Loss 0.157
# Epoch 292: Loss 0.157
# Epoch 293: Loss 0.157
# Epoch 294: Loss 0.156
# Epoch 295: Loss 0.156
# Epoch 296: Loss 0.156
# Epoch 297: Loss 0.156
# Epoch 298: Loss 0.156
# Epoch 299: Loss 0.156
# Epoch 300: Loss 0.155
# Epoch 301: Loss 0.155
# Epoch 302: Loss 0.155
# Epoch 303: Loss 0.155
# Epoch 304: Loss 0.154
# Epoch 305: Loss 0.154
# Epoch 306: Loss 0.154
# Epoch 307: Loss 0.154
# Epoch 308: Loss 0.154
# Epoch 309: Loss 0.153
# Epoch 310: Loss 0.153
# Epoch 311: Loss 0.153
# Epoch 312: Loss 0.153
# Epoch 313: Loss 0.153
# Epoch 314: Loss 0.152
# Epoch 315: Loss 0.152
# Epoch 316: Loss 0.152
# Epoch 317: Loss 0.152
# Epoch 318: Loss 0.152
# Epoch 319: Loss 0.151
# Epoch 320: Loss 0.151
# Epoch 321: Loss 0.151
# Epoch 322: Loss 0.151
# Epoch 323: Loss 0.150
# Epoch 324: Loss 0.151
# Epoch 325: Loss 0.150
# Epoch 326: Loss 0.150
# Epoch 327: Loss 0.150
# Epoch 328: Loss 0.150
# Epoch 329: Loss 0.150
# Epoch 330: Loss 0.149
# Epoch 331: Loss 0.149
# Epoch 332: Loss 0.149
# Epoch 333: Loss 0.149
# Epoch 334: Loss 0.149
# Epoch 335: Loss 0.149
# Epoch 336: Loss 0.149
# Epoch 337: Loss 0.148
# Epoch 338: Loss 0.148
# Epoch 339: Loss 0.148
# Epoch 340: Loss 0.148
# Epoch 341: Loss 0.148
# Epoch 342: Loss 0.148
# Epoch 343: Loss 0.147
# Epoch 344: Loss 0.147
# Epoch 345: Loss 0.147
# Epoch 346: Loss 0.146
# Epoch 347: Loss 0.146
# Epoch 348: Loss 0.146
# Epoch 349: Loss 0.146
# Epoch 350: Loss 0.145
# Epoch 351: Loss 0.145
# Epoch 352: Loss 0.145
# Epoch 353: Loss 0.145
# Epoch 354: Loss 0.145
# Epoch 355: Loss 0.145
# Epoch 356: Loss 0.144
# Epoch 357: Loss 0.144
# Epoch 358: Loss 0.144
# Epoch 359: Loss 0.144
# Epoch 360: Loss 0.144
# Epoch 361: Loss 0.144
# Epoch 362: Loss 0.144
# Epoch 363: Loss 0.143
# Epoch 364: Loss 0.143
# Epoch 365: Loss 0.143
# Epoch 366: Loss 0.142
# Epoch 367: Loss 0.142
# Epoch 368: Loss 0.142
# Epoch 369: Loss 0.142
# Epoch 370: Loss 0.142
# Epoch 371: Loss 0.142
# Epoch 372: Loss 0.142
# Epoch 373: Loss 0.142
# Epoch 374: Loss 0.141
# Epoch 375: Loss 0.141
# Epoch 376: Loss 0.141
# Epoch 377: Loss 0.141
# Epoch 378: Loss 0.141
# Epoch 379: Loss 0.141
# Epoch 380: Loss 0.141
# Epoch 381: Loss 0.141
# Epoch 382: Loss 0.140
# Epoch 383: Loss 0.140
# Epoch 384: Loss 0.140
# Epoch 385: Loss 0.140
# Epoch 386: Loss 0.140
# Epoch 387: Loss 0.140
# Epoch 388: Loss 0.139
# Epoch 389: Loss 0.139
# Epoch 390: Loss 0.139
# Epoch 391: Loss 0.139
# Epoch 392: Loss 0.139
# Epoch 393: Loss 0.139
# Epoch 394: Loss 0.139
# Epoch 395: Loss 0.139
# Epoch 396: Loss 0.139
# Epoch 397: Loss 0.138
# Epoch 398: Loss 0.138
# Epoch 399: Loss 0.138
# Epoch 400: Loss 0.138
# Epoch 401: Loss 0.137
# Epoch 402: Loss 0.138
# Epoch 403: Loss 0.137
# Epoch 404: Loss 0.137
# Epoch 405: Loss 0.137
# Epoch 406: Loss 0.137
# Epoch 407: Loss 0.137
# Epoch 408: Loss 0.137
# Epoch 409: Loss 0.137
# Epoch 410: Loss 0.136
# Epoch 411: Loss 0.137
# Epoch 412: Loss 0.136
# Epoch 413: Loss 0.136
# Epoch 414: Loss 0.136
# Epoch 415: Loss 0.136
# Epoch 416: Loss 0.136
# Epoch 417: Loss 0.136
# Epoch 418: Loss 0.135
# Epoch 419: Loss 0.135
# Epoch 420: Loss 0.135
# Epoch 421: Loss 0.135
# Epoch 422: Loss 0.135
# Epoch 423: Loss 0.135
# Epoch 424: Loss 0.135
# Epoch 425: Loss 0.135
# Epoch 426: Loss 0.134
# Epoch 427: Loss 0.134
# Epoch 428: Loss 0.134
# Epoch 429: Loss 0.133
# Epoch 430: Loss 0.133
# Epoch 431: Loss 0.133
# Epoch 432: Loss 0.133
# Epoch 433: Loss 0.133
# Epoch 434: Loss 0.133
# Epoch 435: Loss 0.133
# Epoch 436: Loss 0.133
# Epoch 437: Loss 0.132
# Epoch 438: Loss 0.132
# Epoch 439: Loss 0.132
# Epoch 440: Loss 0.132
# Epoch 441: Loss 0.132
# Epoch 442: Loss 0.132
# Epoch 443: Loss 0.132
# Epoch 444: Loss 0.132
# Epoch 445: Loss 0.131
# Epoch 446: Loss 0.131
# Epoch 447: Loss 0.131
# Epoch 448: Loss 0.131
# Epoch 449: Loss 0.131
# Epoch 450: Loss 0.131
# Epoch 451: Loss 0.131
# Epoch 452: Loss 0.130
# Epoch 453: Loss 0.130
# Epoch 454: Loss 0.130
# Epoch 455: Loss 0.130
# Epoch 456: Loss 0.130
# Epoch 457: Loss 0.130
# Epoch 458: Loss 0.130
# Epoch 459: Loss 0.130
# Epoch 460: Loss 0.129
# Epoch 461: Loss 0.129
# Epoch 462: Loss 0.129
# Epoch 463: Loss 0.129
# Epoch 464: Loss 0.129
# Epoch 465: Loss 0.129
# Epoch 466: Loss 0.129
# Epoch 467: Loss 0.129
# Epoch 468: Loss 0.129
# Epoch 469: Loss 0.129
# Epoch 470: Loss 0.129
# Epoch 471: Loss 0.129
# Epoch 472: Loss 0.128
# Epoch 473: Loss 0.128
# Epoch 474: Loss 0.128
# Epoch 475: Loss 0.128
# Epoch 476: Loss 0.128
# Epoch 477: Loss 0.128
# Epoch 478: Loss 0.128
# Epoch 479: Loss 0.128
# Epoch 480: Loss 0.128
# Epoch 481: Loss 0.127
# Epoch 482: Loss 0.127
# Epoch 483: Loss 0.127
# Epoch 484: Loss 0.127
# Epoch 485: Loss 0.128
# Epoch 486: Loss 0.127
# Epoch 487: Loss 0.127
# Epoch 488: Loss 0.127
# Epoch 489: Loss 0.127
# Epoch 490: Loss 0.127
# Epoch 491: Loss 0.127
# Epoch 492: Loss 0.126
# Epoch 493: Loss 0.126
# Epoch 494: Loss 0.126
# Epoch 495: Loss 0.126
# Epoch 496: Loss 0.125
# Epoch 497: Loss 0.126
# Epoch 498: Loss 0.125
# Epoch 499: Loss 0.125
# Epoch 500: Loss 0.125
# Epoch 501: Loss 0.125
# Epoch 502: Loss 0.125
# Epoch 503: Loss 0.124
# Epoch 504: Loss 0.124
# Epoch 505: Loss 0.124
# Epoch 506: Loss 0.124
# Epoch 507: Loss 0.124
# Epoch 508: Loss 0.124
# Epoch 509: Loss 0.124
# Epoch 510: Loss 0.124
# Epoch 511: Loss 0.124
# Epoch 512: Loss 0.123
# Epoch 513: Loss 0.123
# Epoch 514: Loss 0.123
# Epoch 515: Loss 0.123
# Epoch 516: Loss 0.123
# Epoch 517: Loss 0.123
# Epoch 518: Loss 0.122
# Epoch 519: Loss 0.122
# Epoch 520: Loss 0.123
# Epoch 521: Loss 0.123
# Epoch 522: Loss 0.122
# Epoch 523: Loss 0.123
# Epoch 524: Loss 0.122
# Epoch 525: Loss 0.122
# Epoch 526: Loss 0.122
# Epoch 527: Loss 0.122
# Epoch 528: Loss 0.121
# Epoch 529: Loss 0.121
# Epoch 530: Loss 0.121
# Epoch 531: Loss 0.121
# Epoch 532: Loss 0.121
# Epoch 533: Loss 0.121
# Epoch 534: Loss 0.121
# Epoch 535: Loss 0.120
# Epoch 536: Loss 0.120
# Epoch 537: Loss 0.120
# Epoch 538: Loss 0.120
# Epoch 539: Loss 0.120
# Epoch 540: Loss 0.119
# Epoch 541: Loss 0.119
# Epoch 542: Loss 0.120
# Epoch 543: Loss 0.119
# Epoch 544: Loss 0.118
# Epoch 545: Loss 0.118
# Epoch 546: Loss 0.119
# Epoch 547: Loss 0.118
# Epoch 548: Loss 0.118
# Epoch 549: Loss 0.118
# Epoch 550: Loss 0.118
# Epoch 551: Loss 0.118
# Epoch 552: Loss 0.117
# Epoch 553: Loss 0.117
# Epoch 554: Loss 0.117
# Epoch 555: Loss 0.117
# Epoch 556: Loss 0.117
# Epoch 557: Loss 0.117
# Epoch 558: Loss 0.116
# Epoch 559: Loss 0.116
# Epoch 560: Loss 0.116
# Epoch 561: Loss 0.116
# Epoch 562: Loss 0.116
# Epoch 563: Loss 0.116
# Epoch 564: Loss 0.115
# Epoch 565: Loss 0.116
# Epoch 566: Loss 0.115
# Epoch 567: Loss 0.115
# Epoch 568: Loss 0.115
# Epoch 569: Loss 0.115
# Epoch 570: Loss 0.114
# Epoch 571: Loss 0.114
# Epoch 572: Loss 0.114
# Epoch 573: Loss 0.114
# Epoch 574: Loss 0.113
# Epoch 575: Loss 0.113
# Epoch 576: Loss 0.113
# Epoch 577: Loss 0.113
# Epoch 578: Loss 0.112
# Epoch 579: Loss 0.112
# Epoch 580: Loss 0.112
# Epoch 581: Loss 0.112
# Epoch 582: Loss 0.111
# Epoch 583: Loss 0.112
# Epoch 584: Loss 0.111
# Epoch 585: Loss 0.111
# Epoch 586: Loss 0.112
# Epoch 587: Loss 0.111
# Epoch 588: Loss 0.111
# Epoch 589: Loss 0.110
# Epoch 590: Loss 0.110
# Epoch 591: Loss 0.110
# Epoch 592: Loss 0.109
# Epoch 593: Loss 0.110
# Epoch 594: Loss 0.109
# Epoch 595: Loss 0.109
# Epoch 596: Loss 0.109
# Epoch 597: Loss 0.108
# Epoch 598: Loss 0.109
# Epoch 599: Loss 0.108
# Epoch 600: Loss 0.108
# Epoch 601: Loss 0.108
# Epoch 602: Loss 0.108
# Epoch 603: Loss 0.108
# Epoch 604: Loss 0.108
# Epoch 605: Loss 0.108
# Epoch 606: Loss 0.108
# Epoch 607: Loss 0.108
# Epoch 608: Loss 0.107
# Epoch 609: Loss 0.107
# Epoch 610: Loss 0.107
# Epoch 611: Loss 0.107
# Epoch 612: Loss 0.107
# Epoch 613: Loss 0.108
# Epoch 614: Loss 0.107
# Epoch 615: Loss 0.108
# Epoch 616: Loss 0.107
# Epoch 617: Loss 0.107
# Epoch 618: Loss 0.107
# Epoch 619: Loss 0.107
# Epoch 620: Loss 0.107
# Epoch 621: Loss 0.107
# Epoch 622: Loss 0.106
# Epoch 623: Loss 0.106
# Epoch 624: Loss 0.106
# Epoch 625: Loss 0.107
# Epoch 626: Loss 0.107
# Epoch 627: Loss 0.106
# Epoch 628: Loss 0.106
# Epoch 629: Loss 0.106
# Epoch 630: Loss 0.106
# Epoch 631: Loss 0.106
# Epoch 632: Loss 0.106
# Epoch 633: Loss 0.105
# Epoch 634: Loss 0.105
# Epoch 635: Loss 0.105
# Epoch 636: Loss 0.106
# Epoch 637: Loss 0.106
# Epoch 638: Loss 0.106
# Epoch 639: Loss 0.105
# Epoch 640: Loss 0.105
# Epoch 641: Loss 0.105
# Epoch 642: Loss 0.105
# Epoch 643: Loss 0.105
# Epoch 644: Loss 0.105
# Epoch 645: Loss 0.103
# Epoch 646: Loss 0.105
# Epoch 647: Loss 0.105
# Epoch 648: Loss 0.105
# Epoch 649: Loss 0.105
# Epoch 650: Loss 0.105
# Epoch 651: Loss 0.104
# Epoch 652: Loss 0.104
# Epoch 653: Loss 0.104
# Epoch 654: Loss 0.104
# Epoch 655: Loss 0.104
# Epoch 656: Loss 0.106
# Epoch 657: Loss 0.102
# Epoch 658: Loss 0.104
# Epoch 659: Loss 0.104
# Epoch 660: Loss 0.104
# Epoch 661: Loss 0.103
# Epoch 662: Loss 0.103
# Epoch 663: Loss 0.102
# Epoch 664: Loss 0.103
# Epoch 665: Loss 0.102
# Epoch 666: Loss 0.103
# Epoch 667: Loss 0.102
# Epoch 668: Loss 0.103
# Epoch 669: Loss 0.102
# Epoch 670: Loss 0.103
# Epoch 671: Loss 0.102
# Epoch 672: Loss 0.101
# Epoch 673: Loss 0.102
# Epoch 674: Loss 0.103
# Epoch 675: Loss 0.101
# Epoch 676: Loss 0.102
# Epoch 677: Loss 0.101
# Epoch 678: Loss 0.100
# Epoch 679: Loss 0.102
# Epoch 680: Loss 0.100
# Epoch 681: Loss 0.101
# Epoch 682: Loss 0.105
# Epoch 683: Loss 0.100
# Epoch 684: Loss 0.102
# Epoch 685: Loss 0.100
# Epoch 686: Loss 0.103
# Epoch 687: Loss 0.099
# Epoch 688: Loss 0.104
# Epoch 689: Loss 0.099
# Epoch 690: Loss 0.103
# Epoch 691: Loss 0.098
# Epoch 692: Loss 0.100
# Epoch 693: Loss 0.100
# Epoch 694: Loss 0.098
# Epoch 695: Loss 0.099
# Epoch 696: Loss 0.101
# Epoch 697: Loss 0.099
# Epoch 698: Loss 0.102
# Epoch 699: Loss 0.098
# Epoch 700: Loss 0.099
# Epoch 701: Loss 0.098
# Epoch 702: Loss 0.098
# Epoch 703: Loss 0.098
# Epoch 704: Loss 0.098
# Epoch 705: Loss 0.100
# Epoch 706: Loss 0.097
# Epoch 707: Loss 0.097
# Epoch 708: Loss 0.097
# Epoch 709: Loss 0.100
# Epoch 710: Loss 0.097
# Epoch 711: Loss 0.096
# Epoch 712: Loss 0.101
# Epoch 713: Loss 0.096
# Epoch 714: Loss 0.097
# Epoch 715: Loss 0.097
# Epoch 716: Loss 0.098
# Epoch 717: Loss 0.097
# Epoch 718: Loss 0.099
# Epoch 719: Loss 0.097
# Epoch 720: Loss 0.096
# Epoch 721: Loss 0.096
# Epoch 722: Loss 0.096
# Epoch 723: Loss 0.097
# Epoch 724: Loss 0.097
# Epoch 725: Loss 0.100
# Epoch 726: Loss 0.096
# Epoch 727: Loss 0.097
# Epoch 728: Loss 0.096
# Epoch 729: Loss 0.095
# Epoch 730: Loss 0.095
# Epoch 731: Loss 0.097
# Epoch 732: Loss 0.095
# Epoch 733: Loss 0.095
# Epoch 734: Loss 0.095
# Epoch 735: Loss 0.096
# Epoch 736: Loss 0.096
# Epoch 737: Loss 0.094
# Epoch 738: Loss 0.093
# Epoch 739: Loss 0.094
# Epoch 740: Loss 0.093
# Epoch 741: Loss 0.093
# Epoch 742: Loss 0.095
# Epoch 743: Loss 0.093
# Epoch 744: Loss 0.094
# Epoch 745: Loss 0.094
# Epoch 746: Loss 0.094
# Epoch 747: Loss 0.093
# Epoch 748: Loss 0.093
# Epoch 749: Loss 0.093
# Epoch 750: Loss 0.093
# Epoch 751: Loss 0.092
# Epoch 752: Loss 0.093
# Epoch 753: Loss 0.093
# Epoch 754: Loss 0.092
# Epoch 755: Loss 0.092
# Epoch 756: Loss 0.093
# Epoch 757: Loss 0.092
# Epoch 758: Loss 0.093
# Epoch 759: Loss 0.092
# Epoch 760: Loss 0.092
# Epoch 761: Loss 0.093
# Epoch 762: Loss 0.092
# Epoch 763: Loss 0.091
# Epoch 764: Loss 0.091
# Epoch 765: Loss 0.092
# Epoch 766: Loss 0.092
# Epoch 767: Loss 0.093
# Epoch 768: Loss 0.092
# Epoch 769: Loss 0.091
# Epoch 770: Loss 0.092
# Epoch 771: Loss 0.092
# Epoch 772: Loss 0.091
# Epoch 773: Loss 0.091
# Epoch 774: Loss 0.090
# Epoch 775: Loss 0.090
# Epoch 776: Loss 0.090
# Epoch 777: Loss 0.092
# Epoch 778: Loss 0.091
# Epoch 779: Loss 0.090
# Epoch 780: Loss 0.090
# Epoch 781: Loss 0.092
# Epoch 782: Loss 0.090
# Epoch 783: Loss 0.094
# Epoch 784: Loss 0.091
# Epoch 785: Loss 0.091
# Epoch 786: Loss 0.091
# Epoch 787: Loss 0.091
# Epoch 788: Loss 0.092
# Epoch 789: Loss 0.091
# Epoch 790: Loss 0.090
# Epoch 791: Loss 0.090
# Epoch 792: Loss 0.089
# Epoch 793: Loss 0.089
# Epoch 794: Loss 0.089
# Epoch 795: Loss 0.089
# Epoch 796: Loss 0.089
# Epoch 797: Loss 0.089
# Epoch 798: Loss 0.089
# Epoch 799: Loss 0.089
# Epoch 800: Loss 0.088
# Epoch 801: Loss 0.089
# Epoch 802: Loss 0.089
# Epoch 803: Loss 0.088
# Epoch 804: Loss 0.089
# Epoch 805: Loss 0.089
# Epoch 806: Loss 0.089
# Epoch 807: Loss 0.089
# Epoch 808: Loss 0.090
# Epoch 809: Loss 0.090
# Epoch 810: Loss 0.088
# Epoch 811: Loss 0.088
# Epoch 812: Loss 0.088
# Epoch 813: Loss 0.087
# Epoch 814: Loss 0.088
# Epoch 815: Loss 0.087
# Epoch 816: Loss 0.088
# Epoch 817: Loss 0.087
# Epoch 818: Loss 0.087
# Epoch 819: Loss 0.087
# Epoch 820: Loss 0.087
# Epoch 821: Loss 0.087
# Epoch 822: Loss 0.087
# Epoch 823: Loss 0.086
# Epoch 824: Loss 0.087
# Epoch 825: Loss 0.087
# Epoch 826: Loss 0.086
# Epoch 827: Loss 0.087
# Epoch 828: Loss 0.085
# Epoch 829: Loss 0.087
# Epoch 830: Loss 0.087
# Epoch 831: Loss 0.086
# Epoch 832: Loss 0.086
# Epoch 833: Loss 0.088
# Epoch 834: Loss 0.088
# Epoch 835: Loss 0.087
# Epoch 836: Loss 0.087
# Epoch 837: Loss 0.088
# Epoch 838: Loss 0.087
# Epoch 839: Loss 0.088
# Epoch 840: Loss 0.085
# Epoch 841: Loss 0.087
# Epoch 842: Loss 0.086
# Epoch 843: Loss 0.087
# Epoch 844: Loss 0.087
# Epoch 845: Loss 0.085
# Epoch 846: Loss 0.087
# Epoch 847: Loss 0.085
# Epoch 848: Loss 0.085
# Epoch 849: Loss 0.086
# Epoch 850: Loss 0.087
# Epoch 851: Loss 0.087
# Epoch 852: Loss 0.087
# Epoch 853: Loss 0.086
# Epoch 854: Loss 0.085
# Epoch 855: Loss 0.087
# Epoch 856: Loss 0.085
# Epoch 857: Loss 0.086
# Epoch 858: Loss 0.086
# Epoch 859: Loss 0.086
# Epoch 860: Loss 0.084
# Epoch 861: Loss 0.086
# Epoch 862: Loss 0.086
# Epoch 863: Loss 0.084
# Epoch 864: Loss 0.086
# Epoch 865: Loss 0.086
# Epoch 866: Loss 0.084
# Epoch 867: Loss 0.086
# Epoch 868: Loss 0.086
# Epoch 869: Loss 0.084
# Epoch 870: Loss 0.088
# Epoch 871: Loss 0.084
# Epoch 872: Loss 0.085
# Epoch 873: Loss 0.085
# Epoch 874: Loss 0.084
# Epoch 875: Loss 0.085
# Epoch 876: Loss 0.083
# Epoch 877: Loss 0.085
# Epoch 878: Loss 0.084
# Epoch 879: Loss 0.083
# Epoch 880: Loss 0.085
# Epoch 881: Loss 0.083
# Epoch 882: Loss 0.086
# Epoch 883: Loss 0.083
# Epoch 884: Loss 0.084
# Epoch 885: Loss 0.084
# Epoch 886: Loss 0.083
# Epoch 887: Loss 0.085
# Epoch 888: Loss 0.082
# Epoch 889: Loss 0.083
# Epoch 890: Loss 0.082
# Epoch 891: Loss 0.084
# Epoch 892: Loss 0.084
# Epoch 893: Loss 0.083
# Epoch 894: Loss 0.082
# Epoch 895: Loss 0.083
# Epoch 896: Loss 0.082
# Epoch 897: Loss 0.083
# Epoch 898: Loss 0.083
# Epoch 899: Loss 0.082
# Epoch 900: Loss 0.084
# Epoch 901: Loss 0.082
# Epoch 902: Loss 0.083
# Epoch 903: Loss 0.081
# Epoch 904: Loss 0.083
# Epoch 905: Loss 0.080
# Epoch 906: Loss 0.083
# Epoch 907: Loss 0.081
# Epoch 908: Loss 0.081
# Epoch 909: Loss 0.082
# Epoch 910: Loss 0.081
# Epoch 911: Loss 0.081
# Epoch 912: Loss 0.081
# Epoch 913: Loss 0.081
# Epoch 914: Loss 0.082
# Epoch 915: Loss 0.081
# Epoch 916: Loss 0.081
# Epoch 917: Loss 0.080
# Epoch 918: Loss 0.081
# Epoch 919: Loss 0.081
# Epoch 920: Loss 0.081
# Epoch 921: Loss 0.081
# Epoch 922: Loss 0.081
# Epoch 923: Loss 0.080
# Epoch 924: Loss 0.081
# Epoch 925: Loss 0.080
# Epoch 926: Loss 0.080
# Epoch 927: Loss 0.081
# Epoch 928: Loss 0.082
# Epoch 929: Loss 0.081
# Epoch 930: Loss 0.080
# Epoch 931: Loss 0.080
# Epoch 932: Loss 0.081
# Epoch 933: Loss 0.080
# Epoch 934: Loss 0.080
# Epoch 935: Loss 0.082
# Epoch 936: Loss 0.081
# Epoch 937: Loss 0.080
# Epoch 938: Loss 0.081
# Epoch 939: Loss 0.081
# Epoch 940: Loss 0.080
# Epoch 941: Loss 0.081
# Epoch 942: Loss 0.080
# Epoch 943: Loss 0.080
# Epoch 944: Loss 0.081
# Epoch 945: Loss 0.080
# Epoch 946: Loss 0.079
# Epoch 947: Loss 0.080
# Epoch 948: Loss 0.079
# Epoch 949: Loss 0.079
# Epoch 950: Loss 0.079
# Epoch 951: Loss 0.079
# Epoch 952: Loss 0.078
# Epoch 953: Loss 0.079
# Epoch 954: Loss 0.079
# Epoch 955: Loss 0.080
# Epoch 956: Loss 0.079
# Epoch 957: Loss 0.079
# Epoch 958: Loss 0.079
# Epoch 959: Loss 0.078
# Epoch 960: Loss 0.079
# Epoch 961: Loss 0.079
# Epoch 962: Loss 0.079
# Epoch 963: Loss 0.079
# Epoch 964: Loss 0.078
# Epoch 965: Loss 0.079
# Epoch 966: Loss 0.079
# Epoch 967: Loss 0.079
# Epoch 968: Loss 0.080
# Epoch 969: Loss 0.079
# Epoch 970: Loss 0.079
# Epoch 971: Loss 0.080
# Epoch 972: Loss 0.080
# Epoch 973: Loss 0.079
# Epoch 974: Loss 0.079
# Epoch 975: Loss 0.078
# Epoch 976: Loss 0.079
# Epoch 977: Loss 0.079
# Epoch 978: Loss 0.080
# Epoch 979: Loss 0.080
# Epoch 980: Loss 0.078
# Epoch 981: Loss 0.080
# Epoch 982: Loss 0.080
# Epoch 983: Loss 0.080
# Epoch 984: Loss 0.079
# Epoch 985: Loss 0.079
# Epoch 986: Loss 0.077
# Epoch 987: Loss 0.079
# Epoch 988: Loss 0.078
# Epoch 989: Loss 0.079
# Epoch 990: Loss 0.079
# Epoch 991: Loss 0.078
# Epoch 992: Loss 0.078
# Epoch 993: Loss 0.078
# Epoch 994: Loss 0.078
# Epoch 995: Loss 0.079
# Epoch 996: Loss 0.079
# Epoch 997: Loss 0.078
# Epoch 998: Loss 0.077
# Epoch 999: Loss 0.078
# Epoch 1000: Loss 0.077
# Epoch 1: Loss 0.434
# Epoch 2: Loss 0.275
# Epoch 3: Loss 0.268
# Epoch 4: Loss 0.265
# Epoch 5: Loss 0.264
# Epoch 6: Loss 0.262
# Epoch 7: Loss 0.260
# Epoch 8: Loss 0.259
# Epoch 9: Loss 0.257
# Epoch 10: Loss 0.256
# Epoch 11: Loss 0.254
# Epoch 12: Loss 0.252
# Epoch 13: Loss 0.250
# Epoch 14: Loss 0.249
# Epoch 15: Loss 0.247
# Epoch 16: Loss 0.245
# Epoch 17: Loss 0.243
# Epoch 18: Loss 0.242
# Epoch 19: Loss 0.240
# Epoch 20: Loss 0.239
# Epoch 21: Loss 0.237
# Epoch 22: Loss 0.236
# Epoch 23: Loss 0.235
# Epoch 24: Loss 0.234
# Epoch 25: Loss 0.233
# Epoch 26: Loss 0.232
# Epoch 27: Loss 0.230
# Epoch 28: Loss 0.229
# Epoch 29: Loss 0.226
# Epoch 30: Loss 0.224
# Epoch 31: Loss 0.222
# Epoch 32: Loss 0.221
# Epoch 33: Loss 0.220
# Epoch 34: Loss 0.219
# Epoch 35: Loss 0.218
# Epoch 36: Loss 0.216
# Epoch 37: Loss 0.215
# Epoch 38: Loss 0.214
# Epoch 39: Loss 0.213
# Epoch 40: Loss 0.212
# Epoch 41: Loss 0.212
# Epoch 42: Loss 0.211
# Epoch 43: Loss 0.210
# Epoch 44: Loss 0.209
# Epoch 45: Loss 0.207
# Epoch 46: Loss 0.206
# Epoch 47: Loss 0.205
# Epoch 48: Loss 0.203
# Epoch 49: Loss 0.203
# Epoch 50: Loss 0.202
# Epoch 51: Loss 0.201
# Epoch 52: Loss 0.201
# Epoch 53: Loss 0.199
# Epoch 54: Loss 0.199
# Epoch 55: Loss 0.198
# Epoch 56: Loss 0.197
# Epoch 57: Loss 0.196
# Epoch 58: Loss 0.195
# Epoch 59: Loss 0.196
# Epoch 60: Loss 0.194
# Epoch 61: Loss 0.193
# Epoch 62: Loss 0.193
# Epoch 63: Loss 0.193
# Epoch 64: Loss 0.192
# Epoch 65: Loss 0.191
# Epoch 66: Loss 0.191
# Epoch 67: Loss 0.190
# Epoch 68: Loss 0.190
# Epoch 69: Loss 0.190
# Epoch 70: Loss 0.190
# Epoch 71: Loss 0.188
# Epoch 72: Loss 0.187
# Epoch 73: Loss 0.188
# Epoch 74: Loss 0.186
# Epoch 75: Loss 0.186
# Epoch 76: Loss 0.187
# Epoch 77: Loss 0.184
# Epoch 78: Loss 0.184
# Epoch 79: Loss 0.184
# Epoch 80: Loss 0.184
# Epoch 81: Loss 0.182
# Epoch 82: Loss 0.182
# Epoch 83: Loss 0.182
# Epoch 84: Loss 0.180
# Epoch 85: Loss 0.180
# Epoch 86: Loss 0.179
# Epoch 87: Loss 0.180
# Epoch 88: Loss 0.178
# Epoch 89: Loss 0.179
# Epoch 90: Loss 0.177
# Epoch 91: Loss 0.177
# Epoch 92: Loss 0.177
# Epoch 93: Loss 0.175
# Epoch 94: Loss 0.175
# Epoch 95: Loss 0.175
# Epoch 96: Loss 0.173
# Epoch 97: Loss 0.176
# Epoch 98: Loss 0.172
# Epoch 99: Loss 0.173
# Epoch 100: Loss 0.171
# Epoch 101: Loss 0.172
# Epoch 102: Loss 0.169
# Epoch 103: Loss 0.169
# Epoch 104: Loss 0.168
# Epoch 105: Loss 0.167
# Epoch 106: Loss 0.168
# Epoch 107: Loss 0.166
# Epoch 108: Loss 0.166
# Epoch 109: Loss 0.165
# Epoch 110: Loss 0.165
# Epoch 111: Loss 0.163
# Epoch 112: Loss 0.163
# Epoch 113: Loss 0.163
# Epoch 114: Loss 0.162
# Epoch 115: Loss 0.161
# Epoch 116: Loss 0.160
# Epoch 117: Loss 0.160
# Epoch 118: Loss 0.159
# Epoch 119: Loss 0.161
# Epoch 120: Loss 0.158
# Epoch 121: Loss 0.157
# Epoch 122: Loss 0.157
# Epoch 123: Loss 0.156
# Epoch 124: Loss 0.156
# Epoch 125: Loss 0.156
# Epoch 126: Loss 0.154
# Epoch 127: Loss 0.154
# Epoch 128: Loss 0.153
# Epoch 129: Loss 0.152
# Epoch 130: Loss 0.152
# Epoch 131: Loss 0.151
# Epoch 132: Loss 0.151
# Epoch 133: Loss 0.150
# Epoch 134: Loss 0.150
# Epoch 135: Loss 0.149
# Epoch 136: Loss 0.150
# Epoch 137: Loss 0.148
# Epoch 138: Loss 0.147
# Epoch 139: Loss 0.148
# Epoch 140: Loss 0.148
# Epoch 141: Loss 0.145
# Epoch 142: Loss 0.145
# Epoch 143: Loss 0.144
# Epoch 144: Loss 0.146
# Epoch 145: Loss 0.146
# Epoch 146: Loss 0.145
# Epoch 147: Loss 0.143
# Epoch 148: Loss 0.144
# Epoch 149: Loss 0.144
# Epoch 150: Loss 0.145
# Epoch 151: Loss 0.143
# Epoch 152: Loss 0.143
# Epoch 153: Loss 0.143
# Epoch 154: Loss 0.143
# Epoch 155: Loss 0.140
# Epoch 156: Loss 0.142
# Epoch 157: Loss 0.141
# Epoch 158: Loss 0.139
# Epoch 159: Loss 0.138
# Epoch 160: Loss 0.142
# Epoch 161: Loss 0.141
# Epoch 162: Loss 0.137
# Epoch 163: Loss 0.140
# Epoch 164: Loss 0.139
# Epoch 165: Loss 0.138
# Epoch 166: Loss 0.141
# Epoch 167: Loss 0.138
# Epoch 168: Loss 0.139
# Epoch 169: Loss 0.138
# Epoch 170: Loss 0.138
# Epoch 171: Loss 0.135
# Epoch 172: Loss 0.135
# Epoch 173: Loss 0.133
# Epoch 174: Loss 0.133
# Epoch 175: Loss 0.135
# Epoch 176: Loss 0.134
# Epoch 177: Loss 0.137
# Epoch 178: Loss 0.135
# Epoch 179: Loss 0.132
# Epoch 180: Loss 0.135
# Epoch 181: Loss 0.134
# Epoch 182: Loss 0.135
# Epoch 183: Loss 0.135
# Epoch 184: Loss 0.136
# Epoch 185: Loss 0.131
# Epoch 186: Loss 0.135
# Epoch 187: Loss 0.138
# Epoch 188: Loss 0.134
# Epoch 189: Loss 0.135
# Epoch 190: Loss 0.135
# Epoch 191: Loss 0.135
# Epoch 192: Loss 0.133
# Epoch 193: Loss 0.135
# Epoch 194: Loss 0.135
# Epoch 195: Loss 0.141
# Epoch 196: Loss 0.136
# ...
# Epoch 274: Loss 0.105
# Epoch 275: Loss 0.122
# Epoch 276: Loss 0.110
# Epoch 277: Loss 0.122
# Epoch 278: Loss 0.115
# Epoch 279: Loss 0.104
# Epoch 280: Loss 0.118
# Epoch 281: Loss 0.104
# Epoch 282: Loss 0.139
# Epoch 283: Loss 0.114
# Epoch 284: Loss 0.111
# Epoch 285: Loss 0.117
# Epoch 286: Loss 0.105
# Epoch 287: Loss 0.130
# Epoch 288: Loss 0.112
# Epoch 289: Loss 0.100
# Epoch 290: Loss 0.109
# Epoch 291: Loss 0.121
# Epoch 292: Loss 0.117
# Epoch 293: Loss 0.114
# Epoch 294: Loss 0.100
# Epoch 295: Loss 0.133
# Epoch 296: Loss 0.121
# Epoch 297: Loss 0.100
# Epoch 298: Loss 0.108
# Epoch 299: Loss 0.099
# Epoch 300: Loss 0.119
# Epoch 301: Loss 0.104
# Epoch 302: Loss 0.137
# Epoch 303: Loss 0.116
# Epoch 304: Loss 0.107
# Epoch 305: Loss 0.098
# Epoch 306: Loss 0.104
# Epoch 307: Loss 0.095
# Epoch 308: Loss 0.109
# Epoch 309: Loss 0.098
# Epoch 310: Loss 0.119
# Epoch 311: Loss 0.103
# Epoch 312: Loss 0.100
# Epoch 313: Loss 0.108
# Epoch 314: Loss 0.097
# Epoch 315: Loss 0.098
# Epoch 316: Loss 0.115
# Epoch 317: Loss 0.106
# Epoch 318: Loss 0.088
# Epoch 319: Loss 0.118
# Epoch 320: Loss 0.101
# Epoch 321: Loss 0.104
# Epoch 322: Loss 0.102
# Epoch 323: Loss 0.098
# Epoch 324: Loss 0.105
# Epoch 325: Loss 0.099
# Epoch 326: Loss 0.099
# Epoch 327: Loss 0.094
# Epoch 328: Loss 0.092
# Epoch 329: Loss 0.105
# Epoch 330: Loss 0.089
# Epoch 331: Loss 0.095
# Epoch 332: Loss 0.098
# Epoch 333: Loss 0.114
# Epoch 334: Loss 0.098
# Epoch 335: Loss 0.100
# Epoch 336: Loss 0.095
# Epoch 337: Loss 0.103
# Epoch 338: Loss 0.102
# Epoch 339: Loss 0.109
# Epoch 340: Loss 0.106
# Epoch 341: Loss 0.093
# Epoch 342: Loss 0.095
# Epoch 343: Loss 0.089
# Epoch 344: Loss 0.105
# Epoch 345: Loss 0.096
# Epoch 346: Loss 0.088
# Epoch 347: Loss 0.113
# Epoch 348: Loss 0.105
# Epoch 349: Loss 0.091
# Epoch 350: Loss 0.090
# Epoch 351: Loss 0.099
# Epoch 352: Loss 0.087
# Epoch 353: Loss 0.101
# Epoch 354: Loss 0.087
# Epoch 355: Loss 0.126
# Epoch 356: Loss 0.107
# Epoch 357: Loss 0.097
# Epoch 358: Loss 0.095
# Epoch 359: Loss 0.093
# Epoch 360: Loss 0.100
# Epoch 361: Loss 0.090
# Epoch 362: Loss 0.087
# Epoch 363: Loss 0.101
# Epoch 364: Loss 0.081
# Epoch 365: Loss 0.097
# Epoch 366: Loss 0.087
# Epoch 367: Loss 0.084
# Epoch 368: Loss 0.116
# Epoch 369: Loss 0.105
# Epoch 370: Loss 0.084
# Epoch 371: Loss 0.083
# Epoch 372: Loss 0.107
# Epoch 373: Loss 0.097
# Epoch 374: Loss 0.090
# Epoch 375: Loss 0.096
# Epoch 376: Loss 0.093
# Epoch 377: Loss 0.081
# Epoch 378: Loss 0.113
# Epoch 379: Loss 0.100
# Epoch 380: Loss 0.085
# Epoch 381: Loss 0.085
# Epoch 382: Loss 0.084
# Epoch 383: Loss 0.092
# Epoch 384: Loss 0.087
# Epoch 385: Loss 0.083
# Epoch 386: Loss 0.086
# Epoch 387: Loss 0.089
# Epoch 388: Loss 0.084
# Epoch 389: Loss 0.091
# Epoch 390: Loss 0.085
# Epoch 391: Loss 0.116
# Epoch 392: Loss 0.112
# Epoch 393: Loss 0.088
# Epoch 394: Loss 0.085
# Epoch 395: Loss 0.087
# Epoch 396: Loss 0.082
# Epoch 397: Loss 0.084
# Epoch 398: Loss 0.088
# Epoch 399: Loss 0.082
# Epoch 400: Loss 0.084
# Epoch 401: Loss 0.083
# Epoch 402: Loss 0.081
# Epoch 403: Loss 0.084
# Epoch 404: Loss 0.077
# Epoch 405: Loss 0.105
# Epoch 406: Loss 0.098
# Epoch 407: Loss 0.083
# Epoch 408: Loss 0.079
# Epoch 409: Loss 0.080
# Epoch 410: Loss 0.081
# Epoch 411: Loss 0.084
# Epoch 412: Loss 0.084
# Epoch 413: Loss 0.079
# Epoch 414: Loss 0.095
# Epoch 415: Loss 0.098
# Epoch 416: Loss 0.075
# Epoch 417: Loss 0.078
# Epoch 418: Loss 0.091
# Epoch 419: Loss 0.099
# Epoch 420: Loss 0.110
# Epoch 421: Loss 0.084
# Epoch 422: Loss 0.084
# Epoch 423: Loss 0.095
# Epoch 424: Loss 0.094
# Epoch 425: Loss 0.071
# Epoch 426: Loss 0.078
# Epoch 427: Loss 0.076
# Epoch 428: Loss 0.077
# Epoch 429: Loss 0.084
# Epoch 430: Loss 0.075
# Epoch 431: Loss 0.097
# Epoch 432: Loss 0.088
# Epoch 433: Loss 0.072
# Epoch 434: Loss 0.074
# Epoch 435: Loss 0.083
# Epoch 436: Loss 0.074
# Epoch 437: Loss 0.093
# Epoch 438: Loss 0.090
# Epoch 439: Loss 0.085
# Epoch 440: Loss 0.080
# Epoch 441: Loss 0.078
# Epoch 442: Loss 0.080
# Epoch 443: Loss 0.078
# Epoch 444: Loss 0.086
# Epoch 445: Loss 0.096
# Epoch 446: Loss 0.074
# Epoch 447: Loss 0.074
# Epoch 448: Loss 0.080
# Epoch 449: Loss 0.076
# Epoch 450: Loss 0.110
# Epoch 451: Loss 0.075
# Epoch 452: Loss 0.067
# Epoch 453: Loss 0.075
# Epoch 454: Loss 0.071
# Epoch 455: Loss 0.087
# Epoch 456: Loss 0.080
# Epoch 457: Loss 0.096
# Epoch 458: Loss 0.072
# Epoch 459: Loss 0.089
# Epoch 460: Loss 0.079
# Epoch 461: Loss 0.067
# Epoch 462: Loss 0.084
# Epoch 463: Loss 0.083
# Epoch 464: Loss 0.098
# Epoch 465: Loss 0.069
# Epoch 466: Loss 0.065
# Epoch 467: Loss 0.070
# Epoch 468: Loss 0.067
# Epoch 469: Loss 0.085
# Epoch 470: Loss 0.070
# Epoch 471: Loss 0.081
# Epoch 472: Loss 0.069
# Epoch 473: Loss 0.074
# Epoch 474: Loss 0.086
# Epoch 475: Loss 0.076
# Epoch 476: Loss 0.081
# Epoch 477: Loss 0.068
# Epoch 478: Loss 0.082
# Epoch 479: Loss 0.078
# Epoch 480: Loss 0.084
# Epoch 481: Loss 0.073
# Epoch 482: Loss 0.076
# Epoch 483: Loss 0.081
# Epoch 484: Loss 0.071
# Epoch 485: Loss 0.072
# Epoch 486: Loss 0.071
# Epoch 487: Loss 0.066
# Epoch 488: Loss 0.075
# Epoch 489: Loss 0.064
# Epoch 490: Loss 0.068
# Epoch 491: Loss 0.077
# Epoch 492: Loss 0.063
# Epoch 493: Loss 0.070
# Epoch 494: Loss 0.067
# Epoch 495: Loss 0.109
# Epoch 496: Loss 0.117
# Epoch 497: Loss 0.081
# Epoch 498: Loss 0.096
# Epoch 499: Loss 0.080
# Epoch 500: Loss 0.082
# Epoch 501: Loss 0.079
# Epoch 502: Loss 0.083
# Epoch 503: Loss 0.077
# Epoch 504: Loss 0.090
# Epoch 505: Loss 0.067
# Epoch 506: Loss 0.104
# Epoch 507: Loss 0.074
# Epoch 508: Loss 0.081
# Epoch 509: Loss 0.079
# Epoch 510: Loss 0.066
# Epoch 511: Loss 0.072
# Epoch 512: Loss 0.065
# Epoch 513: Loss 0.073
# Epoch 514: Loss 0.071
# Epoch 515: Loss 0.063
# Epoch 516: Loss 0.075
# Epoch 517: Loss 0.063
# Epoch 518: Loss 0.069
# Epoch 519: Loss 0.064
# Epoch 520: Loss 0.085
# Epoch 521: Loss 0.064
# Epoch 522: Loss 0.070
# Epoch 523: Loss 0.070
# Epoch 524: Loss 0.072
# Epoch 525: Loss 0.065
# Epoch 526: Loss 0.078
# Epoch 527: Loss 0.065
# Epoch 528: Loss 0.073
# Epoch 529: Loss 0.065
# Epoch 530: Loss 0.073
# Epoch 531: Loss 0.077
# Epoch 532: Loss 0.064
# Epoch 533: Loss 0.073
# Epoch 534: Loss 0.062
# Epoch 535: Loss 0.066
# Epoch 536: Loss 0.076
# Epoch 537: Loss 0.067
# Epoch 538: Loss 0.088
# Epoch 539: Loss 0.075
# Epoch 540: Loss 0.068
# Epoch 541: Loss 0.076
# Epoch 542: Loss 0.088
# Epoch 543: Loss 0.077
# Epoch 544: Loss 0.070
# Epoch 545: Loss 0.065
# Epoch 546: Loss 0.079
# Epoch 547: Loss 0.060
# Epoch 548: Loss 0.069
# Epoch 549: Loss 0.059
# Epoch 550: Loss 0.072
# Epoch 551: Loss 0.059
# Epoch 552: Loss 0.070
# Epoch 553: Loss 0.064
# Epoch 554: Loss 0.062
# Epoch 555: Loss 0.071
# Epoch 556: Loss 0.101
# Epoch 557: Loss 0.071
# Epoch 558: Loss 0.075
# Epoch 559: Loss 0.061
# Epoch 560: Loss 0.064
# Epoch 561: Loss 0.082
# Epoch 562: Loss 0.081
# Epoch 563: Loss 0.077
# Epoch 564: Loss 0.094
# Epoch 565: Loss 0.064
# Epoch 566: Loss 0.074
# Epoch 567: Loss 0.072
# Epoch 568: Loss 0.081
# Epoch 569: Loss 0.060
# Epoch 570: Loss 0.071
# Epoch 571: Loss 0.061
# Epoch 572: Loss 0.066
# Epoch 573: Loss 0.064
# Epoch 574: Loss 0.061
# Epoch 575: Loss 0.078
# Epoch 576: Loss 0.070
# Epoch 577: Loss 0.053
# Epoch 578: Loss 0.070
# Epoch 579: Loss 0.059
# Epoch 580: Loss 0.073
# Epoch 581: Loss 0.057
# Epoch 582: Loss 0.058
# Epoch 583: Loss 0.065
# Epoch 584: Loss 0.065
# Epoch 585: Loss 0.070
# Epoch 586: Loss 0.052
# Epoch 587: Loss 0.060
# Epoch 588: Loss 0.060
# Epoch 589: Loss 0.078
# Epoch 590: Loss 0.071
# Epoch 591: Loss 0.061
# Epoch 592: Loss 0.076
# Epoch 593: Loss 0.052
# Epoch 594: Loss 0.063
# Epoch 595: Loss 0.073
# Epoch 596: Loss 0.070
# Epoch 597: Loss 0.070
# Epoch 598: Loss 0.059
# Epoch 599: Loss 0.058
# Epoch 600: Loss 0.063
# Epoch 601: Loss 0.056
# Epoch 602: Loss 0.058
# Epoch 603: Loss 0.061
# Epoch 604: Loss 0.069
# Epoch 605: Loss 0.069
# Epoch 606: Loss 0.066
# Epoch 607: Loss 0.088
# Epoch 608: Loss 0.075
# Epoch 609: Loss 0.086
# Epoch 610: Loss 0.060
# Epoch 611: Loss 0.070
# Epoch 612: Loss 0.060
# Epoch 613: Loss 0.063
# Epoch 614: Loss 0.059
# Epoch 615: Loss 0.069
# Epoch 616: Loss 0.050
# Epoch 617: Loss 0.069
# Epoch 618: Loss 0.053
# Epoch 619: Loss 0.074
# Epoch 620: Loss 0.057
# Epoch 621: Loss 0.075
# Epoch 622: Loss 0.053
# Epoch 623: Loss 0.057
# Epoch 624: Loss 0.061
# Epoch 625: Loss 0.053
# Epoch 626: Loss 0.063
# Epoch 627: Loss 0.055
# Epoch 628: Loss 0.073
# Epoch 629: Loss 0.058
# Epoch 630: Loss 0.080
# Epoch 631: Loss 0.065
# Epoch 632: Loss 0.057
# Epoch 633: Loss 0.070
# Epoch 634: Loss 0.059
# Epoch 635: Loss 0.061
# Epoch 636: Loss 0.060
# Epoch 637: Loss 0.062
# Epoch 638: Loss 0.060
# Epoch 639: Loss 0.061
# Epoch 640: Loss 0.054
# Epoch 641: Loss 0.058
# Epoch 642: Loss 0.051
# Epoch 643: Loss 0.062
# Epoch 644: Loss 0.069
# Epoch 645: Loss 0.065
# Epoch 646: Loss 0.058
# Epoch 647: Loss 0.069
# Epoch 648: Loss 0.073
# Epoch 649: Loss 0.049
# Epoch 650: Loss 0.058
# Epoch 651: Loss 0.051
# Epoch 652: Loss 0.061
# Epoch 653: Loss 0.056
# Epoch 654: Loss 0.057
# Epoch 655: Loss 0.089
# Epoch 656: Loss 0.065
# Epoch 657: Loss 0.057
# Epoch 658: Loss 0.051
# Epoch 659: Loss 0.064
# Epoch 660: Loss 0.056
# Epoch 661: Loss 0.053
# Epoch 662: Loss 0.063
# Epoch 663: Loss 0.055
# Epoch 664: Loss 0.062
# Epoch 665: Loss 0.064
# Epoch 666: Loss 0.058
# Epoch 667: Loss 0.056
# Epoch 668: Loss 0.064
# Epoch 669: Loss 0.065
# Epoch 670: Loss 0.059
# Epoch 671: Loss 0.071
# Epoch 672: Loss 0.060
# Epoch 673: Loss 0.053
# Epoch 674: Loss 0.058
# Epoch 675: Loss 0.045
# Epoch 676: Loss 0.060
# Epoch 677: Loss 0.061
# Epoch 678: Loss 0.056
# Epoch 679: Loss 0.047
# Epoch 680: Loss 0.053
# Epoch 681: Loss 0.065
# Epoch 682: Loss 0.073
# Epoch 683: Loss 0.042
# Epoch 684: Loss 0.064
# Epoch 685: Loss 0.062
# Epoch 686: Loss 0.095
# Epoch 687: Loss 0.056
# Epoch 688: Loss 0.052
# Epoch 689: Loss 0.056
# Epoch 690: Loss 0.049
# Epoch 691: Loss 0.050
# Epoch 692: Loss 0.048
# Epoch 693: Loss 0.060
# Epoch 694: Loss 0.061
# Epoch 695: Loss 0.101
# Epoch 696: Loss 0.183
# Epoch 697: Loss 0.097
# Epoch 698: Loss 0.095
# Epoch 699: Loss 0.096
# Epoch 700: Loss 0.079
# Epoch 701: Loss 0.075
# Epoch 702: Loss 0.072
# Epoch 703: Loss 0.081
# Epoch 704: Loss 0.069
# Epoch 705: Loss 0.070
# Epoch 706: Loss 0.063
# Epoch 707: Loss 0.081
# Epoch 708: Loss 0.063
# Epoch 709: Loss 0.064
# Epoch 710: Loss 0.060
# Epoch 711: Loss 0.068
# Epoch 712: Loss 0.056
# Epoch 713: Loss 0.066
# Epoch 714: Loss 0.059
# Epoch 715: Loss 0.078
# Epoch 716: Loss 0.068
# Epoch 717: Loss 0.071
# Epoch 718: Loss 0.069
# Epoch 719: Loss 0.083
# Epoch 720: Loss 0.057
# Epoch 721: Loss 0.058
# Epoch 722: Loss 0.056
# Epoch 723: Loss 0.071
# Epoch 724: Loss 0.062
# Epoch 725: Loss 0.081
# Epoch 726: Loss 0.064
# Epoch 727: Loss 0.052
# Epoch 728: Loss 0.060
# Epoch 729: Loss 0.057
# Epoch 730: Loss 0.085
# Epoch 731: Loss 0.059
# Epoch 732: Loss 0.059
# Epoch 733: Loss 0.071
# Epoch 734: Loss 0.054
# Epoch 735: Loss 0.055
# Epoch 736: Loss 0.065
# Epoch 737: Loss 0.057
# Epoch 738: Loss 0.068
# Epoch 739: Loss 0.051
# Epoch 740: Loss 0.060
# Epoch 741: Loss 0.062
# Epoch 742: Loss 0.054
# Epoch 743: Loss 0.063
# Epoch 744: Loss 0.057
# Epoch 745: Loss 0.059
# Epoch 746: Loss 0.058
# Epoch 747: Loss 0.057
# Epoch 748: Loss 0.053
# Epoch 749: Loss 0.055
# Epoch 750: Loss 0.063
# Epoch 751: Loss 0.053
# Epoch 752: Loss 0.064
# Epoch 753: Loss 0.052
# Epoch 754: Loss 0.053
# Epoch 755: Loss 0.063
# Epoch 756: Loss 0.051
# Epoch 757: Loss 0.061
# Epoch 758: Loss 0.057
# Epoch 759: Loss 0.055
# Epoch 760: Loss 0.090
# Epoch 761: Loss 0.060
# Epoch 762: Loss 0.060
# Epoch 763: Loss 0.051
# Epoch 764: Loss 0.053
# Epoch 765: Loss 0.055
# Epoch 766: Loss 0.055
# Epoch 767: Loss 0.050
# Epoch 768: Loss 0.053
# Epoch 769: Loss 0.052
# Epoch 770: Loss 0.075
# Epoch 771: Loss 0.077
# Epoch 772: Loss 0.065
# Epoch 773: Loss 0.106
# Epoch 774: Loss 0.064
# Epoch 775: Loss 0.058
# Epoch 776: Loss 0.057
# Epoch 777: Loss 0.052
# Epoch 778: Loss 0.056
# Epoch 779: Loss 0.047
# Epoch 780: Loss 0.056
# Epoch 781: Loss 0.055
# Epoch 782: Loss 0.052
# Epoch 783: Loss 0.048
# Epoch 784: Loss 0.046
# Epoch 785: Loss 0.058
# Epoch 786: Loss 0.069
# Epoch 787: Loss 0.095
# Epoch 788: Loss 0.058
# Epoch 789: Loss 0.051
# Epoch 790: Loss 0.050
# Epoch 791: Loss 0.055
# Epoch 792: Loss 0.062
# Epoch 793: Loss 0.063
# Epoch 794: Loss 0.062
# Epoch 795: Loss 0.055
# Epoch 796: Loss 0.052
# Epoch 797: Loss 0.068
# Epoch 798: Loss 0.054
# Epoch 799: Loss 0.061
# Epoch 800: Loss 0.048
# Epoch 801: Loss 0.063
# Epoch 802: Loss 0.068
# Epoch 803: Loss 0.054
# Epoch 804: Loss 0.063
# Epoch 805: Loss 0.054
# Epoch 806: Loss 0.058
# Epoch 807: Loss 0.063
# Epoch 808: Loss 0.051
# Epoch 809: Loss 0.050
# Epoch 810: Loss 0.087
# Epoch 811: Loss 0.061
# Epoch 812: Loss 0.056
# Epoch 813: Loss 0.052
# Epoch 814: Loss 0.046
# Epoch 815: Loss 0.059
# Epoch 816: Loss 0.057
# Epoch 817: Loss 0.071
# Epoch 818: Loss 0.058
# Epoch 819: Loss 0.057
# Epoch 820: Loss 0.058
# Epoch 821: Loss 0.047
# Epoch 822: Loss 0.067
# Epoch 823: Loss 0.056
# Epoch 824: Loss 0.056
# Epoch 825: Loss 0.049
# Epoch 826: Loss 0.047
# Epoch 827: Loss 0.048
# Epoch 828: Loss 0.047
# Epoch 829: Loss 0.063
# Epoch 830: Loss 0.070
# Epoch 831: Loss 0.054
# Epoch 832: Loss 0.050
# Epoch 833: Loss 0.062
# Epoch 834: Loss 0.062
# Epoch 835: Loss 0.094
# Epoch 836: Loss 0.057
# Epoch 837: Loss 0.048
# Epoch 838: Loss 0.054
# Epoch 839: Loss 0.060
# Epoch 840: Loss 0.061
# Epoch 841: Loss 0.046
# Epoch 842: Loss 0.054
# Epoch 843: Loss 0.046
# Epoch 844: Loss 0.049
# Epoch 845: Loss 0.059
# Epoch 846: Loss 0.058
# Epoch 847: Loss 0.056
# Epoch 848: Loss 0.054
# Epoch 849: Loss 0.065
# Epoch 850: Loss 0.051
# Epoch 851: Loss 0.062
# Epoch 852: Loss 0.052
# Epoch 853: Loss 0.050
# Epoch 854: Loss 0.057
# Epoch 855: Loss 0.072
# Epoch 856: Loss 0.063
# Epoch 857: Loss 0.048
# Epoch 858: Loss 0.048
# Epoch 859: Loss 0.045
# Epoch 860: Loss 0.052
# Epoch 861: Loss 0.044
# Epoch 862: Loss 0.063
# Epoch 863: Loss 0.052
# Epoch 864: Loss 0.080
# Epoch 865: Loss 0.048
# Epoch 866: Loss 0.049
# Epoch 867: Loss 0.075
# Epoch 868: Loss 0.056
# Epoch 869: Loss 0.077
# Epoch 870: Loss 0.052
# Epoch 871: Loss 0.048
# Epoch 872: Loss 0.059
# Epoch 873: Loss 0.045
# Epoch 874: Loss 0.045
# Epoch 875: Loss 0.063
# Epoch 876: Loss 0.054
# Epoch 877: Loss 0.047
# Epoch 878: Loss 0.050
# Epoch 879: Loss 0.058
# Epoch 880: Loss 0.068
# Epoch 881: Loss 0.069
# Epoch 882: Loss 0.057
# Epoch 883: Loss 0.050
# Epoch 884: Loss 0.052
# Epoch 885: Loss 0.047
# Epoch 886: Loss 0.056
# Epoch 887: Loss 0.045
# Epoch 888: Loss 0.052
# Epoch 889: Loss 0.059
# Epoch 890: Loss 0.065
# Epoch 891: Loss 0.045
# Epoch 892: Loss 0.053
# Epoch 893: Loss 0.050
# Epoch 894: Loss 0.067
# Epoch 895: Loss 0.055
# Epoch 896: Loss 0.052
# Epoch 897: Loss 0.062
# Epoch 898: Loss 0.042
# Epoch 899: Loss 0.049
# Epoch 900: Loss 0.046
# Epoch 901: Loss 0.058
# Epoch 902: Loss 0.064
# Epoch 903: Loss 0.070
# Epoch 904: Loss 0.048
# Epoch 905: Loss 0.041
# Epoch 906: Loss 0.101
# Epoch 907: Loss 0.051
# Epoch 908: Loss 0.057
# Epoch 909: Loss 0.055
# Epoch 910: Loss 0.052
# Epoch 911: Loss 0.058
# Epoch 912: Loss 0.062
# Epoch 913: Loss 0.062
# Epoch 914: Loss 0.083
# Epoch 915: Loss 0.050
# Epoch 916: Loss 0.045
# Epoch 917: Loss 0.051
# Epoch 918: Loss 0.051
# Epoch 919: Loss 0.052
# Epoch 920: Loss 0.058
# Epoch 921: Loss 0.047
# Epoch 922: Loss 0.065
# Epoch 923: Loss 0.048
# Epoch 924: Loss 0.049
# Epoch 925: Loss 0.055
# Epoch 926: Loss 0.060
# Epoch 927: Loss 0.041
# Epoch 928: Loss 0.051
# Epoch 929: Loss 0.055
# Epoch 930: Loss 0.056
# Epoch 931: Loss 0.076
# Epoch 932: Loss 0.055
# Epoch 933: Loss 0.046
# Epoch 934: Loss 0.047
# Epoch 935: Loss 0.038
# Epoch 936: Loss 0.044
# Epoch 937: Loss 0.053
# Epoch 938: Loss 0.060
# Epoch 939: Loss 0.049
# Epoch 940: Loss 0.049
# Epoch 941: Loss 0.039
# Epoch 942: Loss 0.043
# Epoch 943: Loss 0.041
# Epoch 944: Loss 0.055
# Epoch 945: Loss 0.083
# Epoch 946: Loss 0.048
# Epoch 947: Loss 0.044
# Epoch 948: Loss 0.047
# Epoch 949: Loss 0.054
# Epoch 950: Loss 0.056
# Epoch 951: Loss 0.043
# Epoch 952: Loss 0.115
# Epoch 953: Loss 0.058
# Epoch 954: Loss 0.074
# Epoch 955: Loss 0.057
# Epoch 956: Loss 0.099
# Epoch 957: Loss 0.055
# Epoch 958: Loss 0.054
# Epoch 959: Loss 0.046
# Epoch 960: Loss 0.047
# Epoch 961: Loss 0.062
# Epoch 962: Loss 0.045
# Epoch 963: Loss 0.046
# Epoch 964: Loss 0.044
# Epoch 965: Loss 0.044
# Epoch 966: Loss 0.054
# Epoch 967: Loss 0.057
# Epoch 968: Loss 0.042
# Epoch 969: Loss 0.044
# Epoch 970: Loss 0.045
# Epoch 971: Loss 0.050
# Epoch 972: Loss 0.046
# Epoch 973: Loss 0.059
# Epoch 974: Loss 0.040
# Epoch 975: Loss 0.048
# Epoch 976: Loss 0.045
# Epoch 977: Loss 0.086
# Epoch 978: Loss 0.058
# Epoch 979: Loss 0.044
# Epoch 980: Loss 0.061
# Epoch 981: Loss 0.038
# Epoch 982: Loss 0.042
# Epoch 983: Loss 0.043
# Epoch 984: Loss 0.043
# Epoch 985: Loss 0.044
# Epoch 986: Loss 0.047
# Epoch 987: Loss 0.060
# Epoch 988: Loss 0.066
# Epoch 989: Loss 0.042
# Epoch 990: Loss 0.049
# Epoch 991: Loss 0.046
# Epoch 992: Loss 0.069
# Epoch 993: Loss 0.044
# Epoch 994: Loss 0.044
# Epoch 995: Loss 0.046
# Epoch 996: Loss 0.055
# Epoch 997: Loss 0.059
# Epoch 998: Loss 0.091
# Epoch 999: Loss 0.048
# Epoch 1000: Loss 0.039

# %%
fig, axs = plt.subplots(len(number_hidden_layers),max(number_hidden_layers)+2,figsize=(12,8),layout='constrained')

for k, num_h_layers in enumerate(number_hidden_layers):
    axs[k,0].scatter(X[:,0], X[:,1],c=dot_matrices[k][0])
    for n in range(num_h_layers):
        axs[k,1+n].scatter(X[:,0], X[:,1],c=dot_matrices[k][1][n])
    pcm=axs[k,num_h_layers+1].scatter(X[:,0], X[:,1],c=dot_matrices[k][-1])
    fig.colorbar(pcm, ax=axs[k,:])
    for j in range(max(max(number_hidden_layers)-num_h_layers-2,0)):
        axs[k,num_h_layers+1+j].axison=False

#plt.savefig('plots/Stiffness_depth.png')
