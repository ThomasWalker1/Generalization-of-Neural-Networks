# %%
import torch
import torch.nn as nn
from torch.optim import SGD

import numpy as np
from numpy import dot
import matplotlib.pyplot as plt

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.input_layer = nn.Linear(input_size, hidden_size)
        self.hidden = nn.Linear(hidden_size, hidden_size)
        self.output_layer = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        x=self.input_layer(x)
        x=x.relu()
        x=self.hidden(x)
        x=x.relu()
        x=self.output_layer(x)
        return x
    
def ReLU_glorot_init(model):
    for name, param in model.named_parameters():
        
        if name.endswith(".bias"):
            param.data.fill_(0)
        else:
            nn.init.xavier_normal_(param)

# %%
RES=50
X=[]
for x_1 in np.linspace(-1,1,RES):
    for x_2 in np.linspace(-1,1,RES):
        X.append([x_1,x_2])
X=np.array(X)

encode_inputs=lambda x: 1 if x[0]**2+x[1]**2<0.5 else 0
Y=np.array([encode_inputs(x) for x in X])

X=torch.from_numpy(X).float()
Y=torch.from_numpy(Y).float()


colors=np.full(len(Y), 'cadetblue')
colors[Y==0]='teal'

plt.scatter(X[:,0],X[:,1],c=colors)

# %%
model = NeuralNet(2,256,2)
ReLU_glorot_init(model)

def next_batch(inputs, targets, batchSize):
	for i in range(0, inputs.shape[0], batchSize):
		yield (inputs[i:i + batchSize], targets[i:i + batchSize])

BATCH_SIZE = 100
EPOCHS = 200
LR = 0.01

opt = SGD(model.parameters(), lr=LR)
lossFunc = nn.CrossEntropyLoss()

# %%
def training():
	trainLoss = 0
	samples = 0
	model.train()
	for batchX, batchY in next_batch(X, Y, BATCH_SIZE):
		predictions = model(batchX)
		loss = lossFunc(predictions, batchY.long())
		opt.zero_grad()
		loss.backward()
		opt.step()
		samples += len(batchY)
		trainLoss += loss.item()*len(batchY)
	return trainLoss/samples

# %%
for n in range(EPOCHS):
    l=training()
    print('Epoch {}: Loss {:.3f}'.format(n+1,l))

grads=[]
for x,y in zip(X,Y):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient=[]
    gradient+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient+=model.input_layer.bias.grad.tolist()
    gradient+=torch.flatten(model.hidden.weight.grad).tolist()
    gradient+=model.hidden.bias.grad.tolist()
    gradient+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient+=model.output_layer.bias.grad.tolist()
    gradient=np.array(gradient)
    gradient=gradient/np.linalg.norm(gradient)
    grads.append(gradient)


dot_matrix=[]
for i,x1 in enumerate(X):
    avg_dot=0
    samples=0
    for j,x2 in enumerate(X):
        if np.linalg.norm(x1-x2)<0.05 and i!=j:        
            avg_dot+=np.dot(grads[i],grads[j])
            samples+=1
    avg_dot=avg_dot/samples
    dot_matrix.append(avg_dot)
# Out:
# Epoch 1: Loss 0.675
# Epoch 2: Loss 0.656
# Epoch 3: Loss 0.643
# Epoch 4: Loss 0.634
# Epoch 5: Loss 0.627
# Epoch 6: Loss 0.621
# Epoch 7: Loss 0.616
# Epoch 8: Loss 0.611
# Epoch 9: Loss 0.606
# Epoch 10: Loss 0.602
# Epoch 11: Loss 0.597
# Epoch 12: Loss 0.593
# Epoch 13: Loss 0.589
# Epoch 14: Loss 0.584
# Epoch 15: Loss 0.580
# Epoch 16: Loss 0.575
# Epoch 17: Loss 0.571
# Epoch 18: Loss 0.566
# Epoch 19: Loss 0.562
# Epoch 20: Loss 0.557
# Epoch 21: Loss 0.553
# Epoch 22: Loss 0.548
# Epoch 23: Loss 0.543
# Epoch 24: Loss 0.538
# Epoch 25: Loss 0.534
# Epoch 26: Loss 0.529
# Epoch 27: Loss 0.524
# Epoch 28: Loss 0.519
# Epoch 29: Loss 0.514
# Epoch 30: Loss 0.509
# Epoch 31: Loss 0.504
# Epoch 32: Loss 0.498
# Epoch 33: Loss 0.493
# Epoch 34: Loss 0.488
# Epoch 35: Loss 0.482
# Epoch 36: Loss 0.477
# Epoch 37: Loss 0.472
# Epoch 38: Loss 0.466
# Epoch 39: Loss 0.461
# Epoch 40: Loss 0.456
# Epoch 41: Loss 0.450
# Epoch 42: Loss 0.445
# Epoch 43: Loss 0.439
# Epoch 44: Loss 0.434
# Epoch 45: Loss 0.429
# Epoch 46: Loss 0.423
# Epoch 47: Loss 0.418
# Epoch 48: Loss 0.413
# Epoch 49: Loss 0.408
# Epoch 50: Loss 0.402
# Epoch 51: Loss 0.397
# Epoch 52: Loss 0.392
# Epoch 53: Loss 0.387
# Epoch 54: Loss 0.382
# Epoch 55: Loss 0.377
# Epoch 56: Loss 0.372
# Epoch 57: Loss 0.367
# Epoch 58: Loss 0.362
# Epoch 59: Loss 0.358
# Epoch 60: Loss 0.353
# Epoch 61: Loss 0.348
# Epoch 62: Loss 0.344
# Epoch 63: Loss 0.339
# Epoch 64: Loss 0.334
# Epoch 65: Loss 0.330
# Epoch 66: Loss 0.326
# Epoch 67: Loss 0.321
# Epoch 68: Loss 0.317
# Epoch 69: Loss 0.313
# Epoch 70: Loss 0.309
# Epoch 71: Loss 0.304
# Epoch 72: Loss 0.300
# Epoch 73: Loss 0.296
# Epoch 74: Loss 0.292
# Epoch 75: Loss 0.289
# Epoch 76: Loss 0.285
# Epoch 77: Loss 0.281
# Epoch 78: Loss 0.277
# Epoch 79: Loss 0.274
# Epoch 80: Loss 0.270
# Epoch 81: Loss 0.267
# Epoch 82: Loss 0.263
# Epoch 83: Loss 0.260
# Epoch 84: Loss 0.257
# Epoch 85: Loss 0.254
# Epoch 86: Loss 0.250
# Epoch 87: Loss 0.247
# Epoch 88: Loss 0.244
# Epoch 89: Loss 0.241
# Epoch 90: Loss 0.238
# Epoch 91: Loss 0.235
# Epoch 92: Loss 0.233
# Epoch 93: Loss 0.230
# Epoch 94: Loss 0.227
# Epoch 95: Loss 0.225
# Epoch 96: Loss 0.222
# Epoch 97: Loss 0.219
# Epoch 98: Loss 0.217
# Epoch 99: Loss 0.214
# Epoch 100: Loss 0.212
# Epoch 101: Loss 0.210
# Epoch 102: Loss 0.207
# Epoch 103: Loss 0.205
# Epoch 104: Loss 0.203
# Epoch 105: Loss 0.201
# Epoch 106: Loss 0.199
# Epoch 107: Loss 0.197
# Epoch 108: Loss 0.195
# Epoch 109: Loss 0.193
# Epoch 110: Loss 0.191
# Epoch 111: Loss 0.189
# Epoch 112: Loss 0.187
# Epoch 113: Loss 0.185
# Epoch 114: Loss 0.183
# Epoch 115: Loss 0.181
# Epoch 116: Loss 0.179
# Epoch 117: Loss 0.178
# Epoch 118: Loss 0.176
# Epoch 119: Loss 0.174
# Epoch 120: Loss 0.173
# Epoch 121: Loss 0.171
# Epoch 122: Loss 0.170
# Epoch 123: Loss 0.168
# Epoch 124: Loss 0.166
# Epoch 125: Loss 0.165
# Epoch 126: Loss 0.164
# Epoch 127: Loss 0.162
# Epoch 128: Loss 0.161
# Epoch 129: Loss 0.159
# Epoch 130: Loss 0.158
# Epoch 131: Loss 0.157
# Epoch 132: Loss 0.155
# Epoch 133: Loss 0.154
# Epoch 134: Loss 0.153
# Epoch 135: Loss 0.152
# Epoch 136: Loss 0.150
# Epoch 137: Loss 0.149
# Epoch 138: Loss 0.148
# Epoch 139: Loss 0.147
# Epoch 140: Loss 0.146
# Epoch 141: Loss 0.145
# Epoch 142: Loss 0.143
# Epoch 143: Loss 0.142
# Epoch 144: Loss 0.141
# Epoch 145: Loss 0.140
# Epoch 146: Loss 0.139
# Epoch 147: Loss 0.138
# Epoch 148: Loss 0.137
# Epoch 149: Loss 0.136
# Epoch 150: Loss 0.135
# Epoch 151: Loss 0.134
# Epoch 152: Loss 0.133
# Epoch 153: Loss 0.132
# Epoch 154: Loss 0.131
# Epoch 155: Loss 0.131
# Epoch 156: Loss 0.130
# Epoch 157: Loss 0.129
# Epoch 158: Loss 0.128
# Epoch 159: Loss 0.127
# Epoch 160: Loss 0.126
# Epoch 161: Loss 0.126
# Epoch 162: Loss 0.125
# Epoch 163: Loss 0.124
# Epoch 164: Loss 0.123
# Epoch 165: Loss 0.122
# Epoch 166: Loss 0.122
# Epoch 167: Loss 0.121
# Epoch 168: Loss 0.120
# Epoch 169: Loss 0.119
# Epoch 170: Loss 0.119
# Epoch 171: Loss 0.118
# Epoch 172: Loss 0.117
# Epoch 173: Loss 0.117
# Epoch 174: Loss 0.116
# Epoch 175: Loss 0.115
# Epoch 176: Loss 0.115
# Epoch 177: Loss 0.114
# Epoch 178: Loss 0.113
# Epoch 179: Loss 0.113
# Epoch 180: Loss 0.112
# Epoch 181: Loss 0.111
# Epoch 182: Loss 0.111
# Epoch 183: Loss 0.110
# Epoch 184: Loss 0.110
# Epoch 185: Loss 0.109
# Epoch 186: Loss 0.108
# Epoch 187: Loss 0.108
# Epoch 188: Loss 0.107
# Epoch 189: Loss 0.107
# Epoch 190: Loss 0.106
# Epoch 191: Loss 0.106
# Epoch 192: Loss 0.105
# Epoch 193: Loss 0.105
# Epoch 194: Loss 0.104
# Epoch 195: Loss 0.104
# Epoch 196: Loss 0.103
# Epoch 197: Loss 0.103
# Epoch 198: Loss 0.102
# Epoch 199: Loss 0.102
# Epoch 200: Loss 0.101

# %%
fig, axs = plt.subplots(1,1)

pcm = axs.scatter(X[:,0], X[:,1],c=dot_matrix)

fig.colorbar(pcm, ax=axs)
