# %%
import torch
import torch.nn as nn
from torch.optim import SGD

import numpy as np
from numpy import dot
import matplotlib.pyplot as plt

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.input_layer = nn.Linear(input_size, hidden_size)
        self.hidden = nn.Linear(hidden_size, hidden_size)
        self.output_layer = nn.Linear(hidden_size, num_classes)
    
    def forward(self, x):
        x=self.input_layer(x)
        x=x.relu()
        x=self.hidden(x)
        x=x.relu()
        x=self.output_layer(x)
        return x
    
def ReLU_glorot_init(model):
    for name, param in model.named_parameters():
        
        if name.endswith(".bias"):
            param.data.fill_(0)
        else:
            nn.init.xavier_normal_(param)

# %%
RES=50
X=[]
for x_1 in np.linspace(-1,1,RES):
    for x_2 in np.linspace(-1,1,RES):
        X.append([x_1,x_2])
X=np.array(X)

encode_inputs=lambda x: 1 if x[0]**2+x[1]**2<0.5 else 0
Y=np.array([encode_inputs(x) for x in X])

X=torch.from_numpy(X).float()
Y=torch.from_numpy(Y).float()


colors=np.full(len(Y), 'cadetblue')
colors[Y==0]='teal'

plt.scatter(X[:,0],X[:,1],c=colors)

# %%
model = NeuralNet(2,256,2)
ReLU_glorot_init(model)

def next_batch(inputs, targets, batchSize):
	for i in range(0, inputs.shape[0], batchSize):
		yield (inputs[i:i + batchSize], targets[i:i + batchSize])

BATCH_SIZE = 100
EPOCHS = 200
LR = 0.01

opt = SGD(model.parameters(), lr=LR)
lossFunc = nn.CrossEntropyLoss()

# %%
def training():
	trainLoss = 0
	samples = 0
	model.train()
	for batchX, batchY in next_batch(X, Y, BATCH_SIZE):
		predictions = model(batchX)
		loss = lossFunc(predictions, batchY.long())
		opt.zero_grad()
		loss.backward()
		opt.step()
		samples += len(batchY)
		trainLoss += loss.item()*len(batchY)
	return trainLoss/samples

# %%
for n in range(EPOCHS):
    l=training()
    print('Epoch {}: Loss {:.3f}'.format(n+1,l))

grads=[]
for x,y in zip(X,Y):
    predictions = model(x)
    loss = lossFunc(predictions, y.long())
    opt.zero_grad()
    loss.backward()
    gradient=[]
    gradient+=torch.flatten(model.input_layer.weight.grad).tolist()
    gradient+=model.input_layer.bias.grad.tolist()
    gradient+=torch.flatten(model.hidden.weight.grad).tolist()
    gradient+=model.hidden.bias.grad.tolist()
    gradient+=torch.flatten(model.output_layer.weight.grad).tolist()
    gradient+=model.output_layer.bias.grad.tolist()
    gradient=np.array(gradient)
    gradient=gradient/np.linalg.norm(gradient)
    grads.append(gradient)


dot_matrix=[]
for i,x1 in enumerate(X):
    avg_dot=0
    samples=0
    for j,x2 in enumerate(X):
        if np.linalg.norm(x1-x2)<0.05 and i!=j:        
            avg_dot+=np.dot(grads[i],grads[j])
            samples+=1
    avg_dot=avg_dot/samples
    dot_matrix.append(avg_dot)
# Out:
# Epoch 1: Loss 0.667
# Epoch 2: Loss 0.650
# Epoch 3: Loss 0.638
# Epoch 4: Loss 0.629
# Epoch 5: Loss 0.622
# Epoch 6: Loss 0.617
# Epoch 7: Loss 0.612
# Epoch 8: Loss 0.607
# Epoch 9: Loss 0.603
# Epoch 10: Loss 0.598
# Epoch 11: Loss 0.594
# Epoch 12: Loss 0.590
# Epoch 13: Loss 0.586
# Epoch 14: Loss 0.582
# Epoch 15: Loss 0.577
# Epoch 16: Loss 0.573
# Epoch 17: Loss 0.569
# Epoch 18: Loss 0.564
# Epoch 19: Loss 0.559
# Epoch 20: Loss 0.554
# Epoch 21: Loss 0.550
# Epoch 22: Loss 0.545
# Epoch 23: Loss 0.540
# Epoch 24: Loss 0.535
# Epoch 25: Loss 0.530
# Epoch 26: Loss 0.525
# Epoch 27: Loss 0.520
# Epoch 28: Loss 0.515
# Epoch 29: Loss 0.510
# Epoch 30: Loss 0.504
# Epoch 31: Loss 0.499
# Epoch 32: Loss 0.493
# Epoch 33: Loss 0.488
# Epoch 34: Loss 0.482
# Epoch 35: Loss 0.477
# Epoch 36: Loss 0.471
# Epoch 37: Loss 0.465
# Epoch 38: Loss 0.460
# Epoch 39: Loss 0.454
# Epoch 40: Loss 0.449
# Epoch 41: Loss 0.443
# Epoch 42: Loss 0.438
# Epoch 43: Loss 0.432
# Epoch 44: Loss 0.427
# Epoch 45: Loss 0.421
# Epoch 46: Loss 0.416
# Epoch 47: Loss 0.410
# Epoch 48: Loss 0.405
# Epoch 49: Loss 0.400
# Epoch 50: Loss 0.394
# Epoch 51: Loss 0.389
# Epoch 52: Loss 0.384
# Epoch 53: Loss 0.379
# Epoch 54: Loss 0.373
# Epoch 55: Loss 0.368
# Epoch 56: Loss 0.363
# Epoch 57: Loss 0.358
# Epoch 58: Loss 0.354
# Epoch 59: Loss 0.349
# Epoch 60: Loss 0.344
# Epoch 61: Loss 0.339
# Epoch 62: Loss 0.334
# Epoch 63: Loss 0.330
# Epoch 64: Loss 0.325
# Epoch 65: Loss 0.321
# Epoch 66: Loss 0.316
# Epoch 67: Loss 0.312
# Epoch 68: Loss 0.308
# Epoch 69: Loss 0.303
# Epoch 70: Loss 0.299
# Epoch 71: Loss 0.295
# Epoch 72: Loss 0.291
# Epoch 73: Loss 0.287
# Epoch 74: Loss 0.283
# Epoch 75: Loss 0.279
# Epoch 76: Loss 0.276
# Epoch 77: Loss 0.272
# Epoch 78: Loss 0.268
# Epoch 79: Loss 0.265
# Epoch 80: Loss 0.261
# Epoch 81: Loss 0.258
# Epoch 82: Loss 0.255
# Epoch 83: Loss 0.251
# Epoch 84: Loss 0.248
# Epoch 85: Loss 0.245
# Epoch 86: Loss 0.242
# Epoch 87: Loss 0.239
# Epoch 88: Loss 0.236
# Epoch 89: Loss 0.233
# Epoch 90: Loss 0.230
# Epoch 91: Loss 0.227
# Epoch 92: Loss 0.225
# Epoch 93: Loss 0.222
# Epoch 94: Loss 0.219
# Epoch 95: Loss 0.217
# Epoch 96: Loss 0.214
# Epoch 97: Loss 0.212
# Epoch 98: Loss 0.209
# Epoch 99: Loss 0.207
# Epoch 100: Loss 0.204
# Epoch 101: Loss 0.202
# Epoch 102: Loss 0.200
# Epoch 103: Loss 0.198
# Epoch 104: Loss 0.196
# Epoch 105: Loss 0.193
# Epoch 106: Loss 0.191
# Epoch 107: Loss 0.189
# Epoch 108: Loss 0.187
# Epoch 109: Loss 0.185
# Epoch 110: Loss 0.184
# Epoch 111: Loss 0.182
# Epoch 112: Loss 0.180
# Epoch 113: Loss 0.178
# Epoch 114: Loss 0.176
# Epoch 115: Loss 0.175
# Epoch 116: Loss 0.173
# Epoch 117: Loss 0.171
# Epoch 118: Loss 0.170
# Epoch 119: Loss 0.168
# Epoch 120: Loss 0.166
# Epoch 121: Loss 0.165
# Epoch 122: Loss 0.163
# Epoch 123: Loss 0.162
# Epoch 124: Loss 0.160
# Epoch 125: Loss 0.159
# Epoch 126: Loss 0.158
# Epoch 127: Loss 0.156
# Epoch 128: Loss 0.155
# Epoch 129: Loss 0.154
# Epoch 130: Loss 0.152
# Epoch 131: Loss 0.151
# Epoch 132: Loss 0.150
# Epoch 133: Loss 0.148
# Epoch 134: Loss 0.147
# Epoch 135: Loss 0.146
# Epoch 136: Loss 0.145
# Epoch 137: Loss 0.144
# Epoch 138: Loss 0.143
# Epoch 139: Loss 0.142
# Epoch 140: Loss 0.140
# Epoch 141: Loss 0.139
# Epoch 142: Loss 0.138
# Epoch 143: Loss 0.137
# Epoch 144: Loss 0.136
# Epoch 145: Loss 0.135
# Epoch 146: Loss 0.134
# Epoch 147: Loss 0.133
# Epoch 148: Loss 0.132
# Epoch 149: Loss 0.131
# Epoch 150: Loss 0.130
# Epoch 151: Loss 0.130
# Epoch 152: Loss 0.129
# Epoch 153: Loss 0.128
# Epoch 154: Loss 0.127
# Epoch 155: Loss 0.126
# Epoch 156: Loss 0.125
# Epoch 157: Loss 0.124
# Epoch 158: Loss 0.124
# Epoch 159: Loss 0.123
# Epoch 160: Loss 0.122
# Epoch 161: Loss 0.121
# Epoch 162: Loss 0.120
# Epoch 163: Loss 0.120
# Epoch 164: Loss 0.119
# Epoch 165: Loss 0.118
# Epoch 166: Loss 0.117
# Epoch 167: Loss 0.117
# Epoch 168: Loss 0.116
# Epoch 169: Loss 0.115
# Epoch 170: Loss 0.115
# Epoch 171: Loss 0.114
# Epoch 172: Loss 0.113
# Epoch 173: Loss 0.113
# Epoch 174: Loss 0.112
# Epoch 175: Loss 0.111
# Epoch 176: Loss 0.111
# Epoch 177: Loss 0.110
# Epoch 178: Loss 0.110
# Epoch 179: Loss 0.109
# Epoch 180: Loss 0.108
# Epoch 181: Loss 0.108
# Epoch 182: Loss 0.107
# Epoch 183: Loss 0.107
# Epoch 184: Loss 0.106
# Epoch 185: Loss 0.105
# Epoch 186: Loss 0.105
# Epoch 187: Loss 0.104
# Epoch 188: Loss 0.104
# Epoch 189: Loss 0.103
# Epoch 190: Loss 0.103
# Epoch 191: Loss 0.102
# Epoch 192: Loss 0.102
# Epoch 193: Loss 0.101
# Epoch 194: Loss 0.101
# Epoch 195: Loss 0.100
# Epoch 196: Loss 0.100
# Epoch 197: Loss 0.099
# Epoch 198: Loss 0.099
# Epoch 199: Loss 0.098
# Epoch 200: Loss 0.098

# %%
fig, axs = plt.subplots(1,2, figsize=(12,5))

axs[0].scatter(X[:,0],X[:,1],c=colors)

pcm = axs[1].scatter(X[:,0], X[:,1],c=dot_matrix)

fig.colorbar(pcm, ax=axs[1])

plt.savefig('plots/Stiffness_Neighbourhoods.png')
